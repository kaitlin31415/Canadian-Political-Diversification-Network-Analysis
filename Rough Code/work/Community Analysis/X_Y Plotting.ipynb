# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import scipy

# %%
df = pd.read_csv("Network export nodes betweenness undirected with communities and degs and influence.csv")

# %%
df
# Out:
#                        Id  Label  timeset      twittername    first name  \
# 0                83508245    NaN      NaN          dckurek        Damien
# 1              4568748862    NaN      NaN   ziad_aboultaif          Ziad
# 2                44070432    NaN      NaN   LailaGoodridge         Laila
# 3     1425866189780160514    NaN      NaN       POhara2021       Patrick
# 4     1420552213253038080    NaN      NaN  NathalieSincla3      Nathalie
# 5               335769776    NaN      NaN          jwaldag          John
# 6               401738614    NaN      NaN      BerubeABJNE        Sylvie
# 7     1173429508034220032    NaN      NaN     ClaudeDBF_bq        Claude
# 8     1187132490684784642    NaN      NaN   LouiseChabotBQ        Louise
# 9                16279532    NaN      NaN       terrybeech         Terry
# 10              216469057    NaN      NaN        seblemire     Sébastien
# 11    1342125115383939073    NaN      NaN  JeanDenisGaron1    Jean-Denis
# ...

# %%
df.plot(x='influence', y='in_degree_centrality', style='o')

# %%
df.plot(x='influence', y='betweenness_centrality', style='o')

# %%
df.plot(x='betweenness_centrality', y='in_degree_centrality', style='o')

# %%
df.plot(x='betweenness_centrality', y='out_degree_centrality', style='o')

# %%
df.plot(x='influence', y='out_degree_centrality', style='o')
