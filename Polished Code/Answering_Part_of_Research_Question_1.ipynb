# %% [markdown]
# # Answering Part of Research Question 1

# %%
import pandas as pd
import numpy as np

# %%
nodes = pd.read_csv("nodes_with_community_connection_info.csv")

# %% [markdown]
# Target Comm Interaction Count means that you have people from many communities who retweet you
#
# Source Comm Interaction Count means that you retweet people from many communities

# %%
nodes
# Out:
#       Unnamed: 0  Source Comm Interaction Count  \
# 0              0                            0.0
# 1              1                            0.0
# 2              2                            0.0
# 3              3                            0.0
# 4              4                            1.0
# ...          ...                            ...
# 8974        8974                            NaN
# 8975        8975                            NaN
# 8976        8976                            NaN
# 8977        8977                            NaN
# 8978        8978                            NaN
#
#       Target Comm Interaction Count                   Id  Label  timeset  \
# 0                               NaN   866967099415113728    NaN      NaN
# 1                               NaN             47956279    NaN      NaN
# 2                               NaN            161562952    NaN      NaN
# 3                               NaN            709304733    NaN      NaN
# 4                               NaN           1223950760    NaN      NaN
# ...                             ...                  ...    ...      ...
# 8974                            0.0  1093140187486539777    NaN      NaN
# 8975                            0.0            551583496    NaN      NaN
# 8976                            0.0           1497165457    NaN      NaN
# 8977                            0.0           4269886099    NaN      NaN
# 8978                            0.0  1424828295309402117    NaN      NaN
#
#           twittername first name last name  political affiliation  influence  \
# 0                 NaN        NaN       NaN                    NaN   0.003877
# 1                 NaN        NaN       NaN                    NaN   0.003877
# 2                 NaN        NaN       NaN                    NaN   0.003877
# 3                 NaN        NaN       NaN                    NaN   0.003877
# 4                 NaN        NaN       NaN                    NaN   0.003877
# ...               ...        ...       ...                    ...        ...
# 8974    FrankCaputoMD      Frank    Caputo           Conservative   0.007365
# 8975              NaN        NaN       NaN  Activist Organization   0.005039
# 8976              NaN        NaN       NaN  Activist Organization   0.004652
# 8977   PeterFonsecaMP      Peter   Fonseca                Liberal   0.004652
# 8978  drbrendanhanley    Brendan    Hanley                Liberal   0.004652
#
#       betweenness_centrality  communityid  out_degree_centrality  \
# 0               6.254894e+03          1.0               0.000558
# 1               0.000000e+00          1.0               0.000112
# 2               0.000000e+00          1.0               0.000112
# 3               1.070413e+05          1.0               0.002681
# 4               1.266123e+06          1.0               0.007148
# ...                      ...          ...                    ...
# 8974            1.500000e+01         17.0               0.000000
# 8975            3.000000e+00         18.0               0.000000
# 8976            1.000000e+00         19.0               0.000000
# 8977            1.000000e+00         20.0               0.000000
# 8978            1.000000e+00         21.0               0.000000
#
#       in_degree_centrality  polygon                   id      community
# 0                 0.000000        1   866967099415113728        Liberal
# 1                 0.000000        1             47956279        Liberal
# 2                 0.000000        1            161562952        Liberal
# 3                 0.000000        1            709304733        Liberal
# 4                 0.000000        1           1223950760        Liberal
# ...                    ...      ...                  ...            ...
# 8974              0.000670        6  1093140187486539777  Unprofiled 17
# 8975              0.000335        3            551583496  Unprofiled 18
# 8976              0.000223        3           1497165457  Unprofiled 19
# 8977              0.000223        6           4269886099  Unprofiled 20
# 8978              0.000223        6  1424828295309402117  Unprofiled 21
#
# [8979 rows x 18 columns]

# %%
#group each node by their community
comms = nodes.groupby('community')

# %%
for name, group  in comms:
    print(name)
    ser = group['id']
    totalcount = len(ser)
    print ("Total Membership of Community: {}".format(totalcount))
    #find the people who have interacted with another community
    outsidespreaders = group[group['Source Comm Interaction Count'] > 0] 
    #count them up
    print("Total Number of people who have interacted outside of the comunity: {}".format(outsidespreaders['id'].count()))
    print("Total Number of communities: {}".format(outsidespreaders['Source Comm Interaction Count'].sum()))
# Out:
# Bloc Québécois
# Total Membership of Community: 514
# Total Number of people who have interacted outside of the comunity: 23
# Total Number of communities: 25.0
# Conservative
# Total Membership of Community: 1761
# Total Number of people who have interacted outside of the comunity: 98
# Total Number of communities: 103.0
# Conservative Activists
# Total Membership of Community: 258
# Total Number of people who have interacted outside of the comunity: 10
# Total Number of communities: 11.0
# LGBTQ2S+
# Total Membership of Community: 323
# Total Number of people who have interacted outside of the comunity: 11
# Total Number of communities: 12.0
# Liberal
# Total Membership of Community: 3565
# Total Number of people who have interacted outside of the comunity: 99
# Total Number of communities: 112.0
# NDP
# Total Membership of Community: 2195
# Total Number of people who have interacted outside of the comunity: 104
# Total Number of communities: 113.0
# Unprofiled 10
# Total Membership of Community: 40
# Total Number of people who have interacted outside of the comunity: 2
# Total Number of communities: 2.0
# Unprofiled 11
# Total Membership of Community: 29
# Total Number of people who have interacted outside of the comunity: 2
# Total Number of communities: 2.0
# Unprofiled 12
# Total Membership of Community: 15
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 13
# Total Membership of Community: 11
# Total Number of people who have interacted outside of the comunity: 2
# Total Number of communities: 2.0
# Unprofiled 14
# Total Membership of Community: 10
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 15
# Total Membership of Community: 9
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 16
# Total Membership of Community: 8
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 17
# Total Membership of Community: 7
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 18
# Total Membership of Community: 4
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 19
# Total Membership of Community: 3
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 20
# Total Membership of Community: 3
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 21
# Total Membership of Community: 3
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
# Unprofiled 7
# Total Membership of Community: 93
# Total Number of people who have interacted outside of the comunity: 1
# Total Number of communities: 1.0
# Unprofiled 8
# Total Membership of Community: 72
# Total Number of people who have interacted outside of the comunity: 2
# Total Number of communities: 3.0
# Unprofiled 9
# Total Membership of Community: 56
# Total Number of people who have interacted outside of the comunity: 0
# Total Number of communities: 0.0
