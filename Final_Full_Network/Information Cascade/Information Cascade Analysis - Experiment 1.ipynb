# %% [markdown]
# # Information Cascade Analysis

# %%
import pandas as pd
from functools import reduce

# %% [markdown]
# ## Identifying Important Bridges
# Go through each cascade experiment and see if there are any strong,regular, or weak bridges that were impacted during the cascade

# %%
strong_df = pd.read_csv('../Community Analysis/Strong_Bridges.csv')
strong_df
# Out:
#    Unnamed: 0  Source Comm Interaction Count  Target Comm Interaction Count  \
# 0         225                            0.0                            4.0
# 1         222                            0.0                            4.0
# 2        1574                            4.0                            NaN
#
#           Id  Label  timeset      twittername first name  last name  \
# 0  196717787    NaN      NaN    alexboulerice  Alexandre  Boulerice
# 1  215632349    NaN      NaN  CharlieAngusNDP    Charlie      Angus
# 2  596787864    NaN      NaN              NaN        NaN        NaN
#
#   political affiliation  influence  betweenness_centrality  communityid  \
# 0                   NDP   0.076489            8.155527e+05          2.0
# 1                   NDP   0.245437            4.958324e+06          2.0
# 2                   NaN   0.003877            1.321371e+06          1.0
#
#    out_degree_centrality  in_degree_centrality  polygon
# ...

# %%
reg_df = pd.read_csv('../Community Analysis/Regular_Bridges.csv')

# %%
weak_df = pd.read_csv('../Community Analysis/Weak_Bridges.csv')

# %% [markdown]
# ### Liberal Cascade

# %%
lib_df =  pd.read_csv('liberal_Information_Cascade.csv')
lib_df = lib_df.rename(columns={"id":"Id"})
lib_df
# Out:
#                       Id  lib_average_activation_time
# 0               14705053                          1.0
# 1               14837621                          1.0
# 2               15391466                          2.0
# 3               16158419                          1.0
# 4               16213179                          1.0
# ..                   ...                          ...
# 442  1442076364501180423                          2.0
# 443  1442426176287346696                          2.0
# 444  1444654432453529609                          2.0
# 445  1445583571985469450                          1.0
# 446  1446352422272528385                          1.0
#
# [447 rows x 2 columns]

# %% [markdown]
# #### Strong Bridges

# %%
strong_lib = pd.merge(lib_df, strong_df, on="Id")

# %%
strong_lib
# Out:
#           Id  lib_average_activation_time  Unnamed: 0  \
# 0  596787864                          1.0        1574
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            4.0                            NaN    NaN
#
#    timeset twittername first name last name political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN                   NaN   0.003877
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            1.321371e+06          1.0               0.001899
#
#    in_degree_centrality  polygon
# 0                   0.0        1

# %% [markdown]
# #### Regular Bridges

# %%
reg_lib = pd.merge(lib_df, reg_df, on="Id")
reg_lib
# Out:
# Empty DataFrame
# Columns: [Id, lib_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Weak Bridges

# %%
weak_lib = pd.merge(lib_df, weak_df, on="Id")
weak_lib
# Out:
#                     Id  lib_average_activation_time  Unnamed: 0  \
# 0             16272844                          1.0        1010
# 1             22849568                          0.0         112
# 2             40550119                          1.0         130
# 3             61521038                          1.0         149
# 4           2891740872                          0.0         152
# 5  1446352422272528385                          1.0        3071
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            2.0                            NaN    NaN
# 1                            0.0                            2.0    NaN
# 2                            0.0                            2.0    NaN
# 3                            0.0                            2.0    NaN
# 4                            0.0                            2.0    NaN
# 5                            2.0                            NaN    NaN
#
# ...

# %% [markdown]
# ### Conservative Cascade

# %%
con_df =  pd.read_csv('conservative_Information_Cascade.csv')
con_df = con_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_con = pd.merge(con_df, strong_df, on="Id")
strong_con
# Out:
# Empty DataFrame
# Columns: [Id, con_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Regular Bridges

# %%
reg_con = pd.merge(con_df, reg_df, on="Id")
reg_con
# Out:
#                    Id  con_average_activation_time  Unnamed: 0  \
# 0  711980580813066240                          1.0         945
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            3.0                            NaN    NaN
#
#    timeset twittername first name last name political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN                   NaN   0.003877
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0           736622.894841          2.0               0.000782
#
#    in_degree_centrality  polygon
# 0                   0.0        1

# %% [markdown]
# #### Weak Bridges

# %%
weak_con = pd.merge(con_df, weak_df, on="Id")
weak_con
# Out:
#                     Id  con_average_activation_time  Unnamed: 0  \
# 0  1086084557009575936                          0.0          81
# 1  1446352422272528385                          1.0        3071
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            NaN                            2.0    NaN
# 1                            2.0                            NaN    NaN
#
#    timeset twittername first name last name political affiliation  influence  \
# 0      NaN  AlexRuff17       Alex      Ruff          Conservative   0.056597
# 1      NaN         NaN        NaN       NaN                   NaN   0.003877
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            7.056699e+05          3.0               0.000000
# 1            3.781095e+06          1.0               0.005696
#
#    in_degree_centrality  polygon
# 0              0.008936        6
# 1              0.000000        1

# %% [markdown]
# ### NDP Cascade

# %%
ndp_df =  pd.read_csv('ndp_Information_Cascade.csv')
ndp_df = ndp_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_ndp = pd.merge(ndp_df, strong_df, on="Id")
strong_ndp
# Out:
#           Id  ndp_average_activation_time  Unnamed: 0  \
# 0  196717787                          0.0         225
# 1  215632349                          1.0         222
# 2  596787864                          2.0        1574
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            0.0                            4.0    NaN
# 1                            0.0                            4.0    NaN
# 2                            4.0                            NaN    NaN
#
#    timeset      twittername first name  last name political affiliation  \
# 0      NaN    alexboulerice  Alexandre  Boulerice                   NDP
# 1      NaN  CharlieAngusNDP    Charlie      Angus                   NDP
# 2      NaN              NaN        NaN        NaN                   NaN
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.076489            8.155527e+05          2.0               0.000223
# ...

# %% [markdown]
# #### Regular Bridges

# %%
reg_ndp = pd.merge(ndp_df, reg_df, on="Id")
reg_ndp
# Out:
# Empty DataFrame
# Columns: [Id, ndp_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Weak Bridges

# %%
weak_ndp = pd.merge(ndp_df, weak_df, on="Id")
weak_ndp
# Out:
#            Id  ndp_average_activation_time  Unnamed: 0  \
# 0   196717787                          0.0         225
# 1   215632349                          1.0         222
# 2  2715275551                          0.0         277
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            0.0                            4.0    NaN
# 1                            0.0                            4.0    NaN
# 2                            NaN                            2.0    NaN
#
#    timeset      twittername first name  last name  political affiliation  \
# 0      NaN    alexboulerice  Alexandre  Boulerice                    NDP
# 1      NaN  CharlieAngusNDP    Charlie      Angus                    NDP
# 2      NaN              NaN        NaN        NaN  Activist Organization
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.076489            8.155527e+05          2.0               0.000223
# ...

# %% [markdown]
# ### LGBTQ2S+ Cascade

# %%
lgbt_df =  pd.read_csv('LGBTQ2S_Information_Cascade.csv')
lgbt_df = lgbt_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_lgbt = pd.merge(lgbt_df, strong_df, on="Id")
strong_lgbt
# Out:
#           Id  lgbt_average_activation_time  Unnamed: 0  \
# 0  596787864                           1.0        1574
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            4.0                            NaN    NaN
#
#    timeset twittername first name last name political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN                   NaN   0.003877
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            1.321371e+06          1.0               0.001899
#
#    in_degree_centrality  polygon
# 0                   0.0        1

# %% [markdown]
# #### Regular Bridges

# %%
reg_lgbt = pd.merge(lgbt_df, reg_df, on="Id")
reg_lgbt
# Out:
# Empty DataFrame
# Columns: [Id, lgbt_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Weak Bridges

# %%
weak_lgbt = pd.merge(lgbt_df, weak_df, on="Id")
weak_lgbt
# Out:
#           Id  lgbt_average_activation_time  Unnamed: 0  \
# 0  119925381                           0.0         253
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            NaN                            2.0    NaN
#
#    timeset twittername first name last name  political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN  Activist Organization   0.061598
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            1.397821e+06          5.0                    0.0
#
#    in_degree_centrality  polygon
# 0              0.012063        3

# %% [markdown]
# ### Bloc Cascade

# %%
bloc_df =  pd.read_csv('bloc_Information_Cascade.csv')
bloc_df = bloc_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_bloc = pd.merge(bloc_df, strong_df, on="Id")
strong_bloc
# Out:
# Empty DataFrame
# Columns: [Id, bloc_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Regular Bridges

# %%
reg_bloc = pd.merge(bloc_df, reg_df, on="Id")
reg_bloc
# Out:
# Empty DataFrame
# Columns: [Id, bloc_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Weak Bridges

# %%
weak_bloc = pd.merge(bloc_df, weak_df, on="Id")
weak_bloc
# Out:
# Empty DataFrame
# Columns: [Id, bloc_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# ## Inter Community Interaction in Cascades

# %%
nodes = pd.read_csv("../Community Analysis/nodes_with_community_connection_info.csv")

# %%
def find_comm_interaction(df, nodes,name):
    inter_comm = pd.merge(df, nodes, on="Id")
    inter_comm = inter_comm[inter_comm['community'] != name]
    return inter_comm

# %%
def cascade_node_info(df, nodes,name):
    inter_comm = pd.merge(df, nodes, on="Id")
    return inter_comm

# %%
lib_com = find_comm_interaction(lib_df, nodes, "Liberal")
lib = cascade_node_info(lib_df, nodes, "")
con = cascade_node_info(con_df, nodes, "")
bloc = cascade_node_info(bloc_df, nodes, "")
lgbt = cascade_node_info(lgbt_df, nodes, "")
ndp = cascade_node_info(ndp_df, nodes, "")

# %%
con_com = find_comm_interaction(con_df, nodes, "Conservative")

# %%
ndp_com = find_comm_interaction(ndp_df, nodes, "NDP")
ndp_com
# Out:
#                       Id  ndp_average_activation_time  Unnamed: 0  \
# 8               16213179                          1.0        1239
# 51              78429753                          1.0        4817
# 55              86861008                          1.0        1986
# 66             122053347                          2.0        4434
# 99             276093811                          1.0        4571
# 104            291336460                          1.0         925
# 148            596787864                          2.0           5
# 152            760497115                          1.0        4572
# 175           1483413924                          1.0        1846
# 192           2275886439                          1.0        4573
# 194           2292642554                          2.0        4435
# 197           2434162616                          1.0         130
# 199           2557859383                          2.0          92
# ...

# %%
bloc_com = find_comm_interaction(bloc_df, nodes, "Bloc Québécois")
bloc_com
# Out:
#                       Id  bloc_average_activation_time  Unnamed: 0  \
# 2               16213179                           2.0        1239
# 188  1171742672614113282                           1.0        6416
# 216  1384365976922181637                           1.0        3224
#
#      Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 2                              2.0                            NaN    NaN
# 188                            1.0                            NaN    NaN
# 216                            2.0                            NaN    NaN
#
#      timeset twittername first name last name political affiliation  \
# 2        NaN         NaN        NaN       NaN                   NaN
# 188      NaN         NaN        NaN       NaN                   NaN
# 216      NaN         NaN        NaN       NaN                   NaN
#
#      influence  betweenness_centrality  communityid  out_degree_centrality  \
# ...

# %%
lgbt_com = find_comm_interaction(lgbt_df, nodes, "LGBTQ2S+")
lgbt_com
# Out:
#                       Id  lgbt_average_activation_time  Unnamed: 0  \
# 4               17174462                           2.0        4467
# 6               21426717                           2.0        4470
# 21              58340767                           1.0          85
# 23              67758676                           2.0        4462
# 39             225067116                           2.0        4452
# 53             486703473                           2.0        4454
# 64             577727470                           1.0        8114
# 68             596787864                           1.0           5
# 81            1223950760                           1.0           4
# 90            1548315212                           2.0        4461
# 93            1650588223                           2.0        4481
# 96            2262304373                           1.0         142
# 98            2367303485                           2.0        4466
# ...

# %% [markdown]
# https://stackoverflow.com/questions/44327999/python-pandas-merge-multiple-dataframes

# %%
data_frames = [lib, con, ndp, bloc, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)

# %%
df_merged
# Out:
# Empty DataFrame
# ...

# %%
data_frames = [lib, con, ndp, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# ...

# %%
data_frames = [lib, con, ndp, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# ...

# %%
data_frames = [lib, lgbt, ndp, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# ...

# %%
data_frames = [lib, con, lgbt, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# ...

# %%
data_frames = [ndp, con, lgbt, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# ...

# %%
bloc
# Out:
#                       Id  bloc_average_activation_time  Unnamed: 0  \
# 0               12220452                           1.0        7660
# 1               16014404                           0.0        7454
# 2               16213179                           2.0        1239
# 3               16450356                           1.0        7687
# 4               17721863                           1.0        7507
# ..                   ...                           ...         ...
# 225  1435677654699675654                           3.0        7753
# 226  1437734637531504644                           1.0        7656
# 227  1439240496921161733                           1.0        4574
# 228  1440532151582134272                           1.0        7628
# 229  1440664285210767367                           1.0        7600
#
#      Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                              0.0                            NaN    NaN
# ...

# %%
data_frames = [lib, ndp, con]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# Columns: [Id, lib_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, ndp_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, con_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon, id, community]
# Index: []
# ...

# %%
data_frames = [bloc, con]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# Columns: [Id, bloc_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, con_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y]
# Index: []
#
# [0 rows x 37 columns]

# %%
data_frames = [lib, ndp, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#           Id  lib_average_activation_time  Unnamed: 0_x  \
# 0  596787864                          1.0             5
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              4.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name  \
# 0        NaN           NaN          NaN         NaN  ...       NaN
#
#    political affiliation  influence  betweenness_centrality  communityid  \
# 0                    NaN   0.003877            1.321371e+06          1.0
#
#    out_degree_centrality  in_degree_centrality  polygon         id  community
# 0               0.001899                   0.0        1  596787864    Liberal
#
# [1 rows x 55 columns]

# %%
data_frames = [lib, ndp]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  lib_average_activation_time  Unnamed: 0_x  \
# 0             16213179                          1.0          1239
# 1            596787864                          1.0             5
# 2           1483413924                          2.0          1846
# 3           2434162616                          1.0           130
# 4           2557859383                          1.0            92
# 5           3313678069                          1.0           510
# 6   971857794826567680                          1.0          1358
# 7  1265853916077527042                          1.0          1373
# 8  1297554634182209537                          1.0          2695
# 9  1415746394871189504                          2.0          2554
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              2.0                              NaN      NaN
# 1                              4.0                              NaN      NaN
# ...

# %%
data_frames = [lib, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  lib_average_activation_time  Unnamed: 0_x  \
# 0            596787864                          1.0             5
# 1           1223950760                          1.0             4
# 2  1115838887623122954                          1.0           660
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              4.0                              NaN      NaN
# 1                              1.0                              NaN      NaN
# 2                              1.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0        NaN           NaN          NaN         NaN  ...         NaN
# 1        NaN           NaN          NaN         NaN  ...         NaN
# 2        NaN           NaN          NaN         NaN  ...         NaN
#
#    political affiliation_y  influence_y  betweenness_centrality_y  \
# ...

# %%
data_frames = [ndp, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  ndp_average_activation_time  Unnamed: 0_x  \
# 0            596787864                          2.0             5
# 1  1346317368637603841                          2.0          4228
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              4.0                              NaN      NaN
# 1                              0.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0        NaN           NaN          NaN         NaN  ...         NaN
# 1        NaN           NaN          NaN         NaN  ...         NaN
#
#    political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                      NaN     0.003877              1.321371e+06
# 1                      NaN     0.003877              1.819404e+04
#
#    communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# ...

# %%
data_frames = [con, lib]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  con_average_activation_time  Unnamed: 0_x  \
# 0   823933874551959552                          2.0          1375
# 1  1446352422272528385                          1.0           167
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              1.0                              NaN      NaN
# 1                              2.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0        NaN           NaN          NaN         NaN  ...         NaN
# 1        NaN           NaN          NaN         NaN  ...         NaN
#
#    political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                      NaN     0.003877              1.953440e+04
# 1                      NaN     0.003877              3.781095e+06
#
#    communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# ...

# %%
data_frames = [ndp, con]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  ndp_average_activation_time  Unnamed: 0_x  \
# 0   818660875259277313                          2.0          4205
# 1  1178019071821877250                          2.0          4431
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              1.0                              NaN      NaN
# 1                              1.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0        NaN           NaN          NaN         NaN  ...         NaN
# 1        NaN           NaN          NaN         NaN  ...         NaN
#
#    political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                      NaN     0.003877              99684.303627
# 1                      NaN     0.003877             227959.782013
#
#    communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# ...
