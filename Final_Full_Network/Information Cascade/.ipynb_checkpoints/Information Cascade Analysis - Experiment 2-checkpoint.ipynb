# %% [markdown]
# # Information Cascade Analysis

# %% [markdown]
# https://github.com/tctianchi/pyvenn

# %%
import pandas as pd
from functools import reduce

# %% [markdown]
# ## Identifying Important Bridges
# Go through each cascade experiment and see if there are any strong,regular, or weak bridges that were impacted during the cascade

# %%
strong_df = pd.read_csv('../Community Analysis/Strong_Bridges.csv')
strong_df
# Out:
#    Unnamed: 0  Source Comm Interaction Count  Target Comm Interaction Count  \
# 0         225                            0.0                            4.0
# 1         222                            0.0                            4.0
# 2        1574                            4.0                            NaN
#
#           Id  Label  timeset      twittername first name  last name  \
# 0  196717787    NaN      NaN    alexboulerice  Alexandre  Boulerice
# 1  215632349    NaN      NaN  CharlieAngusNDP    Charlie      Angus
# 2  596787864    NaN      NaN              NaN        NaN        NaN
#
#   political affiliation  influence  betweenness_centrality  communityid  \
# 0                   NDP   0.076489            8.155527e+05          2.0
# 1                   NDP   0.245437            4.958324e+06          2.0
# 2                   NaN   0.003877            1.321371e+06          1.0
#
#    out_degree_centrality  in_degree_centrality  polygon
# 0               0.000223              0.007819        6
# 1               0.000335              0.042220        6
# 2               0.001899              0.000000        1

# %%
reg_df = pd.read_csv('../Community Analysis/Regular_Bridges.csv')

# %%
weak_df = pd.read_csv('../Community Analysis/Weak_Bridges.csv')

# %% [markdown]
# ### Liberal Cascade

# %%
lib_df =  pd.read_csv('liberal_Information_Cascade_EXP2.csv')
lib_df = lib_df.rename(columns={"id":"Id"})
lib_df
# Out:
#                        Id  lib_exp2_average_activation_time
# 0                 1263631                               1.0
# 1                 5548282                               1.0
# 2                 7801522                               1.0
# 3                 9898272                               1.0
# 4                 9946272                               2.0
# ...                   ...                               ...
# 2697  1445901048951017472                               1.0
# 2698  1445905244500676608                               1.0
# 2699  1446352422272528385                               2.0
# 2700  1447502440820002819                               1.0
# 2701  1449405859772047365                               1.0
#
# [2702 rows x 2 columns]

# %% [markdown]
# #### Strong Bridges

# %%
strong_lib = pd.merge(lib_df, strong_df, on="Id")

# %%
strong_lib
# Out:
#           Id  lib_exp2_average_activation_time  Unnamed: 0  \
# 0  596787864                               1.0        1574
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            4.0                            NaN    NaN
#
#    timeset twittername first name last name political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN                   NaN   0.003877
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            1.321371e+06          1.0               0.001899
#
#    in_degree_centrality  polygon
# 0                   0.0        1

# %% [markdown]
# #### Regular Bridges

# %%
reg_lib = pd.merge(lib_df, reg_df, on="Id")
reg_lib
# Out:
#                    Id  lib_exp2_average_activation_time  Unnamed: 0  \
# 0            12034642                               2.0        3652
# 1            20199202                               0.0         124
# 2           205786669                               0.0         138
# 3          1707636642                               0.0         215
# 4  711980580813066240                               1.0         945
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            3.0                            NaN    NaN
# 1                            NaN                            3.0    NaN
# 2                            0.0                            3.0    NaN
# 3                            0.0                            3.0    NaN
# 4                            3.0                            NaN    NaN
#
#    timeset   twittername         first name  last name political affiliation  \
# 0      NaN           NaN                NaN        NaN                   NaN
# 1      NaN  OmarAlghabra               Omar   Alghabra               Liberal
# 2      NaN     PamDamoff                Pam     Damoff               Liberal
# 3      NaN  FP_Champagne  François-Philippe  Champagne               Liberal
# 4      NaN           NaN                NaN        NaN                   NaN
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.003877            2.101758e+05          3.0               0.001005
# 1   0.151399            1.875415e+06          1.0               0.000000
# 2   0.070331            1.012662e+06          1.0               0.000335
# 3   0.198697            2.610868e+06          1.0               0.000112
# 4   0.003877            7.366229e+05          2.0               0.000782
#
#    in_degree_centrality  polygon
# 0              0.000000        1
# 1              0.023568        6
# 2              0.013180        6
# 3              0.024684        6
# 4              0.000000        1

# %% [markdown]
# #### Weak Bridges

# %%
weak_lib = pd.merge(lib_df, weak_df, on="Id")
weak_lib
# Out:
#                      Id  lib_exp2_average_activation_time  Unnamed: 0  \
# 0              16272844                               1.0        1010
# 1              20199202                               0.0         124
# 2              22849568                               0.0         112
# 3              25127782                               1.0          19
# 4              25813888                               1.0         258
# 5              40550119                               0.0         130
# 6              47338701                               0.0         153
# 7              61521038                               0.0         149
# 8             205786669                               0.0         138
# 9             234550882                               0.0         106
# 10           1646334073                               0.0         208
# 11           1707636642                               0.0         215
# 12           2891740872                               0.0         152
# 13   720579941184757760                               0.0         107
# 14  1162219997977960449                               1.0         102
# 15  1446352422272528385                               2.0        3071
#
#     Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                             2.0                            NaN    NaN
# 1                             NaN                            3.0    NaN
# 2                             0.0                            2.0    NaN
# 3                             0.0                            2.0    NaN
# 4                             0.0                            2.0    NaN
# 5                             0.0                            2.0    NaN
# 6                             NaN                            2.0    NaN
# 7                             0.0                            2.0    NaN
# 8                             0.0                            3.0    NaN
# 9                             0.0                            2.0    NaN
# 10                            0.0                            2.0    NaN
# 11                            0.0                            3.0    NaN
# 12                            0.0                            2.0    NaN
# 13                            NaN                            2.0    NaN
# 14                            0.0                            2.0    NaN
# 15                            2.0                            NaN    NaN
#
#     timeset      twittername         first name    last name  \
# 0       NaN              NaN                NaN          NaN
# 1       NaN     OmarAlghabra               Omar     Alghabra
# 2       NaN     SeamusORegan             Seamus      O'Regan
# 3       NaN          HedyFry               Hedy          Fry
# 4       NaN              NaN                NaN          NaN
# 5       NaN  Carolyn_Bennett            Carolyn      Bennett
# 6       NaN         MarciIen              Marci          Ien
# 7       NaN      karinagould             Karina        Gould
# 8       NaN        PamDamoff                Pam       Damoff
# 9       NaN        stbstvdan                Dan       Vandal
# 10      NaN     AHousefather            Anthony  Housefather
# 11      NaN     FP_Champagne  François-Philippe    Champagne
# 12      NaN   HonAhmedHussen              Ahmed       Hussen
# 13      NaN       DLeBlancNB            Dominic      LeBlanc
# 14      NaN   PatrickBWeiler            Patrick       Weiler
# 15      NaN              NaN                NaN          NaN
#
#     political affiliation  influence  betweenness_centrality  communityid  \
# 0                     NaN   0.003877            3.097217e+06          1.0
# 1                 Liberal   0.151399            1.875415e+06          1.0
# 2                 Liberal   0.184197            2.048459e+06          1.0
# 3                 Liberal   0.098852            1.420782e+06          1.0
# 4   Activist Organization   0.034113            3.802726e+05          1.0
# 5                 Liberal   0.150814            1.614482e+06          1.0
# 6                 Liberal   0.126394            1.378890e+06          1.0
# 7                 Liberal   0.090343            1.063783e+06          1.0
# 8                 Liberal   0.070331            1.012662e+06          1.0
# 9                 Liberal   0.061421            2.951357e+05          1.0
# 10                Liberal   0.081758            7.558613e+05          1.0
# 11                Liberal   0.198697            2.610868e+06          1.0
# 12                Liberal   0.100984            8.264850e+05          1.0
# 13                Liberal   0.071679            3.318168e+05          1.0
# 14                Liberal   0.045743            3.157218e+05          1.0
# 15                    NaN   0.003877            3.781095e+06          1.0
#
#     out_degree_centrality  in_degree_centrality  polygon
# 0                0.011728              0.000000        1
# 1                0.000000              0.023568        6
# 2                0.000335              0.027477        6
# 3                0.000335              0.017089        6
# 4                0.000112              0.005250        3
# 5                0.000894              0.021557        6
# 6                0.000000              0.021445        6
# 7                0.000112              0.016419        6
# 8                0.000335              0.013180        6
# 9                0.000112              0.005473        6
# 10               0.000112              0.013962        6
# 11               0.000112              0.024684        6
# 12               0.000335              0.013068        6
# 13               0.000000              0.010164        6
# 14               0.000223              0.009047        6
# 15               0.005696              0.000000        1

# %% [markdown]
# ### Conservative Cascade

# %%
con_df =  pd.read_csv('conservative_Information_Cascade_EXP2.csv')
con_df = con_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_con = pd.merge(con_df, strong_df, on="Id")
strong_con
# Out:
# Empty DataFrame
# Columns: [Id, con_exp2_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Regular Bridges

# %%
reg_con = pd.merge(con_df, reg_df, on="Id")
reg_con
# Out:
#                    Id  con_exp2_average_activation_time  Unnamed: 0  \
# 0            36133644                               0.0          91
# 1           343059330                               1.0          74
# 2  711980580813066240                               1.0         945
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            0.0                            3.0    NaN
# 1                            0.0                            3.0    NaN
# 2                            3.0                            NaN    NaN
#
#    timeset    twittername first name last name political affiliation  \
# 0      NaN  gerarddeltell     Gérard   Deltell          Conservative
# 1      NaN   Eric_Melillo       Eric   Melillo          Conservative
# 2      NaN            NaN        NaN       NaN                   NaN
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.076073            1.443833e+06          3.0               0.000112
# 1   0.033338            5.463277e+05          3.0               0.000112
# 2   0.003877            7.366229e+05          2.0               0.000782
#
#    in_degree_centrality  polygon
# 0              0.013850        6
# 1              0.007372        6
# 2              0.000000        1

# %% [markdown]
# #### Weak Bridges

# %%
weak_con = pd.merge(con_df, weak_df, on="Id")
weak_con
# Out:
#                     Id  con_exp2_average_activation_time  Unnamed: 0  \
# 0             21410801                               1.0         261
# 1             36133644                               0.0          91
# 2            343059330                               1.0          74
# 3            412708728                               0.0          89
# 4           1957288050                               1.0         146
# 5  1086084557009575936                               0.0          81
# 6  1446352422272528385                               2.0        3071
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            0.0                            2.0    NaN
# 1                            0.0                            3.0    NaN
# 2                            0.0                            3.0    NaN
# 3                            0.0                            2.0    NaN
# 4                            0.0                            2.0    NaN
# 5                            NaN                            2.0    NaN
# 6                            2.0                            NaN    NaN
#
#    timeset    twittername first name last name  political affiliation  \
# 0      NaN            NaN        NaN       NaN  Activist Organization
# 1      NaN  gerarddeltell     Gérard   Deltell           Conservative
# 2      NaN   Eric_Melillo       Eric   Melillo           Conservative
# 3      NaN  PierrePaulHus     Pierre  Paul-Hus           Conservative
# 4      NaN     GaryAVidal       Gary     Vidal           Conservative
# 5      NaN     AlexRuff17       Alex      Ruff           Conservative
# 6      NaN            NaN        NaN       NaN                    NaN
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.067839            8.191231e+05          3.0               0.000112
# 1   0.076073            1.443833e+06          3.0               0.000112
# 2   0.033338            5.463277e+05          3.0               0.000112
# 3   0.099025            9.061848e+05          3.0               0.000112
# 4   0.022096            2.895761e+05          3.0               0.000223
# 5   0.056597            7.056699e+05          3.0               0.000000
# 6   0.003877            3.781095e+06          1.0               0.005696
#
#    in_degree_centrality  polygon
# 0              0.011840        3
# 1              0.013850        6
# 2              0.007372        6
# 3              0.017313        6
# 4              0.004803        6
# 5              0.008936        6
# 6              0.000000        1

# %% [markdown]
# ### NDP Cascade

# %%
ndp_df =  pd.read_csv('ndp_Information_Cascade_EXP2.csv')
ndp_df = ndp_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_ndp = pd.merge(ndp_df, strong_df, on="Id")
strong_ndp
# Out:
#           Id  ndp_exp2_average_activation_time  Unnamed: 0  \
# 0  196717787                               0.0         225
# 1  215632349                               0.0         222
# 2  596787864                               2.0        1574
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            0.0                            4.0    NaN
# 1                            0.0                            4.0    NaN
# 2                            4.0                            NaN    NaN
#
#    timeset      twittername first name  last name political affiliation  \
# 0      NaN    alexboulerice  Alexandre  Boulerice                   NDP
# 1      NaN  CharlieAngusNDP    Charlie      Angus                   NDP
# 2      NaN              NaN        NaN        NaN                   NaN
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.076489            8.155527e+05          2.0               0.000223
# 1   0.245437            4.958324e+06          2.0               0.000335
# 2   0.003877            1.321371e+06          1.0               0.001899
#
#    in_degree_centrality  polygon
# 0              0.007819        6
# 1              0.042220        6
# 2              0.000000        1

# %% [markdown]
# #### Regular Bridges

# %%
reg_ndp = pd.merge(ndp_df, reg_df, on="Id")
reg_ndp
# Out:
#          Id  ndp_exp2_average_activation_time  Unnamed: 0  \
# 0  12034642                               1.0        3652
# 1  14079041                               0.0         259
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            3.0                            NaN    NaN
# 1                            NaN                            3.0    NaN
#
#    timeset twittername first name last name  political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN                    NaN   0.003877
# 1      NaN         NaN        NaN       NaN  Activist Organization   0.203518
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            2.101758e+05          3.0               0.001005
# 1            3.091533e+06          2.0               0.000000
#
#    in_degree_centrality  polygon
# 0              0.000000        1
# 1              0.036412        3

# %% [markdown]
# #### Weak Bridges

# %%
weak_ndp = pd.merge(ndp_df, weak_df, on="Id")
weak_ndp
# Out:
#                     Id  ndp_exp2_average_activation_time  Unnamed: 0  \
# 0             14079041                               0.0         259
# 1             16220555                               1.0          98
# 2             25813888                               2.0         258
# 3            175259033                               0.0         217
# 4            196717787                               0.0         225
# 5            215632349                               0.0         222
# 6            341866567                               0.0         221
# 7            377588094                               0.0         281
# 8           2715275551                               0.0         277
# 9  1446352422272528385                               1.0        3071
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            NaN                            3.0    NaN
# 1                            0.0                            2.0    NaN
# 2                            0.0                            2.0    NaN
# 3                            NaN                            2.0    NaN
# 4                            0.0                            4.0    NaN
# 5                            0.0                            4.0    NaN
# 6                            0.0                            2.0    NaN
# 7                            NaN                            2.0    NaN
# 8                            NaN                            2.0    NaN
# 9                            2.0                            NaN    NaN
#
#    timeset      twittername first name  last name  political affiliation  \
# 0      NaN              NaN        NaN        NaN  Activist Organization
# 1      NaN     ElizabethMay  Elizabeth        May            Green Party
# 2      NaN              NaN        NaN        NaN  Activist Organization
# 3      NaN   taylorbachrach     Taylor   Bachrach                    NDP
# 4      NaN    alexboulerice  Alexandre  Boulerice                    NDP
# 5      NaN  CharlieAngusNDP    Charlie      Angus                    NDP
# 6      NaN       LoriIdlout       Lori     Idlout                    NDP
# 7      NaN              NaN        NaN        NaN  Activist Organization
# 8      NaN              NaN        NaN        NaN  Activist Organization
# 9      NaN              NaN        NaN        NaN                    NaN
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.203518            3.091533e+06          2.0               0.000000
# 1   0.046518            7.488018e+05          2.0               0.000112
# 2   0.034113            3.802726e+05          1.0               0.000112
# 3   0.072382            5.144278e+05          2.0               0.000000
# 4   0.076489            8.155527e+05          2.0               0.000223
# 5   0.245437            4.958324e+06          2.0               0.000335
# 6   0.067469            4.270648e+05          2.0               0.000223
# 7   0.043572            4.159392e+05          2.0               0.000000
# 8   0.066483            6.853130e+05          2.0               0.000000
# 9   0.003877            3.781095e+06          1.0               0.005696
#
#    in_degree_centrality  polygon
# 0              0.036412        3
# 1              0.009494        6
# 2              0.005250        3
# 3              0.006702        6
# 4              0.007819        6
# 5              0.042220        6
# 6              0.007484        6
# 7              0.005808        3
# 8              0.008712        3
# 9              0.000000        1

# %% [markdown]
# ### LGBTQ2S+ Cascade

# %%
lgbt_df =  pd.read_csv('LGBTQ2S_Information_Cascade_EXP2.csv')
lgbt_df = lgbt_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_lgbt = pd.merge(lgbt_df, strong_df, on="Id")
strong_lgbt
# Out:
#           Id  lgbt_exp2_average_activation_time  Unnamed: 0  \
# 0  596787864                                1.0        1574
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            4.0                            NaN    NaN
#
#    timeset twittername first name last name political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN                   NaN   0.003877
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            1.321371e+06          1.0               0.001899
#
#    in_degree_centrality  polygon
# 0                   0.0        1

# %% [markdown]
# #### Regular Bridges

# %%
reg_lgbt = pd.merge(lgbt_df, reg_df, on="Id")
reg_lgbt
# Out:
# Empty DataFrame
# Columns: [Id, lgbt_exp2_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon]
# Index: []

# %% [markdown]
# #### Weak Bridges

# %%
weak_lgbt = pd.merge(lgbt_df, weak_df, on="Id")
weak_lgbt
# Out:
#           Id  lgbt_exp2_average_activation_time  Unnamed: 0  \
# 0  119925381                                0.0         253
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            NaN                            2.0    NaN
#
#    timeset twittername first name last name  political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN  Activist Organization   0.061598
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            1.397821e+06          5.0                    0.0
#
#    in_degree_centrality  polygon
# 0              0.012063        3

# %% [markdown]
# ### Bloc Cascade

# %%
bloc_df =  pd.read_csv('bloc_Information_Cascade_EXP2.csv')
bloc_df = bloc_df.rename(columns={"id":"Id"})

# %% [markdown]
# #### Strong Bridges

# %%
strong_bloc = pd.merge(bloc_df, strong_df, on="Id")
strong_bloc
# Out:
#           Id  bloc_exp2_average_activation_time  Unnamed: 0  \
# 0  596787864                                1.0        1574
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            4.0                            NaN    NaN
#
#    timeset twittername first name last name political affiliation  influence  \
# 0      NaN         NaN        NaN       NaN                   NaN   0.003877
#
#    betweenness_centrality  communityid  out_degree_centrality  \
# 0            1.321371e+06          1.0               0.001899
#
#    in_degree_centrality  polygon
# 0                   0.0        1

# %% [markdown]
# #### Regular Bridges

# %%
reg_bloc = pd.merge(bloc_df, reg_df, on="Id")
reg_bloc
# Out:
#          Id  bloc_exp2_average_activation_time  Unnamed: 0  \
# 0  12034642                                1.0        3652
# 1  24990450                                0.0          20
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            3.0                            NaN    NaN
# 1                            NaN                            3.0    NaN
#
#    timeset    twittername first name  last name political affiliation  \
# 0      NaN            NaN        NaN        NaN                   NaN
# 1      NaN  renevillemure       René  Villemure        Bloc Québécois
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.003877           210175.768781          3.0               0.001005
# 1   0.068354           595854.835476          4.0               0.000000
#
#    in_degree_centrality  polygon
# 0              0.000000        1
# 1              0.008489        6

# %% [markdown]
# #### Weak Bridges

# %%
weak_bloc = pd.merge(bloc_df, weak_df, on="Id")
weak_bloc
# Out:
#                     Id  bloc_exp2_average_activation_time  Unnamed: 0  \
# 0             24990450                                0.0          20
# 1           2800741820                                0.0         131
# 2  1143229947932229632                                0.0          22
#
#    Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                            NaN                            3.0    NaN
# 1                            NaN                            2.0    NaN
# 2                            0.0                            2.0    NaN
#
#    timeset    twittername first name  last name political affiliation  \
# 0      NaN  renevillemure       René  Villemure        Bloc Québécois
# 1      NaN   trudel_denis      Denis     Trudel        Bloc Québécois
# 2      NaN  LucDesiletsBQ        Luc   Desilets        Bloc Québécois
#
#    influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0   0.068354           595854.835476          4.0               0.000000
# 1   0.072978           284271.951189          4.0               0.000000
# 2   0.134386           812987.549734          4.0               0.000112
#
#    in_degree_centrality  polygon
# 0              0.008489        6
# 1              0.011951        6
# 2              0.019547        6

# %% [markdown]
# ## Inter Community Interaction in Cascades

# %%
nodes = pd.read_csv("../Community Analysis/nodes_with_community_connection_info.csv")

# %%
def find_comm_interaction(df, nodes,name):
    inter_comm = pd.merge(df, nodes, on="Id")
    inter_comm = inter_comm[inter_comm['community'] != name]
    return inter_comm

# %%
def cascade_node_info(df, nodes,name):
    inter_comm = pd.merge(df, nodes, on="Id")
    return inter_comm

# %%
lib_com = find_comm_interaction(lib_df, nodes, "Liberal")
lib = cascade_node_info(lib_df, nodes, "")
con = cascade_node_info(con_df, nodes, "")
bloc = cascade_node_info(bloc_df, nodes, "")
lgbt = cascade_node_info(lgbt_df, nodes, "")
ndp = cascade_node_info(ndp_df, nodes, "")

# %%
con_com = find_comm_interaction(con_df, nodes, "Conservative")

# %%
ndp_com = find_comm_interaction(ndp_df, nodes, "NDP")
ndp_com
# Out:
#                        Id  ndp_exp2_average_activation_time  Unnamed: 0  \
# 15               12034642                               1.0        2374
# 25               14837621                               1.0         202
# 44               16213179                               1.0        1239
# 59               17280115                               2.0        2214
# 68               18108896                               1.0        4433
# ...                   ...                               ...         ...
# 1089  1392927838001459201                               1.0        4436
# 1096  1408262420640960512                               1.0        4429
# 1111  1430883215439540230                               1.0        4430
# 1116  1439240496921161733                               1.0        4574
# 1122  1446352422272528385                               1.0         167
#
#       Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 15                              3.0                            NaN    NaN
# 25                              1.0                            NaN    NaN
# 44                              2.0                            NaN    NaN
# 59                              0.0                            NaN    NaN
# 68                              1.0                            NaN    NaN
# ...                             ...                            ...    ...
# 1089                            1.0                            NaN    NaN
# 1096                            1.0                            NaN    NaN
# 1111                            1.0                            NaN    NaN
# 1116                            1.0                            NaN    NaN
# 1122                            2.0                            NaN    NaN
#
#       timeset twittername first name last name political affiliation  \
# 15        NaN         NaN        NaN       NaN                   NaN
# 25        NaN         NaN        NaN       NaN                   NaN
# 44        NaN         NaN        NaN       NaN                   NaN
# 59        NaN         NaN        NaN       NaN                   NaN
# 68        NaN         NaN        NaN       NaN                   NaN
# ...       ...         ...        ...       ...                   ...
# 1089      NaN         NaN        NaN       NaN                   NaN
# 1096      NaN         NaN        NaN       NaN                   NaN
# 1111      NaN         NaN        NaN       NaN                   NaN
# 1116      NaN         NaN        NaN       NaN                   NaN
# 1122      NaN         NaN        NaN       NaN                   NaN
#
#       influence  betweenness_centrality  communityid  out_degree_centrality  \
# 15     0.003877            2.101758e+05          3.0               0.001005
# 25     0.003877            3.288252e+05          1.0               0.001564
# 44     0.003877            2.325127e+05          1.0               0.000447
# 59     0.003877            0.000000e+00          1.0               0.000112
# 68     0.003877            8.554525e+04          3.0               0.000335
# ...         ...                     ...          ...                    ...
# 1089   0.003877            1.062666e+05          3.0               0.000670
# 1096   0.003877            2.385965e+04          3.0               0.000223
# 1111   0.003877            3.537520e+04          3.0               0.000223
# 1116   0.003877            3.689728e+02          4.0               0.000447
# 1122   0.003877            3.781095e+06          1.0               0.005696
#
#       in_degree_centrality  polygon                   id       community
# 15                     0.0        1             12034642    Conservative
# 25                     0.0        1             14837621         Liberal
# 44                     0.0        1             16213179         Liberal
# 59                     0.0        1             17280115         Liberal
# 68                     0.0        1             18108896    Conservative
# ...                    ...      ...                  ...             ...
# 1089                   0.0        1  1392927838001459201    Conservative
# 1096                   0.0        1  1408262420640960512    Conservative
# 1111                   0.0        1  1430883215439540230    Conservative
# 1116                   0.0        1  1439240496921161733  Bloc Québécois
# 1122                   0.0        1  1446352422272528385         Liberal
#
# [77 rows x 19 columns]

# %%
bloc_com = find_comm_interaction(bloc_df, nodes, "Bloc Québécois")
bloc_com
# Out:
#                       Id  bloc_exp2_average_activation_time  Unnamed: 0  \
# 3               12034642                                1.0        2374
# 8               16213179                                2.0        1239
# 37              86425142                                1.0        6770
# 68             135000298                                1.0        6748
# 151            376391827                                1.0        2993
# 188            596787864                                1.0           5
# 314           3313678069                                1.0         510
# 391  1171742672614113282                                1.0        6416
# 395  1213189717425917953                                1.0        7791
# 421  1309334948847943681                                1.0        2961
# 443  1384365976922181637                                1.0        3224
#
#      Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 3                              3.0                            NaN    NaN
# 8                              2.0                            NaN    NaN
# 37                             1.0                            NaN    NaN
# 68                             1.0                            NaN    NaN
# 151                            2.0                            NaN    NaN
# 188                            4.0                            NaN    NaN
# 314                            2.0                            NaN    NaN
# 391                            1.0                            NaN    NaN
# 395                            1.0                            NaN    NaN
# 421                            1.0                            NaN    NaN
# 443                            2.0                            NaN    NaN
#
#      timeset twittername first name last name political affiliation  \
# 3        NaN         NaN        NaN       NaN                   NaN
# 8        NaN         NaN        NaN       NaN                   NaN
# 37       NaN         NaN        NaN       NaN                   NaN
# 68       NaN         NaN        NaN       NaN                   NaN
# 151      NaN         NaN        NaN       NaN                   NaN
# 188      NaN         NaN        NaN       NaN                   NaN
# 314      NaN         NaN        NaN       NaN                   NaN
# 391      NaN         NaN        NaN       NaN                   NaN
# 395      NaN         NaN        NaN       NaN                   NaN
# 421      NaN         NaN        NaN       NaN                   NaN
# 443      NaN         NaN        NaN       NaN                   NaN
#
#      influence  betweenness_centrality  communityid  out_degree_centrality  \
# 3     0.003877            2.101758e+05          3.0               0.001005
# 8     0.003877            2.325127e+05          1.0               0.000447
# 37    0.003877            2.706911e+04          3.0               0.000558
# 68    0.003877            1.148269e+04          3.0               0.000335
# 151   0.003877            1.768370e+05          2.0               0.000335
# 188   0.003877            1.321371e+06          1.0               0.001899
# 314   0.003877            1.413873e+05          2.0               0.000447
# 391   0.003877            1.380601e+04          3.0               0.000335
# 395   0.003877            2.537661e+04          6.0               0.000223
# 421   0.003877            1.178371e+05          1.0               0.000223
# 443   0.003877            8.867628e+04          3.0               0.000447
#
#      in_degree_centrality  polygon                   id  \
# 3                     0.0        1             12034642
# 8                     0.0        1             16213179
# 37                    0.0        1             86425142
# 68                    0.0        1            135000298
# 151                   0.0        1            376391827
# 188                   0.0        1            596787864
# 314                   0.0        1           3313678069
# 391                   0.0        1  1171742672614113282
# 395                   0.0        1  1213189717425917953
# 421                   0.0        1  1309334948847943681
# 443                   0.0        1  1384365976922181637
#
#                   community
# 3              Conservative
# 8                   Liberal
# 37             Conservative
# 68             Conservative
# 151                     NDP
# 188                 Liberal
# 314                     NDP
# 391            Conservative
# 395  Conservative Activists
# 421                 Liberal
# 443            Conservative

# %%
lgbt_com = find_comm_interaction(lgbt_df, nodes, "LGBTQ2S+")
lgbt_com
# Out:
#                       Id  lgbt_exp2_average_activation_time  Unnamed: 0  \
# 3               16422863                                2.0        4354
# 6               18597273                                2.0        4458
# 7               20346252                                2.0        4323
# 22              58340767                                1.0          85
# 24              67758676                                2.0        4462
# 31             116837959                                2.0        4463
# 63             577727470                                1.0        8114
# 67             596787864                                1.0           5
# 80            1223950760                                1.0           4
# 91            1650588223                                2.0        4481
# 94            2262304373                                1.0         142
# 96            2367303485                                2.0        4466
# 97            2394842400                                2.0        4457
# 132   753744536887824385                                1.0        3756
# 151  1005823371144318977                                2.0        4464
# 152  1024397417423106048                                2.0        4475
# 161  1115838887623122954                                1.0         660
# 172  1346317368637603841                                2.0        4228
# 178  1378038493105037320                                2.0        4479
#
#      Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 3                              0.0                            NaN    NaN
# 6                              0.0                            NaN    NaN
# 7                              0.0                            NaN    NaN
# 22                             1.0                            NaN    NaN
# 24                             0.0                            NaN    NaN
# 31                             0.0                            NaN    NaN
# 63                             1.0                            1.0    NaN
# 67                             4.0                            NaN    NaN
# 80                             1.0                            NaN    NaN
# 91                             0.0                            NaN    NaN
# 94                             2.0                            NaN    NaN
# 96                             0.0                            NaN    NaN
# 97                             0.0                            NaN    NaN
# 132                            1.0                            NaN    NaN
# 151                            0.0                            NaN    NaN
# 152                            0.0                            NaN    NaN
# 161                            1.0                            NaN    NaN
# 172                            0.0                            NaN    NaN
# 178                            0.0                            NaN    NaN
#
#      timeset twittername first name last name  political affiliation  \
# 3        NaN         NaN        NaN       NaN                    NaN
# 6        NaN         NaN        NaN       NaN                    NaN
# 7        NaN         NaN        NaN       NaN                    NaN
# 22       NaN         NaN        NaN       NaN                    NaN
# 24       NaN         NaN        NaN       NaN                    NaN
# 31       NaN         NaN        NaN       NaN                    NaN
# 63       NaN         NaN        NaN       NaN  Activist Organization
# 67       NaN         NaN        NaN       NaN                    NaN
# 80       NaN         NaN        NaN       NaN                    NaN
# 91       NaN         NaN        NaN       NaN                    NaN
# 94       NaN         NaN        NaN       NaN                    NaN
# 96       NaN         NaN        NaN       NaN                    NaN
# 97       NaN         NaN        NaN       NaN                    NaN
# 132      NaN         NaN        NaN       NaN                    NaN
# 151      NaN         NaN        NaN       NaN                    NaN
# 152      NaN         NaN        NaN       NaN                    NaN
# 161      NaN         NaN        NaN       NaN                    NaN
# 172      NaN         NaN        NaN       NaN                    NaN
# 178      NaN         NaN        NaN       NaN                    NaN
#
#      influence  betweenness_centrality  communityid  out_degree_centrality  \
# 3     0.003877            5.696908e+04          2.0               0.000782
# 6     0.003877            0.000000e+00          2.0               0.000112
# 7     0.003877            1.507022e+04          2.0               0.000223
# 22    0.003877            7.338912e+04          1.0               0.000894
# 24    0.003877            0.000000e+00          2.0               0.000112
# 31    0.003877            0.000000e+00          2.0               0.000112
# 63    0.034501            3.735905e+05          2.0               0.000112
# 67    0.003877            1.321371e+06          1.0               0.001899
# 80    0.003877            1.266123e+06          1.0               0.007148
# 91    0.003877            0.000000e+00          2.0               0.000112
# 94    0.003877            2.091874e+05          1.0               0.000447
# 96    0.003877            0.000000e+00          2.0               0.000112
# 97    0.003877            0.000000e+00          2.0               0.000112
# 132   0.003877            1.340788e+05          2.0               0.000447
# 151   0.003877            0.000000e+00          2.0               0.000112
# 152   0.003877            0.000000e+00          2.0               0.000112
# 161   0.003877            1.538537e+05          1.0               0.001564
# 172   0.003877            1.819404e+04          2.0               0.000335
# 178   0.003877            0.000000e+00          2.0               0.000112
#
#      in_degree_centrality  polygon                   id community
# 3                0.000000        1             16422863       NDP
# 6                0.000000        1             18597273       NDP
# 7                0.000000        1             20346252       NDP
# 22               0.000000        1             58340767   Liberal
# 24               0.000000        1             67758676       NDP
# 31               0.000000        1            116837959       NDP
# 63               0.005026        3            577727470       NDP
# 67               0.000000        1            596787864   Liberal
# 80               0.000000        1           1223950760   Liberal
# 91               0.000000        1           1650588223       NDP
# 94               0.000000        1           2262304373   Liberal
# 96               0.000000        1           2367303485       NDP
# 97               0.000000        1           2394842400       NDP
# 132              0.000000        1   753744536887824385       NDP
# 151              0.000000        1  1005823371144318977       NDP
# 152              0.000000        1  1024397417423106048       NDP
# 161              0.000000        1  1115838887623122954   Liberal
# 172              0.000000        1  1346317368637603841       NDP
# 178              0.000000        1  1378038493105037320       NDP

# %% [markdown]
# https://stackoverflow.com/questions/44327999/python-pandas-merge-multiple-dataframes

# %%
data_frames = [lib, con, ndp, bloc, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)

# %%
df_merged
# Out:
# Empty DataFrame
# Columns: [lib_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, con_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, ndp_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, bloc_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, Id, lgbt_exp2_average_activation_time, Unnamed: 0, Source Comm Interaction Count, Target Comm Interaction Count, Label, timeset, twittername, first name, last name, political affiliation, influence, betweenness_centrality, communityid, out_degree_centrality, in_degree_centrality, polygon, id, community]
# Index: []
#
# [0 rows x 91 columns]

# %%
data_frames = [lib, con, ndp, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# Columns: [Id, lib_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, con_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, ndp_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, lgbt_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y]
# Index: []
#
# [0 rows x 73 columns]

# %%
data_frames = [lib, con, ndp, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# Columns: [Id, lib_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, con_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, ndp_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, bloc_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y]
# Index: []
#
# [0 rows x 73 columns]

# %%
data_frames = [lib, lgbt, ndp, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#           Id  lib_exp2_average_activation_time  Unnamed: 0_x  \
# 0  596787864                               1.0             5
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              4.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0        NaN           NaN          NaN         NaN  ...         NaN
#
#    political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                      NaN     0.003877              1.321371e+06
#
#    communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# 0            1.0                 0.001899                     0.0          1
#
#         id_y  community_y
# 0  596787864      Liberal
#
# [1 rows x 73 columns]

# %%
data_frames = [lib, con, lgbt, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# Columns: [Id, lib_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, con_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, lgbt_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, bloc_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y]
# Index: []
#
# [0 rows x 73 columns]

# %%
data_frames = [ndp, con, lgbt, bloc]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# Columns: [ndp_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, con_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, lgbt_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, Id, bloc_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y]
# Index: []
#
# [0 rows x 73 columns]

# %%
data_frames = [lib, ndp, con]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  lib_exp2_average_activation_time  Unnamed: 0_x  \
# 0  1415746394871189504                               1.0          2554
# 1  1446352422272528385                               2.0           167
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              2.0                              NaN      NaN
# 1                              2.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name  \
# 0        NaN           NaN          NaN         NaN  ...       NaN
# 1        NaN           NaN          NaN         NaN  ...       NaN
#
#    political affiliation  influence  betweenness_centrality  communityid  \
# 0                    NaN   0.003877            1.118865e+05          2.0
# 1                    NaN   0.003877            3.781095e+06          1.0
#
#    out_degree_centrality  in_degree_centrality  polygon                   id  \
# 0               0.000558                   0.0        1  1415746394871189504
# 1               0.005696                   0.0        1  1446352422272528385
#
#    community
# 0        NDP
# 1    Liberal
#
# [2 rows x 55 columns]

# %%
data_frames = [bloc, con]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                      Id  bloc_exp2_average_activation_time  Unnamed: 0_x  \
# 0              86425142                                1.0          6770
# 1              92821882                                1.0          6989
# 2             135000298                                1.0          6748
# 3             313250205                                1.0          7410
# 4             491606159                                1.0          6988
# 5             733289617                                1.0          6992
# 6            2275886439                                1.0          4573
# 7            2801095093                                2.0          6990
# 8    896911058459340800                                2.0          6994
# 9   1009785173011988480                                2.0          6993
# 10  1090055713462865925                                2.0          6774
# 11  1100840274136363009                                1.0          6991
# 12  1171742672614113282                                1.0          6416
# 13  1279885961841819649                                2.0          7411
# 14  1319082870498091008                                1.0          6773
# 15  1384365976922181637                                1.0          3224
#
#     Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                               1.0                              NaN      NaN
# 1                               1.0                              NaN      NaN
# 2                               1.0                              NaN      NaN
# 3                               1.0                              NaN      NaN
# 4                               1.0                              NaN      NaN
# 5                               1.0                              NaN      NaN
# 6                               2.0                              NaN      NaN
# 7                               1.0                              NaN      NaN
# 8                               1.0                              NaN      NaN
# 9                               1.0                              NaN      NaN
# 10                              1.0                              NaN      NaN
# 11                              1.0                              NaN      NaN
# 12                              1.0                              NaN      NaN
# 13                              1.0                              NaN      NaN
# 14                              1.0                              NaN      NaN
# 15                              2.0                              NaN      NaN
#
#     timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0         NaN           NaN          NaN         NaN  ...         NaN
# 1         NaN           NaN          NaN         NaN  ...         NaN
# 2         NaN           NaN          NaN         NaN  ...         NaN
# 3         NaN           NaN          NaN         NaN  ...         NaN
# 4         NaN           NaN          NaN         NaN  ...         NaN
# 5         NaN           NaN          NaN         NaN  ...         NaN
# 6         NaN           NaN          NaN         NaN  ...         NaN
# 7         NaN           NaN          NaN         NaN  ...         NaN
# 8         NaN           NaN          NaN         NaN  ...         NaN
# 9         NaN           NaN          NaN         NaN  ...         NaN
# 10        NaN           NaN          NaN         NaN  ...         NaN
# 11        NaN           NaN          NaN         NaN  ...         NaN
# 12        NaN           NaN          NaN         NaN  ...         NaN
# 13        NaN           NaN          NaN         NaN  ...         NaN
# 14        NaN           NaN          NaN         NaN  ...         NaN
# 15        NaN           NaN          NaN         NaN  ...         NaN
#
#     political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                       NaN     0.003877              27069.112035
# 1                       NaN     0.003877             117924.615839
# 2                       NaN     0.003877              11482.692839
# 3                       NaN     0.003877              59809.868456
# 4                       NaN     0.003877               3974.793111
# 5                       NaN     0.003877              21427.487731
# 6                       NaN     0.003877              19200.293649
# 7                       NaN     0.003877             168429.238892
# 8                       NaN     0.003877              92429.712325
# 9                       NaN     0.003877             177177.711251
# 10                      NaN     0.003877              60837.337424
# 11                      NaN     0.003877              55972.193105
# 12                      NaN     0.003877              13806.008781
# 13                      NaN     0.003877             129098.159799
# 14                      NaN     0.003877              11106.678084
# 15                      NaN     0.003877              88676.276989
#
#     communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# 0             3.0                 0.000558                     0.0          1
# 1             4.0                 0.001564                     0.0          1
# 2             3.0                 0.000335                     0.0          1
# 3             4.0                 0.000558                     0.0          1
# 4             4.0                 0.000223                     0.0          1
# 5             4.0                 0.000223                     0.0          1
# 6             4.0                 0.000447                     0.0          1
# 7             4.0                 0.002346                     0.0          1
# 8             4.0                 0.001117                     0.0          1
# 9             4.0                 0.002234                     0.0          1
# 10            4.0                 0.001005                     0.0          1
# 11            4.0                 0.000558                     0.0          1
# 12            3.0                 0.000335                     0.0          1
# 13            4.0                 0.001452                     0.0          1
# 14            4.0                 0.000447                     0.0          1
# 15            3.0                 0.000447                     0.0          1
#
#                    id_y     community_y
# 0              86425142    Conservative
# 1              92821882  Bloc Québécois
# 2             135000298    Conservative
# 3             313250205  Bloc Québécois
# 4             491606159  Bloc Québécois
# 5             733289617  Bloc Québécois
# 6            2275886439  Bloc Québécois
# 7            2801095093  Bloc Québécois
# 8    896911058459340800  Bloc Québécois
# 9   1009785173011988480  Bloc Québécois
# 10  1090055713462865925  Bloc Québécois
# 11  1100840274136363009  Bloc Québécois
# 12  1171742672614113282    Conservative
# 13  1279885961841819649  Bloc Québécois
# 14  1319082870498091008  Bloc Québécois
# 15  1384365976922181637    Conservative
#
# [16 rows x 37 columns]

# %%
data_frames = [lib, ndp, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#            Id  lib_exp2_average_activation_time  Unnamed: 0_x  \
# 0   596787864                               1.0             5
# 1  2262304373                               1.0           142
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              4.0                              NaN      NaN
# 1                              2.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name  \
# 0        NaN           NaN          NaN         NaN  ...       NaN
# 1        NaN           NaN          NaN         NaN  ...       NaN
#
#    political affiliation  influence  betweenness_centrality  communityid  \
# 0                    NaN   0.003877            1.321371e+06          1.0
# 1                    NaN   0.003877            2.091874e+05          1.0
#
#    out_degree_centrality  in_degree_centrality  polygon          id  community
# 0               0.001899                   0.0        1   596787864    Liberal
# 1               0.000447                   0.0        1  2262304373    Liberal
#
# [2 rows x 55 columns]

# %%
data_frames = [lib, ndp]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                      Id  lib_exp2_average_activation_time  Unnamed: 0_x  \
# 0              12034642                               2.0          2374
# 1              14837621                               2.0           202
# 2              16213179                               1.0          1239
# 3              17280115                               1.0          2214
# 4              20750271                               2.0          1058
# ..                  ...                               ...           ...
# 65  1348675178318893056                               1.0          1742
# 66  1380278410736439302                               1.0          1294
# 67  1415746394871189504                               1.0          2554
# 68  1443532517164785664                               1.0          2536
# 69  1446352422272528385                               2.0           167
#
#     Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                               3.0                              NaN      NaN
# 1                               1.0                              NaN      NaN
# 2                               2.0                              NaN      NaN
# 3                               0.0                              NaN      NaN
# 4                               1.0                              NaN      NaN
# ..                              ...                              ...      ...
# 65                              1.0                              NaN      NaN
# 66                              1.0                              NaN      NaN
# 67                              2.0                              NaN      NaN
# 68                              1.0                              NaN      NaN
# 69                              2.0                              NaN      NaN
#
#     timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0         NaN           NaN          NaN         NaN  ...         NaN
# 1         NaN           NaN          NaN         NaN  ...         NaN
# 2         NaN           NaN          NaN         NaN  ...         NaN
# 3         NaN           NaN          NaN         NaN  ...         NaN
# 4         NaN           NaN          NaN         NaN  ...         NaN
# ..        ...           ...          ...         ...  ...         ...
# 65        NaN           NaN          NaN         NaN  ...         NaN
# 66        NaN           NaN          NaN         NaN  ...         NaN
# 67        NaN           NaN          NaN         NaN  ...         NaN
# 68        NaN           NaN          NaN         NaN  ...         NaN
# 69        NaN           NaN          NaN         NaN  ...         NaN
#
#     political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                       NaN     0.003877              2.101758e+05
# 1                       NaN     0.003877              3.288252e+05
# 2                       NaN     0.003877              2.325127e+05
# 3                       NaN     0.003877              0.000000e+00
# 4                       NaN     0.003877              5.551586e+04
# ..                      ...          ...                       ...
# 65                      NaN     0.003877              2.284513e+04
# 66                      NaN     0.003877              2.754767e+04
# 67                      NaN     0.003877              1.118865e+05
# 68                      NaN     0.003877              2.031412e+04
# 69                      NaN     0.003877              3.781095e+06
#
#     communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# 0             3.0                 0.001005                     0.0          1
# 1             1.0                 0.001564                     0.0          1
# 2             1.0                 0.000447                     0.0          1
# 3             1.0                 0.000112                     0.0          1
# 4             2.0                 0.000335                     0.0          1
# ..            ...                      ...                     ...        ...
# 65            1.0                 0.000447                     0.0          1
# 66            1.0                 0.000447                     0.0          1
# 67            2.0                 0.000558                     0.0          1
# 68            2.0                 0.000223                     0.0          1
# 69            1.0                 0.005696                     0.0          1
#
#                    id_y   community_y
# 0              12034642  Conservative
# 1              14837621       Liberal
# 2              16213179       Liberal
# 3              17280115       Liberal
# 4              20750271           NDP
# ..                  ...           ...
# 65  1348675178318893056       Liberal
# 66  1380278410736439302       Liberal
# 67  1415746394871189504           NDP
# 68  1443532517164785664           NDP
# 69  1446352422272528385       Liberal
#
# [70 rows x 37 columns]

# %%
data_frames = [lib, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  lib_exp2_average_activation_time  Unnamed: 0_x  \
# 0             58340767                               1.0            85
# 1            596787864                               1.0             5
# 2           1223950760                               1.0             4
# 3           2262304373                               1.0           142
# 4           2727310657                               1.0          3427
# 5  1115838887623122954                               2.0           660
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              1.0                              NaN      NaN
# 1                              4.0                              NaN      NaN
# 2                              1.0                              NaN      NaN
# 3                              2.0                              NaN      NaN
# 4                              2.0                              NaN      NaN
# 5                              1.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0        NaN           NaN          NaN         NaN  ...         NaN
# 1        NaN           NaN          NaN         NaN  ...         NaN
# 2        NaN           NaN          NaN         NaN  ...         NaN
# 3        NaN           NaN          NaN         NaN  ...         NaN
# 4        NaN           NaN          NaN         NaN  ...         NaN
# 5        NaN           NaN          NaN         NaN  ...         NaN
#
#    political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                      NaN     0.003877              7.338912e+04
# 1                      NaN     0.003877              1.321371e+06
# 2                      NaN     0.003877              1.266123e+06
# 3                      NaN     0.003877              2.091874e+05
# 4                      NaN     0.003877              1.281911e+05
# 5                      NaN     0.003877              1.538537e+05
#
#    communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# 0            1.0                 0.000894                     0.0          1
# 1            1.0                 0.001899                     0.0          1
# 2            1.0                 0.007148                     0.0          1
# 3            1.0                 0.000447                     0.0          1
# 4            5.0                 0.000335                     0.0          1
# 5            1.0                 0.001564                     0.0          1
#
#                   id_y  community_y
# 0             58340767      Liberal
# 1            596787864      Liberal
# 2           1223950760      Liberal
# 3           2262304373      Liberal
# 4           2727310657     LGBTQ2S+
# 5  1115838887623122954      Liberal
#
# [6 rows x 37 columns]

# %%
data_frames = [ndp, lgbt]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                     Id  ndp_exp2_average_activation_time  Unnamed: 0_x  \
# 0             16422863                               1.0          4354
# 1             20346252                               1.0          4323
# 2            596787864                               2.0             5
# 3           2262304373                               1.0           142
# 4   824357739501531136                               1.0          4443
# 5  1117035592565628928                               1.0          4127
# 6  1286102971974025217                               1.0          4128
# 7  1346317368637603841                               1.0          4228
#
#    Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                              0.0                              NaN      NaN
# 1                              0.0                              NaN      NaN
# 2                              4.0                              NaN      NaN
# 3                              2.0                              NaN      NaN
# 4                              1.0                              NaN      NaN
# 5                              1.0                              NaN      NaN
# 6                              1.0                              NaN      NaN
# 7                              0.0                              NaN      NaN
#
#    timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0        NaN           NaN          NaN         NaN  ...         NaN
# 1        NaN           NaN          NaN         NaN  ...         NaN
# 2        NaN           NaN          NaN         NaN  ...         NaN
# 3        NaN           NaN          NaN         NaN  ...         NaN
# 4        NaN           NaN          NaN         NaN  ...         NaN
# 5        NaN           NaN          NaN         NaN  ...         NaN
# 6        NaN           NaN          NaN         NaN  ...         NaN
# 7        NaN           NaN          NaN         NaN  ...         NaN
#
#    political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                      NaN     0.003877              5.696908e+04
# 1                      NaN     0.003877              1.507022e+04
# 2                      NaN     0.003877              1.321371e+06
# 3                      NaN     0.003877              2.091874e+05
# 4                      NaN     0.003877              1.891271e+05
# 5                      NaN     0.003877              4.257638e+04
# 6                      NaN     0.003877              4.257638e+04
# 7                      NaN     0.003877              1.819404e+04
#
#    communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# 0            2.0                 0.000782                     0.0          1
# 1            2.0                 0.000223                     0.0          1
# 2            1.0                 0.001899                     0.0          1
# 3            1.0                 0.000447                     0.0          1
# 4            5.0                 0.000335                     0.0          1
# 5            5.0                 0.000335                     0.0          1
# 6            5.0                 0.000335                     0.0          1
# 7            2.0                 0.000335                     0.0          1
#
#                   id_y  community_y
# 0             16422863          NDP
# 1             20346252          NDP
# 2            596787864      Liberal
# 3           2262304373      Liberal
# 4   824357739501531136     LGBTQ2S+
# 5  1117035592565628928     LGBTQ2S+
# 6  1286102971974025217     LGBTQ2S+
# 7  1346317368637603841          NDP
#
# [8 rows x 37 columns]

# %%
data_frames = [con, lib]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
#                      Id  con_exp2_average_activation_time  Unnamed: 0_x  \
# 0              17954186                               2.0          2108
# 1              25397132                               1.0          2111
# 2              28395319                               2.0          1376
# 3              47371589                               1.0            82
# 4              97751783                               1.0          2075
# 5             124851971                               1.0          1972
# 6             246825072                               1.0          2996
# 7             279679549                               2.0          2389
# 8            1052848710                               1.0          2048
# 9            1939332804                               1.0          1949
# 10           2198725662                               1.0          1025
# 11           2263235551                               1.0          1377
# 12           2321539819                               1.0           221
# 13           2727310657                               1.0          3427
# 14           2942980610                               1.0          2895
# 15           3362989235                               1.0          2783
# 16   711980580813066240                               1.0          2538
# 17   712039917493342209                               1.0          2110
# 18   733429965333520390                               2.0          1952
# 19   788747576598069248                               1.0          2611
# 20   807818269319000064                               2.0          2107
# 21   823933874551959552                               2.0          1375
# 22  1095260188716777472                               1.0          3072
# 23  1303704709123969024                               1.0            14
# 24  1304621913231286272                               1.0          1953
# 25  1360345646826483717                               1.0           154
# 26  1408148208442908673                               2.0          2784
# 27  1415746394871189504                               2.0          2554
# 28  1446352422272528385                               2.0           167
#
#     Source Comm Interaction Count_x  Target Comm Interaction Count_x  Label_x  \
# 0                               1.0                              NaN      NaN
# 1                               1.0                              NaN      NaN
# 2                               1.0                              NaN      NaN
# 3                               1.0                              NaN      NaN
# 4                               1.0                              NaN      NaN
# 5                               1.0                              NaN      NaN
# 6                               1.0                              NaN      NaN
# 7                               1.0                              NaN      NaN
# 8                               1.0                              NaN      NaN
# 9                               1.0                              NaN      NaN
# 10                              1.0                              NaN      NaN
# 11                              1.0                              NaN      NaN
# 12                              2.0                              NaN      NaN
# 13                              2.0                              NaN      NaN
# 14                              1.0                              NaN      NaN
# 15                              1.0                              NaN      NaN
# 16                              3.0                              NaN      NaN
# 17                              1.0                              NaN      NaN
# 18                              1.0                              NaN      NaN
# 19                              1.0                              NaN      NaN
# 20                              1.0                              NaN      NaN
# 21                              1.0                              NaN      NaN
# 22                              1.0                              NaN      NaN
# 23                              1.0                              NaN      NaN
# 24                              1.0                              NaN      NaN
# 25                              1.0                              NaN      NaN
# 26                              1.0                              NaN      NaN
# 27                              2.0                              NaN      NaN
# 28                              2.0                              NaN      NaN
#
#     timeset_x twittername_x first name_x last name_x  ... last name_y  \
# 0         NaN           NaN          NaN         NaN  ...         NaN
# 1         NaN           NaN          NaN         NaN  ...         NaN
# 2         NaN           NaN          NaN         NaN  ...         NaN
# 3         NaN           NaN          NaN         NaN  ...         NaN
# 4         NaN           NaN          NaN         NaN  ...         NaN
# 5         NaN           NaN          NaN         NaN  ...         NaN
# 6         NaN           NaN          NaN         NaN  ...         NaN
# 7         NaN           NaN          NaN         NaN  ...         NaN
# 8         NaN           NaN          NaN         NaN  ...         NaN
# 9         NaN           NaN          NaN         NaN  ...         NaN
# 10        NaN           NaN          NaN         NaN  ...         NaN
# 11        NaN           NaN          NaN         NaN  ...         NaN
# 12        NaN           NaN          NaN         NaN  ...         NaN
# 13        NaN           NaN          NaN         NaN  ...         NaN
# 14        NaN           NaN          NaN         NaN  ...         NaN
# 15        NaN           NaN          NaN         NaN  ...         NaN
# 16        NaN           NaN          NaN         NaN  ...         NaN
# 17        NaN           NaN          NaN         NaN  ...         NaN
# 18        NaN           NaN          NaN         NaN  ...         NaN
# 19        NaN           NaN          NaN         NaN  ...         NaN
# 20        NaN           NaN          NaN         NaN  ...         NaN
# 21        NaN           NaN          NaN         NaN  ...         NaN
# 22        NaN           NaN          NaN         NaN  ...         NaN
# 23        NaN           NaN          NaN         NaN  ...         NaN
# 24        NaN           NaN          NaN         NaN  ...         NaN
# 25        NaN           NaN          NaN         NaN  ...         NaN
# 26        NaN           NaN          NaN         NaN  ...         NaN
# 27        NaN           NaN          NaN         NaN  ...         NaN
# 28        NaN           NaN          NaN         NaN  ...         NaN
#
#     political affiliation_y  influence_y  betweenness_centrality_y  \
# 0                       NaN     0.003877              2.086332e+04
# 1                       NaN     0.003877              2.358163e+04
# 2                       NaN     0.003877              9.641230e+04
# 3                       NaN     0.003877              1.460051e+05
# 4                       NaN     0.003877              2.943397e+04
# 5                       NaN     0.003877              2.992196e+04
# 6                       NaN     0.003877              3.888605e+04
# 7                       NaN     0.003877              7.937442e+04
# 8                       NaN     0.003877              2.699479e+04
# 9                       NaN     0.003877              7.738851e+04
# 10                      NaN     0.003877              9.273671e+04
# 11                      NaN     0.003877              1.059081e+05
# 12                      NaN     0.003877              1.147502e+05
# 13                      NaN     0.003877              1.281911e+05
# 14                      NaN     0.003877              1.697184e+04
# 15                      NaN     0.003877              2.263017e+04
# 16                      NaN     0.003877              7.366229e+05
# 17                      NaN     0.003877              2.718318e+03
# 18                      NaN     0.003877              4.034752e+05
# 19                      NaN     0.003877              2.300678e+04
# 20                      NaN     0.003877              1.508502e+04
# 21                      NaN     0.003877              1.953440e+04
# 22                      NaN     0.003877              9.532123e+03
# 23                      NaN     0.003877              2.164853e+06
# 24                      NaN     0.003877              2.119797e+05
# 25                      NaN     0.003877              4.090774e+05
# 26                      NaN     0.003877              6.128763e+04
# 27                      NaN     0.003877              1.118865e+05
# 28                      NaN     0.003877              3.781095e+06
#
#     communityid_y  out_degree_centrality_y  in_degree_centrality_y  polygon_y  \
# 0             3.0                 0.000223                     0.0          1
# 1             3.0                 0.000335                     0.0          1
# 2             3.0                 0.000447                     0.0          1
# 3             1.0                 0.000558                     0.0          1
# 4             1.0                 0.000335                     0.0          1
# 5             1.0                 0.000447                     0.0          1
# 6             3.0                 0.000223                     0.0          1
# 7             3.0                 0.000558                     0.0          1
# 8             3.0                 0.000335                     0.0          1
# 9             1.0                 0.000335                     0.0          1
# 10            1.0                 0.001340                     0.0          1
# 11            3.0                 0.000558                     0.0          1
# 12            1.0                 0.000447                     0.0          1
# 13            5.0                 0.000335                     0.0          1
# 14            3.0                 0.000223                     0.0          1
# 15            3.0                 0.000223                     0.0          1
# 16            2.0                 0.000782                     0.0          1
# 17            3.0                 0.000223                     0.0          1
# 18            3.0                 0.001899                     0.0          1
# 19            3.0                 0.000558                     0.0          1
# 20            3.0                 0.000223                     0.0          1
# 21            3.0                 0.000447                     0.0          1
# 22            3.0                 0.000223                     0.0          1
# 23            1.0                 0.006367                     0.0          1
# 24            3.0                 0.000670                     0.0          1
# 25            1.0                 0.001564                     0.0          1
# 26            3.0                 0.000223                     0.0          1
# 27            2.0                 0.000558                     0.0          1
# 28            1.0                 0.005696                     0.0          1
#
#                    id_y   community_y
# 0              17954186  Conservative
# 1              25397132  Conservative
# 2              28395319  Conservative
# 3              47371589       Liberal
# 4              97751783       Liberal
# 5             124851971       Liberal
# 6             246825072  Conservative
# 7             279679549  Conservative
# 8            1052848710  Conservative
# 9            1939332804       Liberal
# 10           2198725662       Liberal
# 11           2263235551  Conservative
# 12           2321539819       Liberal
# 13           2727310657      LGBTQ2S+
# 14           2942980610  Conservative
# 15           3362989235  Conservative
# 16   711980580813066240           NDP
# 17   712039917493342209  Conservative
# 18   733429965333520390  Conservative
# 19   788747576598069248  Conservative
# 20   807818269319000064  Conservative
# 21   823933874551959552  Conservative
# 22  1095260188716777472  Conservative
# 23  1303704709123969024       Liberal
# 24  1304621913231286272  Conservative
# 25  1360345646826483717       Liberal
# 26  1408148208442908673  Conservative
# 27  1415746394871189504           NDP
# 28  1446352422272528385       Liberal
#
# [29 rows x 37 columns]

# %%
data_frames = [bloc, lgbt, con, ndp]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Id'],
                                            how='inner'), data_frames)
df_merged
# Out:
# Empty DataFrame
# Columns: [bloc_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, lgbt_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y, con_exp2_average_activation_time, Unnamed: 0_x, Source Comm Interaction Count_x, Target Comm Interaction Count_x, Label_x, timeset_x, twittername_x, first name_x, last name_x, political affiliation_x, influence_x, betweenness_centrality_x, communityid_x, out_degree_centrality_x, in_degree_centrality_x, polygon_x, id_x, community_x, Id, ndp_exp2_average_activation_time, Unnamed: 0_y, Source Comm Interaction Count_y, Target Comm Interaction Count_y, Label_y, timeset_y, twittername_y, first name_y, last name_y, political affiliation_y, influence_y, betweenness_centrality_y, communityid_y, out_degree_centrality_y, in_degree_centrality_y, polygon_y, id_y, community_y]
# Index: []
#
# [0 rows x 73 columns]

# %%
lib
# Out:
#                        Id  lib_exp2_average_activation_time  Unnamed: 0  \
# 0                 1263631                               1.0        3398
# 1                 5548282                               1.0         712
# 2                 7801522                               1.0        3328
# 3                 9898272                               1.0        2923
# 4                 9946272                               2.0         339
# ...                   ...                               ...         ...
# 2697  1445901048951017472                               1.0        3513
# 2698  1445905244500676608                               1.0         677
# 2699  1446352422272528385                               2.0         167
# 2700  1447502440820002819                               1.0        2397
# 2701  1449405859772047365                               1.0        3320
#
#       Source Comm Interaction Count  Target Comm Interaction Count  Label  \
# 0                               0.0                            NaN    NaN
# 1                               0.0                            NaN    NaN
# 2                               0.0                            NaN    NaN
# 3                               0.0                            NaN    NaN
# 4                               0.0                            NaN    NaN
# ...                             ...                            ...    ...
# 2697                            0.0                            NaN    NaN
# 2698                            0.0                            NaN    NaN
# 2699                            2.0                            NaN    NaN
# 2700                            0.0                            NaN    NaN
# 2701                            0.0                            NaN    NaN
#
#       timeset twittername first name last name political affiliation  \
# 0         NaN         NaN        NaN       NaN                   NaN
# 1         NaN         NaN        NaN       NaN                   NaN
# 2         NaN         NaN        NaN       NaN                   NaN
# 3         NaN         NaN        NaN       NaN                   NaN
# 4         NaN         NaN        NaN       NaN                   NaN
# ...       ...         ...        ...       ...                   ...
# 2697      NaN         NaN        NaN       NaN                   NaN
# 2698      NaN         NaN        NaN       NaN                   NaN
# 2699      NaN         NaN        NaN       NaN                   NaN
# 2700      NaN         NaN        NaN       NaN                   NaN
# 2701      NaN         NaN        NaN       NaN                   NaN
#
#       influence  betweenness_centrality  communityid  out_degree_centrality  \
# 0      0.003877            0.000000e+00          1.0               0.000112
# 1      0.003877            0.000000e+00          1.0               0.000112
# 2      0.003877            0.000000e+00          1.0               0.000112
# 3      0.003877            6.999261e+02          1.0               0.000223
# 4      0.003877            0.000000e+00          1.0               0.000112
# ...         ...                     ...          ...                    ...
# 2697   0.003877            0.000000e+00          1.0               0.000112
# 2698   0.003877            0.000000e+00          1.0               0.000112
# 2699   0.003877            3.781095e+06          1.0               0.005696
# 2700   0.003877            1.373276e+02          1.0               0.000223
# 2701   0.003877            0.000000e+00          1.0               0.000112
#
#       in_degree_centrality  polygon                   id community
# 0                      0.0        1              1263631   Liberal
# 1                      0.0        1              5548282   Liberal
# 2                      0.0        1              7801522   Liberal
# 3                      0.0        1              9898272   Liberal
# 4                      0.0        1              9946272   Liberal
# ...                    ...      ...                  ...       ...
# 2697                   0.0        1  1445901048951017472   Liberal
# 2698                   0.0        1  1445905244500676608   Liberal
# 2699                   0.0        1  1446352422272528385   Liberal
# 2700                   0.0        1  1447502440820002819   Liberal
# 2701                   0.0        1  1449405859772047365   Liberal
#
# [2702 rows x 19 columns]

# %%
# %matplotlib inline

import venn

# %%
labels = get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20)], fill=['number', 'logic'])
fig, ax = venn5(labels, names=['list 1', 'list 2', 'list 3', 'list 4', 'list 5'])
fig.show()
# Out:
# c:\users\kaitlin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
labels = get_labels([lib['Id'].unique(), con['Id'].unique(), ndp['Id'].unique(), bloc['Id'].unique(), lgbt['Id'].unique()], fill=['number', 'logic'])
fig, ax = venn5(labels, names=['Liberal', 'Conservative', 'NDP', 'Bloc Quebecois', 'LGBTQ2S+'])
fig.show()
# Out:
# c:\users\kaitlin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# coding: utf-8
from itertools import chain
from collections import Iterable
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import colors
import math

default_colors = [
    # r, g, b, a
     [241, 90, 96, 0.4],
    [90, 155, 212, 0.5],
    [255, 165, 0, 0.6],
     [0, 255, 255, 0.5],
    [255, 0, 255, 0.2],
    [255, 117, 0, 0.3],
]
default_colors = [
    [i[0] / 255.0, i[1] / 255.0, i[2] / 255.0, i[3]]
    for i in default_colors
]

def draw_ellipse(fig, ax, x, y, w, h, a, fillcolor):
    e = patches.Ellipse(
        xy=(x, y),
        width=w,
        height=h,
        angle=a,
        color=fillcolor)
    ax.add_patch(e)

def draw_triangle(fig, ax, x1, y1, x2, y2, x3, y3, fillcolor):
    xy = [
        (x1, y1),
        (x2, y2),
        (x3, y3),
    ]
    polygon = patches.Polygon(
        xy=xy,
        closed=True,
        color=fillcolor)
    ax.add_patch(polygon)

def draw_text(fig, ax, x, y, text, color=[0, 0, 0, 1], fontsize=14, ha="center", va="center"):
    ax.text(
        x, y, text,
        horizontalalignment=ha,
        verticalalignment=va,
        fontsize=fontsize,
        color="black")

def draw_annotate(fig, ax, x, y, textx, texty, text, color=[0, 0, 0, 1], arrowcolor=[0, 0, 0, 0.3]):
    plt.annotate(
        text,
        xy=(x, y),
        xytext=(textx, texty),
        arrowprops=dict(color=arrowcolor, shrink=0, width=0.5, headwidth=8),
        fontsize=14,
        color=color,
        xycoords="data",
        textcoords="data",
        horizontalalignment='center',
        verticalalignment='center'
    )

def get_labels(data, fill=["number"]):
    """
    get a dict of labels for groups in data

    @type data: list[Iterable]
    @rtype: dict[str, str]

    input
      data: data to get label for
      fill: ["number"|"logic"|"percent"]

    return
      labels: a dict of labels for different sets

    example:
    In [12]: get_labels([range(10), range(5,15), range(3,8)], fill=["number"])
    Out[12]:
    {'001': '0',
     '010': '5',
     '011': '0',
     '100': '3',
     '101': '2',
     '110': '2',
     '111': '3'}
    """

    N = len(data)

    sets_data = [set(data[i]) for i in range(N)]  # sets for separate groups
    s_all = set(chain(*data))                     # union of all sets

    # bin(3) --> '0b11', so bin(3).split('0b')[-1] will remove "0b"
    set_collections = {}
    for n in range(1, 2**N):
        key = bin(n).split('0b')[-1].zfill(N)
        value = s_all
        sets_for_intersection = [sets_data[i] for i in range(N) if  key[i] == '1']
        sets_for_difference = [sets_data[i] for i in range(N) if  key[i] == '0']
        for s in sets_for_intersection:
            value = value & s
        for s in sets_for_difference:
            value = value - s
        set_collections[key] = value

    labels = {k: "" for k in set_collections}
    if "logic" in fill:
        for k in set_collections:
            labels[k] = k + ": "
    if "number" in fill:
        for k in set_collections:
            labels[k] += str(len(set_collections[k]))
    if "percent" in fill:
        data_size = len(s_all)
        for k in set_collections:
            labels[k] += "(%.1f%%)" % (100.0 * len(set_collections[k]) / data_size)

    return labels

def venn2(labels, names=['A', 'B'], **options):
    """
    plots a 2-set Venn diagram

    @type labels: dict[str, str]
    @type names: list[str]
    @rtype: (Figure, AxesSubplot)

    input
      labels: a label dict where keys are identified via binary codes ('01', '10', '11'),
              hence a valid set could look like: {'01': 'text 1', '10': 'text 2', '11': 'text 3'}.
              unmentioned codes are considered as ''.
      names:  group names
      more:   colors, figsize, dpi, fontsize

    return
      pyplot Figure and AxesSubplot object
    """
    colors = options.get('colors', [default_colors[i] for i in range(2)])
    figsize = options.get('figsize', (9, 7))
    dpi = options.get('dpi', 96)
    fontsize = options.get('fontsize', 14)

    fig = plt.figure(0, figsize=figsize, dpi=dpi)
    ax = fig.add_subplot(111, aspect='equal')
    ax.set_axis_off()
    ax.set_ylim(bottom=0.0, top=0.7)
    ax.set_xlim(left=0.0, right=1.0)

    # body
    draw_ellipse(fig, ax, 0.375, 0.3, 0.5, 0.5, 0.0, colors[0])
    draw_ellipse(fig, ax, 0.625, 0.3, 0.5, 0.5, 0.0, colors[1])
    draw_text(fig, ax, 0.74, 0.30, labels.get('01', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.26, 0.30, labels.get('10', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.50, 0.30, labels.get('11', ''), fontsize=fontsize)

    # legend
    draw_text(fig, ax, 0.20, 0.56, names[0], colors[0], fontsize=fontsize, ha="right", va="bottom")
    draw_text(fig, ax, 0.80, 0.56, names[1], colors[1], fontsize=fontsize, ha="left", va="bottom")
    leg = ax.legend(names, loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True)
    leg.get_frame().set_alpha(0.5)

    return fig, ax

def venn3(labels, names=['A', 'B', 'C'], **options):
    """
    plots a 3-set Venn diagram

    @type labels: dict[str, str]
    @type names: list[str]
    @rtype: (Figure, AxesSubplot)

    input
      labels: a label dict where keys are identified via binary codes ('001', '010', '100', ...),
              hence a valid set could look like: {'001': 'text 1', '010': 'text 2', '100': 'text 3', ...}.
              unmentioned codes are considered as ''.
      names:  group names
      more:   colors, figsize, dpi, fontsize

    return
      pyplot Figure and AxesSubplot object
    """
    colors = options.get('colors', [default_colors[i] for i in range(3)])
    figsize = options.get('figsize', (9, 9))
    dpi = options.get('dpi', 96)
    fontsize = options.get('fontsize', 14)

    fig = plt.figure(0, figsize=figsize, dpi=dpi)
    ax = fig.add_subplot(111, aspect='equal')
    ax.set_axis_off()
    ax.set_ylim(bottom=0.0, top=1.0)
    ax.set_xlim(left=0.0, right=1.0)

    # body
    draw_ellipse(fig, ax, 0.333, 0.633, 0.5, 0.5, 0.0, colors[0])
    draw_ellipse(fig, ax, 0.666, 0.633, 0.5, 0.5, 0.0, colors[1])
    draw_ellipse(fig, ax, 0.500, 0.310, 0.5, 0.5, 0.0, colors[2])
    draw_text(fig, ax, 0.50, 0.27, labels.get('001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.73, 0.65, labels.get('010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.61, 0.46, labels.get('011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.27, 0.65, labels.get('100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.39, 0.46, labels.get('101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.50, 0.65, labels.get('110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.50, 0.51, labels.get('111', ''), fontsize=fontsize)

    # legend
    draw_text(fig, ax, 0.15, 0.87, names[0], colors[0], fontsize=fontsize, ha="right", va="bottom")
    draw_text(fig, ax, 0.85, 0.87, names[1], colors[1], fontsize=fontsize, ha="left", va="bottom")
    draw_text(fig, ax, 0.50, 0.02, names[2], colors[2], fontsize=fontsize, va="top")
    leg = ax.legend(names, loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True)
    leg.get_frame().set_alpha(0.5)

    return fig, ax

def venn4(labels, names=['A', 'B', 'C', 'D'], **options):
    """
    plots a 4-set Venn diagram

    @type labels: dict[str, str]
    @type names: list[str]
    @rtype: (Figure, AxesSubplot)

    input
      labels: a label dict where keys are identified via binary codes ('0001', '0010', '0100', ...),
              hence a valid set could look like: {'0001': 'text 1', '0010': 'text 2', '0100': 'text 3', ...}.
              unmentioned codes are considered as ''.
      names:  group names
      more:   colors, figsize, dpi, fontsize

    return
      pyplot Figure and AxesSubplot object
    """
    colors = options.get('colors', [default_colors[i] for i in range(4)])
    figsize = options.get('figsize', (12, 12))
    dpi = options.get('dpi', 96)
    fontsize = options.get('fontsize', 14)

    fig = plt.figure(0, figsize=figsize, dpi=dpi)
    ax = fig.add_subplot(111, aspect='equal')
    ax.set_axis_off()
    ax.set_ylim(bottom=0.0, top=1.0)
    ax.set_xlim(left=0.0, right=1.0)

    # body
    draw_ellipse(fig, ax, 0.350, 0.400, 0.72, 0.45, 140.0, colors[0])
    draw_ellipse(fig, ax, 0.450, 0.500, 0.72, 0.45, 140.0, colors[1])
    draw_ellipse(fig, ax, 0.544, 0.500, 0.72, 0.45, 40.0, colors[2])
    draw_ellipse(fig, ax, 0.644, 0.400, 0.72, 0.45, 40.0, colors[3])
    draw_text(fig, ax, 0.85, 0.42, labels.get('0001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.68, 0.72, labels.get('0010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.77, 0.59, labels.get('0011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.32, 0.72, labels.get('0100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.71, 0.30, labels.get('0101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.50, 0.66, labels.get('0110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.65, 0.50, labels.get('0111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.14, 0.42, labels.get('1000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.50, 0.17, labels.get('1001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.29, 0.30, labels.get('1010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.39, 0.24, labels.get('1011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.23, 0.59, labels.get('1100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.61, 0.24, labels.get('1101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.35, 0.50, labels.get('1110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.50, 0.38, labels.get('1111', ''), fontsize=fontsize)

    # legend
    draw_text(fig, ax, 0.13, 0.18, names[0], colors[0], fontsize=fontsize, ha="right")
    draw_text(fig, ax, 0.18, 0.83, names[1], colors[1], fontsize=fontsize, ha="right", va="bottom")
    draw_text(fig, ax, 0.82, 0.83, names[2], colors[2], fontsize=fontsize, ha="left", va="bottom")
    draw_text(fig, ax, 0.87, 0.18, names[3], colors[3], fontsize=fontsize, ha="left", va="top")
    leg = ax.legend(names, loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True)
    leg.get_frame().set_alpha(0.5)

    return fig, ax

def venn5(labels, names=['A', 'B', 'C', 'D', 'E'], **options):
    """
    plots a 5-set Venn diagram

    @type labels: dict[str, str]
    @type names: list[str]
    @rtype: (Figure, AxesSubplot)

    input
      labels: a label dict where keys are identified via binary codes ('00001', '00010', '00100', ...),
              hence a valid set could look like: {'00001': 'text 1', '00010': 'text 2', '00100': 'text 3', ...}.
              unmentioned codes are considered as ''.
      names:  group names
      more:   colors, figsize, dpi, fontsize

    return
      pyplot Figure and AxesSubplot object
    """
    colors = options.get('colors', [default_colors[i] for i in range(5)])
    figsize = options.get('figsize', (13, 13))
    dpi = options.get('dpi', 96)
    fontsize = options.get('fontsize', 14)

    fig = plt.figure(0, figsize=figsize, dpi=dpi)
    ax = fig.add_subplot(111, aspect='equal')
    ax.set_axis_off()
    ax.set_ylim(bottom=0.0, top=1.0)
    ax.set_xlim(left=0.0, right=1.0)

    # body
    draw_ellipse(fig, ax, 0.428, 0.449, 0.87, 0.50, 155.0, colors[0])
    draw_ellipse(fig, ax, 0.469, 0.543, 0.87, 0.50, 82.0, colors[1])
    draw_ellipse(fig, ax, 0.558, 0.523, 0.87, 0.50, 10.0, colors[2])
    draw_ellipse(fig, ax, 0.578, 0.432, 0.87, 0.50, 118.0, colors[3])
    draw_ellipse(fig, ax, 0.489, 0.383, 0.87, 0.50, 46.0, colors[4])
    draw_text(fig, ax, 0.27, 0.11, labels.get('00001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.72, 0.11, labels.get('00010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.55, 0.13, labels.get('00011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.91, 0.58, labels.get('00100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.78, 0.64, labels.get('00101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.84, 0.41, labels.get('00110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.76, 0.55, labels.get('00111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.51, 0.90, labels.get('01000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.39, 0.15, labels.get('01001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.42, 0.78, labels.get('01010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.50, 0.15, labels.get('01011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.67, 0.76, labels.get('01100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.70, 0.71, labels.get('01101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.51, 0.74, labels.get('01110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.64, 0.67, labels.get('01111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.10, 0.61, labels.get('10000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.20, 0.31, labels.get('10001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.76, 0.25, labels.get('10010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.65, 0.23, labels.get('10011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.18, 0.50, labels.get('10100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.21, 0.37, labels.get('10101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.81, 0.37, labels.get('10110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.74, 0.40, labels.get('10111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.27, 0.70, labels.get('11000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.34, 0.25, labels.get('11001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.33, 0.72, labels.get('11010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.51, 0.22, labels.get('11011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.25, 0.58, labels.get('11100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.28, 0.39, labels.get('11101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.36, 0.66, labels.get('11110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.51, 0.47, labels.get('11111', ''), fontsize=fontsize)

    # legend
    draw_text(fig, ax, 0.02, 0.72, names[0], colors[0], fontsize=fontsize, ha="right")
    draw_text(fig, ax, 0.72, 0.94, names[1], colors[1], fontsize=fontsize, va="bottom")
    draw_text(fig, ax, 0.97, 0.74, names[2], colors[2], fontsize=fontsize, ha="left")
    draw_text(fig, ax, 0.88, 0.05, names[3], colors[3], fontsize=fontsize, ha="left")
    draw_text(fig, ax, 0.12, 0.05, names[4], colors[4], fontsize=fontsize, ha="right")
    leg = ax.legend(names, loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True)
    leg.get_frame().set_alpha(0.5)

    return fig, ax

def venn6(labels, names=['A', 'B', 'C', 'D', 'E'], **options):
    """
    plots a 6-set Venn diagram

    @type labels: dict[str, str]
    @type names: list[str]
    @rtype: (Figure, AxesSubplot)

    input
      labels: a label dict where keys are identified via binary codes ('000001', '000010', '000100', ...),
              hence a valid set could look like: {'000001': 'text 1', '000010': 'text 2', '000100': 'text 3', ...}.
              unmentioned codes are considered as ''.
      names:  group names
      more:   colors, figsize, dpi, fontsize

    return
      pyplot Figure and AxesSubplot object
    """
    colors = options.get('colors', [default_colors[i] for i in range(6)])
    figsize = options.get('figsize', (20, 20))
    dpi = options.get('dpi', 96)
    fontsize = options.get('fontsize', 14)

    fig = plt.figure(0, figsize=figsize, dpi=dpi)
    ax = fig.add_subplot(111, aspect='equal')
    ax.set_axis_off()
    ax.set_ylim(bottom=0.230, top=0.845)
    ax.set_xlim(left=0.173, right=0.788)

    # body
    # See https://web.archive.org/web/20040819232503/http://www.hpl.hp.com/techreports/2000/HPL-2000-73.pdf
    draw_triangle(fig, ax, 0.637, 0.921, 0.649, 0.274, 0.188, 0.667, colors[0])
    draw_triangle(fig, ax, 0.981, 0.769, 0.335, 0.191, 0.393, 0.671, colors[1])
    draw_triangle(fig, ax, 0.941, 0.397, 0.292, 0.475, 0.456, 0.747, colors[2])
    draw_triangle(fig, ax, 0.662, 0.119, 0.316, 0.548, 0.662, 0.700, colors[3])
    draw_triangle(fig, ax, 0.309, 0.081, 0.374, 0.718, 0.681, 0.488, colors[4])
    draw_triangle(fig, ax, 0.016, 0.626, 0.726, 0.687, 0.522, 0.327, colors[5])
    draw_text(fig, ax, 0.212, 0.562, labels.get('000001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.430, 0.249, labels.get('000010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.356, 0.444, labels.get('000011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.609, 0.255, labels.get('000100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.323, 0.546, labels.get('000101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.513, 0.316, labels.get('000110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.523, 0.348, labels.get('000111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.747, 0.458, labels.get('001000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.325, 0.492, labels.get('001001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.670, 0.481, labels.get('001010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.359, 0.478, labels.get('001011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.653, 0.444, labels.get('001100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.344, 0.526, labels.get('001101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.653, 0.466, labels.get('001110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.363, 0.503, labels.get('001111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.750, 0.616, labels.get('010000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.682, 0.654, labels.get('010001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.402, 0.310, labels.get('010010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.392, 0.421, labels.get('010011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.653, 0.691, labels.get('010100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.651, 0.644, labels.get('010101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.490, 0.340, labels.get('010110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.468, 0.399, labels.get('010111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.692, 0.545, labels.get('011000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.666, 0.592, labels.get('011001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.665, 0.496, labels.get('011010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.374, 0.470, labels.get('011011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.653, 0.537, labels.get('011100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.652, 0.579, labels.get('011101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.653, 0.488, labels.get('011110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.389, 0.486, labels.get('011111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.553, 0.806, labels.get('100000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.313, 0.604, labels.get('100001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.388, 0.694, labels.get('100010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.375, 0.633, labels.get('100011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.605, 0.359, labels.get('100100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.334, 0.555, labels.get('100101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.582, 0.397, labels.get('100110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.542, 0.372, labels.get('100111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.468, 0.708, labels.get('101000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.355, 0.572, labels.get('101001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.420, 0.679, labels.get('101010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.375, 0.597, labels.get('101011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.641, 0.436, labels.get('101100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.348, 0.538, labels.get('101101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.635, 0.453, labels.get('101110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.370, 0.548, labels.get('101111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.594, 0.689, labels.get('110000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.579, 0.670, labels.get('110001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.398, 0.670, labels.get('110010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.395, 0.653, labels.get('110011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.633, 0.682, labels.get('110100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.616, 0.656, labels.get('110101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.587, 0.427, labels.get('110110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.526, 0.415, labels.get('110111', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.495, 0.677, labels.get('111000', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.505, 0.648, labels.get('111001', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.428, 0.663, labels.get('111010', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.430, 0.631, labels.get('111011', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.639, 0.524, labels.get('111100', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.591, 0.604, labels.get('111101', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.622, 0.477, labels.get('111110', ''), fontsize=fontsize)
    draw_text(fig, ax, 0.501, 0.523, labels.get('111111', ''), fontsize=fontsize)

    # legend
    draw_text(fig, ax, 0.674, 0.824, names[0], colors[0], fontsize=fontsize)
    draw_text(fig, ax, 0.747, 0.751, names[1], colors[1], fontsize=fontsize)
    draw_text(fig, ax, 0.739, 0.396, names[2], colors[2], fontsize=fontsize)
    draw_text(fig, ax, 0.700, 0.247, names[3], colors[3], fontsize=fontsize)
    draw_text(fig, ax, 0.291, 0.255, names[4], colors[4], fontsize=fontsize)
    draw_text(fig, ax, 0.203, 0.484, names[5], colors[5], fontsize=fontsize)
    leg = ax.legend(names, loc='center left', bbox_to_anchor=(1.0, 0.5), fancybox=True)
    leg.get_frame().set_alpha(0.5)

    return fig, ax
