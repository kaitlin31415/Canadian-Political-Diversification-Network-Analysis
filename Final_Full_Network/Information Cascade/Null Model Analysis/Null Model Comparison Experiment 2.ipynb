# %% [markdown]
# # Null Model Comparison Experiment 1

# %%
import networkx as nx
import pandas as pd
import os
import random
from functools import reduce
import numpy as np

# %%
df = pd.read_csv('more_stuff/Directed_Weighted_Random_Null_Model_0_cascades.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  liberal_average_activation_time  \
# 0    14079041                              NaN
# 1    14538949                              NaN
# 2    15810950                              NaN
# 3    16014404                              NaN
# 4    17823761                              1.0
#
#    conservative_average_activation_time  ndp_average_activation_time  \
# 0                                   1.0                          0.0
# 1                                   NaN                          NaN
# 2                                   0.0                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    lgbt_average_activation_time  bloq_average_activation_time
# 0                           NaN                           NaN
# 1                           NaN                           1.0
# 2                           NaN                           NaN
# 3                           NaN                           0.0
# 4                           NaN                           NaN

# %%
df = df.set_index('Unnamed: 0')

# %%
df_lib = df[['liberal_average_activation_time']]
df_con = df[['conservative_average_activation_time']]
df_ndp = df[['ndp_average_activation_time']]
df_lgbt = df[['lgbt_average_activation_time']]
df_bloc = df[['bloq_average_activation_time']]

# %%
df_lib
# Out:
#                      liberal_average_activation_time
# Unnamed: 0
# 14079041                                         NaN
# 14538949                                         NaN
# 15810950                                         NaN
# 16014404                                         NaN
# 17823761                                         1.0
# ...                                              ...
# 1318671397560979456                              0.0
# 1342125115383939073                              1.0
# 1382336580518621186                              0.0
# 1382491059247255554                              1.0
# 1425866189780160514                              NaN
#
# [130 rows x 1 columns]

# %%
df_lib.rename(columns={"liberal_average_activation_time": "liberal_average_activation_time1"})
# Out:
#                      liberal_average_activation_time1
# Unnamed: 0
# 14079041                                          NaN
# 14538949                                          NaN
# 15810950                                          NaN
# 16014404                                          NaN
# 17823761                                          1.0
# ...                                               ...
# 1318671397560979456                               0.0
# 1342125115383939073                               1.0
# 1382336580518621186                               0.0
# 1382491059247255554                               1.0
# 1425866189780160514                               NaN
#
# [130 rows x 1 columns]

# %%
dirname="more_stuff"
directory = os.fsencode(dirname)
i =2
for file in os.listdir(directory):
    i = i +1
    filename = os.fsdecode(file)
    
    df = pd.read_csv(dirname+"/"+filename)
    df = df.set_index('Unnamed: 0')
    df_lib_1 = df[['liberal_average_activation_time']]
    df_lib_1 = df_lib_1.rename(columns={"liberal_average_activation_time": "liberal_average_activation_time{}".format(i)})
    df_con_1 = df[['conservative_average_activation_time']]
    df_con_1 = df_con_1.rename(columns={"conservative_average_activation_time": "conservative_average_activation_time{}".format(i)})
    df_ndp_1 = df[['ndp_average_activation_time']]
    df_ndp_1 = df_ndp_1.rename(columns={"ndp_average_activation_time": "ndp_average_activation_time{}".format(i)})
    df_lgbt_1 = df[['lgbt_average_activation_time']]
    df_lgbt_1 = df_lgbt_1.rename(columns={"lgbt_average_activation_time": "lgbt_average_activation_time{}".format(i)})
    df_bloc_1 = df[['bloq_average_activation_time']]
    df_bloc_1 = df_bloc_1.rename(columns={"bloq_average_activation_time": "bloq_average_activation_time{}".format(i)})
    
    #Perform an outer join on each df with their corresponding df
    
    df_lib = pd.merge(df_lib, df_lib_1, how="outer", right_index=True, left_index=True)
    df_con = pd.merge(df_con, df_con_1, how="outer", right_index=True, left_index=True)
    df_ndp = pd.merge(df_ndp, df_ndp_1, how="outer", right_index=True, left_index=True)
    df_lgbt = pd.merge(df_lgbt, df_lgbt_1, how="outer", right_index=True, left_index=True)
    df_bloc = pd.merge(df_bloc, df_bloc_1, how="outer", right_index=True, left_index=True)

# %%
df_lib.describe()
# Out:
#        liberal_average_activation_time  liberal_average_activation_time3  \
# count                        86.000000                         86.000000
# mean                          0.453488                          0.453488
# std                           0.545721                          0.545721
# min                           0.000000                          0.000000
# 25%                           0.000000                          0.000000
# 50%                           0.000000                          0.000000
# 75%                           1.000000                          1.000000
# max                           2.000000                          2.000000
#
#        liberal_average_activation_time4  liberal_average_activation_time5  \
# count                         94.000000                         83.000000
# mean                           0.510638                          0.457831
# std                            0.563107                          0.590601
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            1.000000                          1.000000
# max                            2.000000                          2.000000
#
#        liberal_average_activation_time6  liberal_average_activation_time7  \
# count                         84.000000                         86.000000
# mean                           0.440476                          0.500000
# std                            0.545545                          0.627788
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            1.000000                          1.000000
# max                            2.000000                          2.000000
#
#        liberal_average_activation_time8  liberal_average_activation_time9  \
# count                         83.000000                         87.000000
# mean                           0.421687                          0.459770
# std                            0.520799                          0.545693
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            1.000000                          1.000000
# max                            2.000000                          2.000000
#
#        liberal_average_activation_time10  liberal_average_activation_time11  \
# count                          89.000000                          85.000000
# mean                            0.483146                           0.458824
# std                             0.566335                           0.568057
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             1.000000                           1.000000
# max                             2.000000                           2.000000
#
#        ...  liberal_average_activation_time993  \
# count  ...                           85.000000
# mean   ...                            0.458824
# std    ...                            0.568057
# min    ...                            0.000000
# 25%    ...                            0.000000
# 50%    ...                            0.000000
# 75%    ...                            1.000000
# max    ...                            2.000000
#
#        liberal_average_activation_time994  liberal_average_activation_time995  \
# count                           80.000000                           84.000000
# mean                             0.400000                            0.464286
# std                              0.518029                            0.590006
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              1.000000                            1.000000
# max                              2.000000                            2.000000
#
#        liberal_average_activation_time996  liberal_average_activation_time997  \
# count                           86.000000                           92.000000
# mean                             0.476744                            0.532609
# std                              0.608310                            0.619306
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              1.000000                            1.000000
# max                              3.000000                            2.000000
#
#        liberal_average_activation_time998  liberal_average_activation_time999  \
# count                           93.000000                           84.000000
# mean                             0.505376                            0.464286
# std                              0.563831                            0.590006
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              1.000000                            1.000000
# max                              2.000000                            2.000000
#
#        liberal_average_activation_time1000  \
# count                            85.000000
# mean                              0.435294
# std                               0.522062
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               2.000000
#
#        liberal_average_activation_time1001  \
# count                            86.000000
# mean                              0.465116
# std                               0.567713
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               2.000000
#
#        liberal_average_activation_time1002
# count                            80.000000
# mean                              0.437500
# std                               0.592009
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               2.000000
#
# [8 rows x 1001 columns]

# %% [markdown]
# ## Take an average of the count of each column

# %% [markdown]
# Calculate the average number of nodes in a cascade

# %%
def count_nodes_per_cascade(df):
    lst = []
    for column in df:
        lst.append(df[column].count())
    return lst


def avg_nodes_per_cascade(df):
    count = 0;
    i
    for column in df:
        i=i+1
        count = count + df[column].count()
    return count / i

# %%
lib_count = np.array(count_nodes_per_cascade(df_lib))

# %%
lib_count
# Out:
# array([86, 86, 94, ..., 85, 86, 80])

# %%
def generate_stats(df):
    counts = np.array(count_nodes_per_cascade(df))
    print("Average Number of Nodes Activated: {}".format(np.average(counts)))
    print("Standard Deviation of Number of Nodes Activated: {}".format(np.std(counts)))
    print("Maximum Time Activated: {}".format(max(df.max())))

# %%
generate_stats(df_lib)
print("------------------")
generate_stats(df_con)
print("------------------")
generate_stats(df_ndp)
print("------------------")
generate_stats(df_lgbt)
print("------------------")
generate_stats(df_bloc)
# Out:
# Average Number of Nodes Activated: 86.94005994005994
# Standard Deviation of Number of Nodes Activated: 3.7582282151416124
# Maximum Time Activated: 3.0
# ------------------
# Average Number of Nodes Activated: 31.085914085914087
# Standard Deviation of Number of Nodes Activated: 2.268802310622656
# Maximum Time Activated: 3.0
# ------------------
# Average Number of Nodes Activated: 16.723276723276722
# Standard Deviation of Number of Nodes Activated: 1.5594600785563708
# Maximum Time Activated: 3.0
# ------------------
# Average Number of Nodes Activated: 3.230769230769231
# Standard Deviation of Number of Nodes Activated: 0.6109983540923855
# Maximum Time Activated: 3.0
# ------------------
# Average Number of Nodes Activated: 33.93206793206793
# Standard Deviation of Number of Nodes Activated: 2.524877346281766
# Maximum Time Activated: 4.0
