# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

import math
import os

# %matplotlib inline

# %%
G = nx.read_edgelist('largest_component_networkx_format.csv', comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=',', 
                     nodetype=int, 
                     encoding='utf-8')

# %%
N = len(G)
L = G.size()
degrees = [G.degree(node) for node in G]
kmin = min(degrees)
kmax = max(degrees)

in_degree = [G.in_degree(node) for node in G]
out_degree = [G.out_degree(node) for node in G]

kmin_in = min(in_degree)
kmax_in = max(in_degree)

kmin_out = min(out_degree)
kmax_out = max(out_degree)

# %%
print("Number of nodes: ", N)
print("Number of edges: ", L)
print()
print("Average degree: ", 2*L/N)
print("Average degree (alternate calculation)", np.mean(degrees))
print()
print("Minimum degree: ", kmin)
print("Maximum degree: ", kmax)

print("Average in-degree ", np.mean(in_degree))
print()
print("Minimum in-degree: ", kmin_in)
print("Maximum in-degree: ", kmax_in)

print("Average out-degree ", np.mean(out_degree))
print()
print("Minimum out-degree: ", kmin_out)
print("Maximum out-degree: ", kmax_out)
# Out:
# Number of nodes:  8932
# Number of edges:  14001
#
# Average degree:  3.1350201522615317
# Average degree (alternate calculation) 3.1350201522615317
#
# Minimum degree:  1
# Maximum degree:  381
# Average in-degree  1.5675100761307659
#
# Minimum in-degree:  0
# Maximum in-degree:  378
# Average out-degree  1.5675100761307659
#
# Minimum out-degree:  0
# Maximum out-degree:  105

# %%
degrees = {}
in_degrees = {}
out_degrees = {}

dirname = "Directed_Unweighted_Models/done"
directory = os.fsencode(dirname)

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    H = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    degree_dist = {}
    in_degree_dist = {}
    out_degree_dist = {}
    
    for node in H:
        degree_dist[node] = H.degree(node)
        in_degree_dist[node] = H.in_degree(node)
        out_degree_dist[node] = H.out_degree(node)
    degrees[filename] = degree_dist
    in_degrees[filename] = in_degree_dist
    out_degrees[filename] = out_degree_dist
# Out:
# Directed_Unweighted_Random_Null_Model_0
# Directed_Unweighted_Random_Null_Model_1
# Directed_Unweighted_Random_Null_Model_10
# Directed_Unweighted_Random_Null_Model_11
# Directed_Unweighted_Random_Null_Model_12
# Directed_Unweighted_Random_Null_Model_13
# Directed_Unweighted_Random_Null_Model_14
# Directed_Unweighted_Random_Null_Model_15
# Directed_Unweighted_Random_Null_Model_16
# Directed_Unweighted_Random_Null_Model_17
# Directed_Unweighted_Random_Null_Model_18
# Directed_Unweighted_Random_Null_Model_19
# Directed_Unweighted_Random_Null_Model_2
# Directed_Unweighted_Random_Null_Model_20
# Directed_Unweighted_Random_Null_Model_21
# Directed_Unweighted_Random_Null_Model_22
# Directed_Unweighted_Random_Null_Model_23
# Directed_Unweighted_Random_Null_Model_24
# Directed_Unweighted_Random_Null_Model_25
# Directed_Unweighted_Random_Null_Model_26
# Directed_Unweighted_Random_Null_Model_27
# Directed_Unweighted_Random_Null_Model_28
# Directed_Unweighted_Random_Null_Model_29
# Directed_Unweighted_Random_Null_Model_3
# Directed_Unweighted_Random_Null_Model_30
# Directed_Unweighted_Random_Null_Model_31
# Directed_Unweighted_Random_Null_Model_32
# Directed_Unweighted_Random_Null_Model_33
# Directed_Unweighted_Random_Null_Model_34
# Directed_Unweighted_Random_Null_Model_35
# Directed_Unweighted_Random_Null_Model_36
# Directed_Unweighted_Random_Null_Model_37
# Directed_Unweighted_Random_Null_Model_38
# Directed_Unweighted_Random_Null_Model_39
# Directed_Unweighted_Random_Null_Model_4
# Directed_Unweighted_Random_Null_Model_40
# Directed_Unweighted_Random_Null_Model_5
# Directed_Unweighted_Random_Null_Model_6
# Directed_Unweighted_Random_Null_Model_7
# Directed_Unweighted_Random_Null_Model_8
# Directed_Unweighted_Random_Null_Model_9

# %% [markdown]
# Go through each degree node in G and for each of the models check if some degree is different. If it is stop and report it

# %%
for node in G:
    print("Inspecting node {}".format(node))
    expectedDeg = G.degree(node) 
    for key, value in degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break
# Out:
# Inspecting node 1385933370090209280
# Inspecting node 158095776
# Inspecting node 1416535505454338050
# Inspecting node 1604931252
# Inspecting node 544695802
# Inspecting node 716257068538327040
# Inspecting node 258170457
# Inspecting node 1086084557009575936
# Inspecting node 2817389862
# Inspecting node 822476228548403200
# Inspecting node 2353730881
# Inspecting node 921026239808208896
# Inspecting node 720934098223542272
# Inspecting node 2922779039
# Inspecting node 552891173
# Inspecting node 982496635
# Inspecting node 1433403537329819654
# Inspecting node 1175052073605353473
# Inspecting node 2784661153
# Inspecting node 102887506
# Inspecting node 18681111
# Inspecting node 952980338745147394
# Inspecting node 1438871779779530755
# Inspecting node 46975259
# Inspecting node 1157395568135557120
# Inspecting node 21951711
# Inspecting node 563064119
# Inspecting node 277332906
# Inspecting node 158458133
# Inspecting node 979827806023618560
# Inspecting node 18308257
# Inspecting node 846667915
# Inspecting node 258916078
# Inspecting node 1138564320390836224
# Inspecting node 17912334
# Inspecting node 2821464243
# Inspecting node 928790819145842688
# Inspecting node 753638148958216192
# Inspecting node 2256955027
# Inspecting node 1185936230393024512
# Inspecting node 14079041
# Inspecting node 3021899490
# Inspecting node 13880132
# Inspecting node 960624707820113920
# Inspecting node 52003137
# Inspecting node 1887595058
# Inspecting node 331864347
# Inspecting node 961514730
# Inspecting node 70750793
# Inspecting node 155629527
# Inspecting node 1161351506983038976
# Inspecting node 766360387
# Inspecting node 150270263
# Inspecting node 38471212
# Inspecting node 83153695
# Inspecting node 118937966
# Inspecting node 871189841186357248
# Inspecting node 293403080
# Inspecting node 629539554
# Inspecting node 1104422828
# Inspecting node 602083976
# Inspecting node 1311896805920043009
# Inspecting node 1318741345905922048
# Inspecting node 25314619
# Inspecting node 104300984
# Inspecting node 15702055
# Inspecting node 1153463878195589125
# Inspecting node 15633240
# Inspecting node 14991184
# Inspecting node 1242522201770856449
# Inspecting node 1440522413687521295
# Inspecting node 106524304
# Inspecting node 1292608204845834241
# Inspecting node 1446846657551683588
# Inspecting node 1389700907697270787
# Inspecting node 1445880242707570691
# Inspecting node 1545912997
# Inspecting node 831084798621782016
# Inspecting node 55976571
# Inspecting node 305401065
# Inspecting node 704798725747531776
# Inspecting node 47452040
# Inspecting node 475298690
# Inspecting node 16220555
# Inspecting node 4744498950
# Inspecting node 766759351973404672
# Inspecting node 47781573
# Inspecting node 994077337
# Inspecting node 14055736
# Inspecting node 1236010900693356549
# Inspecting node 1171683272
# Inspecting node 1338338931792756737
# Inspecting node 562243642
# Inspecting node 15772683
# Inspecting node 1251340447387172868
# Inspecting node 1350484767255519233
# Inspecting node 1335046616697372675
# Inspecting node 20750271
# Inspecting node 1162219997977960449
# Inspecting node 175259033
# Inspecting node 130909683
# Inspecting node 1364261390614106113
# Inspecting node 44416854
# Inspecting node 1511003670
# Inspecting node 536594609
# Inspecting node 24913022
# Inspecting node 17823761
# Inspecting node 273683993
# Inspecting node 215632349
# Inspecting node 1156602559378804741
# Inspecting node 1156033982586208256
# Inspecting node 47338701
# Inspecting node 139819609
# Inspecting node 413514250
# Inspecting node 2852899113
# Inspecting node 1381435843492085760
# Inspecting node 1189800120
# Inspecting node 138418077
# Inspecting node 382489139
# Inspecting node 374300583
# Inspecting node 3226840807
# Inspecting node 133863908
# Inspecting node 57127265
# Inspecting node 142731825
# Inspecting node 1417929933800751104
# Inspecting node 55823004
# Inspecting node 1447315781289750532
# Inspecting node 14262411
# Inspecting node 1707636642
# Inspecting node 845487573011173380
# Inspecting node 109144163
# Inspecting node 20199202
# Inspecting node 785448020628430849
# Inspecting node 77283552
# Inspecting node 38055290
# Inspecting node 34506336
# Inspecting node 242798024
# Inspecting node 138077463
# Inspecting node 121343164
# Inspecting node 814078628
# Inspecting node 196717787
# Inspecting node 18519855
# Inspecting node 268824309
# Inspecting node 2439928526
# Inspecting node 1169378542737661954
# Inspecting node 299228245
# Inspecting node 2369365718
# Inspecting node 1373493122
# Inspecting node 2834753506
# Inspecting node 999476893970763777
# Inspecting node 120320139
# Inspecting node 84734389
# Inspecting node 15407637
# Inspecting node 1899063048
# Inspecting node 1301967293849755653
# Inspecting node 324602007
# Inspecting node 292667439
# Inspecting node 522345885
# Inspecting node 12599562
# Inspecting node 4856851754
# Inspecting node 1248842158553141250
# Inspecting node 4026045455
# Inspecting node 3303438653
# Inspecting node 1129203001
# Inspecting node 2813664079
# Inspecting node 14518712
# Inspecting node 95209129
# Inspecting node 119797208
# Inspecting node 201984482
# Inspecting node 593944500
# Inspecting node 17105128
# Inspecting node 3409346380
# Inspecting node 33826892
# Inspecting node 273866823
# Inspecting node 37552089
# Inspecting node 377588094
# Inspecting node 266855812
# Inspecting node 341866567
# Inspecting node 60916234
# Inspecting node 262436837
# Inspecting node 1092244447184719873
# Inspecting node 2548489298
# Inspecting node 218952640
# Inspecting node 1382491059247255554
# Inspecting node 516915897
# Inspecting node 965028316460797953
# Inspecting node 195899568
# Inspecting node 2432750568
# Inspecting node 331067472
# Inspecting node 272133230
# Inspecting node 108413104
# Inspecting node 177347829
# Inspecting node 964446120402300928
# Inspecting node 1573418346
# Inspecting node 89496127
# Inspecting node 735508941258399744
# Inspecting node 542244178
# Inspecting node 1005899772916477952
# Inspecting node 366171300
# Inspecting node 29545977
# Inspecting node 59686058
# Inspecting node 965478102594863104
# Inspecting node 366225624
# Inspecting node 393713239
# Inspecting node 1185972487538040832
# Inspecting node 889661863100907520
# Inspecting node 2813399220
# Inspecting node 2436061363
# Inspecting node 17900758
# Inspecting node 23491400
# Inspecting node 382949896
# Inspecting node 1009115210546929664
# Inspecting node 3148281878
# Inspecting node 1064964294448750595
# Inspecting node 814289414
# Inspecting node 2896012540
# Inspecting node 1280589273335500801
# Inspecting node 1227766472921014272
# Inspecting node 869639001400942592
# Inspecting node 116679707
# Inspecting node 342176065
# Inspecting node 1890389540
# Inspecting node 2785990732
# Inspecting node 40591485
# Inspecting node 3191905064
# Inspecting node 25813888
# Inspecting node 237536271
# Inspecting node 16982577
# Inspecting node 1563418116
# Inspecting node 2580573206
# Inspecting node 275979196
# Inspecting node 193471925
# Inspecting node 53772503
# Inspecting node 16195103
# Inspecting node 2776775090
# Inspecting node 998590102573023232
# Inspecting node 179129165
# Inspecting node 27101995
# Inspecting node 872156101
# Inspecting node 128908662
# Inspecting node 363070453
# Inspecting node 211564038
# Inspecting node 189349553
# Inspecting node 25127782
# Inspecting node 1166717268975333376
# Inspecting node 40550119
# Inspecting node 417389780
# Inspecting node 61521038
# Inspecting node 85428184
# Inspecting node 58319221
# Inspecting node 52080359
# Inspecting node 2513973205
# Inspecting node 283226685
# Inspecting node 45848808
# Inspecting node 1646334073
# Inspecting node 1360838234
# Inspecting node 21221149
# Inspecting node 507802048
# Inspecting node 190231473
# Inspecting node 993705834470367232
# Inspecting node 360677740
# Inspecting node 1362286033
# Inspecting node 3079986094
# Inspecting node 268528986
# Inspecting node 321752222
# Inspecting node 17280115
# Inspecting node 274220538
# Inspecting node 2352629420
# Inspecting node 51184630
# Inspecting node 908811901
# Inspecting node 408526152
# Inspecting node 371447080
# Inspecting node 2314531026
# Inspecting node 1172199939243425792
# Inspecting node 390392773
# Inspecting node 2289973748
# Inspecting node 495066576
# Inspecting node 1545053600
# Inspecting node 1318671397560979456
# Inspecting node 2891740872
# Inspecting node 2848993491
# Inspecting node 103297393
# Inspecting node 1851634098
# Inspecting node 398483708
# Inspecting node 1313212802799206406
# Inspecting node 79260190
# Inspecting node 27652488
# Inspecting node 89609585
# Inspecting node 44618408
# Inspecting node 880491635896922112
# Inspecting node 2761710808
# Inspecting node 1240867313445830656
# Inspecting node 247412217
# Inspecting node 1347654502787076096
# Inspecting node 982630470008553474
# Inspecting node 82167100
# Inspecting node 110754237
# Inspecting node 768069259100622848
# Inspecting node 1304210384367349770
# Inspecting node 1300291239581892609
# Inspecting node 2253903906
# Inspecting node 78403337
# Inspecting node 862703683
# Inspecting node 1071951545212723200
# Inspecting node 840470152391016448
# Inspecting node 498423001
# Inspecting node 1197522605760303104
# Inspecting node 510093784
# Inspecting node 447415943
# Inspecting node 1201788959719936007
# Inspecting node 1633538270
# Inspecting node 122525211
# Inspecting node 192842634
# Inspecting node 551152504
# Inspecting node 378351271
# Inspecting node 57033548
# Inspecting node 255067647
# Inspecting node 35863342
# Inspecting node 2715275551
# Inspecting node 719557076599619584
# Inspecting node 980875592
# Inspecting node 1051100859831148544
# Inspecting node 2300474413
# Inspecting node 1238447220
# Inspecting node 994295935
# Inspecting node 838098877
# Inspecting node 829761553218072576
# Inspecting node 951280545421410305
# Inspecting node 1157684886
# Inspecting node 80970676
# Inspecting node 18923250
# Inspecting node 1136294664
# Inspecting node 951892305098788864
# Inspecting node 3010143902
# Inspecting node 297020666
# Inspecting node 1045793762063060992
# Inspecting node 98588419
# Inspecting node 76179144
# Inspecting node 46956207
# Inspecting node 819853925184638976
# Inspecting node 16552108
# Inspecting node 29754743
# Inspecting node 153515520
# Inspecting node 386330680
# Inspecting node 2736446758
# Inspecting node 35095520
# Inspecting node 1239564608941113347
# Inspecting node 58261480
# Inspecting node 169614697
# Inspecting node 1005522675761057792
# Inspecting node 816308397360508928
# Inspecting node 1407160205117435908
# Inspecting node 1175457080561537025
# Inspecting node 1011936943247101952
# Inspecting node 365078935
# Inspecting node 17540009
# Inspecting node 49660950
# Inspecting node 296549487
# Inspecting node 1228605451
# Inspecting node 1122706063466356737
# Inspecting node 234593598
# Inspecting node 1204301854433316866
# Inspecting node 1204430581410353154
# Inspecting node 893202244077854721
# Inspecting node 22971125
# Inspecting node 1193458951976869888
# Inspecting node 785853390
# Inspecting node 322106815
# Inspecting node 1957597519
# Inspecting node 1101092779378249729
# Inspecting node 3331826578
# Inspecting node 38720614
# Inspecting node 2912843536
# Inspecting node 183642459
# Inspecting node 2247495353
# Inspecting node 2748289416
# Inspecting node 2592210108
# Inspecting node 103701079
# Inspecting node 1352713370772770816
# Inspecting node 86410896
# Inspecting node 1038301598
# Inspecting node 1134248217472843787
# Inspecting node 999320625117196288
# Inspecting node 18390213
# Inspecting node 768295011007934469
# Inspecting node 1262878353431777280
# Inspecting node 729232479840800768
# Inspecting node 1415442622135603206
# Inspecting node 346123223
# Inspecting node 167912183
# Inspecting node 1076249609125675010
# Inspecting node 67793897
# Inspecting node 823096488
# Inspecting node 50154666
# Inspecting node 302593437
# Inspecting node 291862583
# Inspecting node 168371680
# Inspecting node 1251332171211644931
# Inspecting node 962073414
# Inspecting node 291523600
# Inspecting node 277085673
# Inspecting node 62664213
# Inspecting node 1337551744457469952
# Inspecting node 716460064039575552
# Inspecting node 3007815702
# Inspecting node 55819705
# Inspecting node 1404102585317986308
# Inspecting node 1280249212567818240
# Inspecting node 740981264740679681
# Inspecting node 247511435
# Inspecting node 1303772129847111681
# Inspecting node 1027307702047961088
# Inspecting node 1020156666204090368
# Inspecting node 38751529
# Inspecting node 718873385346797569
# Inspecting node 285806588
# Inspecting node 541129316
# Inspecting node 1655457050
# Inspecting node 57759275
# Inspecting node 824281652423753728
# Inspecting node 132015712
# Inspecting node 40647043
# Inspecting node 12992772
# Inspecting node 365132365
# Inspecting node 1129088815
# Inspecting node 1262268501823303680
# Inspecting node 288548798
# Inspecting node 87632735
# Inspecting node 40246161
# Inspecting node 1252686295
# Inspecting node 25333228
# Inspecting node 1093876945
# Inspecting node 205786669
# Inspecting node 1942350667
# Inspecting node 2863551224
# Inspecting node 720083863830069249
# Inspecting node 176207343
# Inspecting node 412708728
# Inspecting node 414218319
# Inspecting node 1271987860577517568
# Inspecting node 626984632
# Inspecting node 237594523
# Inspecting node 714340176
# Inspecting node 300638343
# Inspecting node 739845530612830208
# Inspecting node 715244769
# Inspecting node 817207955930001409
# Inspecting node 1363561650624733184
# Inspecting node 212468225
# Inspecting node 2673432539
# Inspecting node 23601374
# Inspecting node 51852542
# Inspecting node 321482430
# Inspecting node 1058965681671028736
# Inspecting node 35617919
# Inspecting node 371288369
# Inspecting node 4492249646
# Inspecting node 396106258
# Inspecting node 2287331581
# Inspecting node 150671052
# Inspecting node 3302256527
# Inspecting node 3269322830
# Inspecting node 1364751078659477504
# Inspecting node 168123931
# Inspecting node 1072189285
# Inspecting node 45976740
# Inspecting node 1435257575482740741
# Inspecting node 1099109729308008448
# Inspecting node 1366925295291424768
# Inspecting node 1356073687691141121
# Inspecting node 1580475270
# Inspecting node 1442893993935716361
# Inspecting node 392132054
# Inspecting node 207703739
# Inspecting node 1419489038747070467
# Inspecting node 928451444633563136
# Inspecting node 1119464753318043649
# Inspecting node 1440690378533838857
# Inspecting node 2931943245
# Inspecting node 1727398412
# Inspecting node 1444061901172854786
# Inspecting node 2938869339
# Inspecting node 1243723946660421637
# Inspecting node 2476755039
# Inspecting node 1331773252792770560
# Inspecting node 901618905076174848
# Inspecting node 339780511
# Inspecting node 980817985668550656
# Inspecting node 53694666
# Inspecting node 1445437990940004352
# Inspecting node 1243574020802367488
# Inspecting node 1055536236
# Inspecting node 68670486
# Inspecting node 451989089
# Inspecting node 1077731978
# Inspecting node 1271115442573185024
# Inspecting node 969744550955749383
# Inspecting node 26577630
# Inspecting node 1391981080945643523
# Inspecting node 46232947
# Inspecting node 266048357
# Inspecting node 293745266
# Inspecting node 415532452
# Inspecting node 3107597132
# Inspecting node 1183316407104266241
# Inspecting node 982472677775454209
# Inspecting node 3295839203
# Inspecting node 880913594531139584
# Inspecting node 1911858061
# Inspecting node 1097694473952342022
# Inspecting node 1388650232100134915
# Inspecting node 14100537
# Inspecting node 820656479812227073
# Inspecting node 1325249450793701376
# Inspecting node 1427996716138127360
# Inspecting node 1347691972358778885
# Inspecting node 1365678726
# Inspecting node 1295377965438644235
# Inspecting node 322090834
# Inspecting node 1342962255248424961
# Inspecting node 1195026680609292288
# Inspecting node 1116360718687690758
# Inspecting node 737359208945844224
# Inspecting node 3375064758
# Inspecting node 14538949
# Inspecting node 1084856644687679496
# Inspecting node 36133644
# Inspecting node 976345683681619968
# Inspecting node 366785595
# Inspecting node 2849064914
# Inspecting node 343059330
# Inspecting node 64123717
# Inspecting node 18420573
# Inspecting node 957106791753555968
# Inspecting node 751054068974575616
# Inspecting node 1186136760981454854
# Inspecting node 854065048683204615
# Inspecting node 317823907
# Inspecting node 952759886
# Inspecting node 474883984
# Inspecting node 1258133514421239813
# Inspecting node 2198792101
# Inspecting node 324555383
# Inspecting node 744660163873771520
# Inspecting node 726025903
# Inspecting node 1263514760584167424
# Inspecting node 714569357267853312
# Inspecting node 739149720
# Inspecting node 1136772811656126464
# Inspecting node 270307297
# Inspecting node 454774863
# Inspecting node 772948513
# Inspecting node 3333795492
# Inspecting node 2209473078
# Inspecting node 838196271571591168
# Inspecting node 18386792
# Inspecting node 1166799265806503936
# Inspecting node 262522708
# Inspecting node 1370402422062002179
# Inspecting node 1429982282891239433
# Inspecting node 1434265814325202944
# Inspecting node 1087134051914395648
# Inspecting node 791076864
# Inspecting node 121949981
# Inspecting node 256360738
# Inspecting node 1172475064870027264
# Inspecting node 1443468994107822081
# Inspecting node 941115769429024769
# Inspecting node 1313732971061362690
# Inspecting node 2305422800
# Inspecting node 242885214
# Inspecting node 1354230346586447877
# Inspecting node 469747759
# Inspecting node 432114850
# Inspecting node 1166000110586626048
# Inspecting node 884527637569323009
# Inspecting node 369653658
# Inspecting node 1434643524495020043
# Inspecting node 75984040
# Inspecting node 586195164
# Inspecting node 2902344555
# Inspecting node 564257648
# Inspecting node 1027229536902098944
# Inspecting node 2316626342
# Inspecting node 1925354744
# Inspecting node 958204773282533376
# Inspecting node 1445751022526160908
# Inspecting node 1183078912265355265
# Inspecting node 98767459
# Inspecting node 87297879
# Inspecting node 753394222267527168
# Inspecting node 373580557
# Inspecting node 1430260512688902150
# Inspecting node 2468436247
# Inspecting node 3308781515
# Inspecting node 2273880732
# Inspecting node 1302114263771668481
# Inspecting node 24181491
# Inspecting node 1309179346565898241
# Inspecting node 2231471516
# Inspecting node 1352351686778630145
# Inspecting node 1413321993470943237
# Inspecting node 603011131
# Inspecting node 1438876255202406406
# Inspecting node 1375883715776294914
# Inspecting node 1002002024
# Inspecting node 51384524
# Inspecting node 724114092672335874
# Inspecting node 552725069
# Inspecting node 1184298786329448448
# Inspecting node 334954251
# Inspecting node 101915304
# Inspecting node 1252767510983737344
# Inspecting node 1099811037975642112
# Inspecting node 1388988366247575559
# Inspecting node 1326022742286749696
# Inspecting node 1388801354244702209
# Inspecting node 961162177
# Inspecting node 1389555148318404610
# Inspecting node 1151641780267261952
# Inspecting node 27320189
# Inspecting node 1215379886887428096
# Inspecting node 1184882383
# Inspecting node 257699447
# Inspecting node 2397398196
# Inspecting node 807034969902252032
# Inspecting node 1353486048618274816
# Inspecting node 4866566489
# Inspecting node 3058888765
# Inspecting node 1173239638116446208
# Inspecting node 42894434
# Inspecting node 3078011282
# Inspecting node 32691118
# Inspecting node 544080126
# Inspecting node 1336660494
# Inspecting node 957190068594130946
# Inspecting node 1074149416699719681
# Inspecting node 825518936733085696
# Inspecting node 43199433
# Inspecting node 969376788525830146
# Inspecting node 35107179
# Inspecting node 366074756
# Inspecting node 359672860
# Inspecting node 82679357
# Inspecting node 883774859452579840
# Inspecting node 3418588623
# Inspecting node 710270422290403328
# Inspecting node 763168867371843584
# Inspecting node 1575198925
# Inspecting node 1301995158485958656
# Inspecting node 1260291453973983232
# Inspecting node 1601907697
# Inspecting node 29823611
# Inspecting node 1393039117110317058
# Inspecting node 236055343
# Inspecting node 320919057
# Inspecting node 2812908133
# Inspecting node 1325519307359490048
# Inspecting node 590735039
# Inspecting node 95577307
# Inspecting node 43948485
# Inspecting node 136332449
# Inspecting node 623936216
# Inspecting node 2873956499
# Inspecting node 4803873902
# Inspecting node 1147245556651233280
# Inspecting node 918919026344120321
# Inspecting node 37813045
# Inspecting node 24574252
# Inspecting node 1440809899500335110
# Inspecting node 1334205408110551042
# Inspecting node 1071298949837770753
# Inspecting node 915968072
# Inspecting node 885818088
# Inspecting node 227849419
# Inspecting node 2493753559
# Inspecting node 778842486
# Inspecting node 124839366
# Inspecting node 263750524
# Inspecting node 1357001901229899777
# Inspecting node 990301302264479749
# Inspecting node 1136065885456740352
# Inspecting node 1335377050878676992
# Inspecting node 138710067
# Inspecting node 1441961640459599874
# Inspecting node 2793008984
# Inspecting node 120187876
# Inspecting node 178544594
# Inspecting node 2838327755
# Inspecting node 1559780652
# Inspecting node 2291354802
# Inspecting node 1352707350784659456
# Inspecting node 1417352097150816256
# Inspecting node 1427768108614291465
# Inspecting node 1117485007944048640
# Inspecting node 1297264458
# Inspecting node 1194794785762004993
# Inspecting node 26089782
# Inspecting node 1446289055935864836
# Inspecting node 412499776
# Inspecting node 416476088
# Inspecting node 1028871362499305473
# Inspecting node 1438317451469541377
# Inspecting node 546527413
# Inspecting node 1323421765658431488
# Inspecting node 280677070
# Inspecting node 2332742508
# Inspecting node 1347272097786171394
# Inspecting node 2344419362
# Inspecting node 252150132
# Inspecting node 4787666543
# Inspecting node 1454456569
# Inspecting node 587733016
# Inspecting node 823265236916416512
# Inspecting node 1168589910825213952
# Inspecting node 753744536887824385
# Inspecting node 119925381
# Inspecting node 1269692602204532738
# Inspecting node 853722212741898240
# Inspecting node 43089397
# Inspecting node 2323751900
# Inspecting node 1213405462021853185
# Inspecting node 2937436849
# Inspecting node 272250877
# Inspecting node 1406573892
# Inspecting node 1942107584
# Inspecting node 2678072299
# Inspecting node 86384661
# Inspecting node 2983179809
# Inspecting node 3188558830
# Inspecting node 2874772780
# Inspecting node 222386937
# Inspecting node 261788602
# Inspecting node 292468351
# Inspecting node 22849568
# Inspecting node 1203545123356839936
# Inspecting node 19893907
# Inspecting node 1729880688
# Inspecting node 1361500715659755520
# Inspecting node 700287952
# Inspecting node 169268197
# Inspecting node 18622393
# Inspecting node 1304185921433227264
# Inspecting node 97121931
# Inspecting node 1699266222
# Inspecting node 729194378779078656
# Inspecting node 2752659114
# Inspecting node 373460084
# Inspecting node 908018227040710656
# Inspecting node 245149238
# Inspecting node 3242606862
# Inspecting node 29891001
# Inspecting node 720579941184757760
# Inspecting node 276713213
# Inspecting node 1424060815947206662
# Inspecting node 609432652
# Inspecting node 38625077
# Inspecting node 234550882
# Inspecting node 408072407
# Inspecting node 1427258589077508100
# Inspecting node 2242940071
# Inspecting node 44171755
# Inspecting node 41043869
# Inspecting node 436087744
# Inspecting node 578640179
# Inspecting node 132210296
# Inspecting node 923683393
# Inspecting node 1245003009555419137
# Inspecting node 1267504449087553539
# Inspecting node 65666257
# Inspecting node 407943040
# Inspecting node 240908125
# Inspecting node 1057988206963056640
# Inspecting node 130857133
# Inspecting node 1441410998355726344
# Inspecting node 24819740
# Inspecting node 1412813687811760135
# Inspecting node 2762829798
# Inspecting node 1317417438640697344
# Inspecting node 1185990712132812800
# Inspecting node 711980580813066240
# Inspecting node 3237884919
# Inspecting node 9455112
# Inspecting node 19198775
# Inspecting node 22630846
# Inspecting node 1434341584670273544
# Inspecting node 844292741077061632
# Inspecting node 1300624324206817280
# Inspecting node 1332164996592066561
# Inspecting node 337816824
# Inspecting node 153798495
# Inspecting node 1249204176548245504
# Inspecting node 3092462976
# Inspecting node 547671992
# Inspecting node 151547845
# Inspecting node 23554969
# Inspecting node 1314208704
# Inspecting node 808450734240972800
# Inspecting node 204846220
# Inspecting node 19478009
# Inspecting node 18940341
# Inspecting node 62292631
# Inspecting node 1239692519094575104
# Inspecting node 64261339
# Inspecting node 271989352
# Inspecting node 66334416
# Inspecting node 756584190112591872
# Inspecting node 24459228
# Inspecting node 771870952544096257
# Inspecting node 1242251887
# Inspecting node 15908286
# Inspecting node 1390840055200108546
# Inspecting node 2408260398
# Inspecting node 488067802
# Inspecting node 1511667030
# Inspecting node 579614622
# Inspecting node 728304522662043648
# Inspecting node 1092960066
# Inspecting node 64099329
# Inspecting node 1393055510480441345
# Inspecting node 2555583872
# Inspecting node 2452465303
# Inspecting node 282526718
# Inspecting node 4298769753
# Inspecting node 572827030
# Inspecting node 1414623993529880576
# Inspecting node 1255927911045095425
# Inspecting node 1373016955
# Inspecting node 2720800274
# Inspecting node 57661541
# Inspecting node 708739471
# Inspecting node 722623738672517120
# Inspecting node 157591483
# Inspecting node 1390378070482165763
# Inspecting node 2707780448
# Inspecting node 898554931271127042
# Inspecting node 525857359
# Inspecting node 2536457582
# Inspecting node 19634262
# Inspecting node 1357304889831878657
# Inspecting node 1243221104560345090
# Inspecting node 431141725
# Inspecting node 1244435052
# Inspecting node 159655782
# Inspecting node 382223500
# Inspecting node 535452718
# Inspecting node 1293199610178080775
# Inspecting node 12923812
# Inspecting node 16272844
# Inspecting node 335769776
# Inspecting node 16279532
# Inspecting node 3358671
# Inspecting node 16180205
# Inspecting node 2322580746
# Inspecting node 171115367
# Inspecting node 208750527
# Inspecting node 240786249
# Inspecting node 3257047456
# Inspecting node 500232993
# Inspecting node 1171073846335721472
# Inspecting node 1304472952482783232
# Inspecting node 1072270926
# Inspecting node 2789770741
# Inspecting node 2327530022
# Inspecting node 1002181382
# Inspecting node 47692251
# Inspecting node 743129088
# Inspecting node 271073165
# Inspecting node 1895316878
# Inspecting node 631988630
# Inspecting node 290162716
# Inspecting node 2229187188
# Inspecting node 274507495
# Inspecting node 417524720
# Inspecting node 415774799
# Inspecting node 579377522
# Inspecting node 32915303
# Inspecting node 245954929
# Inspecting node 170377354
# Inspecting node 1390883714
# Inspecting node 3363252329
# Inspecting node 1143342270399373313
# Inspecting node 272185225
# Inspecting node 1144289639924207616
# Inspecting node 43510607
# Inspecting node 524557553
# Inspecting node 256775505
# Inspecting node 493488747
# Inspecting node 868245382148521984
# Inspecting node 1170770038208565248
# Inspecting node 339752726
# Inspecting node 249221867
# Inspecting node 488052222
# Inspecting node 911471588
# Inspecting node 246466184
# Inspecting node 280552762
# Inspecting node 295951367
# Inspecting node 973087261
# Inspecting node 1321710295245447169
# Inspecting node 48369926
# Inspecting node 1438956476588957701
# Inspecting node 385008014
# Inspecting node 918152297544380417
# Inspecting node 33562561
# Inspecting node 987136895162384384
# Inspecting node 1327442450957303809
# Inspecting node 870473605473198080
# Inspecting node 35337644
# Inspecting node 1103832363363127297
# Inspecting node 1243323314652602368
# Inspecting node 1268045786312593408
# Inspecting node 17355421
# Inspecting node 24348660
# Inspecting node 14247924
# Inspecting node 106512310
# Inspecting node 1269254845615095810
# Inspecting node 1219578234
# Inspecting node 1380813355
# Inspecting node 883334379023597568
# Inspecting node 58878834
# Inspecting node 912346683291389953
# Inspecting node 3179475258
# Inspecting node 245939022
# Inspecting node 363654070
# Inspecting node 3071603495
# Inspecting node 573788425
# Inspecting node 878490462
# Inspecting node 1423385158263132168
# Inspecting node 1268728504964825088
# Inspecting node 46894332
# Inspecting node 136160953
# Inspecting node 107218304
# Inspecting node 73411833
# Inspecting node 1405971529217740812
# Inspecting node 1275123310788063233
# Inspecting node 1173035282461089793
# Inspecting node 1445090669643517961
# Inspecting node 1389241812276023296
# Inspecting node 501994958
# Inspecting node 2799175653
# Inspecting node 1429555219457773581
# Inspecting node 1668333199
# Inspecting node 1218019404992196609
# Inspecting node 1366204146957885445
# Inspecting node 1198972583288459265
# Inspecting node 1433247289330577408
# Inspecting node 502160853
# Inspecting node 41520537
# Inspecting node 1294478815628890112
# Inspecting node 395394840
# Inspecting node 1151704477
# Inspecting node 1044711566354960384
# Inspecting node 1271855851330916353
# Inspecting node 1497052201
# Inspecting node 975757898004549633
# Inspecting node 3245708989
# Inspecting node 1267640853000007680
# Inspecting node 29917096
# Inspecting node 245373521
# Inspecting node 1420482733135040522
# Inspecting node 1242510089145266182
# Inspecting node 28737527
# Inspecting node 1731401322
# Inspecting node 979870450577686528
# Inspecting node 1354922263418523648
# Inspecting node 24951781
# Inspecting node 15613754
# Inspecting node 100851235
# Inspecting node 59243738
# Inspecting node 17360968
# Inspecting node 360129945
# Inspecting node 1174006316412674048
# Inspecting node 21809306
# Inspecting node 1134558647835430912
# Inspecting node 855478711
# Inspecting node 25178951
# Inspecting node 52350953
# Inspecting node 20796969
# Inspecting node 55158039
# Inspecting node 1401659310015397889
# Inspecting node 215896862
# Inspecting node 4540976253
# Inspecting node 56016987
# Inspecting node 1357857933019598849
# Inspecting node 1125841354716696576
# Inspecting node 793343793642680320
# Inspecting node 48219360
# Inspecting node 399184212
# Inspecting node 827222807121637377
# Inspecting node 1138228267
# Inspecting node 1671821988
# Inspecting node 2321539819
# Inspecting node 17969963
# Inspecting node 1337935917298962434
# Inspecting node 1055170328442224641
# Inspecting node 325805788
# Inspecting node 1128406689802276865
# Inspecting node 1560811022
# Inspecting node 1264568784318345218
# Inspecting node 254240108
# Inspecting node 2237957942
# Inspecting node 387828045
# Inspecting node 3355188729
# Inspecting node 1483945802
# Inspecting node 1663608300
# Inspecting node 1335613030852386817
# Inspecting node 2678629590
# Inspecting node 884681534
# Inspecting node 420536762
# Inspecting node 4329525312
# Inspecting node 1547244656
# Inspecting node 109341612
# Inspecting node 108689047
# Inspecting node 1223265601147342848
# Inspecting node 297968019
# Inspecting node 183758895
# Inspecting node 45932749
# Inspecting node 418786259
# Inspecting node 70240459
# Inspecting node 1606592767
# Inspecting node 1047167241119326211
# Inspecting node 978673214283853825
# Inspecting node 17136419
# Inspecting node 1242152485
# Inspecting node 4445748801
# Inspecting node 1413908511461945350
# Inspecting node 1314819918328729600
# Inspecting node 1140532022
# Inspecting node 1200932043544117248
# Inspecting node 3109560272
# Inspecting node 162924629
# Inspecting node 182072629
# Inspecting node 980237238
# Inspecting node 1213189717425917953
# Inspecting node 2800741820
# Inspecting node 19135439
# Inspecting node 967241034873933824
# Inspecting node 3236492411
# Inspecting node 1235422076082589696
# Inspecting node 534591437
# Inspecting node 1454880680
# Inspecting node 1069754111078354948
# Inspecting node 2286750115
# Inspecting node 1375862610
# Inspecting node 26071396
# Inspecting node 375764669
# Inspecting node 1833674827
# Inspecting node 392380645
# Inspecting node 769165632738762752
# Inspecting node 989311745100566529
# Inspecting node 256552850
# Inspecting node 2218371769
# Inspecting node 29721598
# Inspecting node 1008103433822351360
# Inspecting node 1214027006242742273
# Inspecting node 142107502
# Inspecting node 1314568089300873216
# Inspecting node 801218452618956800
# Inspecting node 1330675961839443973
# Inspecting node 1441448795921952768
# Inspecting node 102491634
# Inspecting node 24978284
# Inspecting node 36988268
# Inspecting node 712792479729192960
# Inspecting node 890560416526594048
# Inspecting node 1413820603
# Inspecting node 37044121
# Inspecting node 832619717785329664
# Inspecting node 1171471512085389312
# Inspecting node 61542328
# Inspecting node 494320156
# Inspecting node 13716572
# Inspecting node 1017461230984990720
# Inspecting node 25703839
# Inspecting node 363666493
# Inspecting node 975491119734763522
# Inspecting node 61888526
# Inspecting node 2502596130
# Inspecting node 763867259777519618
# Inspecting node 1185294078256254977
# Inspecting node 1296424847149588483
# Inspecting node 2721515522
# Inspecting node 224600898
# Inspecting node 524785211
# Inspecting node 777617628009332736
# Inspecting node 189341190
# Inspecting node 2451955022
# Inspecting node 835061048533082113
# Inspecting node 248022226
# Inspecting node 2988258574
# Inspecting node 1001287095472873473
# Inspecting node 1182252711833718784
# Inspecting node 1861048644
# Inspecting node 2842385693
# Inspecting node 248065960
# Inspecting node 931882614
# Inspecting node 3290783049
# Inspecting node 359260523
# Inspecting node 16116228
# Inspecting node 243912778
# Inspecting node 2439108320
# Inspecting node 1176536298179284993
# Inspecting node 297771685
# Inspecting node 1128366660128260097
# Inspecting node 222987791
# Inspecting node 18597273
# Inspecting node 577727470
# Inspecting node 112767813
# Inspecting node 116837959
# Inspecting node 83712358
# Inspecting node 486703473
# Inspecting node 67758676
# Inspecting node 20346252
# Inspecting node 420560195
# Inspecting node 3153084524
# Inspecting node 1308040042724519939
# Inspecting node 1182947209
# Inspecting node 1258576501
# Inspecting node 213140093
# Inspecting node 225067116
# Inspecting node 18340314
# Inspecting node 1310724884008321028
# Inspecting node 160429871
# Inspecting node 214530013
# Inspecting node 110504574
# Inspecting node 24692082
# Inspecting node 16422863
# Inspecting node 1650588223
# Inspecting node 1548315212
# Inspecting node 1378038493105037320
# Inspecting node 4731285264
# Inspecting node 1260770767123312640
# Inspecting node 1260759194833006593
# Inspecting node 975784752648212480
# Inspecting node 2367303485
# Inspecting node 1346317368637603841
# Inspecting node 1426665402147360769
# Inspecting node 1024397417423106048
# Inspecting node 776153719675072512
# Inspecting node 787738985481240576
# Inspecting node 911264470210682880
# Inspecting node 1005823371144318977
# Inspecting node 1416921060788801539
# Inspecting node 17174462
# Inspecting node 1214396742
# Inspecting node 2379113581
# Inspecting node 1426711288462417921
# Inspecting node 21426717
# Inspecting node 975519759105060864
# Inspecting node 2394842400
# Inspecting node 1430196796781912066
# Inspecting node 1433249159474200577
# Inspecting node 20467453
# Inspecting node 1353457212799262720
# Inspecting node 877710910780985345
# Inspecting node 1413615091224924164
# Inspecting node 739208182837321729
# Inspecting node 16545084
# Inspecting node 1234968032734216193
# Inspecting node 979741136725184512
# Inspecting node 509604564
# Inspecting node 731972892
# Inspecting node 1357259774
# Inspecting node 308032537
# Inspecting node 782939425
# Inspecting node 824028437568438277
# Inspecting node 1255919262998441987
# Inspecting node 1291405539046457345
# Inspecting node 1306024583858917376
# Inspecting node 578272027
# Inspecting node 294660973
# Inspecting node 1212202179777331200
# Inspecting node 21632185
# Inspecting node 1227080599451701249
# Inspecting node 2906452022
# Inspecting node 1298675867061805056
# Inspecting node 15128653
# Inspecting node 820499790
# Inspecting node 1238950146559352834
# Inspecting node 1854934933
# Inspecting node 1444459015875014657
# Inspecting node 147340782
# Inspecting node 15677734
# Inspecting node 195207470
# Inspecting node 1282074147884015616
# Inspecting node 977009074217795584
# Inspecting node 3331283445
# Inspecting node 826085293677748224
# Inspecting node 1355980761443217415
# Inspecting node 92256613
# Inspecting node 1278822500143677442
# Inspecting node 187257177
# Inspecting node 902402049022808064
# Inspecting node 1694247541
# Inspecting node 403374868
# Inspecting node 42142250
# Inspecting node 4856189107
# Inspecting node 483313162
# Inspecting node 2427741792
# Inspecting node 2174574218
# Inspecting node 3831737053
# Inspecting node 892123934119927809
# Inspecting node 3660694460
# Inspecting node 3298660936
# Inspecting node 3289694144
# Inspecting node 459311957
# Inspecting node 33456207
# Inspecting node 144036263
# Inspecting node 1049412181559787521
# Inspecting node 826499437585371136
# Inspecting node 540672851
# Inspecting node 1444511517379026948
# Inspecting node 1023207519060197383
# Inspecting node 22532501
# Inspecting node 1067386991250206721
# Inspecting node 2800244863
# Inspecting node 92736596
# Inspecting node 1225489734178344962
# Inspecting node 66621998
# Inspecting node 1059573444214439937
# Inspecting node 1442259927779532808
# Inspecting node 751872198961487872
# Inspecting node 1190792680877559810
# Inspecting node 147981741
# Inspecting node 3158178364
# Inspecting node 1198789568214044672
# Inspecting node 1118222712818868229
# Inspecting node 1296542987850113024
# Inspecting node 1294643635397550080
# Inspecting node 920714531537481729
# Inspecting node 779333693936721920
# Inspecting node 49707487
# Inspecting node 1424936529621774338
# Inspecting node 1129198217164234753
# Inspecting node 1366519801997193216
# Inspecting node 32235586
# Inspecting node 44674554
# Inspecting node 224063162
# Inspecting node 369093
# Inspecting node 2883808867
# Inspecting node 292524345
# Inspecting node 22968164
# Inspecting node 1001274194443821064
# Inspecting node 15054416
# Inspecting node 21400756
# Inspecting node 4860164601
# Inspecting node 467804527
# Inspecting node 958181344286269440
# Inspecting node 778262568272027648
# Inspecting node 38929865
# Inspecting node 297074777
# Inspecting node 760353522718081026
# Inspecting node 928262146542026752
# Inspecting node 160673089
# Inspecting node 175939051
# Inspecting node 1187760523829563392
# Inspecting node 78429753
# Inspecting node 4722097454
# Inspecting node 1070001735454875648
# Inspecting node 35728556
# Inspecting node 1402352323851083779
# Inspecting node 1097176821622284289
# Inspecting node 150699925
# Inspecting node 1060278863874478080
# Inspecting node 813073081761570816
# Inspecting node 722880943380242432
# Inspecting node 14960142
# Inspecting node 1346936882
# Inspecting node 1073283389288005632
# Inspecting node 1297250167
# Inspecting node 1322191014455554048
# Inspecting node 1357200256618795008
# Inspecting node 16504074
# Inspecting node 158100294
# Inspecting node 817811639516991488
# Inspecting node 824357739501531136
# Inspecting node 268237247
# Inspecting node 21815663
# Inspecting node 318420941
# Inspecting node 341180420
# Inspecting node 2267952750
# Inspecting node 454336947
# Inspecting node 725309237862223872
# Inspecting node 353903334
# Inspecting node 2247798150
# Inspecting node 489749588
# Inspecting node 4819639768
# Inspecting node 1330218727
# Inspecting node 1481076481
# Inspecting node 2479224015
# Inspecting node 563152589
# Inspecting node 1317418116
# Inspecting node 1350924172554366979
# Inspecting node 23101207
# Inspecting node 1357917347181453312
# Inspecting node 721401357
# Inspecting node 2926114316
# Inspecting node 968303534822313984
# Inspecting node 77035084
# Inspecting node 85859978
# Inspecting node 2720749324
# Inspecting node 734095130
# Inspecting node 3257661611
# Inspecting node 1219432023044939776
# Inspecting node 998712356
# Inspecting node 603662056
# Inspecting node 4729460081
# Inspecting node 188565420
# Inspecting node 2534622463
# Inspecting node 165020784
# Inspecting node 84704052
# Inspecting node 4273980252
# Inspecting node 29256016
# Inspecting node 577968691
# Inspecting node 845271811097055234
# Inspecting node 470780364
# Inspecting node 22531935
# Inspecting node 59829657
# Inspecting node 275735174
# Inspecting node 559870034
# Inspecting node 7491592
# Inspecting node 23282993
# Inspecting node 2411078349
# Inspecting node 4148412316
# Inspecting node 73199415
# Inspecting node 366968661
# Inspecting node 341653196
# Inspecting node 605379442
# Inspecting node 28045785
# Inspecting node 40216513
# Inspecting node 925675836526776321
# Inspecting node 1080965055007592456
# Inspecting node 1032507164
# Inspecting node 820730609043505152
# Inspecting node 495401684
# Inspecting node 29904143
# Inspecting node 365563514
# Inspecting node 1142295084572073985
# Inspecting node 23522098
# Inspecting node 624251860
# Inspecting node 80212065
# Inspecting node 2829798301
# Inspecting node 1390067256080621568
# Inspecting node 38878429
# Inspecting node 2801061205
# Inspecting node 935335003084423168
# Inspecting node 622885791
# Inspecting node 1112914064076931072
# Inspecting node 384288098
# Inspecting node 515847342
# Inspecting node 3111765339
# Inspecting node 3419010088
# Inspecting node 571519594
# Inspecting node 935697022400602112
# Inspecting node 349692386
# Inspecting node 1223950760
# Inspecting node 3341414159
# Inspecting node 1382336580518621186
# Inspecting node 3142614406
# Inspecting node 731469980890476545
# Inspecting node 58340767
# Inspecting node 266653082
# Inspecting node 2853989866
# Inspecting node 3607702640
# Inspecting node 1421968442
# Inspecting node 297986745
# Inspecting node 54042169
# Inspecting node 577170668
# Inspecting node 880108852162707456
# Inspecting node 1380189591735517190
# Inspecting node 35051540
# Inspecting node 1074335960
# Inspecting node 1371923720609095686
# Inspecting node 1280972258
# Inspecting node 491697655
# Inspecting node 2651576688
# Inspecting node 1117035592565628928
# Inspecting node 163922710
# Inspecting node 1286102971974025217
# Inspecting node 2620272561
# Inspecting node 52516962
# Inspecting node 1065829609
# Inspecting node 1437800221375963143
# Inspecting node 1247541393121087495
# Inspecting node 892060639526395904
# Inspecting node 543143031
# Inspecting node 124878802
# Inspecting node 1341618252
# Inspecting node 727897637098135552
# Inspecting node 14221144
# Inspecting node 950848085802004480
# Inspecting node 16267310
# Inspecting node 2262304373
# Inspecting node 727519870590541824
# Inspecting node 92551736
# Inspecting node 3438124552
# Inspecting node 2749373577
# Inspecting node 535799622
# Inspecting node 1354038378640134145
# Inspecting node 1239698227739459584
# Inspecting node 196164822
# Inspecting node 3075929388
# Inspecting node 1212777267169873920
# Inspecting node 140253506
# Inspecting node 1571464364
# Inspecting node 37609730
# Inspecting node 1396338835596795904
# Inspecting node 1069734050301128705
# Inspecting node 1581712848
# Inspecting node 3268565808
# Inspecting node 786738726466707460
# Inspecting node 1115838887623122954
# Inspecting node 1498327201
# Inspecting node 1316013080250216453
# Inspecting node 957808962983755776
# Inspecting node 2727310657
# Inspecting node 2353185104
# Inspecting node 992390491105882112
# Inspecting node 1133696644422275072
# Inspecting node 3087811674
# Inspecting node 2151893489
# Inspecting node 904365258399244288
# Inspecting node 1393384383650975744
# Inspecting node 707364896153980928
# Inspecting node 371739649
# Inspecting node 1203817853494779904
# Inspecting node 1081036726758531072
# Inspecting node 2968424080
# Inspecting node 2151613567
# Inspecting node 198927392
# Inspecting node 951527727365988352
# Inspecting node 1093890667909124100
# Inspecting node 593891991
# Inspecting node 4850122813
# Inspecting node 872152901870911489
# Inspecting node 878242924567441408
# Inspecting node 1335043297
# Inspecting node 725731648017424385
# Inspecting node 1198351736
# Inspecting node 26557104
# Inspecting node 1042821954821087232
# Inspecting node 1428826266
# Inspecting node 2831610879
# Inspecting node 4681656433
# Inspecting node 775279674
# Inspecting node 596787864
# Inspecting node 273262205
# Inspecting node 24990450
# Inspecting node 342699819
# Inspecting node 378321467
# Inspecting node 217485938
# Inspecting node 967837552425119744
# Inspecting node 18579611
# Inspecting node 16811701
# Inspecting node 63476527
# Inspecting node 17442269
# Inspecting node 1366423551704784897
# Inspecting node 1070588953105969152
# Inspecting node 119911112
# Inspecting node 145878023
# Inspecting node 28540616
# Inspecting node 17050123
# Inspecting node 1432002021398306821
# Inspecting node 930479718
# Inspecting node 2341257349
# Inspecting node 587087289
# Inspecting node 708990479895896066
# Inspecting node 566196508
# Inspecting node 1019405015855878144
# Inspecting node 1275466513529671681
# Inspecting node 1347609010434953217
# Inspecting node 1419539298
# Inspecting node 57527830
# Inspecting node 24752425
# Inspecting node 29586080
# Inspecting node 1250609616192446466
# Inspecting node 2589728724
# Inspecting node 7922582
# Inspecting node 1124423281765797888
# Inspecting node 1077139237
# Inspecting node 199876983
# Inspecting node 18680879
# Inspecting node 380327126
# Inspecting node 3139690604
# Inspecting node 282111410
# Inspecting node 273727399
# Inspecting node 703722876
# Inspecting node 3357096478
# Inspecting node 838912397066846208
# Inspecting node 1437539837477748738
# Inspecting node 751919973497384962
# Inspecting node 1404491652580843525
# Inspecting node 1067154574278971392
# Inspecting node 576365948
# Inspecting node 31513326
# Inspecting node 1297575021578256388
# Inspecting node 1233196108211294209
# Inspecting node 19359977
# Inspecting node 745800926
# Inspecting node 2448257995
# Inspecting node 839668692866723840
# Inspecting node 15023001
# Inspecting node 30270072
# Inspecting node 17929195
# Inspecting node 385678932
# Inspecting node 1065257588151996422
# Inspecting node 1687712964
# Inspecting node 1345709200618389504
# Inspecting node 224737149
# Inspecting node 373940903
# Inspecting node 6013662
# Inspecting node 907302868645953537
# Inspecting node 1243336421164732416
# Inspecting node 240831038
# Inspecting node 290312086
# Inspecting node 4026420858
# Inspecting node 540103190
# Inspecting node 248866864
# Inspecting node 148618115
# Inspecting node 83307703
# Inspecting node 918318518
# Inspecting node 21166754
# Inspecting node 493604178
# Inspecting node 1222274097935073281
# Inspecting node 336662190
# Inspecting node 1254832256
# Inspecting node 65917423
# Inspecting node 15257975
# Inspecting node 18148460
# Inspecting node 168350399
# Inspecting node 18457918
# Inspecting node 165890739
# Inspecting node 1380663772906356737
# Inspecting node 554805867
# Inspecting node 1344041868779110400
# Inspecting node 373667686
# Inspecting node 1261311256151183362
# Inspecting node 1116067546778628097
# Inspecting node 1416035013502685184
# Inspecting node 24313572
# Inspecting node 1144704604442988544
# Inspecting node 222126993
# Inspecting node 2655180373
# Inspecting node 887262626
# Inspecting node 3131039404
# Inspecting node 249386982
# Inspecting node 4759974372
# Inspecting node 494732315
# Inspecting node 1405037853579436035
# Inspecting node 15049380
# Inspecting node 396149168
# Inspecting node 977021137
# Inspecting node 3320688247
# Inspecting node 880997516
# Inspecting node 264439847
# Inspecting node 1068193791511678977
# Inspecting node 636649732
# Inspecting node 14837621
# Inspecting node 596793900
# Inspecting node 4767685428
# Inspecting node 1407536941680279552
# Inspecting node 717895042602504192
# Inspecting node 52245251
# Inspecting node 2574056066
# Inspecting node 35476624
# Inspecting node 48035511
# Inspecting node 207677544
# Inspecting node 56029187
# Inspecting node 3306930701
# Inspecting node 1177657984220053506
# Inspecting node 165971686
# Inspecting node 758042170968375296
# Inspecting node 242492168
# Inspecting node 27460814
# Inspecting node 1231982311253708803
# Inspecting node 2533511951
# Inspecting node 3317590829
# Inspecting node 2416130503
# Inspecting node 724952267162542080
# Inspecting node 22491454
# Inspecting node 3029210380
# Inspecting node 2157300561
# Inspecting node 1053529093285785601
# Inspecting node 1130348139607576576
# Inspecting node 1232835905616011264
# Inspecting node 2922358250
# Inspecting node 1001986308343033856
# Inspecting node 1022679197976678400
# Inspecting node 2560632538
# Inspecting node 1317802041423646720
# Inspecting node 884265045479313408
# Inspecting node 1229474724142604288
# Inspecting node 486317915
# Inspecting node 235070820
# Inspecting node 755749623491244032
# Inspecting node 32189160
# Inspecting node 416468980
# Inspecting node 1051556700
# Inspecting node 1171534270168367105
# Inspecting node 23370368
# Inspecting node 1399510991885455362
# Inspecting node 1438462388647440386
# Inspecting node 214708464
# Inspecting node 547747984
# Inspecting node 366117993
# Inspecting node 262910171
# Inspecting node 1416997300199641091
# Inspecting node 24707528
# Inspecting node 521255914
# Inspecting node 1267810083389480963
# Inspecting node 165587758
# Inspecting node 1398595872187830274
# Inspecting node 1392128666998542337
# Inspecting node 2612807188
# Inspecting node 2652768953
# Inspecting node 292728050
# Inspecting node 96450418
# Inspecting node 2811765535
# Inspecting node 45010284
# Inspecting node 128290965
# Inspecting node 1088791968451313665
# Inspecting node 268573963
# Inspecting node 41089713
# Inspecting node 55841183
# Inspecting node 1419998048562909204
# Inspecting node 2969192164
# Inspecting node 1338252288
# Inspecting node 887732866423173125
# Inspecting node 39268708
# Inspecting node 995530035892121601
# Inspecting node 2694473137
# Inspecting node 421830937
# Inspecting node 1097531188338552832
# Inspecting node 64514213
# Inspecting node 67254536
# Inspecting node 1191423138954981382
# Inspecting node 244328935
# Inspecting node 15782904
# Inspecting node 147965270
# Inspecting node 2944338467
# ...
# Inspecting node 1411006381117919235
# Inspecting node 84353854
# Inspecting node 1446920962671185920
# Inspecting node 1365798226717151233
# Inspecting node 281811081
# Inspecting node 1406365981329346565
# Inspecting node 65767300
# Inspecting node 3011968549
# Inspecting node 1438896900070117381
# Inspecting node 547245887
# Inspecting node 1615902452
# Inspecting node 38885578
# Inspecting node 948223698649124870
# Inspecting node 1242785654368382979
# Inspecting node 3145151881
# Inspecting node 1148750306634883077
# Inspecting node 40109301
# Inspecting node 895679481720872960
# Inspecting node 2966914766
# Inspecting node 1347952445985497088
# Inspecting node 922806178446327809
# Inspecting node 131591657
# Inspecting node 1374005511495028737
# Inspecting node 408241959
# Inspecting node 809552357763661824
# Inspecting node 1556631295
# Inspecting node 282728904
# Inspecting node 785667382224293888
# Inspecting node 1013808600
# Inspecting node 16271356
# Inspecting node 4762708393
# Inspecting node 2167166754
# Inspecting node 517098546
# Inspecting node 886380609026785280
# Inspecting node 2869430815
# Inspecting node 937525764
# Inspecting node 981670040062779392
# Inspecting node 909852173479104512
# Inspecting node 220518078
# Inspecting node 226666386
# Inspecting node 288515399
# Inspecting node 220871206
# Inspecting node 17394737
# Inspecting node 85688497
# Inspecting node 85625597
# Inspecting node 32611097
# Inspecting node 1144689874424999937
# Inspecting node 2465329364
# Inspecting node 149701807
# Inspecting node 26186692
# Inspecting node 23371273
# Inspecting node 3015944460
# Inspecting node 760257132675600386
# Inspecting node 730797462991065088
# Inspecting node 771466526348107776
# Inspecting node 45950539
# Inspecting node 1160209698
# Inspecting node 1109141736972939264
# Inspecting node 169237647
# Inspecting node 1145662294849990656
# Inspecting node 78641250
# Inspecting node 821066393143672836
# Inspecting node 27740019
# Inspecting node 2201466604
# Inspecting node 1361822936
# Inspecting node 21108458
# Inspecting node 382935719
# Inspecting node 1252040788982169600
# Inspecting node 23937700
# Inspecting node 372577100
# Inspecting node 53807352
# Inspecting node 1177551303725240322
# Inspecting node 1252976493971595265
# Inspecting node 441289118
# Inspecting node 897094186213588992
# Inspecting node 3676427473
# Inspecting node 469671065
# Inspecting node 846920964113870848
# Inspecting node 268469213
# Inspecting node 24573102
# Inspecting node 16170023
# Inspecting node 2458783644
# Inspecting node 258405050
# Inspecting node 301144504
# Inspecting node 495918203
# Inspecting node 1239567083404292097
# Inspecting node 536853804
# Inspecting node 250839952
# Inspecting node 856686343144955904
# Inspecting node 981229378825801728
# Inspecting node 1335769353124343808
# Inspecting node 54650770
# Inspecting node 1691207420
# Inspecting node 479862010
# Inspecting node 702598323958620163
# Inspecting node 1197864396
# Inspecting node 272677124
# Inspecting node 54426656
# Inspecting node 1965901333
# Inspecting node 1336451673053679620
# Inspecting node 1442989306256113667
# Inspecting node 516604259
# Inspecting node 1420446766869225478
# Inspecting node 250804618
# Inspecting node 963133478
# Inspecting node 224723351
# Inspecting node 1329430334195208192
# Inspecting node 1107013222853304320
# Inspecting node 216438127
# Inspecting node 56568168
# Inspecting node 2289086672
# Inspecting node 342281222
# Inspecting node 250170548
# Inspecting node 896453296059146240
# Inspecting node 246116520
# Inspecting node 1017842910740410368
# Inspecting node 1281660648
# Inspecting node 818467340895522817
# Inspecting node 2414991108
# Inspecting node 2579229572
# Inspecting node 2568029796
# Inspecting node 1424797446845173778
# Inspecting node 24219018
# Inspecting node 1363912931151384588
# Inspecting node 103031465
# Inspecting node 2211020226
# Inspecting node 1310374181687537664
# Inspecting node 1239007657803026432
# Inspecting node 1384893312797003781
# Inspecting node 1927067096
# Inspecting node 17670732
# Inspecting node 939007961388662784
# Inspecting node 823680319274381312
# Inspecting node 1232369847134121986
# Inspecting node 1337783599446286338
# Inspecting node 17076793
# Inspecting node 1025381606
# Inspecting node 87863020
# Inspecting node 38042361
# Inspecting node 2699710783
# Inspecting node 316245912
# Inspecting node 1375846488031432705
# Inspecting node 8820062
# Inspecting node 1396272483309862913
# Inspecting node 830585528961495040
# Inspecting node 246667561
# Inspecting node 885644906915663872
# Inspecting node 375303344
# Inspecting node 1147137986431258624
# Inspecting node 1171095411307753472
# Inspecting node 18418465
# Inspecting node 590154066
# Inspecting node 59835490
# Inspecting node 1705708466
# Inspecting node 1041561337
# Inspecting node 1486136467
# Inspecting node 2807874943
# Inspecting node 17221430
# Inspecting node 1205581352
# Inspecting node 79121813
# Inspecting node 389705011
# Inspecting node 2190688044
# Inspecting node 715394299207090179
# Inspecting node 1382439377406722048
# Inspecting node 1199890847954882560
# Inspecting node 246380006
# Inspecting node 3179422780
# Inspecting node 36471917
# Inspecting node 23424817
# Inspecting node 9814812
# Inspecting node 840697793618550787
# Inspecting node 730780438269206528
# Inspecting node 294539923
# Inspecting node 1279157580799983617
# Inspecting node 403643684
# Inspecting node 53452624
# Inspecting node 2466115268
# Inspecting node 278882082
# Inspecting node 7562042
# Inspecting node 2395405134
# Inspecting node 18163138
# Inspecting node 865300797130764288
# Inspecting node 1287896006550589442
# Inspecting node 59342468
# Inspecting node 2886941025
# Inspecting node 962424351596281856
# Inspecting node 560765411
# Inspecting node 2924898800
# Inspecting node 1218987476112543744
# Inspecting node 2710528980
# Inspecting node 279748443
# Inspecting node 17702445
# Inspecting node 842121813278752768
# Inspecting node 327394273
# Inspecting node 1012406984719470592
# Inspecting node 10155832
# Inspecting node 439313680
# Inspecting node 1151231204923977729
# Inspecting node 989298765163937792
# Inspecting node 866416675
# Inspecting node 36877221
# Inspecting node 351155835
# Inspecting node 11423372
# Inspecting node 41378883
# Inspecting node 2334251844
# Inspecting node 263163489
# Inspecting node 1096251117745332226
# Inspecting node 1407372687316590594
# Inspecting node 1250830543119319042
# Inspecting node 2903614908
# Inspecting node 1351286814313738243
# Inspecting node 1403372126304866305
# Inspecting node 69712457
# Inspecting node 2730870751
# Inspecting node 16189107
# Inspecting node 414275183
# Inspecting node 393348427
# Inspecting node 248911548
# Inspecting node 34774986
# Inspecting node 1194310568200548352
# Inspecting node 1240872856508137472
# Inspecting node 242533078
# Inspecting node 78084063
# Inspecting node 42232039
# Inspecting node 41239526
# Inspecting node 3112228915
# Inspecting node 1852773120
# Inspecting node 1242517797621530625
# Inspecting node 960897097
# Inspecting node 185290543
# Inspecting node 305945328
# Inspecting node 155777848
# Inspecting node 248891184
# Inspecting node 1357931292
# Inspecting node 1582129344
# Inspecting node 63863473
# Inspecting node 744530425
# Inspecting node 1367957858
# Inspecting node 2469606308
# Inspecting node 326461319
# Inspecting node 529665584
# Inspecting node 154271777
# Inspecting node 1270383308
# Inspecting node 2312086998
# Inspecting node 1447429249
# Inspecting node 2861279433
# Inspecting node 466832463
# Inspecting node 67278150
# Inspecting node 1660911480
# Inspecting node 467664297
# Inspecting node 2573566824
# Inspecting node 132989977
# Inspecting node 954431291629473794
# Inspecting node 238865666
# Inspecting node 2569323896
# Inspecting node 788806262045732864
# Inspecting node 14165217
# Inspecting node 1447951549
# Inspecting node 1594767902
# Inspecting node 491779798
# Inspecting node 946092660795744256
# Inspecting node 74211986
# Inspecting node 524590563
# Inspecting node 1338157627453427713
# Inspecting node 823317383838253056
# Inspecting node 1044778781230039042
# Inspecting node 922963142300143616
# Inspecting node 74937543
# Inspecting node 1305697758
# Inspecting node 18463733
# Inspecting node 76264942
# Inspecting node 2905252436
# Inspecting node 44539994
# Inspecting node 396745864
# Inspecting node 1176801
# Inspecting node 1229442788623818752
# Inspecting node 2993775174
# Inspecting node 2462641501
# Inspecting node 560903736
# Inspecting node 1427351911410257934
# Inspecting node 245651739
# Inspecting node 4922698441
# Inspecting node 4024032261
# Inspecting node 15099646
# Inspecting node 75841164
# Inspecting node 794664236
# Inspecting node 1440828246132596736
# Inspecting node 3069762388
# Inspecting node 700994268
# Inspecting node 1104945319
# Inspecting node 38221378
# Inspecting node 3218932860
# Inspecting node 1201882182
# Inspecting node 1395092719
# Inspecting node 2871728962
# Inspecting node 815428708144218112
# Inspecting node 976143225927839744
# Inspecting node 727212809948401664
# Inspecting node 1373435309782822912
# Inspecting node 568769809
# Inspecting node 982017242354388992
# Inspecting node 36395646
# Inspecting node 40697478
# Inspecting node 1423672567869624322
# Inspecting node 164368721
# Inspecting node 46214091
# Inspecting node 2194496264
# Inspecting node 1057723606027792385
# Inspecting node 25209036
# Inspecting node 1347801793930035200
# Inspecting node 868994263
# Inspecting node 117589552
# Inspecting node 1080529497152278528
# Inspecting node 624962704
# Inspecting node 47022386
# Inspecting node 942370814
# Inspecting node 70499348
# Inspecting node 929856990934790144
# Inspecting node 314093378
# Inspecting node 3053107588
# Inspecting node 1459578954
# Inspecting node 4880637512
# Inspecting node 1932563430
# Inspecting node 1282257536
# Inspecting node 17300548
# Inspecting node 1236439017433989122
# Inspecting node 1444458812614709250
# Inspecting node 1386793782683652096
# Inspecting node 9575562
# Inspecting node 120139457
# Inspecting node 1240478580510871552
# Inspecting node 117562974
# Inspecting node 312422268
# Inspecting node 1333030975681536000
# Inspecting node 1040629333210148865
# Inspecting node 252399534
# Inspecting node 2459730643
# Inspecting node 1264712331457638400
# Inspecting node 1428151019981180932
# Inspecting node 280831905
# Inspecting node 1416101066580627464
# Inspecting node 1135929275272634369
# Inspecting node 360214917
# Inspecting node 1302065426961174530
# Inspecting node 39637553
# Inspecting node 114977658
# Inspecting node 1327696892608724992
# Inspecting node 1409204814534299649
# Inspecting node 371939653
# Inspecting node 190010892
# Inspecting node 1275457555490320385
# Inspecting node 1445833073770184706
# Inspecting node 1601728627
# Inspecting node 41748110
# Inspecting node 1438198932606160901
# Inspecting node 16491468
# Inspecting node 323895654
# Inspecting node 137045661
# Inspecting node 1352682350228942848
# Inspecting node 770683230223634433
# Inspecting node 3368587707
# Inspecting node 1120673221236408320
# Inspecting node 213879574
# Inspecting node 1414982991059709954
# Inspecting node 809651491
# Inspecting node 1491487802
# Inspecting node 4886317138
# Inspecting node 14912051
# Inspecting node 915727372443414528
# Inspecting node 966560892262502400
# Inspecting node 885737117745164288
# Inspecting node 981191210705530880
# Inspecting node 341002490
# Inspecting node 1948425750
# Inspecting node 1391765775594180612
# Inspecting node 1346126893733462016
# Inspecting node 1443254711381946371
# Inspecting node 95348250
# Inspecting node 1351325172184264704
# Inspecting node 487857297
# Inspecting node 94885717
# Inspecting node 925876396878020608
# Inspecting node 15300266
# Inspecting node 1212089073323503616
# Inspecting node 239096810
# Inspecting node 1353758379160834051
# Inspecting node 24728011
# Inspecting node 85640352
# Inspecting node 1012839192253075456
# Inspecting node 1259289117805776896
# Inspecting node 1309184065
# Inspecting node 1881851268
# Inspecting node 132512731
# Inspecting node 1181627354621399040
# Inspecting node 34478789
# Inspecting node 2842764204
# Inspecting node 1034903210547277824
# Inspecting node 1202669441000996864
# Inspecting node 961989099623137280
# Inspecting node 1263895193784184832
# Inspecting node 471366697
# Inspecting node 829731473443975170
# Inspecting node 590822892
# Inspecting node 382409124
# Inspecting node 851681
# Inspecting node 870842873628864513
# Inspecting node 271124533
# Inspecting node 446471174
# Inspecting node 228477243
# Inspecting node 1202388934208172032
# Inspecting node 1060751566657867776
# Inspecting node 257304118
# Inspecting node 4096225454
# Inspecting node 216266808
# Inspecting node 159065078
# Inspecting node 1058391394681868289
# Inspecting node 428602423
# Inspecting node 823397168975409152
# Inspecting node 1345473368494104580
# Inspecting node 46563847
# Inspecting node 2444436240
# Inspecting node 1126848839594467328
# Inspecting node 1257895028724203521
# Inspecting node 277513651
# Inspecting node 1110790944821932034
# Inspecting node 1161332556312326144
# Inspecting node 1346332104234295296
# Inspecting node 165942840
# Inspecting node 259587504
# Inspecting node 1925416346
# Inspecting node 15012924
# Inspecting node 18537391
# Inspecting node 42989776
# Inspecting node 93654204
# Inspecting node 34921899
# Inspecting node 2239987934
# Inspecting node 86320422
# Inspecting node 171411616
# Inspecting node 14650213
# Inspecting node 1087961
# Inspecting node 602903529
# Inspecting node 244204227
# Inspecting node 519071482
# Inspecting node 251635353
# Inspecting node 5654722
# Inspecting node 725037770033532929
# Inspecting node 40059893
# Inspecting node 237480031
# Inspecting node 1056707817216720896
# Inspecting node 1383581104473468929
# Inspecting node 373477857
# Inspecting node 20122522
# Inspecting node 4254675664
# Inspecting node 1259345602980298753
# Inspecting node 725344413162049536
# Inspecting node 1433115420563853312
# Inspecting node 166701763
# Inspecting node 582342806
# Inspecting node 14257934
# Inspecting node 1163072647661522946
# Inspecting node 1201151072733138945
# Inspecting node 1352358388638875652
# Inspecting node 549023337
# Inspecting node 936473743387394048
# Inspecting node 437944231
# Inspecting node 400071841
# Inspecting node 637320913
# Inspecting node 19114577
# Inspecting node 70065285
# Inspecting node 1268920433086210048
# Inspecting node 1176689353885724674
# Inspecting node 460592390
# Inspecting node 2262160692
# Inspecting node 2293461198
# Inspecting node 15219830
# Inspecting node 1201532829860892673
# Inspecting node 92417373
# Inspecting node 122127786
# Inspecting node 362454062
# Inspecting node 2984610092
# Inspecting node 415126004
# Inspecting node 844452866
# Inspecting node 14501713
# Inspecting node 1258440535402065920
# Inspecting node 2254247360
# Inspecting node 104585835
# Inspecting node 1410832490701467650
# Inspecting node 365780558
# Inspecting node 21632994
# Inspecting node 1338474046095233026
# Inspecting node 1113547517105528833
# Inspecting node 293588108
# Inspecting node 1155208255066558475
# Inspecting node 22523896
# Inspecting node 3675933919
# Inspecting node 2796774360
# Inspecting node 1095219121447301120
# Inspecting node 816758120819015680
# Inspecting node 825925386110382080
# Inspecting node 1529643188
# Inspecting node 246811073
# Inspecting node 3351916392
# Inspecting node 123910630
# Inspecting node 29304563
# Inspecting node 1396107226608283649
# Inspecting node 549598823
# Inspecting node 797133264716754944
# Inspecting node 768559569891012608
# Inspecting node 1880517650
# Inspecting node 1232471924145577985
# Inspecting node 1300309398166949889
# Inspecting node 1923754400
# Inspecting node 53754232
# Inspecting node 307324209
# Inspecting node 3165242127
# Inspecting node 730826158258946050
# Inspecting node 1577656471
# Inspecting node 1214368702277308421
# Inspecting node 299993498
# Inspecting node 1235344992765448193
# Inspecting node 625193066
# Inspecting node 467817388
# Inspecting node 3135148227
# Inspecting node 872810605
# Inspecting node 271504586
# Inspecting node 306967462
# Inspecting node 3299469609
# Inspecting node 1225848216467509248
# Inspecting node 259388196
# Inspecting node 525910396
# Inspecting node 358143304
# Inspecting node 1088545656002801664
# Inspecting node 1283460034182209537
# Inspecting node 1326306504027287554
# Inspecting node 100874975
# Inspecting node 811549418
# Inspecting node 145058470
# Inspecting node 15892547
# Inspecting node 2797935107
# Inspecting node 27388441
# Inspecting node 288495993
# Inspecting node 77596220
# Inspecting node 891058415195303939
# Inspecting node 1095768409449459712
# Inspecting node 881426857
# Inspecting node 17388526

# %% [markdown]
# Okay I have confirmed Degree is being respected for these 50 models

# %%
for node in G:
    print("Inspecting node {}".format(node))
    expectedDeg = G.in_degree(node) 
    for key, value in in_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break
# Out:
# Inspecting node 1385933370090209280
# Inspecting node 158095776
# Inspecting node 1416535505454338050
# Inspecting node 1604931252
# Inspecting node 544695802
# Inspecting node 716257068538327040
# Inspecting node 258170457
# Inspecting node 1086084557009575936
# Inspecting node 2817389862
# Inspecting node 822476228548403200
# Inspecting node 2353730881
# Inspecting node 921026239808208896
# Inspecting node 720934098223542272
# Inspecting node 2922779039
# Inspecting node 552891173
# Inspecting node 982496635
# Inspecting node 1433403537329819654
# Inspecting node 1175052073605353473
# Inspecting node 2784661153
# Inspecting node 102887506
# Inspecting node 18681111
# Inspecting node 952980338745147394
# Inspecting node 1438871779779530755
# Inspecting node 46975259
# Inspecting node 1157395568135557120
# Inspecting node 21951711
# Inspecting node 563064119
# Inspecting node 277332906
# Inspecting node 158458133
# Inspecting node 979827806023618560
# Inspecting node 18308257
# Inspecting node 846667915
# Inspecting node 258916078
# Inspecting node 1138564320390836224
# Inspecting node 17912334
# Inspecting node 2821464243
# Inspecting node 928790819145842688
# Inspecting node 753638148958216192
# Inspecting node 2256955027
# Inspecting node 1185936230393024512
# Inspecting node 14079041
# Inspecting node 3021899490
# Inspecting node 13880132
# Inspecting node 960624707820113920
# Inspecting node 52003137
# Inspecting node 1887595058
# Inspecting node 331864347
# Inspecting node 961514730
# Inspecting node 70750793
# Inspecting node 155629527
# Inspecting node 1161351506983038976
# Inspecting node 766360387
# Inspecting node 150270263
# Inspecting node 38471212
# Inspecting node 83153695
# Inspecting node 118937966
# Inspecting node 871189841186357248
# Inspecting node 293403080
# Inspecting node 629539554
# Inspecting node 1104422828
# Inspecting node 602083976
# Inspecting node 1311896805920043009
# Inspecting node 1318741345905922048
# Inspecting node 25314619
# Inspecting node 104300984
# Inspecting node 15702055
# Inspecting node 1153463878195589125
# Inspecting node 15633240
# Inspecting node 14991184
# Inspecting node 1242522201770856449
# Inspecting node 1440522413687521295
# Inspecting node 106524304
# Inspecting node 1292608204845834241
# Inspecting node 1446846657551683588
# Inspecting node 1389700907697270787
# Inspecting node 1445880242707570691
# Inspecting node 1545912997
# Inspecting node 831084798621782016
# Inspecting node 55976571
# Inspecting node 305401065
# Inspecting node 704798725747531776
# Inspecting node 47452040
# Inspecting node 475298690
# Inspecting node 16220555
# Inspecting node 4744498950
# Inspecting node 766759351973404672
# Inspecting node 47781573
# Inspecting node 994077337
# Inspecting node 14055736
# Inspecting node 1236010900693356549
# Inspecting node 1171683272
# Inspecting node 1338338931792756737
# Inspecting node 562243642
# Inspecting node 15772683
# Inspecting node 1251340447387172868
# Inspecting node 1350484767255519233
# Inspecting node 1335046616697372675
# Inspecting node 20750271
# Inspecting node 1162219997977960449
# Inspecting node 175259033
# Inspecting node 130909683
# Inspecting node 1364261390614106113
# Inspecting node 44416854
# Inspecting node 1511003670
# Inspecting node 536594609
# Inspecting node 24913022
# Inspecting node 17823761
# Inspecting node 273683993
# Inspecting node 215632349
# Inspecting node 1156602559378804741
# Inspecting node 1156033982586208256
# Inspecting node 47338701
# Inspecting node 139819609
# Inspecting node 413514250
# Inspecting node 2852899113
# Inspecting node 1381435843492085760
# Inspecting node 1189800120
# Inspecting node 138418077
# Inspecting node 382489139
# Inspecting node 374300583
# Inspecting node 3226840807
# Inspecting node 133863908
# Inspecting node 57127265
# Inspecting node 142731825
# Inspecting node 1417929933800751104
# Inspecting node 55823004
# Inspecting node 1447315781289750532
# Inspecting node 14262411
# Inspecting node 1707636642
# Inspecting node 845487573011173380
# Inspecting node 109144163
# Inspecting node 20199202
# Inspecting node 785448020628430849
# Inspecting node 77283552
# Inspecting node 38055290
# Inspecting node 34506336
# Inspecting node 242798024
# Inspecting node 138077463
# Inspecting node 121343164
# Inspecting node 814078628
# Inspecting node 196717787
# Inspecting node 18519855
# Inspecting node 268824309
# Inspecting node 2439928526
# Inspecting node 1169378542737661954
# Inspecting node 299228245
# Inspecting node 2369365718
# Inspecting node 1373493122
# Inspecting node 2834753506
# Inspecting node 999476893970763777
# Inspecting node 120320139
# Inspecting node 84734389
# Inspecting node 15407637
# Inspecting node 1899063048
# Inspecting node 1301967293849755653
# Inspecting node 324602007
# Inspecting node 292667439
# Inspecting node 522345885
# Inspecting node 12599562
# Inspecting node 4856851754
# Inspecting node 1248842158553141250
# Inspecting node 4026045455
# Inspecting node 3303438653
# Inspecting node 1129203001
# Inspecting node 2813664079
# Inspecting node 14518712
# Inspecting node 95209129
# Inspecting node 119797208
# Inspecting node 201984482
# Inspecting node 593944500
# Inspecting node 17105128
# Inspecting node 3409346380
# Inspecting node 33826892
# Inspecting node 273866823
# Inspecting node 37552089
# Inspecting node 377588094
# Inspecting node 266855812
# Inspecting node 341866567
# Inspecting node 60916234
# Inspecting node 262436837
# Inspecting node 1092244447184719873
# Inspecting node 2548489298
# Inspecting node 218952640
# Inspecting node 1382491059247255554
# Inspecting node 516915897
# Inspecting node 965028316460797953
# Inspecting node 195899568
# Inspecting node 2432750568
# Inspecting node 331067472
# Inspecting node 272133230
# Inspecting node 108413104
# Inspecting node 177347829
# Inspecting node 964446120402300928
# Inspecting node 1573418346
# Inspecting node 89496127
# Inspecting node 735508941258399744
# Inspecting node 542244178
# Inspecting node 1005899772916477952
# Inspecting node 366171300
# Inspecting node 29545977
# Inspecting node 59686058
# Inspecting node 965478102594863104
# Inspecting node 366225624
# Inspecting node 393713239
# Inspecting node 1185972487538040832
# Inspecting node 889661863100907520
# Inspecting node 2813399220
# Inspecting node 2436061363
# Inspecting node 17900758
# Inspecting node 23491400
# Inspecting node 382949896
# Inspecting node 1009115210546929664
# Inspecting node 3148281878
# Inspecting node 1064964294448750595
# Inspecting node 814289414
# Inspecting node 2896012540
# Inspecting node 1280589273335500801
# Inspecting node 1227766472921014272
# Inspecting node 869639001400942592
# Inspecting node 116679707
# Inspecting node 342176065
# Inspecting node 1890389540
# Inspecting node 2785990732
# Inspecting node 40591485
# Inspecting node 3191905064
# Inspecting node 25813888
# Inspecting node 237536271
# Inspecting node 16982577
# Inspecting node 1563418116
# Inspecting node 2580573206
# Inspecting node 275979196
# Inspecting node 193471925
# Inspecting node 53772503
# Inspecting node 16195103
# Inspecting node 2776775090
# Inspecting node 998590102573023232
# Inspecting node 179129165
# Inspecting node 27101995
# Inspecting node 872156101
# Inspecting node 128908662
# Inspecting node 363070453
# Inspecting node 211564038
# Inspecting node 189349553
# Inspecting node 25127782
# Inspecting node 1166717268975333376
# Inspecting node 40550119
# Inspecting node 417389780
# Inspecting node 61521038
# Inspecting node 85428184
# Inspecting node 58319221
# Inspecting node 52080359
# Inspecting node 2513973205
# Inspecting node 283226685
# Inspecting node 45848808
# Inspecting node 1646334073
# Inspecting node 1360838234
# Inspecting node 21221149
# Inspecting node 507802048
# Inspecting node 190231473
# Inspecting node 993705834470367232
# Inspecting node 360677740
# Inspecting node 1362286033
# Inspecting node 3079986094
# Inspecting node 268528986
# Inspecting node 321752222
# Inspecting node 17280115
# Inspecting node 274220538
# Inspecting node 2352629420
# Inspecting node 51184630
# Inspecting node 908811901
# Inspecting node 408526152
# Inspecting node 371447080
# Inspecting node 2314531026
# Inspecting node 1172199939243425792
# Inspecting node 390392773
# Inspecting node 2289973748
# Inspecting node 495066576
# Inspecting node 1545053600
# Inspecting node 1318671397560979456
# Inspecting node 2891740872
# Inspecting node 2848993491
# Inspecting node 103297393
# Inspecting node 1851634098
# Inspecting node 398483708
# Inspecting node 1313212802799206406
# Inspecting node 79260190
# Inspecting node 27652488
# Inspecting node 89609585
# Inspecting node 44618408
# Inspecting node 880491635896922112
# Inspecting node 2761710808
# Inspecting node 1240867313445830656
# Inspecting node 247412217
# Inspecting node 1347654502787076096
# Inspecting node 982630470008553474
# Inspecting node 82167100
# Inspecting node 110754237
# Inspecting node 768069259100622848
# Inspecting node 1304210384367349770
# Inspecting node 1300291239581892609
# Inspecting node 2253903906
# Inspecting node 78403337
# Inspecting node 862703683
# Inspecting node 1071951545212723200
# Inspecting node 840470152391016448
# Inspecting node 498423001
# Inspecting node 1197522605760303104
# Inspecting node 510093784
# Inspecting node 447415943
# Inspecting node 1201788959719936007
# Inspecting node 1633538270
# Inspecting node 122525211
# Inspecting node 192842634
# Inspecting node 551152504
# Inspecting node 378351271
# Inspecting node 57033548
# Inspecting node 255067647
# Inspecting node 35863342
# Inspecting node 2715275551
# Inspecting node 719557076599619584
# Inspecting node 980875592
# Inspecting node 1051100859831148544
# Inspecting node 2300474413
# Inspecting node 1238447220
# Inspecting node 994295935
# Inspecting node 838098877
# Inspecting node 829761553218072576
# Inspecting node 951280545421410305
# Inspecting node 1157684886
# Inspecting node 80970676
# Inspecting node 18923250
# Inspecting node 1136294664
# Inspecting node 951892305098788864
# Inspecting node 3010143902
# Inspecting node 297020666
# Inspecting node 1045793762063060992
# Inspecting node 98588419
# Inspecting node 76179144
# Inspecting node 46956207
# Inspecting node 819853925184638976
# Inspecting node 16552108
# Inspecting node 29754743
# Inspecting node 153515520
# Inspecting node 386330680
# Inspecting node 2736446758
# Inspecting node 35095520
# Inspecting node 1239564608941113347
# Inspecting node 58261480
# Inspecting node 169614697
# Inspecting node 1005522675761057792
# Inspecting node 816308397360508928
# Inspecting node 1407160205117435908
# Inspecting node 1175457080561537025
# Inspecting node 1011936943247101952
# Inspecting node 365078935
# Inspecting node 17540009
# Inspecting node 49660950
# Inspecting node 296549487
# Inspecting node 1228605451
# Inspecting node 1122706063466356737
# Inspecting node 234593598
# Inspecting node 1204301854433316866
# Inspecting node 1204430581410353154
# Inspecting node 893202244077854721
# Inspecting node 22971125
# Inspecting node 1193458951976869888
# Inspecting node 785853390
# Inspecting node 322106815
# Inspecting node 1957597519
# Inspecting node 1101092779378249729
# Inspecting node 3331826578
# Inspecting node 38720614
# Inspecting node 2912843536
# Inspecting node 183642459
# Inspecting node 2247495353
# Inspecting node 2748289416
# Inspecting node 2592210108
# Inspecting node 103701079
# Inspecting node 1352713370772770816
# Inspecting node 86410896
# Inspecting node 1038301598
# Inspecting node 1134248217472843787
# Inspecting node 999320625117196288
# Inspecting node 18390213
# Inspecting node 768295011007934469
# Inspecting node 1262878353431777280
# Inspecting node 729232479840800768
# Inspecting node 1415442622135603206
# Inspecting node 346123223
# Inspecting node 167912183
# Inspecting node 1076249609125675010
# Inspecting node 67793897
# Inspecting node 823096488
# Inspecting node 50154666
# Inspecting node 302593437
# Inspecting node 291862583
# Inspecting node 168371680
# Inspecting node 1251332171211644931
# Inspecting node 962073414
# Inspecting node 291523600
# Inspecting node 277085673
# Inspecting node 62664213
# Inspecting node 1337551744457469952
# Inspecting node 716460064039575552
# Inspecting node 3007815702
# Inspecting node 55819705
# Inspecting node 1404102585317986308
# Inspecting node 1280249212567818240
# Inspecting node 740981264740679681
# Inspecting node 247511435
# Inspecting node 1303772129847111681
# Inspecting node 1027307702047961088
# Inspecting node 1020156666204090368
# Inspecting node 38751529
# Inspecting node 718873385346797569
# Inspecting node 285806588
# Inspecting node 541129316
# Inspecting node 1655457050
# Inspecting node 57759275
# Inspecting node 824281652423753728
# Inspecting node 132015712
# Inspecting node 40647043
# Inspecting node 12992772
# Inspecting node 365132365
# Inspecting node 1129088815
# Inspecting node 1262268501823303680
# Inspecting node 288548798
# Inspecting node 87632735
# Inspecting node 40246161
# Inspecting node 1252686295
# Inspecting node 25333228
# Inspecting node 1093876945
# Inspecting node 205786669
# Inspecting node 1942350667
# Inspecting node 2863551224
# Inspecting node 720083863830069249
# Inspecting node 176207343
# Inspecting node 412708728
# Inspecting node 414218319
# Inspecting node 1271987860577517568
# Inspecting node 626984632
# Inspecting node 237594523
# Inspecting node 714340176
# Inspecting node 300638343
# Inspecting node 739845530612830208
# Inspecting node 715244769
# Inspecting node 817207955930001409
# Inspecting node 1363561650624733184
# Inspecting node 212468225
# Inspecting node 2673432539
# Inspecting node 23601374
# Inspecting node 51852542
# Inspecting node 321482430
# Inspecting node 1058965681671028736
# Inspecting node 35617919
# Inspecting node 371288369
# Inspecting node 4492249646
# Inspecting node 396106258
# Inspecting node 2287331581
# Inspecting node 150671052
# Inspecting node 3302256527
# Inspecting node 3269322830
# Inspecting node 1364751078659477504
# Inspecting node 168123931
# Inspecting node 1072189285
# Inspecting node 45976740
# Inspecting node 1435257575482740741
# Inspecting node 1099109729308008448
# Inspecting node 1366925295291424768
# Inspecting node 1356073687691141121
# Inspecting node 1580475270
# Inspecting node 1442893993935716361
# Inspecting node 392132054
# Inspecting node 207703739
# Inspecting node 1419489038747070467
# Inspecting node 928451444633563136
# Inspecting node 1119464753318043649
# Inspecting node 1440690378533838857
# Inspecting node 2931943245
# Inspecting node 1727398412
# Inspecting node 1444061901172854786
# Inspecting node 2938869339
# Inspecting node 1243723946660421637
# Inspecting node 2476755039
# Inspecting node 1331773252792770560
# Inspecting node 901618905076174848
# Inspecting node 339780511
# Inspecting node 980817985668550656
# Inspecting node 53694666
# Inspecting node 1445437990940004352
# Inspecting node 1243574020802367488
# Inspecting node 1055536236
# Inspecting node 68670486
# Inspecting node 451989089
# Inspecting node 1077731978
# Inspecting node 1271115442573185024
# Inspecting node 969744550955749383
# Inspecting node 26577630
# Inspecting node 1391981080945643523
# Inspecting node 46232947
# Inspecting node 266048357
# Inspecting node 293745266
# Inspecting node 415532452
# Inspecting node 3107597132
# Inspecting node 1183316407104266241
# Inspecting node 982472677775454209
# Inspecting node 3295839203
# Inspecting node 880913594531139584
# Inspecting node 1911858061
# Inspecting node 1097694473952342022
# Inspecting node 1388650232100134915
# Inspecting node 14100537
# Inspecting node 820656479812227073
# Inspecting node 1325249450793701376
# Inspecting node 1427996716138127360
# Inspecting node 1347691972358778885
# Inspecting node 1365678726
# Inspecting node 1295377965438644235
# Inspecting node 322090834
# Inspecting node 1342962255248424961
# Inspecting node 1195026680609292288
# Inspecting node 1116360718687690758
# Inspecting node 737359208945844224
# Inspecting node 3375064758
# Inspecting node 14538949
# Inspecting node 1084856644687679496
# Inspecting node 36133644
# Inspecting node 976345683681619968
# Inspecting node 366785595
# Inspecting node 2849064914
# Inspecting node 343059330
# Inspecting node 64123717
# Inspecting node 18420573
# Inspecting node 957106791753555968
# Inspecting node 751054068974575616
# Inspecting node 1186136760981454854
# Inspecting node 854065048683204615
# Inspecting node 317823907
# Inspecting node 952759886
# Inspecting node 474883984
# Inspecting node 1258133514421239813
# Inspecting node 2198792101
# Inspecting node 324555383
# Inspecting node 744660163873771520
# Inspecting node 726025903
# Inspecting node 1263514760584167424
# Inspecting node 714569357267853312
# Inspecting node 739149720
# Inspecting node 1136772811656126464
# Inspecting node 270307297
# Inspecting node 454774863
# Inspecting node 772948513
# Inspecting node 3333795492
# Inspecting node 2209473078
# Inspecting node 838196271571591168
# Inspecting node 18386792
# Inspecting node 1166799265806503936
# Inspecting node 262522708
# Inspecting node 1370402422062002179
# Inspecting node 1429982282891239433
# Inspecting node 1434265814325202944
# Inspecting node 1087134051914395648
# Inspecting node 791076864
# Inspecting node 121949981
# Inspecting node 256360738
# Inspecting node 1172475064870027264
# Inspecting node 1443468994107822081
# Inspecting node 941115769429024769
# Inspecting node 1313732971061362690
# Inspecting node 2305422800
# Inspecting node 242885214
# Inspecting node 1354230346586447877
# Inspecting node 469747759
# Inspecting node 432114850
# Inspecting node 1166000110586626048
# Inspecting node 884527637569323009
# Inspecting node 369653658
# Inspecting node 1434643524495020043
# Inspecting node 75984040
# Inspecting node 586195164
# Inspecting node 2902344555
# Inspecting node 564257648
# Inspecting node 1027229536902098944
# Inspecting node 2316626342
# Inspecting node 1925354744
# Inspecting node 958204773282533376
# Inspecting node 1445751022526160908
# Inspecting node 1183078912265355265
# Inspecting node 98767459
# Inspecting node 87297879
# Inspecting node 753394222267527168
# Inspecting node 373580557
# Inspecting node 1430260512688902150
# Inspecting node 2468436247
# Inspecting node 3308781515
# Inspecting node 2273880732
# Inspecting node 1302114263771668481
# Inspecting node 24181491
# Inspecting node 1309179346565898241
# Inspecting node 2231471516
# Inspecting node 1352351686778630145
# Inspecting node 1413321993470943237
# Inspecting node 603011131
# Inspecting node 1438876255202406406
# Inspecting node 1375883715776294914
# Inspecting node 1002002024
# Inspecting node 51384524
# Inspecting node 724114092672335874
# Inspecting node 552725069
# Inspecting node 1184298786329448448
# Inspecting node 334954251
# Inspecting node 101915304
# Inspecting node 1252767510983737344
# Inspecting node 1099811037975642112
# Inspecting node 1388988366247575559
# Inspecting node 1326022742286749696
# Inspecting node 1388801354244702209
# Inspecting node 961162177
# Inspecting node 1389555148318404610
# Inspecting node 1151641780267261952
# Inspecting node 27320189
# Inspecting node 1215379886887428096
# Inspecting node 1184882383
# Inspecting node 257699447
# Inspecting node 2397398196
# Inspecting node 807034969902252032
# Inspecting node 1353486048618274816
# Inspecting node 4866566489
# Inspecting node 3058888765
# Inspecting node 1173239638116446208
# Inspecting node 42894434
# Inspecting node 3078011282
# Inspecting node 32691118
# Inspecting node 544080126
# Inspecting node 1336660494
# Inspecting node 957190068594130946
# Inspecting node 1074149416699719681
# Inspecting node 825518936733085696
# Inspecting node 43199433
# Inspecting node 969376788525830146
# Inspecting node 35107179
# Inspecting node 366074756
# Inspecting node 359672860
# Inspecting node 82679357
# Inspecting node 883774859452579840
# Inspecting node 3418588623
# Inspecting node 710270422290403328
# Inspecting node 763168867371843584
# Inspecting node 1575198925
# Inspecting node 1301995158485958656
# Inspecting node 1260291453973983232
# Inspecting node 1601907697
# Inspecting node 29823611
# Inspecting node 1393039117110317058
# Inspecting node 236055343
# Inspecting node 320919057
# Inspecting node 2812908133
# Inspecting node 1325519307359490048
# Inspecting node 590735039
# Inspecting node 95577307
# Inspecting node 43948485
# Inspecting node 136332449
# Inspecting node 623936216
# Inspecting node 2873956499
# Inspecting node 4803873902
# Inspecting node 1147245556651233280
# Inspecting node 918919026344120321
# Inspecting node 37813045
# Inspecting node 24574252
# Inspecting node 1440809899500335110
# Inspecting node 1334205408110551042
# Inspecting node 1071298949837770753
# Inspecting node 915968072
# Inspecting node 885818088
# Inspecting node 227849419
# Inspecting node 2493753559
# Inspecting node 778842486
# Inspecting node 124839366
# Inspecting node 263750524
# Inspecting node 1357001901229899777
# Inspecting node 990301302264479749
# Inspecting node 1136065885456740352
# Inspecting node 1335377050878676992
# Inspecting node 138710067
# Inspecting node 1441961640459599874
# Inspecting node 2793008984
# Inspecting node 120187876
# Inspecting node 178544594
# Inspecting node 2838327755
# Inspecting node 1559780652
# Inspecting node 2291354802
# Inspecting node 1352707350784659456
# Inspecting node 1417352097150816256
# Inspecting node 1427768108614291465
# Inspecting node 1117485007944048640
# Inspecting node 1297264458
# Inspecting node 1194794785762004993
# Inspecting node 26089782
# Inspecting node 1446289055935864836
# Inspecting node 412499776
# Inspecting node 416476088
# Inspecting node 1028871362499305473
# Inspecting node 1438317451469541377
# Inspecting node 546527413
# Inspecting node 1323421765658431488
# Inspecting node 280677070
# Inspecting node 2332742508
# Inspecting node 1347272097786171394
# Inspecting node 2344419362
# Inspecting node 252150132
# Inspecting node 4787666543
# Inspecting node 1454456569
# Inspecting node 587733016
# Inspecting node 823265236916416512
# Inspecting node 1168589910825213952
# Inspecting node 753744536887824385
# Inspecting node 119925381
# Inspecting node 1269692602204532738
# Inspecting node 853722212741898240
# Inspecting node 43089397
# Inspecting node 2323751900
# Inspecting node 1213405462021853185
# Inspecting node 2937436849
# Inspecting node 272250877
# Inspecting node 1406573892
# Inspecting node 1942107584
# Inspecting node 2678072299
# Inspecting node 86384661
# Inspecting node 2983179809
# Inspecting node 3188558830
# Inspecting node 2874772780
# Inspecting node 222386937
# Inspecting node 261788602
# Inspecting node 292468351
# Inspecting node 22849568
# Inspecting node 1203545123356839936
# Inspecting node 19893907
# Inspecting node 1729880688
# Inspecting node 1361500715659755520
# Inspecting node 700287952
# Inspecting node 169268197
# Inspecting node 18622393
# Inspecting node 1304185921433227264
# Inspecting node 97121931
# Inspecting node 1699266222
# Inspecting node 729194378779078656
# Inspecting node 2752659114
# Inspecting node 373460084
# Inspecting node 908018227040710656
# Inspecting node 245149238
# Inspecting node 3242606862
# Inspecting node 29891001
# Inspecting node 720579941184757760
# Inspecting node 276713213
# Inspecting node 1424060815947206662
# Inspecting node 609432652
# Inspecting node 38625077
# Inspecting node 234550882
# Inspecting node 408072407
# Inspecting node 1427258589077508100
# Inspecting node 2242940071
# Inspecting node 44171755
# Inspecting node 41043869
# Inspecting node 436087744
# Inspecting node 578640179
# Inspecting node 132210296
# Inspecting node 923683393
# Inspecting node 1245003009555419137
# Inspecting node 1267504449087553539
# Inspecting node 65666257
# Inspecting node 407943040
# Inspecting node 240908125
# Inspecting node 1057988206963056640
# Inspecting node 130857133
# Inspecting node 1441410998355726344
# Inspecting node 24819740
# Inspecting node 1412813687811760135
# Inspecting node 2762829798
# Inspecting node 1317417438640697344
# Inspecting node 1185990712132812800
# Inspecting node 711980580813066240
# Inspecting node 3237884919
# Inspecting node 9455112
# Inspecting node 19198775
# Inspecting node 22630846
# Inspecting node 1434341584670273544
# Inspecting node 844292741077061632
# Inspecting node 1300624324206817280
# Inspecting node 1332164996592066561
# Inspecting node 337816824
# Inspecting node 153798495
# Inspecting node 1249204176548245504
# Inspecting node 3092462976
# Inspecting node 547671992
# Inspecting node 151547845
# Inspecting node 23554969
# Inspecting node 1314208704
# Inspecting node 808450734240972800
# Inspecting node 204846220
# Inspecting node 19478009
# Inspecting node 18940341
# Inspecting node 62292631
# Inspecting node 1239692519094575104
# Inspecting node 64261339
# Inspecting node 271989352
# Inspecting node 66334416
# Inspecting node 756584190112591872
# Inspecting node 24459228
# Inspecting node 771870952544096257
# Inspecting node 1242251887
# Inspecting node 15908286
# Inspecting node 1390840055200108546
# Inspecting node 2408260398
# Inspecting node 488067802
# Inspecting node 1511667030
# Inspecting node 579614622
# Inspecting node 728304522662043648
# Inspecting node 1092960066
# Inspecting node 64099329
# Inspecting node 1393055510480441345
# Inspecting node 2555583872
# Inspecting node 2452465303
# Inspecting node 282526718
# Inspecting node 4298769753
# Inspecting node 572827030
# Inspecting node 1414623993529880576
# Inspecting node 1255927911045095425
# Inspecting node 1373016955
# Inspecting node 2720800274
# Inspecting node 57661541
# Inspecting node 708739471
# Inspecting node 722623738672517120
# Inspecting node 157591483
# Inspecting node 1390378070482165763
# Inspecting node 2707780448
# Inspecting node 898554931271127042
# Inspecting node 525857359
# Inspecting node 2536457582
# Inspecting node 19634262
# Inspecting node 1357304889831878657
# Inspecting node 1243221104560345090
# Inspecting node 431141725
# Inspecting node 1244435052
# Inspecting node 159655782
# Inspecting node 382223500
# Inspecting node 535452718
# Inspecting node 1293199610178080775
# Inspecting node 12923812
# Inspecting node 16272844
# Inspecting node 335769776
# Inspecting node 16279532
# Inspecting node 3358671
# Inspecting node 16180205
# Inspecting node 2322580746
# Inspecting node 171115367
# Inspecting node 208750527
# Inspecting node 240786249
# Inspecting node 3257047456
# Inspecting node 500232993
# Inspecting node 1171073846335721472
# Inspecting node 1304472952482783232
# Inspecting node 1072270926
# Inspecting node 2789770741
# Inspecting node 2327530022
# Inspecting node 1002181382
# Inspecting node 47692251
# Inspecting node 743129088
# Inspecting node 271073165
# Inspecting node 1895316878
# Inspecting node 631988630
# Inspecting node 290162716
# Inspecting node 2229187188
# Inspecting node 274507495
# Inspecting node 417524720
# Inspecting node 415774799
# Inspecting node 579377522
# Inspecting node 32915303
# Inspecting node 245954929
# Inspecting node 170377354
# Inspecting node 1390883714
# Inspecting node 3363252329
# Inspecting node 1143342270399373313
# Inspecting node 272185225
# Inspecting node 1144289639924207616
# Inspecting node 43510607
# Inspecting node 524557553
# Inspecting node 256775505
# Inspecting node 493488747
# Inspecting node 868245382148521984
# Inspecting node 1170770038208565248
# Inspecting node 339752726
# Inspecting node 249221867
# Inspecting node 488052222
# Inspecting node 911471588
# Inspecting node 246466184
# Inspecting node 280552762
# Inspecting node 295951367
# Inspecting node 973087261
# Inspecting node 1321710295245447169
# Inspecting node 48369926
# Inspecting node 1438956476588957701
# Inspecting node 385008014
# Inspecting node 918152297544380417
# Inspecting node 33562561
# Inspecting node 987136895162384384
# Inspecting node 1327442450957303809
# Inspecting node 870473605473198080
# Inspecting node 35337644
# Inspecting node 1103832363363127297
# Inspecting node 1243323314652602368
# Inspecting node 1268045786312593408
# Inspecting node 17355421
# Inspecting node 24348660
# Inspecting node 14247924
# Inspecting node 106512310
# Inspecting node 1269254845615095810
# Inspecting node 1219578234
# Inspecting node 1380813355
# Inspecting node 883334379023597568
# Inspecting node 58878834
# Inspecting node 912346683291389953
# Inspecting node 3179475258
# Inspecting node 245939022
# Inspecting node 363654070
# Inspecting node 3071603495
# Inspecting node 573788425
# Inspecting node 878490462
# Inspecting node 1423385158263132168
# Inspecting node 1268728504964825088
# Inspecting node 46894332
# Inspecting node 136160953
# Inspecting node 107218304
# Inspecting node 73411833
# Inspecting node 1405971529217740812
# Inspecting node 1275123310788063233
# Inspecting node 1173035282461089793
# Inspecting node 1445090669643517961
# Inspecting node 1389241812276023296
# Inspecting node 501994958
# Inspecting node 2799175653
# Inspecting node 1429555219457773581
# Inspecting node 1668333199
# Inspecting node 1218019404992196609
# Inspecting node 1366204146957885445
# Inspecting node 1198972583288459265
# Inspecting node 1433247289330577408
# Inspecting node 502160853
# Inspecting node 41520537
# Inspecting node 1294478815628890112
# Inspecting node 395394840
# Inspecting node 1151704477
# Inspecting node 1044711566354960384
# Inspecting node 1271855851330916353
# Inspecting node 1497052201
# Inspecting node 975757898004549633
# Inspecting node 3245708989
# Inspecting node 1267640853000007680
# Inspecting node 29917096
# Inspecting node 245373521
# Inspecting node 1420482733135040522
# Inspecting node 1242510089145266182
# Inspecting node 28737527
# Inspecting node 1731401322
# Inspecting node 979870450577686528
# Inspecting node 1354922263418523648
# Inspecting node 24951781
# Inspecting node 15613754
# Inspecting node 100851235
# Inspecting node 59243738
# Inspecting node 17360968
# Inspecting node 360129945
# Inspecting node 1174006316412674048
# Inspecting node 21809306
# Inspecting node 1134558647835430912
# Inspecting node 855478711
# Inspecting node 25178951
# Inspecting node 52350953
# Inspecting node 20796969
# Inspecting node 55158039
# Inspecting node 1401659310015397889
# Inspecting node 215896862
# Inspecting node 4540976253
# Inspecting node 56016987
# Inspecting node 1357857933019598849
# Inspecting node 1125841354716696576
# Inspecting node 793343793642680320
# Inspecting node 48219360
# Inspecting node 399184212
# Inspecting node 827222807121637377
# Inspecting node 1138228267
# Inspecting node 1671821988
# Inspecting node 2321539819
# Inspecting node 17969963
# Inspecting node 1337935917298962434
# Inspecting node 1055170328442224641
# Inspecting node 325805788
# Inspecting node 1128406689802276865
# Inspecting node 1560811022
# Inspecting node 1264568784318345218
# Inspecting node 254240108
# Inspecting node 2237957942
# Inspecting node 387828045
# Inspecting node 3355188729
# Inspecting node 1483945802
# Inspecting node 1663608300
# Inspecting node 1335613030852386817
# Inspecting node 2678629590
# Inspecting node 884681534
# Inspecting node 420536762
# Inspecting node 4329525312
# Inspecting node 1547244656
# Inspecting node 109341612
# Inspecting node 108689047
# Inspecting node 1223265601147342848
# Inspecting node 297968019
# Inspecting node 183758895
# Inspecting node 45932749
# Inspecting node 418786259
# Inspecting node 70240459
# Inspecting node 1606592767
# Inspecting node 1047167241119326211
# Inspecting node 978673214283853825
# Inspecting node 17136419
# Inspecting node 1242152485
# Inspecting node 4445748801
# Inspecting node 1413908511461945350
# Inspecting node 1314819918328729600
# Inspecting node 1140532022
# Inspecting node 1200932043544117248
# Inspecting node 3109560272
# Inspecting node 162924629
# Inspecting node 182072629
# Inspecting node 980237238
# Inspecting node 1213189717425917953
# Inspecting node 2800741820
# Inspecting node 19135439
# Inspecting node 967241034873933824
# Inspecting node 3236492411
# Inspecting node 1235422076082589696
# Inspecting node 534591437
# Inspecting node 1454880680
# Inspecting node 1069754111078354948
# Inspecting node 2286750115
# Inspecting node 1375862610
# Inspecting node 26071396
# Inspecting node 375764669
# Inspecting node 1833674827
# Inspecting node 392380645
# Inspecting node 769165632738762752
# Inspecting node 989311745100566529
# Inspecting node 256552850
# Inspecting node 2218371769
# Inspecting node 29721598
# Inspecting node 1008103433822351360
# Inspecting node 1214027006242742273
# Inspecting node 142107502
# Inspecting node 1314568089300873216
# Inspecting node 801218452618956800
# Inspecting node 1330675961839443973
# Inspecting node 1441448795921952768
# Inspecting node 102491634
# Inspecting node 24978284
# Inspecting node 36988268
# Inspecting node 712792479729192960
# Inspecting node 890560416526594048
# Inspecting node 1413820603
# Inspecting node 37044121
# Inspecting node 832619717785329664
# Inspecting node 1171471512085389312
# Inspecting node 61542328
# Inspecting node 494320156
# Inspecting node 13716572
# Inspecting node 1017461230984990720
# Inspecting node 25703839
# Inspecting node 363666493
# Inspecting node 975491119734763522
# Inspecting node 61888526
# Inspecting node 2502596130
# Inspecting node 763867259777519618
# Inspecting node 1185294078256254977
# Inspecting node 1296424847149588483
# Inspecting node 2721515522
# Inspecting node 224600898
# Inspecting node 524785211
# Inspecting node 777617628009332736
# Inspecting node 189341190
# Inspecting node 2451955022
# Inspecting node 835061048533082113
# Inspecting node 248022226
# Inspecting node 2988258574
# Inspecting node 1001287095472873473
# Inspecting node 1182252711833718784
# Inspecting node 1861048644
# Inspecting node 2842385693
# Inspecting node 248065960
# Inspecting node 931882614
# Inspecting node 3290783049
# Inspecting node 359260523
# Inspecting node 16116228
# Inspecting node 243912778
# Inspecting node 2439108320
# Inspecting node 1176536298179284993
# Inspecting node 297771685
# Inspecting node 1128366660128260097
# Inspecting node 222987791
# Inspecting node 18597273
# Inspecting node 577727470
# Inspecting node 112767813
# Inspecting node 116837959
# Inspecting node 83712358
# Inspecting node 486703473
# Inspecting node 67758676
# Inspecting node 20346252
# Inspecting node 420560195
# Inspecting node 3153084524
# Inspecting node 1308040042724519939
# Inspecting node 1182947209
# Inspecting node 1258576501
# Inspecting node 213140093
# Inspecting node 225067116
# Inspecting node 18340314
# Inspecting node 1310724884008321028
# Inspecting node 160429871
# Inspecting node 214530013
# Inspecting node 110504574
# Inspecting node 24692082
# Inspecting node 16422863
# Inspecting node 1650588223
# Inspecting node 1548315212
# Inspecting node 1378038493105037320
# Inspecting node 4731285264
# Inspecting node 1260770767123312640
# Inspecting node 1260759194833006593
# Inspecting node 975784752648212480
# Inspecting node 2367303485
# Inspecting node 1346317368637603841
# Inspecting node 1426665402147360769
# Inspecting node 1024397417423106048
# Inspecting node 776153719675072512
# Inspecting node 787738985481240576
# Inspecting node 911264470210682880
# Inspecting node 1005823371144318977
# Inspecting node 1416921060788801539
# Inspecting node 17174462
# Inspecting node 1214396742
# Inspecting node 2379113581
# Inspecting node 1426711288462417921
# Inspecting node 21426717
# Inspecting node 975519759105060864
# Inspecting node 2394842400
# Inspecting node 1430196796781912066
# Inspecting node 1433249159474200577
# Inspecting node 20467453
# Inspecting node 1353457212799262720
# Inspecting node 877710910780985345
# Inspecting node 1413615091224924164
# Inspecting node 739208182837321729
# Inspecting node 16545084
# Inspecting node 1234968032734216193
# Inspecting node 979741136725184512
# Inspecting node 509604564
# Inspecting node 731972892
# Inspecting node 1357259774
# Inspecting node 308032537
# Inspecting node 782939425
# Inspecting node 824028437568438277
# Inspecting node 1255919262998441987
# Inspecting node 1291405539046457345
# Inspecting node 1306024583858917376
# Inspecting node 578272027
# Inspecting node 294660973
# Inspecting node 1212202179777331200
# Inspecting node 21632185
# Inspecting node 1227080599451701249
# Inspecting node 2906452022
# Inspecting node 1298675867061805056
# Inspecting node 15128653
# Inspecting node 820499790
# Inspecting node 1238950146559352834
# Inspecting node 1854934933
# Inspecting node 1444459015875014657
# Inspecting node 147340782
# Inspecting node 15677734
# Inspecting node 195207470
# Inspecting node 1282074147884015616
# Inspecting node 977009074217795584
# Inspecting node 3331283445
# Inspecting node 826085293677748224
# Inspecting node 1355980761443217415
# Inspecting node 92256613
# Inspecting node 1278822500143677442
# Inspecting node 187257177
# Inspecting node 902402049022808064
# Inspecting node 1694247541
# Inspecting node 403374868
# Inspecting node 42142250
# Inspecting node 4856189107
# Inspecting node 483313162
# Inspecting node 2427741792
# Inspecting node 2174574218
# Inspecting node 3831737053
# Inspecting node 892123934119927809
# Inspecting node 3660694460
# Inspecting node 3298660936
# Inspecting node 3289694144
# Inspecting node 459311957
# Inspecting node 33456207
# Inspecting node 144036263
# Inspecting node 1049412181559787521
# Inspecting node 826499437585371136
# Inspecting node 540672851
# Inspecting node 1444511517379026948
# Inspecting node 1023207519060197383
# Inspecting node 22532501
# Inspecting node 1067386991250206721
# Inspecting node 2800244863
# Inspecting node 92736596
# Inspecting node 1225489734178344962
# Inspecting node 66621998
# Inspecting node 1059573444214439937
# Inspecting node 1442259927779532808
# Inspecting node 751872198961487872
# Inspecting node 1190792680877559810
# Inspecting node 147981741
# Inspecting node 3158178364
# Inspecting node 1198789568214044672
# Inspecting node 1118222712818868229
# Inspecting node 1296542987850113024
# Inspecting node 1294643635397550080
# Inspecting node 920714531537481729
# Inspecting node 779333693936721920
# Inspecting node 49707487
# Inspecting node 1424936529621774338
# Inspecting node 1129198217164234753
# Inspecting node 1366519801997193216
# Inspecting node 32235586
# Inspecting node 44674554
# Inspecting node 224063162
# Inspecting node 369093
# Inspecting node 2883808867
# Inspecting node 292524345
# Inspecting node 22968164
# Inspecting node 1001274194443821064
# Inspecting node 15054416
# Inspecting node 21400756
# Inspecting node 4860164601
# Inspecting node 467804527
# Inspecting node 958181344286269440
# Inspecting node 778262568272027648
# Inspecting node 38929865
# Inspecting node 297074777
# Inspecting node 760353522718081026
# Inspecting node 928262146542026752
# Inspecting node 160673089
# Inspecting node 175939051
# Inspecting node 1187760523829563392
# Inspecting node 78429753
# Inspecting node 4722097454
# Inspecting node 1070001735454875648
# Inspecting node 35728556
# Inspecting node 1402352323851083779
# Inspecting node 1097176821622284289
# Inspecting node 150699925
# Inspecting node 1060278863874478080
# Inspecting node 813073081761570816
# Inspecting node 722880943380242432
# Inspecting node 14960142
# Inspecting node 1346936882
# Inspecting node 1073283389288005632
# Inspecting node 1297250167
# Inspecting node 1322191014455554048
# Inspecting node 1357200256618795008
# Inspecting node 16504074
# Inspecting node 158100294
# Inspecting node 817811639516991488
# Inspecting node 824357739501531136
# Inspecting node 268237247
# Inspecting node 21815663
# Inspecting node 318420941
# Inspecting node 341180420
# Inspecting node 2267952750
# Inspecting node 454336947
# Inspecting node 725309237862223872
# Inspecting node 353903334
# Inspecting node 2247798150
# Inspecting node 489749588
# Inspecting node 4819639768
# Inspecting node 1330218727
# Inspecting node 1481076481
# Inspecting node 2479224015
# Inspecting node 563152589
# Inspecting node 1317418116
# Inspecting node 1350924172554366979
# Inspecting node 23101207
# Inspecting node 1357917347181453312
# Inspecting node 721401357
# Inspecting node 2926114316
# Inspecting node 968303534822313984
# Inspecting node 77035084
# Inspecting node 85859978
# Inspecting node 2720749324
# Inspecting node 734095130
# Inspecting node 3257661611
# Inspecting node 1219432023044939776
# Inspecting node 998712356
# Inspecting node 603662056
# Inspecting node 4729460081
# Inspecting node 188565420
# Inspecting node 2534622463
# Inspecting node 165020784
# Inspecting node 84704052
# Inspecting node 4273980252
# Inspecting node 29256016
# Inspecting node 577968691
# Inspecting node 845271811097055234
# Inspecting node 470780364
# Inspecting node 22531935
# Inspecting node 59829657
# Inspecting node 275735174
# Inspecting node 559870034
# Inspecting node 7491592
# Inspecting node 23282993
# Inspecting node 2411078349
# Inspecting node 4148412316
# Inspecting node 73199415
# Inspecting node 366968661
# Inspecting node 341653196
# Inspecting node 605379442
# Inspecting node 28045785
# Inspecting node 40216513
# Inspecting node 925675836526776321
# Inspecting node 1080965055007592456
# Inspecting node 1032507164
# Inspecting node 820730609043505152
# Inspecting node 495401684
# Inspecting node 29904143
# Inspecting node 365563514
# Inspecting node 1142295084572073985
# Inspecting node 23522098
# Inspecting node 624251860
# Inspecting node 80212065
# Inspecting node 2829798301
# Inspecting node 1390067256080621568
# Inspecting node 38878429
# Inspecting node 2801061205
# Inspecting node 935335003084423168
# Inspecting node 622885791
# Inspecting node 1112914064076931072
# Inspecting node 384288098
# Inspecting node 515847342
# Inspecting node 3111765339
# Inspecting node 3419010088
# Inspecting node 571519594
# Inspecting node 935697022400602112
# Inspecting node 349692386
# Inspecting node 1223950760
# Inspecting node 3341414159
# Inspecting node 1382336580518621186
# Inspecting node 3142614406
# Inspecting node 731469980890476545
# Inspecting node 58340767
# Inspecting node 266653082
# Inspecting node 2853989866
# Inspecting node 3607702640
# Inspecting node 1421968442
# Inspecting node 297986745
# Inspecting node 54042169
# Inspecting node 577170668
# Inspecting node 880108852162707456
# Inspecting node 1380189591735517190
# Inspecting node 35051540
# Inspecting node 1074335960
# Inspecting node 1371923720609095686
# Inspecting node 1280972258
# Inspecting node 491697655
# Inspecting node 2651576688
# Inspecting node 1117035592565628928
# Inspecting node 163922710
# Inspecting node 1286102971974025217
# Inspecting node 2620272561
# Inspecting node 52516962
# Inspecting node 1065829609
# Inspecting node 1437800221375963143
# Inspecting node 1247541393121087495
# Inspecting node 892060639526395904
# Inspecting node 543143031
# Inspecting node 124878802
# Inspecting node 1341618252
# Inspecting node 727897637098135552
# Inspecting node 14221144
# Inspecting node 950848085802004480
# Inspecting node 16267310
# Inspecting node 2262304373
# Inspecting node 727519870590541824
# Inspecting node 92551736
# Inspecting node 3438124552
# Inspecting node 2749373577
# Inspecting node 535799622
# Inspecting node 1354038378640134145
# Inspecting node 1239698227739459584
# Inspecting node 196164822
# Inspecting node 3075929388
# Inspecting node 1212777267169873920
# Inspecting node 140253506
# Inspecting node 1571464364
# Inspecting node 37609730
# Inspecting node 1396338835596795904
# Inspecting node 1069734050301128705
# Inspecting node 1581712848
# Inspecting node 3268565808
# Inspecting node 786738726466707460
# Inspecting node 1115838887623122954
# Inspecting node 1498327201
# Inspecting node 1316013080250216453
# Inspecting node 957808962983755776
# Inspecting node 2727310657
# Inspecting node 2353185104
# Inspecting node 992390491105882112
# Inspecting node 1133696644422275072
# Inspecting node 3087811674
# Inspecting node 2151893489
# Inspecting node 904365258399244288
# Inspecting node 1393384383650975744
# Inspecting node 707364896153980928
# Inspecting node 371739649
# Inspecting node 1203817853494779904
# Inspecting node 1081036726758531072
# Inspecting node 2968424080
# Inspecting node 2151613567
# Inspecting node 198927392
# Inspecting node 951527727365988352
# Inspecting node 1093890667909124100
# Inspecting node 593891991
# Inspecting node 4850122813
# Inspecting node 872152901870911489
# Inspecting node 878242924567441408
# Inspecting node 1335043297
# Inspecting node 725731648017424385
# Inspecting node 1198351736
# Inspecting node 26557104
# Inspecting node 1042821954821087232
# Inspecting node 1428826266
# Inspecting node 2831610879
# Inspecting node 4681656433
# Inspecting node 775279674
# Inspecting node 596787864
# Inspecting node 273262205
# Inspecting node 24990450
# Inspecting node 342699819
# Inspecting node 378321467
# Inspecting node 217485938
# Inspecting node 967837552425119744
# Inspecting node 18579611
# Inspecting node 16811701
# Inspecting node 63476527
# Inspecting node 17442269
# Inspecting node 1366423551704784897
# Inspecting node 1070588953105969152
# Inspecting node 119911112
# Inspecting node 145878023
# Inspecting node 28540616
# Inspecting node 17050123
# Inspecting node 1432002021398306821
# Inspecting node 930479718
# Inspecting node 2341257349
# Inspecting node 587087289
# Inspecting node 708990479895896066
# Inspecting node 566196508
# Inspecting node 1019405015855878144
# Inspecting node 1275466513529671681
# Inspecting node 1347609010434953217
# Inspecting node 1419539298
# Inspecting node 57527830
# Inspecting node 24752425
# Inspecting node 29586080
# Inspecting node 1250609616192446466
# Inspecting node 2589728724
# Inspecting node 7922582
# Inspecting node 1124423281765797888
# Inspecting node 1077139237
# Inspecting node 199876983
# Inspecting node 18680879
# Inspecting node 380327126
# Inspecting node 3139690604
# Inspecting node 282111410
# Inspecting node 273727399
# Inspecting node 703722876
# Inspecting node 3357096478
# Inspecting node 838912397066846208
# Inspecting node 1437539837477748738
# Inspecting node 751919973497384962
# Inspecting node 1404491652580843525
# Inspecting node 1067154574278971392
# Inspecting node 576365948
# Inspecting node 31513326
# Inspecting node 1297575021578256388
# Inspecting node 1233196108211294209
# Inspecting node 19359977
# Inspecting node 745800926
# Inspecting node 2448257995
# Inspecting node 839668692866723840
# Inspecting node 15023001
# Inspecting node 30270072
# Inspecting node 17929195
# Inspecting node 385678932
# Inspecting node 1065257588151996422
# Inspecting node 1687712964
# Inspecting node 1345709200618389504
# Inspecting node 224737149
# Inspecting node 373940903
# Inspecting node 6013662
# Inspecting node 907302868645953537
# Inspecting node 1243336421164732416
# Inspecting node 240831038
# Inspecting node 290312086
# Inspecting node 4026420858
# Inspecting node 540103190
# Inspecting node 248866864
# Inspecting node 148618115
# Inspecting node 83307703
# Inspecting node 918318518
# Inspecting node 21166754
# Inspecting node 493604178
# Inspecting node 1222274097935073281
# Inspecting node 336662190
# Inspecting node 1254832256
# Inspecting node 65917423
# Inspecting node 15257975
# Inspecting node 18148460
# Inspecting node 168350399
# Inspecting node 18457918
# Inspecting node 165890739
# Inspecting node 1380663772906356737
# Inspecting node 554805867
# Inspecting node 1344041868779110400
# Inspecting node 373667686
# Inspecting node 1261311256151183362
# Inspecting node 1116067546778628097
# Inspecting node 1416035013502685184
# Inspecting node 24313572
# Inspecting node 1144704604442988544
# Inspecting node 222126993
# Inspecting node 2655180373
# Inspecting node 887262626
# Inspecting node 3131039404
# Inspecting node 249386982
# Inspecting node 4759974372
# Inspecting node 494732315
# Inspecting node 1405037853579436035
# Inspecting node 15049380
# Inspecting node 396149168
# Inspecting node 977021137
# Inspecting node 3320688247
# Inspecting node 880997516
# Inspecting node 264439847
# Inspecting node 1068193791511678977
# Inspecting node 636649732
# Inspecting node 14837621
# Inspecting node 596793900
# Inspecting node 4767685428
# Inspecting node 1407536941680279552
# Inspecting node 717895042602504192
# Inspecting node 52245251
# Inspecting node 2574056066
# Inspecting node 35476624
# Inspecting node 48035511
# Inspecting node 207677544
# Inspecting node 56029187
# Inspecting node 3306930701
# Inspecting node 1177657984220053506
# Inspecting node 165971686
# Inspecting node 758042170968375296
# Inspecting node 242492168
# Inspecting node 27460814
# Inspecting node 1231982311253708803
# Inspecting node 2533511951
# Inspecting node 3317590829
# Inspecting node 2416130503
# Inspecting node 724952267162542080
# Inspecting node 22491454
# Inspecting node 3029210380
# Inspecting node 2157300561
# Inspecting node 1053529093285785601
# Inspecting node 1130348139607576576
# Inspecting node 1232835905616011264
# Inspecting node 2922358250
# Inspecting node 1001986308343033856
# Inspecting node 1022679197976678400
# Inspecting node 2560632538
# Inspecting node 1317802041423646720
# Inspecting node 884265045479313408
# Inspecting node 1229474724142604288
# Inspecting node 486317915
# Inspecting node 235070820
# Inspecting node 755749623491244032
# Inspecting node 32189160
# Inspecting node 416468980
# Inspecting node 1051556700
# Inspecting node 1171534270168367105
# Inspecting node 23370368
# Inspecting node 1399510991885455362
# Inspecting node 1438462388647440386
# Inspecting node 214708464
# Inspecting node 547747984
# Inspecting node 366117993
# Inspecting node 262910171
# Inspecting node 1416997300199641091
# Inspecting node 24707528
# Inspecting node 521255914
# Inspecting node 1267810083389480963
# Inspecting node 165587758
# Inspecting node 1398595872187830274
# Inspecting node 1392128666998542337
# Inspecting node 2612807188
# Inspecting node 2652768953
# Inspecting node 292728050
# Inspecting node 96450418
# Inspecting node 2811765535
# Inspecting node 45010284
# Inspecting node 128290965
# Inspecting node 1088791968451313665
# Inspecting node 268573963
# Inspecting node 41089713
# Inspecting node 55841183
# Inspecting node 1419998048562909204
# Inspecting node 2969192164
# Inspecting node 1338252288
# Inspecting node 887732866423173125
# Inspecting node 39268708
# Inspecting node 995530035892121601
# Inspecting node 2694473137
# Inspecting node 421830937
# Inspecting node 1097531188338552832
# Inspecting node 64514213
# Inspecting node 67254536
# Inspecting node 1191423138954981382
# Inspecting node 244328935
# Inspecting node 15782904
# Inspecting node 147965270
# Inspecting node 2944338467
# ...
# Inspecting node 1411006381117919235
# Inspecting node 84353854
# Inspecting node 1446920962671185920
# Inspecting node 1365798226717151233
# Inspecting node 281811081
# Inspecting node 1406365981329346565
# Inspecting node 65767300
# Inspecting node 3011968549
# Inspecting node 1438896900070117381
# Inspecting node 547245887
# Inspecting node 1615902452
# Inspecting node 38885578
# Inspecting node 948223698649124870
# Inspecting node 1242785654368382979
# Inspecting node 3145151881
# Inspecting node 1148750306634883077
# Inspecting node 40109301
# Inspecting node 895679481720872960
# Inspecting node 2966914766
# Inspecting node 1347952445985497088
# Inspecting node 922806178446327809
# Inspecting node 131591657
# Inspecting node 1374005511495028737
# Inspecting node 408241959
# Inspecting node 809552357763661824
# Inspecting node 1556631295
# Inspecting node 282728904
# Inspecting node 785667382224293888
# Inspecting node 1013808600
# Inspecting node 16271356
# Inspecting node 4762708393
# Inspecting node 2167166754
# Inspecting node 517098546
# Inspecting node 886380609026785280
# Inspecting node 2869430815
# Inspecting node 937525764
# Inspecting node 981670040062779392
# Inspecting node 909852173479104512
# Inspecting node 220518078
# Inspecting node 226666386
# Inspecting node 288515399
# Inspecting node 220871206
# Inspecting node 17394737
# Inspecting node 85688497
# Inspecting node 85625597
# Inspecting node 32611097
# Inspecting node 1144689874424999937
# Inspecting node 2465329364
# Inspecting node 149701807
# Inspecting node 26186692
# Inspecting node 23371273
# Inspecting node 3015944460
# Inspecting node 760257132675600386
# Inspecting node 730797462991065088
# Inspecting node 771466526348107776
# Inspecting node 45950539
# Inspecting node 1160209698
# Inspecting node 1109141736972939264
# Inspecting node 169237647
# Inspecting node 1145662294849990656
# Inspecting node 78641250
# Inspecting node 821066393143672836
# Inspecting node 27740019
# Inspecting node 2201466604
# Inspecting node 1361822936
# Inspecting node 21108458
# Inspecting node 382935719
# Inspecting node 1252040788982169600
# Inspecting node 23937700
# Inspecting node 372577100
# Inspecting node 53807352
# Inspecting node 1177551303725240322
# Inspecting node 1252976493971595265
# Inspecting node 441289118
# Inspecting node 897094186213588992
# Inspecting node 3676427473
# Inspecting node 469671065
# Inspecting node 846920964113870848
# Inspecting node 268469213
# Inspecting node 24573102
# Inspecting node 16170023
# Inspecting node 2458783644
# Inspecting node 258405050
# Inspecting node 301144504
# Inspecting node 495918203
# Inspecting node 1239567083404292097
# Inspecting node 536853804
# Inspecting node 250839952
# Inspecting node 856686343144955904
# Inspecting node 981229378825801728
# Inspecting node 1335769353124343808
# Inspecting node 54650770
# Inspecting node 1691207420
# Inspecting node 479862010
# Inspecting node 702598323958620163
# Inspecting node 1197864396
# Inspecting node 272677124
# Inspecting node 54426656
# Inspecting node 1965901333
# Inspecting node 1336451673053679620
# Inspecting node 1442989306256113667
# Inspecting node 516604259
# Inspecting node 1420446766869225478
# Inspecting node 250804618
# Inspecting node 963133478
# Inspecting node 224723351
# Inspecting node 1329430334195208192
# Inspecting node 1107013222853304320
# Inspecting node 216438127
# Inspecting node 56568168
# Inspecting node 2289086672
# Inspecting node 342281222
# Inspecting node 250170548
# Inspecting node 896453296059146240
# Inspecting node 246116520
# Inspecting node 1017842910740410368
# Inspecting node 1281660648
# Inspecting node 818467340895522817
# Inspecting node 2414991108
# Inspecting node 2579229572
# Inspecting node 2568029796
# Inspecting node 1424797446845173778
# Inspecting node 24219018
# Inspecting node 1363912931151384588
# Inspecting node 103031465
# Inspecting node 2211020226
# Inspecting node 1310374181687537664
# Inspecting node 1239007657803026432
# Inspecting node 1384893312797003781
# Inspecting node 1927067096
# Inspecting node 17670732
# Inspecting node 939007961388662784
# Inspecting node 823680319274381312
# Inspecting node 1232369847134121986
# Inspecting node 1337783599446286338
# Inspecting node 17076793
# Inspecting node 1025381606
# Inspecting node 87863020
# Inspecting node 38042361
# Inspecting node 2699710783
# Inspecting node 316245912
# Inspecting node 1375846488031432705
# Inspecting node 8820062
# Inspecting node 1396272483309862913
# Inspecting node 830585528961495040
# Inspecting node 246667561
# Inspecting node 885644906915663872
# Inspecting node 375303344
# Inspecting node 1147137986431258624
# Inspecting node 1171095411307753472
# Inspecting node 18418465
# Inspecting node 590154066
# Inspecting node 59835490
# Inspecting node 1705708466
# Inspecting node 1041561337
# Inspecting node 1486136467
# Inspecting node 2807874943
# Inspecting node 17221430
# Inspecting node 1205581352
# Inspecting node 79121813
# Inspecting node 389705011
# Inspecting node 2190688044
# Inspecting node 715394299207090179
# Inspecting node 1382439377406722048
# Inspecting node 1199890847954882560
# Inspecting node 246380006
# Inspecting node 3179422780
# Inspecting node 36471917
# Inspecting node 23424817
# Inspecting node 9814812
# Inspecting node 840697793618550787
# Inspecting node 730780438269206528
# Inspecting node 294539923
# Inspecting node 1279157580799983617
# Inspecting node 403643684
# Inspecting node 53452624
# Inspecting node 2466115268
# Inspecting node 278882082
# Inspecting node 7562042
# Inspecting node 2395405134
# Inspecting node 18163138
# Inspecting node 865300797130764288
# Inspecting node 1287896006550589442
# Inspecting node 59342468
# Inspecting node 2886941025
# Inspecting node 962424351596281856
# Inspecting node 560765411
# Inspecting node 2924898800
# Inspecting node 1218987476112543744
# Inspecting node 2710528980
# Inspecting node 279748443
# Inspecting node 17702445
# Inspecting node 842121813278752768
# Inspecting node 327394273
# Inspecting node 1012406984719470592
# Inspecting node 10155832
# Inspecting node 439313680
# Inspecting node 1151231204923977729
# Inspecting node 989298765163937792
# Inspecting node 866416675
# Inspecting node 36877221
# Inspecting node 351155835
# Inspecting node 11423372
# Inspecting node 41378883
# Inspecting node 2334251844
# Inspecting node 263163489
# Inspecting node 1096251117745332226
# Inspecting node 1407372687316590594
# Inspecting node 1250830543119319042
# Inspecting node 2903614908
# Inspecting node 1351286814313738243
# Inspecting node 1403372126304866305
# Inspecting node 69712457
# Inspecting node 2730870751
# Inspecting node 16189107
# Inspecting node 414275183
# Inspecting node 393348427
# Inspecting node 248911548
# Inspecting node 34774986
# Inspecting node 1194310568200548352
# Inspecting node 1240872856508137472
# Inspecting node 242533078
# Inspecting node 78084063
# Inspecting node 42232039
# Inspecting node 41239526
# Inspecting node 3112228915
# Inspecting node 1852773120
# Inspecting node 1242517797621530625
# Inspecting node 960897097
# Inspecting node 185290543
# Inspecting node 305945328
# Inspecting node 155777848
# Inspecting node 248891184
# Inspecting node 1357931292
# Inspecting node 1582129344
# Inspecting node 63863473
# Inspecting node 744530425
# Inspecting node 1367957858
# Inspecting node 2469606308
# Inspecting node 326461319
# Inspecting node 529665584
# Inspecting node 154271777
# Inspecting node 1270383308
# Inspecting node 2312086998
# Inspecting node 1447429249
# Inspecting node 2861279433
# Inspecting node 466832463
# Inspecting node 67278150
# Inspecting node 1660911480
# Inspecting node 467664297
# Inspecting node 2573566824
# Inspecting node 132989977
# Inspecting node 954431291629473794
# Inspecting node 238865666
# Inspecting node 2569323896
# Inspecting node 788806262045732864
# Inspecting node 14165217
# Inspecting node 1447951549
# Inspecting node 1594767902
# Inspecting node 491779798
# Inspecting node 946092660795744256
# Inspecting node 74211986
# Inspecting node 524590563
# Inspecting node 1338157627453427713
# Inspecting node 823317383838253056
# Inspecting node 1044778781230039042
# Inspecting node 922963142300143616
# Inspecting node 74937543
# Inspecting node 1305697758
# Inspecting node 18463733
# Inspecting node 76264942
# Inspecting node 2905252436
# Inspecting node 44539994
# Inspecting node 396745864
# Inspecting node 1176801
# Inspecting node 1229442788623818752
# Inspecting node 2993775174
# Inspecting node 2462641501
# Inspecting node 560903736
# Inspecting node 1427351911410257934
# Inspecting node 245651739
# Inspecting node 4922698441
# Inspecting node 4024032261
# Inspecting node 15099646
# Inspecting node 75841164
# Inspecting node 794664236
# Inspecting node 1440828246132596736
# Inspecting node 3069762388
# Inspecting node 700994268
# Inspecting node 1104945319
# Inspecting node 38221378
# Inspecting node 3218932860
# Inspecting node 1201882182
# Inspecting node 1395092719
# Inspecting node 2871728962
# Inspecting node 815428708144218112
# Inspecting node 976143225927839744
# Inspecting node 727212809948401664
# Inspecting node 1373435309782822912
# Inspecting node 568769809
# Inspecting node 982017242354388992
# Inspecting node 36395646
# Inspecting node 40697478
# Inspecting node 1423672567869624322
# Inspecting node 164368721
# Inspecting node 46214091
# Inspecting node 2194496264
# Inspecting node 1057723606027792385
# Inspecting node 25209036
# Inspecting node 1347801793930035200
# Inspecting node 868994263
# Inspecting node 117589552
# Inspecting node 1080529497152278528
# Inspecting node 624962704
# Inspecting node 47022386
# Inspecting node 942370814
# Inspecting node 70499348
# Inspecting node 929856990934790144
# Inspecting node 314093378
# Inspecting node 3053107588
# Inspecting node 1459578954
# Inspecting node 4880637512
# Inspecting node 1932563430
# Inspecting node 1282257536
# Inspecting node 17300548
# Inspecting node 1236439017433989122
# Inspecting node 1444458812614709250
# Inspecting node 1386793782683652096
# Inspecting node 9575562
# Inspecting node 120139457
# Inspecting node 1240478580510871552
# Inspecting node 117562974
# Inspecting node 312422268
# Inspecting node 1333030975681536000
# Inspecting node 1040629333210148865
# Inspecting node 252399534
# Inspecting node 2459730643
# Inspecting node 1264712331457638400
# Inspecting node 1428151019981180932
# Inspecting node 280831905
# Inspecting node 1416101066580627464
# Inspecting node 1135929275272634369
# Inspecting node 360214917
# Inspecting node 1302065426961174530
# Inspecting node 39637553
# Inspecting node 114977658
# Inspecting node 1327696892608724992
# Inspecting node 1409204814534299649
# Inspecting node 371939653
# Inspecting node 190010892
# Inspecting node 1275457555490320385
# Inspecting node 1445833073770184706
# Inspecting node 1601728627
# Inspecting node 41748110
# Inspecting node 1438198932606160901
# Inspecting node 16491468
# Inspecting node 323895654
# Inspecting node 137045661
# Inspecting node 1352682350228942848
# Inspecting node 770683230223634433
# Inspecting node 3368587707
# Inspecting node 1120673221236408320
# Inspecting node 213879574
# Inspecting node 1414982991059709954
# Inspecting node 809651491
# Inspecting node 1491487802
# Inspecting node 4886317138
# Inspecting node 14912051
# Inspecting node 915727372443414528
# Inspecting node 966560892262502400
# Inspecting node 885737117745164288
# Inspecting node 981191210705530880
# Inspecting node 341002490
# Inspecting node 1948425750
# Inspecting node 1391765775594180612
# Inspecting node 1346126893733462016
# Inspecting node 1443254711381946371
# Inspecting node 95348250
# Inspecting node 1351325172184264704
# Inspecting node 487857297
# Inspecting node 94885717
# Inspecting node 925876396878020608
# Inspecting node 15300266
# Inspecting node 1212089073323503616
# Inspecting node 239096810
# Inspecting node 1353758379160834051
# Inspecting node 24728011
# Inspecting node 85640352
# Inspecting node 1012839192253075456
# Inspecting node 1259289117805776896
# Inspecting node 1309184065
# Inspecting node 1881851268
# Inspecting node 132512731
# Inspecting node 1181627354621399040
# Inspecting node 34478789
# Inspecting node 2842764204
# Inspecting node 1034903210547277824
# Inspecting node 1202669441000996864
# Inspecting node 961989099623137280
# Inspecting node 1263895193784184832
# Inspecting node 471366697
# Inspecting node 829731473443975170
# Inspecting node 590822892
# Inspecting node 382409124
# Inspecting node 851681
# Inspecting node 870842873628864513
# Inspecting node 271124533
# Inspecting node 446471174
# Inspecting node 228477243
# Inspecting node 1202388934208172032
# Inspecting node 1060751566657867776
# Inspecting node 257304118
# Inspecting node 4096225454
# Inspecting node 216266808
# Inspecting node 159065078
# Inspecting node 1058391394681868289
# Inspecting node 428602423
# Inspecting node 823397168975409152
# Inspecting node 1345473368494104580
# Inspecting node 46563847
# Inspecting node 2444436240
# Inspecting node 1126848839594467328
# Inspecting node 1257895028724203521
# Inspecting node 277513651
# Inspecting node 1110790944821932034
# Inspecting node 1161332556312326144
# Inspecting node 1346332104234295296
# Inspecting node 165942840
# Inspecting node 259587504
# Inspecting node 1925416346
# Inspecting node 15012924
# Inspecting node 18537391
# Inspecting node 42989776
# Inspecting node 93654204
# Inspecting node 34921899
# Inspecting node 2239987934
# Inspecting node 86320422
# Inspecting node 171411616
# Inspecting node 14650213
# Inspecting node 1087961
# Inspecting node 602903529
# Inspecting node 244204227
# Inspecting node 519071482
# Inspecting node 251635353
# Inspecting node 5654722
# Inspecting node 725037770033532929
# Inspecting node 40059893
# Inspecting node 237480031
# Inspecting node 1056707817216720896
# Inspecting node 1383581104473468929
# Inspecting node 373477857
# Inspecting node 20122522
# Inspecting node 4254675664
# Inspecting node 1259345602980298753
# Inspecting node 725344413162049536
# Inspecting node 1433115420563853312
# Inspecting node 166701763
# Inspecting node 582342806
# Inspecting node 14257934
# Inspecting node 1163072647661522946
# Inspecting node 1201151072733138945
# Inspecting node 1352358388638875652
# Inspecting node 549023337
# Inspecting node 936473743387394048
# Inspecting node 437944231
# Inspecting node 400071841
# Inspecting node 637320913
# Inspecting node 19114577
# Inspecting node 70065285
# Inspecting node 1268920433086210048
# Inspecting node 1176689353885724674
# Inspecting node 460592390
# Inspecting node 2262160692
# Inspecting node 2293461198
# Inspecting node 15219830
# Inspecting node 1201532829860892673
# Inspecting node 92417373
# Inspecting node 122127786
# Inspecting node 362454062
# Inspecting node 2984610092
# Inspecting node 415126004
# Inspecting node 844452866
# Inspecting node 14501713
# Inspecting node 1258440535402065920
# Inspecting node 2254247360
# Inspecting node 104585835
# Inspecting node 1410832490701467650
# Inspecting node 365780558
# Inspecting node 21632994
# Inspecting node 1338474046095233026
# Inspecting node 1113547517105528833
# Inspecting node 293588108
# Inspecting node 1155208255066558475
# Inspecting node 22523896
# Inspecting node 3675933919
# Inspecting node 2796774360
# Inspecting node 1095219121447301120
# Inspecting node 816758120819015680
# Inspecting node 825925386110382080
# Inspecting node 1529643188
# Inspecting node 246811073
# Inspecting node 3351916392
# Inspecting node 123910630
# Inspecting node 29304563
# Inspecting node 1396107226608283649
# Inspecting node 549598823
# Inspecting node 797133264716754944
# Inspecting node 768559569891012608
# Inspecting node 1880517650
# Inspecting node 1232471924145577985
# Inspecting node 1300309398166949889
# Inspecting node 1923754400
# Inspecting node 53754232
# Inspecting node 307324209
# Inspecting node 3165242127
# Inspecting node 730826158258946050
# Inspecting node 1577656471
# Inspecting node 1214368702277308421
# Inspecting node 299993498
# Inspecting node 1235344992765448193
# Inspecting node 625193066
# Inspecting node 467817388
# Inspecting node 3135148227
# Inspecting node 872810605
# Inspecting node 271504586
# Inspecting node 306967462
# Inspecting node 3299469609
# Inspecting node 1225848216467509248
# Inspecting node 259388196
# Inspecting node 525910396
# Inspecting node 358143304
# Inspecting node 1088545656002801664
# Inspecting node 1283460034182209537
# Inspecting node 1326306504027287554
# Inspecting node 100874975
# Inspecting node 811549418
# Inspecting node 145058470
# Inspecting node 15892547
# Inspecting node 2797935107
# Inspecting node 27388441
# Inspecting node 288495993
# Inspecting node 77596220
# Inspecting node 891058415195303939
# Inspecting node 1095768409449459712
# Inspecting node 881426857
# Inspecting node 17388526

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.out_degree(node) 
    for key, value in out_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
degrees = {}
in_degrees = {}
out_degrees = {}

dirname = "Directed_Unweighted_Models/done_2"
directory = os.fsencode(dirname)

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    H = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    degree_dist = {}
    in_degree_dist = {}
    out_degree_dist = {}
    
    for node in H:
        degree_dist[node] = H.degree(node)
        in_degree_dist[node] = H.in_degree(node)
        out_degree_dist[node] = H.out_degree(node)
    degrees[filename] = degree_dist
    in_degrees[filename] = in_degree_dist
    out_degrees[filename] = out_degree_dist
# Out:
# Directed_Unweighted_Random_Null_Model_100
# Directed_Unweighted_Random_Null_Model_101
# Directed_Unweighted_Random_Null_Model_102
# Directed_Unweighted_Random_Null_Model_103
# Directed_Unweighted_Random_Null_Model_104
# Directed_Unweighted_Random_Null_Model_105
# Directed_Unweighted_Random_Null_Model_106
# Directed_Unweighted_Random_Null_Model_107
# Directed_Unweighted_Random_Null_Model_108
# Directed_Unweighted_Random_Null_Model_109
# Directed_Unweighted_Random_Null_Model_110
# Directed_Unweighted_Random_Null_Model_111
# Directed_Unweighted_Random_Null_Model_112
# Directed_Unweighted_Random_Null_Model_113
# Directed_Unweighted_Random_Null_Model_114
# Directed_Unweighted_Random_Null_Model_115
# Directed_Unweighted_Random_Null_Model_116
# Directed_Unweighted_Random_Null_Model_117
# Directed_Unweighted_Random_Null_Model_118
# Directed_Unweighted_Random_Null_Model_119
# Directed_Unweighted_Random_Null_Model_120
# Directed_Unweighted_Random_Null_Model_121
# Directed_Unweighted_Random_Null_Model_122
# Directed_Unweighted_Random_Null_Model_123
# Directed_Unweighted_Random_Null_Model_124
# Directed_Unweighted_Random_Null_Model_125
# Directed_Unweighted_Random_Null_Model_126
# Directed_Unweighted_Random_Null_Model_127
# Directed_Unweighted_Random_Null_Model_128
# Directed_Unweighted_Random_Null_Model_129
# Directed_Unweighted_Random_Null_Model_130
# Directed_Unweighted_Random_Null_Model_131
# Directed_Unweighted_Random_Null_Model_132
# Directed_Unweighted_Random_Null_Model_133
# Directed_Unweighted_Random_Null_Model_134
# Directed_Unweighted_Random_Null_Model_135
# Directed_Unweighted_Random_Null_Model_136
# Directed_Unweighted_Random_Null_Model_137
# Directed_Unweighted_Random_Null_Model_138
# Directed_Unweighted_Random_Null_Model_139
# Directed_Unweighted_Random_Null_Model_140
# Directed_Unweighted_Random_Null_Model_141
# Directed_Unweighted_Random_Null_Model_142
# Directed_Unweighted_Random_Null_Model_143
# Directed_Unweighted_Random_Null_Model_144
# Directed_Unweighted_Random_Null_Model_145
# Directed_Unweighted_Random_Null_Model_146
# Directed_Unweighted_Random_Null_Model_147
# Directed_Unweighted_Random_Null_Model_148
# Directed_Unweighted_Random_Null_Model_149
# Directed_Unweighted_Random_Null_Model_150
# Directed_Unweighted_Random_Null_Model_151
# Directed_Unweighted_Random_Null_Model_152
# Directed_Unweighted_Random_Null_Model_153
# Directed_Unweighted_Random_Null_Model_154
# Directed_Unweighted_Random_Null_Model_155
# Directed_Unweighted_Random_Null_Model_156
# Directed_Unweighted_Random_Null_Model_157
# Directed_Unweighted_Random_Null_Model_158
# Directed_Unweighted_Random_Null_Model_159
# Directed_Unweighted_Random_Null_Model_160
# Directed_Unweighted_Random_Null_Model_161
# Directed_Unweighted_Random_Null_Model_162
# Directed_Unweighted_Random_Null_Model_163
# Directed_Unweighted_Random_Null_Model_164
# Directed_Unweighted_Random_Null_Model_165
# Directed_Unweighted_Random_Null_Model_166
# Directed_Unweighted_Random_Null_Model_167
# Directed_Unweighted_Random_Null_Model_168
# Directed_Unweighted_Random_Null_Model_169
# Directed_Unweighted_Random_Null_Model_170
# Directed_Unweighted_Random_Null_Model_171
# Directed_Unweighted_Random_Null_Model_172
# Directed_Unweighted_Random_Null_Model_173
# Directed_Unweighted_Random_Null_Model_174
# Directed_Unweighted_Random_Null_Model_175
# Directed_Unweighted_Random_Null_Model_176
# Directed_Unweighted_Random_Null_Model_177
# Directed_Unweighted_Random_Null_Model_178
# Directed_Unweighted_Random_Null_Model_179
# Directed_Unweighted_Random_Null_Model_180
# Directed_Unweighted_Random_Null_Model_181
# Directed_Unweighted_Random_Null_Model_182
# Directed_Unweighted_Random_Null_Model_183
# Directed_Unweighted_Random_Null_Model_184
# Directed_Unweighted_Random_Null_Model_185
# Directed_Unweighted_Random_Null_Model_186
# Directed_Unweighted_Random_Null_Model_187
# Directed_Unweighted_Random_Null_Model_188
# Directed_Unweighted_Random_Null_Model_189
# Directed_Unweighted_Random_Null_Model_190
# Directed_Unweighted_Random_Null_Model_191
# Directed_Unweighted_Random_Null_Model_192
# Directed_Unweighted_Random_Null_Model_193
# Directed_Unweighted_Random_Null_Model_194
# Directed_Unweighted_Random_Null_Model_195
# Directed_Unweighted_Random_Null_Model_196
# Directed_Unweighted_Random_Null_Model_197
# Directed_Unweighted_Random_Null_Model_198
# Directed_Unweighted_Random_Null_Model_199
# Directed_Unweighted_Random_Null_Model_200
# Directed_Unweighted_Random_Null_Model_201
# Directed_Unweighted_Random_Null_Model_202
# Directed_Unweighted_Random_Null_Model_203
# Directed_Unweighted_Random_Null_Model_204
# Directed_Unweighted_Random_Null_Model_205
# Directed_Unweighted_Random_Null_Model_206
# Directed_Unweighted_Random_Null_Model_207
# Directed_Unweighted_Random_Null_Model_208
# Directed_Unweighted_Random_Null_Model_209
# Directed_Unweighted_Random_Null_Model_210
# Directed_Unweighted_Random_Null_Model_211
# Directed_Unweighted_Random_Null_Model_212
# Directed_Unweighted_Random_Null_Model_213
# Directed_Unweighted_Random_Null_Model_214
# Directed_Unweighted_Random_Null_Model_215
# Directed_Unweighted_Random_Null_Model_216
# Directed_Unweighted_Random_Null_Model_217
# Directed_Unweighted_Random_Null_Model_218
# Directed_Unweighted_Random_Null_Model_219
# Directed_Unweighted_Random_Null_Model_220
# Directed_Unweighted_Random_Null_Model_221
# Directed_Unweighted_Random_Null_Model_222
# Directed_Unweighted_Random_Null_Model_223
# Directed_Unweighted_Random_Null_Model_224
# Directed_Unweighted_Random_Null_Model_225
# Directed_Unweighted_Random_Null_Model_226
# Directed_Unweighted_Random_Null_Model_227
# Directed_Unweighted_Random_Null_Model_228
# Directed_Unweighted_Random_Null_Model_229
# Directed_Unweighted_Random_Null_Model_230
# Directed_Unweighted_Random_Null_Model_231
# Directed_Unweighted_Random_Null_Model_232
# Directed_Unweighted_Random_Null_Model_233
# Directed_Unweighted_Random_Null_Model_234
# Directed_Unweighted_Random_Null_Model_235
# Directed_Unweighted_Random_Null_Model_236
# Directed_Unweighted_Random_Null_Model_237
# Directed_Unweighted_Random_Null_Model_238
# Directed_Unweighted_Random_Null_Model_239
# Directed_Unweighted_Random_Null_Model_240
# Directed_Unweighted_Random_Null_Model_241
# Directed_Unweighted_Random_Null_Model_242
# Directed_Unweighted_Random_Null_Model_243
# Directed_Unweighted_Random_Null_Model_244
# Directed_Unweighted_Random_Null_Model_245
# Directed_Unweighted_Random_Null_Model_246
# Directed_Unweighted_Random_Null_Model_247
# Directed_Unweighted_Random_Null_Model_248
# Directed_Unweighted_Random_Null_Model_249
# Directed_Unweighted_Random_Null_Model_250
# Directed_Unweighted_Random_Null_Model_251
# Directed_Unweighted_Random_Null_Model_252
# Directed_Unweighted_Random_Null_Model_253
# Directed_Unweighted_Random_Null_Model_254
# Directed_Unweighted_Random_Null_Model_255
# Directed_Unweighted_Random_Null_Model_256
# Directed_Unweighted_Random_Null_Model_257
# Directed_Unweighted_Random_Null_Model_258
# Directed_Unweighted_Random_Null_Model_259
# Directed_Unweighted_Random_Null_Model_260
# Directed_Unweighted_Random_Null_Model_261
# Directed_Unweighted_Random_Null_Model_262
# Directed_Unweighted_Random_Null_Model_263
# Directed_Unweighted_Random_Null_Model_264
# Directed_Unweighted_Random_Null_Model_265
# Directed_Unweighted_Random_Null_Model_266
# Directed_Unweighted_Random_Null_Model_267
# Directed_Unweighted_Random_Null_Model_268
# Directed_Unweighted_Random_Null_Model_269
# Directed_Unweighted_Random_Null_Model_270
# Directed_Unweighted_Random_Null_Model_271
# Directed_Unweighted_Random_Null_Model_272
# Directed_Unweighted_Random_Null_Model_273
# Directed_Unweighted_Random_Null_Model_274
# Directed_Unweighted_Random_Null_Model_275
# Directed_Unweighted_Random_Null_Model_276
# Directed_Unweighted_Random_Null_Model_277
# Directed_Unweighted_Random_Null_Model_278
# Directed_Unweighted_Random_Null_Model_279
# Directed_Unweighted_Random_Null_Model_280
# Directed_Unweighted_Random_Null_Model_281
# Directed_Unweighted_Random_Null_Model_282
# Directed_Unweighted_Random_Null_Model_283
# Directed_Unweighted_Random_Null_Model_284
# Directed_Unweighted_Random_Null_Model_285
# Directed_Unweighted_Random_Null_Model_286
# Directed_Unweighted_Random_Null_Model_287
# Directed_Unweighted_Random_Null_Model_288
# Directed_Unweighted_Random_Null_Model_289
# Directed_Unweighted_Random_Null_Model_290
# Directed_Unweighted_Random_Null_Model_291
# Directed_Unweighted_Random_Null_Model_292
# Directed_Unweighted_Random_Null_Model_293
# Directed_Unweighted_Random_Null_Model_294
# Directed_Unweighted_Random_Null_Model_300
# Directed_Unweighted_Random_Null_Model_301
# Directed_Unweighted_Random_Null_Model_302
# Directed_Unweighted_Random_Null_Model_303
# Directed_Unweighted_Random_Null_Model_304
# Directed_Unweighted_Random_Null_Model_305
# Directed_Unweighted_Random_Null_Model_306
# Directed_Unweighted_Random_Null_Model_307
# Directed_Unweighted_Random_Null_Model_308
# Directed_Unweighted_Random_Null_Model_309
# Directed_Unweighted_Random_Null_Model_310
# Directed_Unweighted_Random_Null_Model_311
# Directed_Unweighted_Random_Null_Model_312
# Directed_Unweighted_Random_Null_Model_313
# Directed_Unweighted_Random_Null_Model_314
# Directed_Unweighted_Random_Null_Model_315
# Directed_Unweighted_Random_Null_Model_316
# Directed_Unweighted_Random_Null_Model_317
# Directed_Unweighted_Random_Null_Model_318
# Directed_Unweighted_Random_Null_Model_319
# Directed_Unweighted_Random_Null_Model_320
# Directed_Unweighted_Random_Null_Model_321
# Directed_Unweighted_Random_Null_Model_322
# Directed_Unweighted_Random_Null_Model_323
# Directed_Unweighted_Random_Null_Model_324
# Directed_Unweighted_Random_Null_Model_325
# Directed_Unweighted_Random_Null_Model_326
# Directed_Unweighted_Random_Null_Model_327
# Directed_Unweighted_Random_Null_Model_328
# Directed_Unweighted_Random_Null_Model_329
# Directed_Unweighted_Random_Null_Model_330
# Directed_Unweighted_Random_Null_Model_331
# Directed_Unweighted_Random_Null_Model_332
# Directed_Unweighted_Random_Null_Model_333
# Directed_Unweighted_Random_Null_Model_334
# Directed_Unweighted_Random_Null_Model_335
# Directed_Unweighted_Random_Null_Model_336
# Directed_Unweighted_Random_Null_Model_337
# Directed_Unweighted_Random_Null_Model_338
# Directed_Unweighted_Random_Null_Model_339
# Directed_Unweighted_Random_Null_Model_340
# Directed_Unweighted_Random_Null_Model_341
# Directed_Unweighted_Random_Null_Model_342
# Directed_Unweighted_Random_Null_Model_343
# Directed_Unweighted_Random_Null_Model_344
# Directed_Unweighted_Random_Null_Model_345
# Directed_Unweighted_Random_Null_Model_346
# Directed_Unweighted_Random_Null_Model_347
# Directed_Unweighted_Random_Null_Model_348
# Directed_Unweighted_Random_Null_Model_349
# Directed_Unweighted_Random_Null_Model_350
# Directed_Unweighted_Random_Null_Model_351
# Directed_Unweighted_Random_Null_Model_352
# Directed_Unweighted_Random_Null_Model_353
# Directed_Unweighted_Random_Null_Model_354
# Directed_Unweighted_Random_Null_Model_355
# Directed_Unweighted_Random_Null_Model_356
# Directed_Unweighted_Random_Null_Model_357
# Directed_Unweighted_Random_Null_Model_358
# Directed_Unweighted_Random_Null_Model_359
# Directed_Unweighted_Random_Null_Model_360
# Directed_Unweighted_Random_Null_Model_361
# Directed_Unweighted_Random_Null_Model_362
# Directed_Unweighted_Random_Null_Model_363
# Directed_Unweighted_Random_Null_Model_364
# Directed_Unweighted_Random_Null_Model_365
# Directed_Unweighted_Random_Null_Model_366
# Directed_Unweighted_Random_Null_Model_367
# Directed_Unweighted_Random_Null_Model_368
# Directed_Unweighted_Random_Null_Model_369
# Directed_Unweighted_Random_Null_Model_370
# Directed_Unweighted_Random_Null_Model_371
# Directed_Unweighted_Random_Null_Model_372
# Directed_Unweighted_Random_Null_Model_373
# Directed_Unweighted_Random_Null_Model_374
# Directed_Unweighted_Random_Null_Model_375
# Directed_Unweighted_Random_Null_Model_376
# Directed_Unweighted_Random_Null_Model_377
# Directed_Unweighted_Random_Null_Model_378
# Directed_Unweighted_Random_Null_Model_379
# Directed_Unweighted_Random_Null_Model_380
# Directed_Unweighted_Random_Null_Model_381
# Directed_Unweighted_Random_Null_Model_382
# Directed_Unweighted_Random_Null_Model_383
# Directed_Unweighted_Random_Null_Model_384
# Directed_Unweighted_Random_Null_Model_385
# Directed_Unweighted_Random_Null_Model_386
# Directed_Unweighted_Random_Null_Model_387
# Directed_Unweighted_Random_Null_Model_388
# Directed_Unweighted_Random_Null_Model_389
# Directed_Unweighted_Random_Null_Model_390
# Directed_Unweighted_Random_Null_Model_391
# Directed_Unweighted_Random_Null_Model_392
# Directed_Unweighted_Random_Null_Model_393
# Directed_Unweighted_Random_Null_Model_394
# Directed_Unweighted_Random_Null_Model_395
# Directed_Unweighted_Random_Null_Model_396
# Directed_Unweighted_Random_Null_Model_397
# Directed_Unweighted_Random_Null_Model_398
# Directed_Unweighted_Random_Null_Model_399
# Directed_Unweighted_Random_Null_Model_400
# Directed_Unweighted_Random_Null_Model_401
# Directed_Unweighted_Random_Null_Model_402
# Directed_Unweighted_Random_Null_Model_403
# Directed_Unweighted_Random_Null_Model_404
# Directed_Unweighted_Random_Null_Model_405
# Directed_Unweighted_Random_Null_Model_406
# Directed_Unweighted_Random_Null_Model_407
# Directed_Unweighted_Random_Null_Model_408
# Directed_Unweighted_Random_Null_Model_409
# Directed_Unweighted_Random_Null_Model_41
# Directed_Unweighted_Random_Null_Model_410
# Directed_Unweighted_Random_Null_Model_411
# Directed_Unweighted_Random_Null_Model_412
# Directed_Unweighted_Random_Null_Model_413
# Directed_Unweighted_Random_Null_Model_414
# Directed_Unweighted_Random_Null_Model_415
# Directed_Unweighted_Random_Null_Model_416
# Directed_Unweighted_Random_Null_Model_417
# Directed_Unweighted_Random_Null_Model_418
# Directed_Unweighted_Random_Null_Model_419
# Directed_Unweighted_Random_Null_Model_42
# Directed_Unweighted_Random_Null_Model_420
# Directed_Unweighted_Random_Null_Model_421
# Directed_Unweighted_Random_Null_Model_422
# Directed_Unweighted_Random_Null_Model_423
# Directed_Unweighted_Random_Null_Model_424
# Directed_Unweighted_Random_Null_Model_425
# Directed_Unweighted_Random_Null_Model_426
# Directed_Unweighted_Random_Null_Model_427
# Directed_Unweighted_Random_Null_Model_428
# Directed_Unweighted_Random_Null_Model_429
# Directed_Unweighted_Random_Null_Model_43
# Directed_Unweighted_Random_Null_Model_430
# Directed_Unweighted_Random_Null_Model_431
# Directed_Unweighted_Random_Null_Model_432
# Directed_Unweighted_Random_Null_Model_433
# Directed_Unweighted_Random_Null_Model_434
# Directed_Unweighted_Random_Null_Model_435
# Directed_Unweighted_Random_Null_Model_436
# Directed_Unweighted_Random_Null_Model_437
# Directed_Unweighted_Random_Null_Model_438
# Directed_Unweighted_Random_Null_Model_439
# Directed_Unweighted_Random_Null_Model_44
# Directed_Unweighted_Random_Null_Model_440
# Directed_Unweighted_Random_Null_Model_441
# Directed_Unweighted_Random_Null_Model_442
# Directed_Unweighted_Random_Null_Model_443
# Directed_Unweighted_Random_Null_Model_444
# Directed_Unweighted_Random_Null_Model_445
# Directed_Unweighted_Random_Null_Model_446
# Directed_Unweighted_Random_Null_Model_447
# Directed_Unweighted_Random_Null_Model_448
# Directed_Unweighted_Random_Null_Model_449
# Directed_Unweighted_Random_Null_Model_45
# Directed_Unweighted_Random_Null_Model_450
# Directed_Unweighted_Random_Null_Model_451
# Directed_Unweighted_Random_Null_Model_452
# Directed_Unweighted_Random_Null_Model_453
# Directed_Unweighted_Random_Null_Model_454
# Directed_Unweighted_Random_Null_Model_455
# Directed_Unweighted_Random_Null_Model_456
# Directed_Unweighted_Random_Null_Model_457
# Directed_Unweighted_Random_Null_Model_458
# Directed_Unweighted_Random_Null_Model_459
# Directed_Unweighted_Random_Null_Model_46
# Directed_Unweighted_Random_Null_Model_460
# Directed_Unweighted_Random_Null_Model_461
# Directed_Unweighted_Random_Null_Model_462
# Directed_Unweighted_Random_Null_Model_463
# Directed_Unweighted_Random_Null_Model_464
# Directed_Unweighted_Random_Null_Model_465
# Directed_Unweighted_Random_Null_Model_466
# Directed_Unweighted_Random_Null_Model_467
# Directed_Unweighted_Random_Null_Model_468
# Directed_Unweighted_Random_Null_Model_469
# Directed_Unweighted_Random_Null_Model_47
# Directed_Unweighted_Random_Null_Model_470
# Directed_Unweighted_Random_Null_Model_471
# Directed_Unweighted_Random_Null_Model_472
# Directed_Unweighted_Random_Null_Model_473
# Directed_Unweighted_Random_Null_Model_474
# Directed_Unweighted_Random_Null_Model_475
# Directed_Unweighted_Random_Null_Model_476
# Directed_Unweighted_Random_Null_Model_477
# Directed_Unweighted_Random_Null_Model_478
# Directed_Unweighted_Random_Null_Model_479
# Directed_Unweighted_Random_Null_Model_48
# Directed_Unweighted_Random_Null_Model_480
# Directed_Unweighted_Random_Null_Model_481
# Directed_Unweighted_Random_Null_Model_482
# Directed_Unweighted_Random_Null_Model_483
# Directed_Unweighted_Random_Null_Model_484
# Directed_Unweighted_Random_Null_Model_485
# Directed_Unweighted_Random_Null_Model_486
# Directed_Unweighted_Random_Null_Model_487
# Directed_Unweighted_Random_Null_Model_488
# Directed_Unweighted_Random_Null_Model_489
# Directed_Unweighted_Random_Null_Model_49
# Directed_Unweighted_Random_Null_Model_490
# Directed_Unweighted_Random_Null_Model_491
# Directed_Unweighted_Random_Null_Model_492
# Directed_Unweighted_Random_Null_Model_493
# Directed_Unweighted_Random_Null_Model_494
# Directed_Unweighted_Random_Null_Model_495
# Directed_Unweighted_Random_Null_Model_496
# Directed_Unweighted_Random_Null_Model_497
# Directed_Unweighted_Random_Null_Model_498
# Directed_Unweighted_Random_Null_Model_499
# Directed_Unweighted_Random_Null_Model_50
# Directed_Unweighted_Random_Null_Model_500
# Directed_Unweighted_Random_Null_Model_501
# Directed_Unweighted_Random_Null_Model_502
# Directed_Unweighted_Random_Null_Model_503
# Directed_Unweighted_Random_Null_Model_504
# Directed_Unweighted_Random_Null_Model_505
# Directed_Unweighted_Random_Null_Model_506
# Directed_Unweighted_Random_Null_Model_507
# Directed_Unweighted_Random_Null_Model_508
# Directed_Unweighted_Random_Null_Model_509
# Directed_Unweighted_Random_Null_Model_51
# Directed_Unweighted_Random_Null_Model_510
# Directed_Unweighted_Random_Null_Model_511
# Directed_Unweighted_Random_Null_Model_512
# Directed_Unweighted_Random_Null_Model_513
# Directed_Unweighted_Random_Null_Model_514
# Directed_Unweighted_Random_Null_Model_515
# Directed_Unweighted_Random_Null_Model_516
# Directed_Unweighted_Random_Null_Model_517
# Directed_Unweighted_Random_Null_Model_518
# Directed_Unweighted_Random_Null_Model_519
# Directed_Unweighted_Random_Null_Model_52
# Directed_Unweighted_Random_Null_Model_520
# Directed_Unweighted_Random_Null_Model_521
# Directed_Unweighted_Random_Null_Model_522
# Directed_Unweighted_Random_Null_Model_523
# Directed_Unweighted_Random_Null_Model_524
# Directed_Unweighted_Random_Null_Model_525
# Directed_Unweighted_Random_Null_Model_526
# Directed_Unweighted_Random_Null_Model_527
# Directed_Unweighted_Random_Null_Model_528
# Directed_Unweighted_Random_Null_Model_529
# Directed_Unweighted_Random_Null_Model_53
# Directed_Unweighted_Random_Null_Model_530
# Directed_Unweighted_Random_Null_Model_531
# Directed_Unweighted_Random_Null_Model_532
# Directed_Unweighted_Random_Null_Model_533
# Directed_Unweighted_Random_Null_Model_534
# Directed_Unweighted_Random_Null_Model_535
# Directed_Unweighted_Random_Null_Model_536
# Directed_Unweighted_Random_Null_Model_537
# Directed_Unweighted_Random_Null_Model_538
# Directed_Unweighted_Random_Null_Model_539
# Directed_Unweighted_Random_Null_Model_54
# Directed_Unweighted_Random_Null_Model_540
# Directed_Unweighted_Random_Null_Model_541
# Directed_Unweighted_Random_Null_Model_542
# Directed_Unweighted_Random_Null_Model_543
# Directed_Unweighted_Random_Null_Model_544
# Directed_Unweighted_Random_Null_Model_545
# Directed_Unweighted_Random_Null_Model_546
# Directed_Unweighted_Random_Null_Model_547
# Directed_Unweighted_Random_Null_Model_548
# Directed_Unweighted_Random_Null_Model_549
# Directed_Unweighted_Random_Null_Model_55
# Directed_Unweighted_Random_Null_Model_550
# Directed_Unweighted_Random_Null_Model_551
# Directed_Unweighted_Random_Null_Model_552
# Directed_Unweighted_Random_Null_Model_553
# Directed_Unweighted_Random_Null_Model_554
# Directed_Unweighted_Random_Null_Model_555
# Directed_Unweighted_Random_Null_Model_556
# Directed_Unweighted_Random_Null_Model_557
# Directed_Unweighted_Random_Null_Model_558
# Directed_Unweighted_Random_Null_Model_559
# Directed_Unweighted_Random_Null_Model_56
# Directed_Unweighted_Random_Null_Model_560
# Directed_Unweighted_Random_Null_Model_561
# Directed_Unweighted_Random_Null_Model_562
# Directed_Unweighted_Random_Null_Model_563
# Directed_Unweighted_Random_Null_Model_564
# Directed_Unweighted_Random_Null_Model_565
# Directed_Unweighted_Random_Null_Model_566
# Directed_Unweighted_Random_Null_Model_567
# Directed_Unweighted_Random_Null_Model_568
# Directed_Unweighted_Random_Null_Model_569
# Directed_Unweighted_Random_Null_Model_57
# Directed_Unweighted_Random_Null_Model_570
# Directed_Unweighted_Random_Null_Model_571
# Directed_Unweighted_Random_Null_Model_572
# Directed_Unweighted_Random_Null_Model_573
# Directed_Unweighted_Random_Null_Model_574
# Directed_Unweighted_Random_Null_Model_575
# Directed_Unweighted_Random_Null_Model_576
# Directed_Unweighted_Random_Null_Model_58
# Directed_Unweighted_Random_Null_Model_59
# Directed_Unweighted_Random_Null_Model_60
# Directed_Unweighted_Random_Null_Model_61
# Directed_Unweighted_Random_Null_Model_62
# Directed_Unweighted_Random_Null_Model_63
# Directed_Unweighted_Random_Null_Model_64
# Directed_Unweighted_Random_Null_Model_65
# Directed_Unweighted_Random_Null_Model_66
# Directed_Unweighted_Random_Null_Model_67
# Directed_Unweighted_Random_Null_Model_68
# Directed_Unweighted_Random_Null_Model_69
# Directed_Unweighted_Random_Null_Model_70
# Directed_Unweighted_Random_Null_Model_71
# Directed_Unweighted_Random_Null_Model_72
# Directed_Unweighted_Random_Null_Model_73
# Directed_Unweighted_Random_Null_Model_74
# Directed_Unweighted_Random_Null_Model_75
# Directed_Unweighted_Random_Null_Model_76
# Directed_Unweighted_Random_Null_Model_77
# Directed_Unweighted_Random_Null_Model_78
# Directed_Unweighted_Random_Null_Model_79
# Directed_Unweighted_Random_Null_Model_80
# Directed_Unweighted_Random_Null_Model_81
# Directed_Unweighted_Random_Null_Model_82
# Directed_Unweighted_Random_Null_Model_83
# Directed_Unweighted_Random_Null_Model_84
# Directed_Unweighted_Random_Null_Model_85
# Directed_Unweighted_Random_Null_Model_86
# Directed_Unweighted_Random_Null_Model_87
# Directed_Unweighted_Random_Null_Model_88
# Directed_Unweighted_Random_Null_Model_89
# Directed_Unweighted_Random_Null_Model_90
# Directed_Unweighted_Random_Null_Model_91
# Directed_Unweighted_Random_Null_Model_92
# Directed_Unweighted_Random_Null_Model_93
# Directed_Unweighted_Random_Null_Model_94
# Directed_Unweighted_Random_Null_Model_95
# Directed_Unweighted_Random_Null_Model_96
# Directed_Unweighted_Random_Null_Model_97
# Directed_Unweighted_Random_Null_Model_98
# Directed_Unweighted_Random_Null_Model_99

# %% [markdown]
# Go through each degree node in G and for each of the models check if some degree is different. If it is stop and report it

# %%
for node in G:
    print("Inspecting node {}".format(node))
    expectedDeg = G.degree(node) 
    for key, value in degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break
# Out:
# Inspecting node 1385933370090209280
# Inspecting node 158095776
# Inspecting node 1416535505454338050
# Inspecting node 1604931252
# Inspecting node 544695802
# Inspecting node 716257068538327040
# Inspecting node 258170457
# Inspecting node 1086084557009575936
# Inspecting node 2817389862
# Inspecting node 822476228548403200
# Inspecting node 2353730881
# Inspecting node 921026239808208896
# Inspecting node 720934098223542272
# Inspecting node 2922779039
# Inspecting node 552891173
# Inspecting node 982496635
# Inspecting node 1433403537329819654
# Inspecting node 1175052073605353473
# Inspecting node 2784661153
# Inspecting node 102887506
# Inspecting node 18681111
# Inspecting node 952980338745147394
# Inspecting node 1438871779779530755
# Inspecting node 46975259
# Inspecting node 1157395568135557120
# Inspecting node 21951711
# Inspecting node 563064119
# Inspecting node 277332906
# Inspecting node 158458133
# Inspecting node 979827806023618560
# Inspecting node 18308257
# Inspecting node 846667915
# Inspecting node 258916078
# Inspecting node 1138564320390836224
# Inspecting node 17912334
# Inspecting node 2821464243
# Inspecting node 928790819145842688
# Inspecting node 753638148958216192
# Inspecting node 2256955027
# Inspecting node 1185936230393024512
# Inspecting node 14079041
# Inspecting node 3021899490
# Inspecting node 13880132
# Inspecting node 960624707820113920
# Inspecting node 52003137
# Inspecting node 1887595058
# Inspecting node 331864347
# Inspecting node 961514730
# Inspecting node 70750793
# Inspecting node 155629527
# Inspecting node 1161351506983038976
# Inspecting node 766360387
# Inspecting node 150270263
# Inspecting node 38471212
# Inspecting node 83153695
# Inspecting node 118937966
# Inspecting node 871189841186357248
# Inspecting node 293403080
# Inspecting node 629539554
# Inspecting node 1104422828
# Inspecting node 602083976
# Inspecting node 1311896805920043009
# Inspecting node 1318741345905922048
# Inspecting node 25314619
# Inspecting node 104300984
# Inspecting node 15702055
# Inspecting node 1153463878195589125
# Inspecting node 15633240
# Inspecting node 14991184
# Inspecting node 1242522201770856449
# Inspecting node 1440522413687521295
# Inspecting node 106524304
# Inspecting node 1292608204845834241
# Inspecting node 1446846657551683588
# Inspecting node 1389700907697270787
# Inspecting node 1445880242707570691
# Inspecting node 1545912997
# Inspecting node 831084798621782016
# Inspecting node 55976571
# Inspecting node 305401065
# Inspecting node 704798725747531776
# Inspecting node 47452040
# Inspecting node 475298690
# Inspecting node 16220555
# Inspecting node 4744498950
# Inspecting node 766759351973404672
# Inspecting node 47781573
# Inspecting node 994077337
# Inspecting node 14055736
# Inspecting node 1236010900693356549
# Inspecting node 1171683272
# Inspecting node 1338338931792756737
# Inspecting node 562243642
# Inspecting node 15772683
# Inspecting node 1251340447387172868
# Inspecting node 1350484767255519233
# Inspecting node 1335046616697372675
# Inspecting node 20750271
# Inspecting node 1162219997977960449
# Inspecting node 175259033
# Inspecting node 130909683
# Inspecting node 1364261390614106113
# Inspecting node 44416854
# Inspecting node 1511003670
# Inspecting node 536594609
# Inspecting node 24913022
# Inspecting node 17823761
# Inspecting node 273683993
# Inspecting node 215632349
# Inspecting node 1156602559378804741
# Inspecting node 1156033982586208256
# Inspecting node 47338701
# Inspecting node 139819609
# Inspecting node 413514250
# Inspecting node 2852899113
# Inspecting node 1381435843492085760
# Inspecting node 1189800120
# Inspecting node 138418077
# Inspecting node 382489139
# Inspecting node 374300583
# Inspecting node 3226840807
# Inspecting node 133863908
# Inspecting node 57127265
# Inspecting node 142731825
# Inspecting node 1417929933800751104
# Inspecting node 55823004
# Inspecting node 1447315781289750532
# Inspecting node 14262411
# Inspecting node 1707636642
# Inspecting node 845487573011173380
# Inspecting node 109144163
# Inspecting node 20199202
# Inspecting node 785448020628430849
# Inspecting node 77283552
# Inspecting node 38055290
# Inspecting node 34506336
# Inspecting node 242798024
# Inspecting node 138077463
# Inspecting node 121343164
# Inspecting node 814078628
# Inspecting node 196717787
# Inspecting node 18519855
# Inspecting node 268824309
# Inspecting node 2439928526
# Inspecting node 1169378542737661954
# Inspecting node 299228245
# Inspecting node 2369365718
# Inspecting node 1373493122
# Inspecting node 2834753506
# Inspecting node 999476893970763777
# Inspecting node 120320139
# Inspecting node 84734389
# Inspecting node 15407637
# Inspecting node 1899063048
# Inspecting node 1301967293849755653
# Inspecting node 324602007
# Inspecting node 292667439
# Inspecting node 522345885
# Inspecting node 12599562
# Inspecting node 4856851754
# Inspecting node 1248842158553141250
# Inspecting node 4026045455
# Inspecting node 3303438653
# Inspecting node 1129203001
# Inspecting node 2813664079
# Inspecting node 14518712
# Inspecting node 95209129
# Inspecting node 119797208
# Inspecting node 201984482
# Inspecting node 593944500
# Inspecting node 17105128
# Inspecting node 3409346380
# Inspecting node 33826892
# Inspecting node 273866823
# Inspecting node 37552089
# Inspecting node 377588094
# Inspecting node 266855812
# Inspecting node 341866567
# Inspecting node 60916234
# Inspecting node 262436837
# Inspecting node 1092244447184719873
# Inspecting node 2548489298
# Inspecting node 218952640
# Inspecting node 1382491059247255554
# Inspecting node 516915897
# Inspecting node 965028316460797953
# Inspecting node 195899568
# Inspecting node 2432750568
# Inspecting node 331067472
# Inspecting node 272133230
# Inspecting node 108413104
# Inspecting node 177347829
# Inspecting node 964446120402300928
# Inspecting node 1573418346
# Inspecting node 89496127
# Inspecting node 735508941258399744
# Inspecting node 542244178
# Inspecting node 1005899772916477952
# Inspecting node 366171300
# Inspecting node 29545977
# Inspecting node 59686058
# Inspecting node 965478102594863104
# Inspecting node 366225624
# Inspecting node 393713239
# Inspecting node 1185972487538040832
# Inspecting node 889661863100907520
# Inspecting node 2813399220
# Inspecting node 2436061363
# Inspecting node 17900758
# Inspecting node 23491400
# Inspecting node 382949896
# Inspecting node 1009115210546929664
# Inspecting node 3148281878
# Inspecting node 1064964294448750595
# Inspecting node 814289414
# Inspecting node 2896012540
# Inspecting node 1280589273335500801
# Inspecting node 1227766472921014272
# Inspecting node 869639001400942592
# Inspecting node 116679707
# Inspecting node 342176065
# Inspecting node 1890389540
# Inspecting node 2785990732
# Inspecting node 40591485
# Inspecting node 3191905064
# Inspecting node 25813888
# Inspecting node 237536271
# Inspecting node 16982577
# Inspecting node 1563418116
# Inspecting node 2580573206
# Inspecting node 275979196
# Inspecting node 193471925
# Inspecting node 53772503
# Inspecting node 16195103
# Inspecting node 2776775090
# Inspecting node 998590102573023232
# Inspecting node 179129165
# Inspecting node 27101995
# Inspecting node 872156101
# Inspecting node 128908662
# Inspecting node 363070453
# Inspecting node 211564038
# Inspecting node 189349553
# Inspecting node 25127782
# Inspecting node 1166717268975333376
# Inspecting node 40550119
# Inspecting node 417389780
# Inspecting node 61521038
# Inspecting node 85428184
# Inspecting node 58319221
# Inspecting node 52080359
# Inspecting node 2513973205
# Inspecting node 283226685
# Inspecting node 45848808
# Inspecting node 1646334073
# Inspecting node 1360838234
# Inspecting node 21221149
# Inspecting node 507802048
# Inspecting node 190231473
# Inspecting node 993705834470367232
# Inspecting node 360677740
# Inspecting node 1362286033
# Inspecting node 3079986094
# Inspecting node 268528986
# Inspecting node 321752222
# Inspecting node 17280115
# Inspecting node 274220538
# Inspecting node 2352629420
# Inspecting node 51184630
# Inspecting node 908811901
# Inspecting node 408526152
# Inspecting node 371447080
# Inspecting node 2314531026
# Inspecting node 1172199939243425792
# Inspecting node 390392773
# Inspecting node 2289973748
# Inspecting node 495066576
# Inspecting node 1545053600
# Inspecting node 1318671397560979456
# Inspecting node 2891740872
# Inspecting node 2848993491
# Inspecting node 103297393
# Inspecting node 1851634098
# Inspecting node 398483708
# Inspecting node 1313212802799206406
# Inspecting node 79260190
# Inspecting node 27652488
# Inspecting node 89609585
# Inspecting node 44618408
# Inspecting node 880491635896922112
# Inspecting node 2761710808
# Inspecting node 1240867313445830656
# Inspecting node 247412217
# Inspecting node 1347654502787076096
# Inspecting node 982630470008553474
# Inspecting node 82167100
# Inspecting node 110754237
# Inspecting node 768069259100622848
# Inspecting node 1304210384367349770
# Inspecting node 1300291239581892609
# Inspecting node 2253903906
# Inspecting node 78403337
# Inspecting node 862703683
# Inspecting node 1071951545212723200
# Inspecting node 840470152391016448
# Inspecting node 498423001
# Inspecting node 1197522605760303104
# Inspecting node 510093784
# Inspecting node 447415943
# Inspecting node 1201788959719936007
# Inspecting node 1633538270
# Inspecting node 122525211
# Inspecting node 192842634
# Inspecting node 551152504
# Inspecting node 378351271
# Inspecting node 57033548
# Inspecting node 255067647
# Inspecting node 35863342
# Inspecting node 2715275551
# Inspecting node 719557076599619584
# Inspecting node 980875592
# Inspecting node 1051100859831148544
# Inspecting node 2300474413
# Inspecting node 1238447220
# Inspecting node 994295935
# Inspecting node 838098877
# Inspecting node 829761553218072576
# Inspecting node 951280545421410305
# Inspecting node 1157684886
# Inspecting node 80970676
# Inspecting node 18923250
# Inspecting node 1136294664
# Inspecting node 951892305098788864
# Inspecting node 3010143902
# Inspecting node 297020666
# Inspecting node 1045793762063060992
# Inspecting node 98588419
# Inspecting node 76179144
# Inspecting node 46956207
# Inspecting node 819853925184638976
# Inspecting node 16552108
# Inspecting node 29754743
# Inspecting node 153515520
# Inspecting node 386330680
# Inspecting node 2736446758
# Inspecting node 35095520
# Inspecting node 1239564608941113347
# Inspecting node 58261480
# Inspecting node 169614697
# Inspecting node 1005522675761057792
# Inspecting node 816308397360508928
# Inspecting node 1407160205117435908
# Inspecting node 1175457080561537025
# Inspecting node 1011936943247101952
# Inspecting node 365078935
# Inspecting node 17540009
# Inspecting node 49660950
# Inspecting node 296549487
# Inspecting node 1228605451
# Inspecting node 1122706063466356737
# Inspecting node 234593598
# Inspecting node 1204301854433316866
# Inspecting node 1204430581410353154
# Inspecting node 893202244077854721
# Inspecting node 22971125
# Inspecting node 1193458951976869888
# Inspecting node 785853390
# Inspecting node 322106815
# Inspecting node 1957597519
# Inspecting node 1101092779378249729
# Inspecting node 3331826578
# Inspecting node 38720614
# Inspecting node 2912843536
# Inspecting node 183642459
# Inspecting node 2247495353
# Inspecting node 2748289416
# Inspecting node 2592210108
# Inspecting node 103701079
# Inspecting node 1352713370772770816
# Inspecting node 86410896
# Inspecting node 1038301598
# Inspecting node 1134248217472843787
# Inspecting node 999320625117196288
# Inspecting node 18390213
# Inspecting node 768295011007934469
# Inspecting node 1262878353431777280
# Inspecting node 729232479840800768
# Inspecting node 1415442622135603206
# Inspecting node 346123223
# Inspecting node 167912183
# Inspecting node 1076249609125675010
# Inspecting node 67793897
# Inspecting node 823096488
# Inspecting node 50154666
# Inspecting node 302593437
# Inspecting node 291862583
# Inspecting node 168371680
# Inspecting node 1251332171211644931
# Inspecting node 962073414
# Inspecting node 291523600
# Inspecting node 277085673
# Inspecting node 62664213
# Inspecting node 1337551744457469952
# Inspecting node 716460064039575552
# Inspecting node 3007815702
# Inspecting node 55819705
# Inspecting node 1404102585317986308
# Inspecting node 1280249212567818240
# Inspecting node 740981264740679681
# Inspecting node 247511435
# Inspecting node 1303772129847111681
# Inspecting node 1027307702047961088
# Inspecting node 1020156666204090368
# Inspecting node 38751529
# Inspecting node 718873385346797569
# Inspecting node 285806588
# Inspecting node 541129316
# Inspecting node 1655457050
# Inspecting node 57759275
# Inspecting node 824281652423753728
# Inspecting node 132015712
# Inspecting node 40647043
# Inspecting node 12992772
# Inspecting node 365132365
# Inspecting node 1129088815
# Inspecting node 1262268501823303680
# Inspecting node 288548798
# Inspecting node 87632735
# Inspecting node 40246161
# Inspecting node 1252686295
# Inspecting node 25333228
# Inspecting node 1093876945
# Inspecting node 205786669
# Inspecting node 1942350667
# Inspecting node 2863551224
# Inspecting node 720083863830069249
# Inspecting node 176207343
# Inspecting node 412708728
# Inspecting node 414218319
# Inspecting node 1271987860577517568
# Inspecting node 626984632
# Inspecting node 237594523
# Inspecting node 714340176
# Inspecting node 300638343
# Inspecting node 739845530612830208
# Inspecting node 715244769
# Inspecting node 817207955930001409
# Inspecting node 1363561650624733184
# Inspecting node 212468225
# Inspecting node 2673432539
# Inspecting node 23601374
# Inspecting node 51852542
# Inspecting node 321482430
# Inspecting node 1058965681671028736
# Inspecting node 35617919
# Inspecting node 371288369
# Inspecting node 4492249646
# Inspecting node 396106258
# Inspecting node 2287331581
# Inspecting node 150671052
# Inspecting node 3302256527
# Inspecting node 3269322830
# Inspecting node 1364751078659477504
# Inspecting node 168123931
# Inspecting node 1072189285
# Inspecting node 45976740
# Inspecting node 1435257575482740741
# Inspecting node 1099109729308008448
# Inspecting node 1366925295291424768
# Inspecting node 1356073687691141121
# Inspecting node 1580475270
# Inspecting node 1442893993935716361
# Inspecting node 392132054
# Inspecting node 207703739
# Inspecting node 1419489038747070467
# Inspecting node 928451444633563136
# Inspecting node 1119464753318043649
# Inspecting node 1440690378533838857
# Inspecting node 2931943245
# Inspecting node 1727398412
# Inspecting node 1444061901172854786
# Inspecting node 2938869339
# Inspecting node 1243723946660421637
# Inspecting node 2476755039
# Inspecting node 1331773252792770560
# Inspecting node 901618905076174848
# Inspecting node 339780511
# Inspecting node 980817985668550656
# Inspecting node 53694666
# Inspecting node 1445437990940004352
# Inspecting node 1243574020802367488
# Inspecting node 1055536236
# Inspecting node 68670486
# Inspecting node 451989089
# Inspecting node 1077731978
# Inspecting node 1271115442573185024
# Inspecting node 969744550955749383
# Inspecting node 26577630
# Inspecting node 1391981080945643523
# Inspecting node 46232947
# Inspecting node 266048357
# Inspecting node 293745266
# Inspecting node 415532452
# Inspecting node 3107597132
# Inspecting node 1183316407104266241
# Inspecting node 982472677775454209
# Inspecting node 3295839203
# Inspecting node 880913594531139584
# Inspecting node 1911858061
# Inspecting node 1097694473952342022
# Inspecting node 1388650232100134915
# Inspecting node 14100537
# Inspecting node 820656479812227073
# Inspecting node 1325249450793701376
# Inspecting node 1427996716138127360
# Inspecting node 1347691972358778885
# Inspecting node 1365678726
# Inspecting node 1295377965438644235
# Inspecting node 322090834
# Inspecting node 1342962255248424961
# Inspecting node 1195026680609292288
# Inspecting node 1116360718687690758
# Inspecting node 737359208945844224
# Inspecting node 3375064758
# Inspecting node 14538949
# Inspecting node 1084856644687679496
# Inspecting node 36133644
# Inspecting node 976345683681619968
# Inspecting node 366785595
# Inspecting node 2849064914
# Inspecting node 343059330
# Inspecting node 64123717
# Inspecting node 18420573
# Inspecting node 957106791753555968
# Inspecting node 751054068974575616
# Inspecting node 1186136760981454854
# Inspecting node 854065048683204615
# Inspecting node 317823907
# Inspecting node 952759886
# Inspecting node 474883984
# Inspecting node 1258133514421239813
# Inspecting node 2198792101
# Inspecting node 324555383
# Inspecting node 744660163873771520
# Inspecting node 726025903
# Inspecting node 1263514760584167424
# Inspecting node 714569357267853312
# Inspecting node 739149720
# Inspecting node 1136772811656126464
# Inspecting node 270307297
# Inspecting node 454774863
# Inspecting node 772948513
# Inspecting node 3333795492
# Inspecting node 2209473078
# Inspecting node 838196271571591168
# Inspecting node 18386792
# Inspecting node 1166799265806503936
# Inspecting node 262522708
# Inspecting node 1370402422062002179
# Inspecting node 1429982282891239433
# Inspecting node 1434265814325202944
# Inspecting node 1087134051914395648
# Inspecting node 791076864
# Inspecting node 121949981
# Inspecting node 256360738
# Inspecting node 1172475064870027264
# Inspecting node 1443468994107822081
# Inspecting node 941115769429024769
# Inspecting node 1313732971061362690
# Inspecting node 2305422800
# Inspecting node 242885214
# Inspecting node 1354230346586447877
# Inspecting node 469747759
# Inspecting node 432114850
# Inspecting node 1166000110586626048
# Inspecting node 884527637569323009
# Inspecting node 369653658
# Inspecting node 1434643524495020043
# Inspecting node 75984040
# Inspecting node 586195164
# Inspecting node 2902344555
# Inspecting node 564257648
# Inspecting node 1027229536902098944
# Inspecting node 2316626342
# Inspecting node 1925354744
# Inspecting node 958204773282533376
# Inspecting node 1445751022526160908
# Inspecting node 1183078912265355265
# Inspecting node 98767459
# Inspecting node 87297879
# Inspecting node 753394222267527168
# Inspecting node 373580557
# Inspecting node 1430260512688902150
# Inspecting node 2468436247
# Inspecting node 3308781515
# Inspecting node 2273880732
# Inspecting node 1302114263771668481
# Inspecting node 24181491
# Inspecting node 1309179346565898241
# Inspecting node 2231471516
# Inspecting node 1352351686778630145
# Inspecting node 1413321993470943237
# Inspecting node 603011131
# Inspecting node 1438876255202406406
# Inspecting node 1375883715776294914
# Inspecting node 1002002024
# Inspecting node 51384524
# Inspecting node 724114092672335874
# Inspecting node 552725069
# Inspecting node 1184298786329448448
# Inspecting node 334954251
# Inspecting node 101915304
# Inspecting node 1252767510983737344
# Inspecting node 1099811037975642112
# Inspecting node 1388988366247575559
# Inspecting node 1326022742286749696
# Inspecting node 1388801354244702209
# Inspecting node 961162177
# Inspecting node 1389555148318404610
# Inspecting node 1151641780267261952
# Inspecting node 27320189
# Inspecting node 1215379886887428096
# Inspecting node 1184882383
# Inspecting node 257699447
# Inspecting node 2397398196
# Inspecting node 807034969902252032
# Inspecting node 1353486048618274816
# Inspecting node 4866566489
# Inspecting node 3058888765
# Inspecting node 1173239638116446208
# Inspecting node 42894434
# Inspecting node 3078011282
# Inspecting node 32691118
# Inspecting node 544080126
# Inspecting node 1336660494
# Inspecting node 957190068594130946
# Inspecting node 1074149416699719681
# Inspecting node 825518936733085696
# Inspecting node 43199433
# Inspecting node 969376788525830146
# Inspecting node 35107179
# Inspecting node 366074756
# Inspecting node 359672860
# Inspecting node 82679357
# Inspecting node 883774859452579840
# Inspecting node 3418588623
# Inspecting node 710270422290403328
# Inspecting node 763168867371843584
# Inspecting node 1575198925
# Inspecting node 1301995158485958656
# Inspecting node 1260291453973983232
# Inspecting node 1601907697
# Inspecting node 29823611
# Inspecting node 1393039117110317058
# Inspecting node 236055343
# Inspecting node 320919057
# Inspecting node 2812908133
# Inspecting node 1325519307359490048
# Inspecting node 590735039
# Inspecting node 95577307
# Inspecting node 43948485
# Inspecting node 136332449
# Inspecting node 623936216
# Inspecting node 2873956499
# Inspecting node 4803873902
# Inspecting node 1147245556651233280
# Inspecting node 918919026344120321
# Inspecting node 37813045
# Inspecting node 24574252
# Inspecting node 1440809899500335110
# Inspecting node 1334205408110551042
# Inspecting node 1071298949837770753
# Inspecting node 915968072
# Inspecting node 885818088
# Inspecting node 227849419
# Inspecting node 2493753559
# Inspecting node 778842486
# Inspecting node 124839366
# Inspecting node 263750524
# Inspecting node 1357001901229899777
# Inspecting node 990301302264479749
# Inspecting node 1136065885456740352
# Inspecting node 1335377050878676992
# Inspecting node 138710067
# Inspecting node 1441961640459599874
# Inspecting node 2793008984
# Inspecting node 120187876
# Inspecting node 178544594
# Inspecting node 2838327755
# Inspecting node 1559780652
# Inspecting node 2291354802
# Inspecting node 1352707350784659456
# Inspecting node 1417352097150816256
# Inspecting node 1427768108614291465
# Inspecting node 1117485007944048640
# Inspecting node 1297264458
# Inspecting node 1194794785762004993
# Inspecting node 26089782
# Inspecting node 1446289055935864836
# Inspecting node 412499776
# Inspecting node 416476088
# Inspecting node 1028871362499305473
# Inspecting node 1438317451469541377
# Inspecting node 546527413
# Inspecting node 1323421765658431488
# Inspecting node 280677070
# Inspecting node 2332742508
# Inspecting node 1347272097786171394
# Inspecting node 2344419362
# Inspecting node 252150132
# Inspecting node 4787666543
# Inspecting node 1454456569
# Inspecting node 587733016
# Inspecting node 823265236916416512
# Inspecting node 1168589910825213952
# Inspecting node 753744536887824385
# Inspecting node 119925381
# Inspecting node 1269692602204532738
# Inspecting node 853722212741898240
# Inspecting node 43089397
# Inspecting node 2323751900
# Inspecting node 1213405462021853185
# Inspecting node 2937436849
# Inspecting node 272250877
# Inspecting node 1406573892
# Inspecting node 1942107584
# Inspecting node 2678072299
# Inspecting node 86384661
# Inspecting node 2983179809
# Inspecting node 3188558830
# Inspecting node 2874772780
# Inspecting node 222386937
# Inspecting node 261788602
# Inspecting node 292468351
# Inspecting node 22849568
# Inspecting node 1203545123356839936
# Inspecting node 19893907
# Inspecting node 1729880688
# Inspecting node 1361500715659755520
# Inspecting node 700287952
# Inspecting node 169268197
# Inspecting node 18622393
# Inspecting node 1304185921433227264
# Inspecting node 97121931
# Inspecting node 1699266222
# Inspecting node 729194378779078656
# Inspecting node 2752659114
# Inspecting node 373460084
# Inspecting node 908018227040710656
# Inspecting node 245149238
# Inspecting node 3242606862
# Inspecting node 29891001
# Inspecting node 720579941184757760
# Inspecting node 276713213
# Inspecting node 1424060815947206662
# Inspecting node 609432652
# Inspecting node 38625077
# Inspecting node 234550882
# Inspecting node 408072407
# Inspecting node 1427258589077508100
# Inspecting node 2242940071
# Inspecting node 44171755
# Inspecting node 41043869
# Inspecting node 436087744
# Inspecting node 578640179
# Inspecting node 132210296
# Inspecting node 923683393
# Inspecting node 1245003009555419137
# Inspecting node 1267504449087553539
# Inspecting node 65666257
# Inspecting node 407943040
# Inspecting node 240908125
# Inspecting node 1057988206963056640
# Inspecting node 130857133
# Inspecting node 1441410998355726344
# Inspecting node 24819740
# Inspecting node 1412813687811760135
# Inspecting node 2762829798
# Inspecting node 1317417438640697344
# Inspecting node 1185990712132812800
# Inspecting node 711980580813066240
# Inspecting node 3237884919
# Inspecting node 9455112
# Inspecting node 19198775
# Inspecting node 22630846
# Inspecting node 1434341584670273544
# Inspecting node 844292741077061632
# Inspecting node 1300624324206817280
# Inspecting node 1332164996592066561
# Inspecting node 337816824
# Inspecting node 153798495
# Inspecting node 1249204176548245504
# Inspecting node 3092462976
# Inspecting node 547671992
# Inspecting node 151547845
# Inspecting node 23554969
# Inspecting node 1314208704
# Inspecting node 808450734240972800
# Inspecting node 204846220
# Inspecting node 19478009
# Inspecting node 18940341
# Inspecting node 62292631
# Inspecting node 1239692519094575104
# Inspecting node 64261339
# Inspecting node 271989352
# Inspecting node 66334416
# Inspecting node 756584190112591872
# Inspecting node 24459228
# Inspecting node 771870952544096257
# Inspecting node 1242251887
# Inspecting node 15908286
# Inspecting node 1390840055200108546
# Inspecting node 2408260398
# Inspecting node 488067802
# Inspecting node 1511667030
# Inspecting node 579614622
# Inspecting node 728304522662043648
# Inspecting node 1092960066
# Inspecting node 64099329
# Inspecting node 1393055510480441345
# Inspecting node 2555583872
# Inspecting node 2452465303
# Inspecting node 282526718
# Inspecting node 4298769753
# Inspecting node 572827030
# Inspecting node 1414623993529880576
# Inspecting node 1255927911045095425
# Inspecting node 1373016955
# Inspecting node 2720800274
# Inspecting node 57661541
# Inspecting node 708739471
# Inspecting node 722623738672517120
# Inspecting node 157591483
# Inspecting node 1390378070482165763
# Inspecting node 2707780448
# Inspecting node 898554931271127042
# Inspecting node 525857359
# Inspecting node 2536457582
# Inspecting node 19634262
# Inspecting node 1357304889831878657
# Inspecting node 1243221104560345090
# Inspecting node 431141725
# Inspecting node 1244435052
# Inspecting node 159655782
# Inspecting node 382223500
# Inspecting node 535452718
# Inspecting node 1293199610178080775
# Inspecting node 12923812
# Inspecting node 16272844
# Inspecting node 335769776
# Inspecting node 16279532
# Inspecting node 3358671
# Inspecting node 16180205
# Inspecting node 2322580746
# Inspecting node 171115367
# Inspecting node 208750527
# Inspecting node 240786249
# Inspecting node 3257047456
# Inspecting node 500232993
# Inspecting node 1171073846335721472
# Inspecting node 1304472952482783232
# Inspecting node 1072270926
# Inspecting node 2789770741
# Inspecting node 2327530022
# Inspecting node 1002181382
# Inspecting node 47692251
# Inspecting node 743129088
# Inspecting node 271073165
# Inspecting node 1895316878
# Inspecting node 631988630
# Inspecting node 290162716
# Inspecting node 2229187188
# Inspecting node 274507495
# Inspecting node 417524720
# Inspecting node 415774799
# Inspecting node 579377522
# Inspecting node 32915303
# Inspecting node 245954929
# Inspecting node 170377354
# Inspecting node 1390883714
# Inspecting node 3363252329
# Inspecting node 1143342270399373313
# Inspecting node 272185225
# Inspecting node 1144289639924207616
# Inspecting node 43510607
# Inspecting node 524557553
# Inspecting node 256775505
# Inspecting node 493488747
# Inspecting node 868245382148521984
# Inspecting node 1170770038208565248
# Inspecting node 339752726
# Inspecting node 249221867
# Inspecting node 488052222
# Inspecting node 911471588
# Inspecting node 246466184
# Inspecting node 280552762
# Inspecting node 295951367
# Inspecting node 973087261
# Inspecting node 1321710295245447169
# Inspecting node 48369926
# Inspecting node 1438956476588957701
# Inspecting node 385008014
# Inspecting node 918152297544380417
# Inspecting node 33562561
# Inspecting node 987136895162384384
# Inspecting node 1327442450957303809
# Inspecting node 870473605473198080
# Inspecting node 35337644
# Inspecting node 1103832363363127297
# Inspecting node 1243323314652602368
# Inspecting node 1268045786312593408
# Inspecting node 17355421
# Inspecting node 24348660
# Inspecting node 14247924
# Inspecting node 106512310
# Inspecting node 1269254845615095810
# Inspecting node 1219578234
# Inspecting node 1380813355
# Inspecting node 883334379023597568
# Inspecting node 58878834
# Inspecting node 912346683291389953
# Inspecting node 3179475258
# Inspecting node 245939022
# Inspecting node 363654070
# Inspecting node 3071603495
# Inspecting node 573788425
# Inspecting node 878490462
# Inspecting node 1423385158263132168
# Inspecting node 1268728504964825088
# Inspecting node 46894332
# Inspecting node 136160953
# Inspecting node 107218304
# Inspecting node 73411833
# Inspecting node 1405971529217740812
# Inspecting node 1275123310788063233
# Inspecting node 1173035282461089793
# Inspecting node 1445090669643517961
# Inspecting node 1389241812276023296
# Inspecting node 501994958
# Inspecting node 2799175653
# Inspecting node 1429555219457773581
# Inspecting node 1668333199
# Inspecting node 1218019404992196609
# Inspecting node 1366204146957885445
# Inspecting node 1198972583288459265
# Inspecting node 1433247289330577408
# Inspecting node 502160853
# Inspecting node 41520537
# Inspecting node 1294478815628890112
# Inspecting node 395394840
# Inspecting node 1151704477
# Inspecting node 1044711566354960384
# Inspecting node 1271855851330916353
# Inspecting node 1497052201
# Inspecting node 975757898004549633
# Inspecting node 3245708989
# Inspecting node 1267640853000007680
# Inspecting node 29917096
# Inspecting node 245373521
# Inspecting node 1420482733135040522
# Inspecting node 1242510089145266182
# Inspecting node 28737527
# Inspecting node 1731401322
# Inspecting node 979870450577686528
# Inspecting node 1354922263418523648
# Inspecting node 24951781
# Inspecting node 15613754
# Inspecting node 100851235
# Inspecting node 59243738
# Inspecting node 17360968
# Inspecting node 360129945
# Inspecting node 1174006316412674048
# Inspecting node 21809306
# Inspecting node 1134558647835430912
# Inspecting node 855478711
# Inspecting node 25178951
# Inspecting node 52350953
# Inspecting node 20796969
# Inspecting node 55158039
# Inspecting node 1401659310015397889
# Inspecting node 215896862
# Inspecting node 4540976253
# Inspecting node 56016987
# Inspecting node 1357857933019598849
# Inspecting node 1125841354716696576
# Inspecting node 793343793642680320
# Inspecting node 48219360
# Inspecting node 399184212
# Inspecting node 827222807121637377
# Inspecting node 1138228267
# Inspecting node 1671821988
# Inspecting node 2321539819
# Inspecting node 17969963
# Inspecting node 1337935917298962434
# Inspecting node 1055170328442224641
# Inspecting node 325805788
# Inspecting node 1128406689802276865
# Inspecting node 1560811022
# Inspecting node 1264568784318345218
# Inspecting node 254240108
# Inspecting node 2237957942
# Inspecting node 387828045
# Inspecting node 3355188729
# Inspecting node 1483945802
# Inspecting node 1663608300
# Inspecting node 1335613030852386817
# Inspecting node 2678629590
# Inspecting node 884681534
# Inspecting node 420536762
# Inspecting node 4329525312
# Inspecting node 1547244656
# Inspecting node 109341612
# Inspecting node 108689047
# Inspecting node 1223265601147342848
# Inspecting node 297968019
# Inspecting node 183758895
# Inspecting node 45932749
# Inspecting node 418786259
# Inspecting node 70240459
# Inspecting node 1606592767
# Inspecting node 1047167241119326211
# Inspecting node 978673214283853825
# Inspecting node 17136419
# Inspecting node 1242152485
# Inspecting node 4445748801
# Inspecting node 1413908511461945350
# Inspecting node 1314819918328729600
# Inspecting node 1140532022
# Inspecting node 1200932043544117248
# Inspecting node 3109560272
# Inspecting node 162924629
# Inspecting node 182072629
# Inspecting node 980237238
# Inspecting node 1213189717425917953
# Inspecting node 2800741820
# Inspecting node 19135439
# Inspecting node 967241034873933824
# Inspecting node 3236492411
# Inspecting node 1235422076082589696
# Inspecting node 534591437
# Inspecting node 1454880680
# Inspecting node 1069754111078354948
# Inspecting node 2286750115
# Inspecting node 1375862610
# Inspecting node 26071396
# Inspecting node 375764669
# Inspecting node 1833674827
# Inspecting node 392380645
# Inspecting node 769165632738762752
# Inspecting node 989311745100566529
# Inspecting node 256552850
# Inspecting node 2218371769
# Inspecting node 29721598
# Inspecting node 1008103433822351360
# Inspecting node 1214027006242742273
# Inspecting node 142107502
# Inspecting node 1314568089300873216
# Inspecting node 801218452618956800
# Inspecting node 1330675961839443973
# Inspecting node 1441448795921952768
# Inspecting node 102491634
# Inspecting node 24978284
# Inspecting node 36988268
# Inspecting node 712792479729192960
# Inspecting node 890560416526594048
# Inspecting node 1413820603
# Inspecting node 37044121
# Inspecting node 832619717785329664
# Inspecting node 1171471512085389312
# Inspecting node 61542328
# Inspecting node 494320156
# Inspecting node 13716572
# Inspecting node 1017461230984990720
# Inspecting node 25703839
# Inspecting node 363666493
# Inspecting node 975491119734763522
# Inspecting node 61888526
# Inspecting node 2502596130
# Inspecting node 763867259777519618
# Inspecting node 1185294078256254977
# Inspecting node 1296424847149588483
# Inspecting node 2721515522
# Inspecting node 224600898
# Inspecting node 524785211
# Inspecting node 777617628009332736
# Inspecting node 189341190
# Inspecting node 2451955022
# Inspecting node 835061048533082113
# Inspecting node 248022226
# Inspecting node 2988258574
# Inspecting node 1001287095472873473
# Inspecting node 1182252711833718784
# Inspecting node 1861048644
# Inspecting node 2842385693
# Inspecting node 248065960
# Inspecting node 931882614
# Inspecting node 3290783049
# Inspecting node 359260523
# Inspecting node 16116228
# Inspecting node 243912778
# Inspecting node 2439108320
# Inspecting node 1176536298179284993
# Inspecting node 297771685
# Inspecting node 1128366660128260097
# Inspecting node 222987791
# Inspecting node 18597273
# Inspecting node 577727470
# Inspecting node 112767813
# Inspecting node 116837959
# Inspecting node 83712358
# Inspecting node 486703473
# Inspecting node 67758676
# Inspecting node 20346252
# Inspecting node 420560195
# Inspecting node 3153084524
# Inspecting node 1308040042724519939
# Inspecting node 1182947209
# Inspecting node 1258576501
# Inspecting node 213140093
# Inspecting node 225067116
# Inspecting node 18340314
# Inspecting node 1310724884008321028
# Inspecting node 160429871
# Inspecting node 214530013
# Inspecting node 110504574
# Inspecting node 24692082
# Inspecting node 16422863
# Inspecting node 1650588223
# Inspecting node 1548315212
# Inspecting node 1378038493105037320
# Inspecting node 4731285264
# Inspecting node 1260770767123312640
# Inspecting node 1260759194833006593
# Inspecting node 975784752648212480
# Inspecting node 2367303485
# Inspecting node 1346317368637603841
# Inspecting node 1426665402147360769
# Inspecting node 1024397417423106048
# Inspecting node 776153719675072512
# Inspecting node 787738985481240576
# Inspecting node 911264470210682880
# Inspecting node 1005823371144318977
# Inspecting node 1416921060788801539
# Inspecting node 17174462
# Inspecting node 1214396742
# Inspecting node 2379113581
# Inspecting node 1426711288462417921
# Inspecting node 21426717
# Inspecting node 975519759105060864
# Inspecting node 2394842400
# Inspecting node 1430196796781912066
# Inspecting node 1433249159474200577
# Inspecting node 20467453
# Inspecting node 1353457212799262720
# Inspecting node 877710910780985345
# Inspecting node 1413615091224924164
# Inspecting node 739208182837321729
# Inspecting node 16545084
# Inspecting node 1234968032734216193
# Inspecting node 979741136725184512
# Inspecting node 509604564
# Inspecting node 731972892
# Inspecting node 1357259774
# Inspecting node 308032537
# Inspecting node 782939425
# Inspecting node 824028437568438277
# Inspecting node 1255919262998441987
# Inspecting node 1291405539046457345
# Inspecting node 1306024583858917376
# Inspecting node 578272027
# Inspecting node 294660973
# Inspecting node 1212202179777331200
# Inspecting node 21632185
# Inspecting node 1227080599451701249
# Inspecting node 2906452022
# Inspecting node 1298675867061805056
# Inspecting node 15128653
# Inspecting node 820499790
# Inspecting node 1238950146559352834
# Inspecting node 1854934933
# Inspecting node 1444459015875014657
# Inspecting node 147340782
# Inspecting node 15677734
# Inspecting node 195207470
# Inspecting node 1282074147884015616
# Inspecting node 977009074217795584
# Inspecting node 3331283445
# Inspecting node 826085293677748224
# Inspecting node 1355980761443217415
# Inspecting node 92256613
# Inspecting node 1278822500143677442
# Inspecting node 187257177
# Inspecting node 902402049022808064
# Inspecting node 1694247541
# Inspecting node 403374868
# Inspecting node 42142250
# Inspecting node 4856189107
# Inspecting node 483313162
# Inspecting node 2427741792
# Inspecting node 2174574218
# Inspecting node 3831737053
# Inspecting node 892123934119927809
# Inspecting node 3660694460
# Inspecting node 3298660936
# Inspecting node 3289694144
# Inspecting node 459311957
# Inspecting node 33456207
# Inspecting node 144036263
# Inspecting node 1049412181559787521
# Inspecting node 826499437585371136
# Inspecting node 540672851
# Inspecting node 1444511517379026948
# Inspecting node 1023207519060197383
# Inspecting node 22532501
# Inspecting node 1067386991250206721
# Inspecting node 2800244863
# Inspecting node 92736596
# Inspecting node 1225489734178344962
# Inspecting node 66621998
# Inspecting node 1059573444214439937
# Inspecting node 1442259927779532808
# Inspecting node 751872198961487872
# Inspecting node 1190792680877559810
# Inspecting node 147981741
# Inspecting node 3158178364
# Inspecting node 1198789568214044672
# Inspecting node 1118222712818868229
# Inspecting node 1296542987850113024
# Inspecting node 1294643635397550080
# Inspecting node 920714531537481729
# Inspecting node 779333693936721920
# Inspecting node 49707487
# Inspecting node 1424936529621774338
# Inspecting node 1129198217164234753
# Inspecting node 1366519801997193216
# Inspecting node 32235586
# Inspecting node 44674554
# Inspecting node 224063162
# Inspecting node 369093
# Inspecting node 2883808867
# Inspecting node 292524345
# Inspecting node 22968164
# Inspecting node 1001274194443821064
# Inspecting node 15054416
# Inspecting node 21400756
# Inspecting node 4860164601
# Inspecting node 467804527
# Inspecting node 958181344286269440
# Inspecting node 778262568272027648
# Inspecting node 38929865
# Inspecting node 297074777
# Inspecting node 760353522718081026
# Inspecting node 928262146542026752
# Inspecting node 160673089
# Inspecting node 175939051
# Inspecting node 1187760523829563392
# Inspecting node 78429753
# Inspecting node 4722097454
# Inspecting node 1070001735454875648
# Inspecting node 35728556
# Inspecting node 1402352323851083779
# Inspecting node 1097176821622284289
# Inspecting node 150699925
# Inspecting node 1060278863874478080
# Inspecting node 813073081761570816
# Inspecting node 722880943380242432
# Inspecting node 14960142
# Inspecting node 1346936882
# Inspecting node 1073283389288005632
# Inspecting node 1297250167
# Inspecting node 1322191014455554048
# Inspecting node 1357200256618795008
# Inspecting node 16504074
# Inspecting node 158100294
# Inspecting node 817811639516991488
# Inspecting node 824357739501531136
# Inspecting node 268237247
# Inspecting node 21815663
# Inspecting node 318420941
# Inspecting node 341180420
# Inspecting node 2267952750
# Inspecting node 454336947
# Inspecting node 725309237862223872
# Inspecting node 353903334
# Inspecting node 2247798150
# Inspecting node 489749588
# Inspecting node 4819639768
# Inspecting node 1330218727
# Inspecting node 1481076481
# Inspecting node 2479224015
# Inspecting node 563152589
# Inspecting node 1317418116
# Inspecting node 1350924172554366979
# Inspecting node 23101207
# Inspecting node 1357917347181453312
# Inspecting node 721401357
# Inspecting node 2926114316
# Inspecting node 968303534822313984
# Inspecting node 77035084
# Inspecting node 85859978
# Inspecting node 2720749324
# Inspecting node 734095130
# Inspecting node 3257661611
# Inspecting node 1219432023044939776
# Inspecting node 998712356
# Inspecting node 603662056
# Inspecting node 4729460081
# Inspecting node 188565420
# Inspecting node 2534622463
# Inspecting node 165020784
# Inspecting node 84704052
# Inspecting node 4273980252
# Inspecting node 29256016
# Inspecting node 577968691
# Inspecting node 845271811097055234
# Inspecting node 470780364
# Inspecting node 22531935
# Inspecting node 59829657
# Inspecting node 275735174
# Inspecting node 559870034
# Inspecting node 7491592
# Inspecting node 23282993
# Inspecting node 2411078349
# Inspecting node 4148412316
# Inspecting node 73199415
# Inspecting node 366968661
# Inspecting node 341653196
# Inspecting node 605379442
# Inspecting node 28045785
# Inspecting node 40216513
# Inspecting node 925675836526776321
# Inspecting node 1080965055007592456
# Inspecting node 1032507164
# Inspecting node 820730609043505152
# Inspecting node 495401684
# Inspecting node 29904143
# Inspecting node 365563514
# Inspecting node 1142295084572073985
# Inspecting node 23522098
# Inspecting node 624251860
# Inspecting node 80212065
# Inspecting node 2829798301
# Inspecting node 1390067256080621568
# Inspecting node 38878429
# Inspecting node 2801061205
# Inspecting node 935335003084423168
# Inspecting node 622885791
# Inspecting node 1112914064076931072
# Inspecting node 384288098
# Inspecting node 515847342
# Inspecting node 3111765339
# Inspecting node 3419010088
# Inspecting node 571519594
# Inspecting node 935697022400602112
# Inspecting node 349692386
# Inspecting node 1223950760
# Inspecting node 3341414159
# Inspecting node 1382336580518621186
# Inspecting node 3142614406
# Inspecting node 731469980890476545
# Inspecting node 58340767
# Inspecting node 266653082
# Inspecting node 2853989866
# Inspecting node 3607702640
# Inspecting node 1421968442
# Inspecting node 297986745
# Inspecting node 54042169
# Inspecting node 577170668
# Inspecting node 880108852162707456
# Inspecting node 1380189591735517190
# Inspecting node 35051540
# Inspecting node 1074335960
# Inspecting node 1371923720609095686
# Inspecting node 1280972258
# Inspecting node 491697655
# Inspecting node 2651576688
# Inspecting node 1117035592565628928
# Inspecting node 163922710
# Inspecting node 1286102971974025217
# Inspecting node 2620272561
# Inspecting node 52516962
# Inspecting node 1065829609
# Inspecting node 1437800221375963143
# Inspecting node 1247541393121087495
# Inspecting node 892060639526395904
# Inspecting node 543143031
# Inspecting node 124878802
# Inspecting node 1341618252
# Inspecting node 727897637098135552
# Inspecting node 14221144
# Inspecting node 950848085802004480
# Inspecting node 16267310
# Inspecting node 2262304373
# Inspecting node 727519870590541824
# Inspecting node 92551736
# Inspecting node 3438124552
# Inspecting node 2749373577
# Inspecting node 535799622
# Inspecting node 1354038378640134145
# Inspecting node 1239698227739459584
# Inspecting node 196164822
# Inspecting node 3075929388
# Inspecting node 1212777267169873920
# Inspecting node 140253506
# Inspecting node 1571464364
# Inspecting node 37609730
# Inspecting node 1396338835596795904
# Inspecting node 1069734050301128705
# Inspecting node 1581712848
# Inspecting node 3268565808
# Inspecting node 786738726466707460
# Inspecting node 1115838887623122954
# Inspecting node 1498327201
# Inspecting node 1316013080250216453
# Inspecting node 957808962983755776
# Inspecting node 2727310657
# Inspecting node 2353185104
# Inspecting node 992390491105882112
# Inspecting node 1133696644422275072
# Inspecting node 3087811674
# Inspecting node 2151893489
# Inspecting node 904365258399244288
# Inspecting node 1393384383650975744
# Inspecting node 707364896153980928
# Inspecting node 371739649
# Inspecting node 1203817853494779904
# Inspecting node 1081036726758531072
# Inspecting node 2968424080
# Inspecting node 2151613567
# Inspecting node 198927392
# Inspecting node 951527727365988352
# Inspecting node 1093890667909124100
# Inspecting node 593891991
# Inspecting node 4850122813
# Inspecting node 872152901870911489
# Inspecting node 878242924567441408
# Inspecting node 1335043297
# Inspecting node 725731648017424385
# Inspecting node 1198351736
# Inspecting node 26557104
# Inspecting node 1042821954821087232
# Inspecting node 1428826266
# Inspecting node 2831610879
# Inspecting node 4681656433
# Inspecting node 775279674
# Inspecting node 596787864
# Inspecting node 273262205
# Inspecting node 24990450
# Inspecting node 342699819
# Inspecting node 378321467
# Inspecting node 217485938
# Inspecting node 967837552425119744
# Inspecting node 18579611
# Inspecting node 16811701
# Inspecting node 63476527
# Inspecting node 17442269
# Inspecting node 1366423551704784897
# Inspecting node 1070588953105969152
# Inspecting node 119911112
# Inspecting node 145878023
# Inspecting node 28540616
# Inspecting node 17050123
# Inspecting node 1432002021398306821
# Inspecting node 930479718
# Inspecting node 2341257349
# Inspecting node 587087289
# Inspecting node 708990479895896066
# Inspecting node 566196508
# Inspecting node 1019405015855878144
# Inspecting node 1275466513529671681
# Inspecting node 1347609010434953217
# Inspecting node 1419539298
# Inspecting node 57527830
# Inspecting node 24752425
# Inspecting node 29586080
# Inspecting node 1250609616192446466
# Inspecting node 2589728724
# Inspecting node 7922582
# Inspecting node 1124423281765797888
# Inspecting node 1077139237
# Inspecting node 199876983
# Inspecting node 18680879
# Inspecting node 380327126
# Inspecting node 3139690604
# Inspecting node 282111410
# Inspecting node 273727399
# Inspecting node 703722876
# Inspecting node 3357096478
# Inspecting node 838912397066846208
# Inspecting node 1437539837477748738
# Inspecting node 751919973497384962
# Inspecting node 1404491652580843525
# Inspecting node 1067154574278971392
# Inspecting node 576365948
# Inspecting node 31513326
# Inspecting node 1297575021578256388
# Inspecting node 1233196108211294209
# Inspecting node 19359977
# Inspecting node 745800926
# Inspecting node 2448257995
# Inspecting node 839668692866723840
# Inspecting node 15023001
# Inspecting node 30270072
# Inspecting node 17929195
# Inspecting node 385678932
# Inspecting node 1065257588151996422
# Inspecting node 1687712964
# Inspecting node 1345709200618389504
# Inspecting node 224737149
# Inspecting node 373940903
# Inspecting node 6013662
# Inspecting node 907302868645953537
# Inspecting node 1243336421164732416
# Inspecting node 240831038
# Inspecting node 290312086
# Inspecting node 4026420858
# Inspecting node 540103190
# Inspecting node 248866864
# Inspecting node 148618115
# Inspecting node 83307703
# Inspecting node 918318518
# Inspecting node 21166754
# Inspecting node 493604178
# Inspecting node 1222274097935073281
# Inspecting node 336662190
# Inspecting node 1254832256
# Inspecting node 65917423
# Inspecting node 15257975
# Inspecting node 18148460
# Inspecting node 168350399
# Inspecting node 18457918
# Inspecting node 165890739
# Inspecting node 1380663772906356737
# Inspecting node 554805867
# Inspecting node 1344041868779110400
# Inspecting node 373667686
# Inspecting node 1261311256151183362
# Inspecting node 1116067546778628097
# Inspecting node 1416035013502685184
# Inspecting node 24313572
# Inspecting node 1144704604442988544
# Inspecting node 222126993
# Inspecting node 2655180373
# Inspecting node 887262626
# Inspecting node 3131039404
# Inspecting node 249386982
# Inspecting node 4759974372
# Inspecting node 494732315
# Inspecting node 1405037853579436035
# Inspecting node 15049380
# Inspecting node 396149168
# Inspecting node 977021137
# Inspecting node 3320688247
# Inspecting node 880997516
# Inspecting node 264439847
# Inspecting node 1068193791511678977
# Inspecting node 636649732
# Inspecting node 14837621
# Inspecting node 596793900
# Inspecting node 4767685428
# Inspecting node 1407536941680279552
# Inspecting node 717895042602504192
# Inspecting node 52245251
# Inspecting node 2574056066
# Inspecting node 35476624
# Inspecting node 48035511
# Inspecting node 207677544
# Inspecting node 56029187
# Inspecting node 3306930701
# Inspecting node 1177657984220053506
# Inspecting node 165971686
# Inspecting node 758042170968375296
# Inspecting node 242492168
# Inspecting node 27460814
# Inspecting node 1231982311253708803
# Inspecting node 2533511951
# Inspecting node 3317590829
# Inspecting node 2416130503
# Inspecting node 724952267162542080
# Inspecting node 22491454
# Inspecting node 3029210380
# Inspecting node 2157300561
# Inspecting node 1053529093285785601
# Inspecting node 1130348139607576576
# Inspecting node 1232835905616011264
# Inspecting node 2922358250
# Inspecting node 1001986308343033856
# Inspecting node 1022679197976678400
# Inspecting node 2560632538
# Inspecting node 1317802041423646720
# Inspecting node 884265045479313408
# Inspecting node 1229474724142604288
# Inspecting node 486317915
# Inspecting node 235070820
# Inspecting node 755749623491244032
# Inspecting node 32189160
# Inspecting node 416468980
# Inspecting node 1051556700
# Inspecting node 1171534270168367105
# Inspecting node 23370368
# Inspecting node 1399510991885455362
# Inspecting node 1438462388647440386
# Inspecting node 214708464
# Inspecting node 547747984
# Inspecting node 366117993
# Inspecting node 262910171
# Inspecting node 1416997300199641091
# Inspecting node 24707528
# Inspecting node 521255914
# Inspecting node 1267810083389480963
# Inspecting node 165587758
# Inspecting node 1398595872187830274
# Inspecting node 1392128666998542337
# Inspecting node 2612807188
# Inspecting node 2652768953
# Inspecting node 292728050
# Inspecting node 96450418
# Inspecting node 2811765535
# Inspecting node 45010284
# Inspecting node 128290965
# Inspecting node 1088791968451313665
# Inspecting node 268573963
# Inspecting node 41089713
# Inspecting node 55841183
# Inspecting node 1419998048562909204
# Inspecting node 2969192164
# Inspecting node 1338252288
# Inspecting node 887732866423173125
# Inspecting node 39268708
# Inspecting node 995530035892121601
# Inspecting node 2694473137
# Inspecting node 421830937
# Inspecting node 1097531188338552832
# Inspecting node 64514213
# Inspecting node 67254536
# Inspecting node 1191423138954981382
# Inspecting node 244328935
# Inspecting node 15782904
# Inspecting node 147965270
# Inspecting node 2944338467
# ...
# Inspecting node 1411006381117919235
# Inspecting node 84353854
# Inspecting node 1446920962671185920
# Inspecting node 1365798226717151233
# Inspecting node 281811081
# Inspecting node 1406365981329346565
# Inspecting node 65767300
# Inspecting node 3011968549
# Inspecting node 1438896900070117381
# Inspecting node 547245887
# Inspecting node 1615902452
# Inspecting node 38885578
# Inspecting node 948223698649124870
# Inspecting node 1242785654368382979
# Inspecting node 3145151881
# Inspecting node 1148750306634883077
# Inspecting node 40109301
# Inspecting node 895679481720872960
# Inspecting node 2966914766
# Inspecting node 1347952445985497088
# Inspecting node 922806178446327809
# Inspecting node 131591657
# Inspecting node 1374005511495028737
# Inspecting node 408241959
# Inspecting node 809552357763661824
# Inspecting node 1556631295
# Inspecting node 282728904
# Inspecting node 785667382224293888
# Inspecting node 1013808600
# Inspecting node 16271356
# Inspecting node 4762708393
# Inspecting node 2167166754
# Inspecting node 517098546
# Inspecting node 886380609026785280
# Inspecting node 2869430815
# Inspecting node 937525764
# Inspecting node 981670040062779392
# Inspecting node 909852173479104512
# Inspecting node 220518078
# Inspecting node 226666386
# Inspecting node 288515399
# Inspecting node 220871206
# Inspecting node 17394737
# Inspecting node 85688497
# Inspecting node 85625597
# Inspecting node 32611097
# Inspecting node 1144689874424999937
# Inspecting node 2465329364
# Inspecting node 149701807
# Inspecting node 26186692
# Inspecting node 23371273
# Inspecting node 3015944460
# Inspecting node 760257132675600386
# Inspecting node 730797462991065088
# Inspecting node 771466526348107776
# Inspecting node 45950539
# Inspecting node 1160209698
# Inspecting node 1109141736972939264
# Inspecting node 169237647
# Inspecting node 1145662294849990656
# Inspecting node 78641250
# Inspecting node 821066393143672836
# Inspecting node 27740019
# Inspecting node 2201466604
# Inspecting node 1361822936
# Inspecting node 21108458
# Inspecting node 382935719
# Inspecting node 1252040788982169600
# Inspecting node 23937700
# Inspecting node 372577100
# Inspecting node 53807352
# Inspecting node 1177551303725240322
# Inspecting node 1252976493971595265
# Inspecting node 441289118
# Inspecting node 897094186213588992
# Inspecting node 3676427473
# Inspecting node 469671065
# Inspecting node 846920964113870848
# Inspecting node 268469213
# Inspecting node 24573102
# Inspecting node 16170023
# Inspecting node 2458783644
# Inspecting node 258405050
# Inspecting node 301144504
# Inspecting node 495918203
# Inspecting node 1239567083404292097
# Inspecting node 536853804
# Inspecting node 250839952
# Inspecting node 856686343144955904
# Inspecting node 981229378825801728
# Inspecting node 1335769353124343808
# Inspecting node 54650770
# Inspecting node 1691207420
# Inspecting node 479862010
# Inspecting node 702598323958620163
# Inspecting node 1197864396
# Inspecting node 272677124
# Inspecting node 54426656
# Inspecting node 1965901333
# Inspecting node 1336451673053679620
# Inspecting node 1442989306256113667
# Inspecting node 516604259
# Inspecting node 1420446766869225478
# Inspecting node 250804618
# Inspecting node 963133478
# Inspecting node 224723351
# Inspecting node 1329430334195208192
# Inspecting node 1107013222853304320
# Inspecting node 216438127
# Inspecting node 56568168
# Inspecting node 2289086672
# Inspecting node 342281222
# Inspecting node 250170548
# Inspecting node 896453296059146240
# Inspecting node 246116520
# Inspecting node 1017842910740410368
# Inspecting node 1281660648
# Inspecting node 818467340895522817
# Inspecting node 2414991108
# Inspecting node 2579229572
# Inspecting node 2568029796
# Inspecting node 1424797446845173778
# Inspecting node 24219018
# Inspecting node 1363912931151384588
# Inspecting node 103031465
# Inspecting node 2211020226
# Inspecting node 1310374181687537664
# Inspecting node 1239007657803026432
# Inspecting node 1384893312797003781
# Inspecting node 1927067096
# Inspecting node 17670732
# Inspecting node 939007961388662784
# Inspecting node 823680319274381312
# Inspecting node 1232369847134121986
# Inspecting node 1337783599446286338
# Inspecting node 17076793
# Inspecting node 1025381606
# Inspecting node 87863020
# Inspecting node 38042361
# Inspecting node 2699710783
# Inspecting node 316245912
# Inspecting node 1375846488031432705
# Inspecting node 8820062
# Inspecting node 1396272483309862913
# Inspecting node 830585528961495040
# Inspecting node 246667561
# Inspecting node 885644906915663872
# Inspecting node 375303344
# Inspecting node 1147137986431258624
# Inspecting node 1171095411307753472
# Inspecting node 18418465
# Inspecting node 590154066
# Inspecting node 59835490
# Inspecting node 1705708466
# Inspecting node 1041561337
# Inspecting node 1486136467
# Inspecting node 2807874943
# Inspecting node 17221430
# Inspecting node 1205581352
# Inspecting node 79121813
# Inspecting node 389705011
# Inspecting node 2190688044
# Inspecting node 715394299207090179
# Inspecting node 1382439377406722048
# Inspecting node 1199890847954882560
# Inspecting node 246380006
# Inspecting node 3179422780
# Inspecting node 36471917
# Inspecting node 23424817
# Inspecting node 9814812
# Inspecting node 840697793618550787
# Inspecting node 730780438269206528
# Inspecting node 294539923
# Inspecting node 1279157580799983617
# Inspecting node 403643684
# Inspecting node 53452624
# Inspecting node 2466115268
# Inspecting node 278882082
# Inspecting node 7562042
# Inspecting node 2395405134
# Inspecting node 18163138
# Inspecting node 865300797130764288
# Inspecting node 1287896006550589442
# Inspecting node 59342468
# Inspecting node 2886941025
# Inspecting node 962424351596281856
# Inspecting node 560765411
# Inspecting node 2924898800
# Inspecting node 1218987476112543744
# Inspecting node 2710528980
# Inspecting node 279748443
# Inspecting node 17702445
# Inspecting node 842121813278752768
# Inspecting node 327394273
# Inspecting node 1012406984719470592
# Inspecting node 10155832
# Inspecting node 439313680
# Inspecting node 1151231204923977729
# Inspecting node 989298765163937792
# Inspecting node 866416675
# Inspecting node 36877221
# Inspecting node 351155835
# Inspecting node 11423372
# Inspecting node 41378883
# Inspecting node 2334251844
# Inspecting node 263163489
# Inspecting node 1096251117745332226
# Inspecting node 1407372687316590594
# Inspecting node 1250830543119319042
# Inspecting node 2903614908
# Inspecting node 1351286814313738243
# Inspecting node 1403372126304866305
# Inspecting node 69712457
# Inspecting node 2730870751
# Inspecting node 16189107
# Inspecting node 414275183
# Inspecting node 393348427
# Inspecting node 248911548
# Inspecting node 34774986
# Inspecting node 1194310568200548352
# Inspecting node 1240872856508137472
# Inspecting node 242533078
# Inspecting node 78084063
# Inspecting node 42232039
# Inspecting node 41239526
# Inspecting node 3112228915
# Inspecting node 1852773120
# Inspecting node 1242517797621530625
# Inspecting node 960897097
# Inspecting node 185290543
# Inspecting node 305945328
# Inspecting node 155777848
# Inspecting node 248891184
# Inspecting node 1357931292
# Inspecting node 1582129344
# Inspecting node 63863473
# Inspecting node 744530425
# Inspecting node 1367957858
# Inspecting node 2469606308
# Inspecting node 326461319
# Inspecting node 529665584
# Inspecting node 154271777
# Inspecting node 1270383308
# Inspecting node 2312086998
# Inspecting node 1447429249
# Inspecting node 2861279433
# Inspecting node 466832463
# Inspecting node 67278150
# Inspecting node 1660911480
# Inspecting node 467664297
# Inspecting node 2573566824
# Inspecting node 132989977
# Inspecting node 954431291629473794
# Inspecting node 238865666
# Inspecting node 2569323896
# Inspecting node 788806262045732864
# Inspecting node 14165217
# Inspecting node 1447951549
# Inspecting node 1594767902
# Inspecting node 491779798
# Inspecting node 946092660795744256
# Inspecting node 74211986
# Inspecting node 524590563
# Inspecting node 1338157627453427713
# Inspecting node 823317383838253056
# Inspecting node 1044778781230039042
# Inspecting node 922963142300143616
# Inspecting node 74937543
# Inspecting node 1305697758
# Inspecting node 18463733
# Inspecting node 76264942
# Inspecting node 2905252436
# Inspecting node 44539994
# Inspecting node 396745864
# Inspecting node 1176801
# Inspecting node 1229442788623818752
# Inspecting node 2993775174
# Inspecting node 2462641501
# Inspecting node 560903736
# Inspecting node 1427351911410257934
# Inspecting node 245651739
# Inspecting node 4922698441
# Inspecting node 4024032261
# Inspecting node 15099646
# Inspecting node 75841164
# Inspecting node 794664236
# Inspecting node 1440828246132596736
# Inspecting node 3069762388
# Inspecting node 700994268
# Inspecting node 1104945319
# Inspecting node 38221378
# Inspecting node 3218932860
# Inspecting node 1201882182
# Inspecting node 1395092719
# Inspecting node 2871728962
# Inspecting node 815428708144218112
# Inspecting node 976143225927839744
# Inspecting node 727212809948401664
# Inspecting node 1373435309782822912
# Inspecting node 568769809
# Inspecting node 982017242354388992
# Inspecting node 36395646
# Inspecting node 40697478
# Inspecting node 1423672567869624322
# Inspecting node 164368721
# Inspecting node 46214091
# Inspecting node 2194496264
# Inspecting node 1057723606027792385
# Inspecting node 25209036
# Inspecting node 1347801793930035200
# Inspecting node 868994263
# Inspecting node 117589552
# Inspecting node 1080529497152278528
# Inspecting node 624962704
# Inspecting node 47022386
# Inspecting node 942370814
# Inspecting node 70499348
# Inspecting node 929856990934790144
# Inspecting node 314093378
# Inspecting node 3053107588
# Inspecting node 1459578954
# Inspecting node 4880637512
# Inspecting node 1932563430
# Inspecting node 1282257536
# Inspecting node 17300548
# Inspecting node 1236439017433989122
# Inspecting node 1444458812614709250
# Inspecting node 1386793782683652096
# Inspecting node 9575562
# Inspecting node 120139457
# Inspecting node 1240478580510871552
# Inspecting node 117562974
# Inspecting node 312422268
# Inspecting node 1333030975681536000
# Inspecting node 1040629333210148865
# Inspecting node 252399534
# Inspecting node 2459730643
# Inspecting node 1264712331457638400
# Inspecting node 1428151019981180932
# Inspecting node 280831905
# Inspecting node 1416101066580627464
# Inspecting node 1135929275272634369
# Inspecting node 360214917
# Inspecting node 1302065426961174530
# Inspecting node 39637553
# Inspecting node 114977658
# Inspecting node 1327696892608724992
# Inspecting node 1409204814534299649
# Inspecting node 371939653
# Inspecting node 190010892
# Inspecting node 1275457555490320385
# Inspecting node 1445833073770184706
# Inspecting node 1601728627
# Inspecting node 41748110
# Inspecting node 1438198932606160901
# Inspecting node 16491468
# Inspecting node 323895654
# Inspecting node 137045661
# Inspecting node 1352682350228942848
# Inspecting node 770683230223634433
# Inspecting node 3368587707
# Inspecting node 1120673221236408320
# Inspecting node 213879574
# Inspecting node 1414982991059709954
# Inspecting node 809651491
# Inspecting node 1491487802
# Inspecting node 4886317138
# Inspecting node 14912051
# Inspecting node 915727372443414528
# Inspecting node 966560892262502400
# Inspecting node 885737117745164288
# Inspecting node 981191210705530880
# Inspecting node 341002490
# Inspecting node 1948425750
# Inspecting node 1391765775594180612
# Inspecting node 1346126893733462016
# Inspecting node 1443254711381946371
# Inspecting node 95348250
# Inspecting node 1351325172184264704
# Inspecting node 487857297
# Inspecting node 94885717
# Inspecting node 925876396878020608
# Inspecting node 15300266
# Inspecting node 1212089073323503616
# Inspecting node 239096810
# Inspecting node 1353758379160834051
# Inspecting node 24728011
# Inspecting node 85640352
# Inspecting node 1012839192253075456
# Inspecting node 1259289117805776896
# Inspecting node 1309184065
# Inspecting node 1881851268
# Inspecting node 132512731
# Inspecting node 1181627354621399040
# Inspecting node 34478789
# Inspecting node 2842764204
# Inspecting node 1034903210547277824
# Inspecting node 1202669441000996864
# Inspecting node 961989099623137280
# Inspecting node 1263895193784184832
# Inspecting node 471366697
# Inspecting node 829731473443975170
# Inspecting node 590822892
# Inspecting node 382409124
# Inspecting node 851681
# Inspecting node 870842873628864513
# Inspecting node 271124533
# Inspecting node 446471174
# Inspecting node 228477243
# Inspecting node 1202388934208172032
# Inspecting node 1060751566657867776
# Inspecting node 257304118
# Inspecting node 4096225454
# Inspecting node 216266808
# Inspecting node 159065078
# Inspecting node 1058391394681868289
# Inspecting node 428602423
# Inspecting node 823397168975409152
# Inspecting node 1345473368494104580
# Inspecting node 46563847
# Inspecting node 2444436240
# Inspecting node 1126848839594467328
# Inspecting node 1257895028724203521
# Inspecting node 277513651
# Inspecting node 1110790944821932034
# Inspecting node 1161332556312326144
# Inspecting node 1346332104234295296
# Inspecting node 165942840
# Inspecting node 259587504
# Inspecting node 1925416346
# Inspecting node 15012924
# Inspecting node 18537391
# Inspecting node 42989776
# Inspecting node 93654204
# Inspecting node 34921899
# Inspecting node 2239987934
# Inspecting node 86320422
# Inspecting node 171411616
# Inspecting node 14650213
# Inspecting node 1087961
# Inspecting node 602903529
# Inspecting node 244204227
# Inspecting node 519071482
# Inspecting node 251635353
# Inspecting node 5654722
# Inspecting node 725037770033532929
# Inspecting node 40059893
# Inspecting node 237480031
# Inspecting node 1056707817216720896
# Inspecting node 1383581104473468929
# Inspecting node 373477857
# Inspecting node 20122522
# Inspecting node 4254675664
# Inspecting node 1259345602980298753
# Inspecting node 725344413162049536
# Inspecting node 1433115420563853312
# Inspecting node 166701763
# Inspecting node 582342806
# Inspecting node 14257934
# Inspecting node 1163072647661522946
# Inspecting node 1201151072733138945
# Inspecting node 1352358388638875652
# Inspecting node 549023337
# Inspecting node 936473743387394048
# Inspecting node 437944231
# Inspecting node 400071841
# Inspecting node 637320913
# Inspecting node 19114577
# Inspecting node 70065285
# Inspecting node 1268920433086210048
# Inspecting node 1176689353885724674
# Inspecting node 460592390
# Inspecting node 2262160692
# Inspecting node 2293461198
# Inspecting node 15219830
# Inspecting node 1201532829860892673
# Inspecting node 92417373
# Inspecting node 122127786
# Inspecting node 362454062
# Inspecting node 2984610092
# Inspecting node 415126004
# Inspecting node 844452866
# Inspecting node 14501713
# Inspecting node 1258440535402065920
# Inspecting node 2254247360
# Inspecting node 104585835
# Inspecting node 1410832490701467650
# Inspecting node 365780558
# Inspecting node 21632994
# Inspecting node 1338474046095233026
# Inspecting node 1113547517105528833
# Inspecting node 293588108
# Inspecting node 1155208255066558475
# Inspecting node 22523896
# Inspecting node 3675933919
# Inspecting node 2796774360
# Inspecting node 1095219121447301120
# Inspecting node 816758120819015680
# Inspecting node 825925386110382080
# Inspecting node 1529643188
# Inspecting node 246811073
# Inspecting node 3351916392
# Inspecting node 123910630
# Inspecting node 29304563
# Inspecting node 1396107226608283649
# Inspecting node 549598823
# Inspecting node 797133264716754944
# Inspecting node 768559569891012608
# Inspecting node 1880517650
# Inspecting node 1232471924145577985
# Inspecting node 1300309398166949889
# Inspecting node 1923754400
# Inspecting node 53754232
# Inspecting node 307324209
# Inspecting node 3165242127
# Inspecting node 730826158258946050
# Inspecting node 1577656471
# Inspecting node 1214368702277308421
# Inspecting node 299993498
# Inspecting node 1235344992765448193
# Inspecting node 625193066
# Inspecting node 467817388
# Inspecting node 3135148227
# Inspecting node 872810605
# Inspecting node 271504586
# Inspecting node 306967462
# Inspecting node 3299469609
# Inspecting node 1225848216467509248
# Inspecting node 259388196
# Inspecting node 525910396
# Inspecting node 358143304
# Inspecting node 1088545656002801664
# Inspecting node 1283460034182209537
# Inspecting node 1326306504027287554
# Inspecting node 100874975
# Inspecting node 811549418
# Inspecting node 145058470
# Inspecting node 15892547
# Inspecting node 2797935107
# Inspecting node 27388441
# Inspecting node 288495993
# Inspecting node 77596220
# Inspecting node 891058415195303939
# Inspecting node 1095768409449459712
# Inspecting node 881426857
# Inspecting node 17388526

# %% [markdown]
# Okay I have confirmed Degree is being respected for these 50 models

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.in_degree(node) 
    for key, value in in_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.out_degree(node) 
    for key, value in out_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
degrees = {}
in_degrees = {}
out_degrees = {}

dirname = "Directed_Unweighted_Models/Group1_5_4"
directory = os.fsencode(dirname)

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    H = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    degree_dist = {}
    in_degree_dist = {}
    out_degree_dist = {}
    
    for node in H:
        degree_dist[node] = H.degree(node)
        in_degree_dist[node] = H.in_degree(node)
        out_degree_dist[node] = H.out_degree(node)
    degrees[filename] = degree_dist
    in_degrees[filename] = in_degree_dist
    out_degrees[filename] = out_degree_dist
# Out:
# Directed_Unweighted_Random_Null_Model_295
# Directed_Unweighted_Random_Null_Model_296
# Directed_Unweighted_Random_Null_Model_297
# Directed_Unweighted_Random_Null_Model_298
# Directed_Unweighted_Random_Null_Model_299

# %% [markdown]
# Go through each degree node in G and for each of the models check if some degree is different. If it is stop and report it

# %%
for node in G:
    print("Inspecting node {}".format(node))
    expectedDeg = G.degree(node) 
    for key, value in degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break
# Out:
# Inspecting node 1385933370090209280
# Inspecting node 158095776
# Inspecting node 1416535505454338050
# Inspecting node 1604931252
# Inspecting node 544695802
# Inspecting node 716257068538327040
# Inspecting node 258170457
# Inspecting node 1086084557009575936
# Inspecting node 2817389862
# Inspecting node 822476228548403200
# Inspecting node 2353730881
# Inspecting node 921026239808208896
# Inspecting node 720934098223542272
# Inspecting node 2922779039
# Inspecting node 552891173
# Inspecting node 982496635
# Inspecting node 1433403537329819654
# Inspecting node 1175052073605353473
# Inspecting node 2784661153
# Inspecting node 102887506
# Inspecting node 18681111
# Inspecting node 952980338745147394
# Inspecting node 1438871779779530755
# Inspecting node 46975259
# Inspecting node 1157395568135557120
# Inspecting node 21951711
# Inspecting node 563064119
# Inspecting node 277332906
# Inspecting node 158458133
# Inspecting node 979827806023618560
# Inspecting node 18308257
# Inspecting node 846667915
# Inspecting node 258916078
# Inspecting node 1138564320390836224
# Inspecting node 17912334
# Inspecting node 2821464243
# Inspecting node 928790819145842688
# Inspecting node 753638148958216192
# Inspecting node 2256955027
# Inspecting node 1185936230393024512
# Inspecting node 14079041
# Inspecting node 3021899490
# Inspecting node 13880132
# Inspecting node 960624707820113920
# Inspecting node 52003137
# Inspecting node 1887595058
# Inspecting node 331864347
# Inspecting node 961514730
# Inspecting node 70750793
# Inspecting node 155629527
# Inspecting node 1161351506983038976
# Inspecting node 766360387
# Inspecting node 150270263
# Inspecting node 38471212
# Inspecting node 83153695
# Inspecting node 118937966
# Inspecting node 871189841186357248
# Inspecting node 293403080
# Inspecting node 629539554
# Inspecting node 1104422828
# Inspecting node 602083976
# Inspecting node 1311896805920043009
# Inspecting node 1318741345905922048
# Inspecting node 25314619
# Inspecting node 104300984
# Inspecting node 15702055
# Inspecting node 1153463878195589125
# Inspecting node 15633240
# Inspecting node 14991184
# Inspecting node 1242522201770856449
# Inspecting node 1440522413687521295
# Inspecting node 106524304
# Inspecting node 1292608204845834241
# Inspecting node 1446846657551683588
# Inspecting node 1389700907697270787
# Inspecting node 1445880242707570691
# Inspecting node 1545912997
# Inspecting node 831084798621782016
# Inspecting node 55976571
# Inspecting node 305401065
# Inspecting node 704798725747531776
# Inspecting node 47452040
# Inspecting node 475298690
# Inspecting node 16220555
# Inspecting node 4744498950
# Inspecting node 766759351973404672
# Inspecting node 47781573
# Inspecting node 994077337
# Inspecting node 14055736
# Inspecting node 1236010900693356549
# Inspecting node 1171683272
# Inspecting node 1338338931792756737
# Inspecting node 562243642
# Inspecting node 15772683
# Inspecting node 1251340447387172868
# Inspecting node 1350484767255519233
# Inspecting node 1335046616697372675
# Inspecting node 20750271
# Inspecting node 1162219997977960449
# Inspecting node 175259033
# Inspecting node 130909683
# Inspecting node 1364261390614106113
# Inspecting node 44416854
# Inspecting node 1511003670
# Inspecting node 536594609
# Inspecting node 24913022
# Inspecting node 17823761
# Inspecting node 273683993
# Inspecting node 215632349
# Inspecting node 1156602559378804741
# Inspecting node 1156033982586208256
# Inspecting node 47338701
# Inspecting node 139819609
# Inspecting node 413514250
# Inspecting node 2852899113
# Inspecting node 1381435843492085760
# Inspecting node 1189800120
# Inspecting node 138418077
# Inspecting node 382489139
# Inspecting node 374300583
# Inspecting node 3226840807
# Inspecting node 133863908
# Inspecting node 57127265
# Inspecting node 142731825
# Inspecting node 1417929933800751104
# Inspecting node 55823004
# Inspecting node 1447315781289750532
# Inspecting node 14262411
# Inspecting node 1707636642
# Inspecting node 845487573011173380
# Inspecting node 109144163
# Inspecting node 20199202
# Inspecting node 785448020628430849
# Inspecting node 77283552
# Inspecting node 38055290
# Inspecting node 34506336
# Inspecting node 242798024
# Inspecting node 138077463
# Inspecting node 121343164
# Inspecting node 814078628
# Inspecting node 196717787
# Inspecting node 18519855
# Inspecting node 268824309
# Inspecting node 2439928526
# Inspecting node 1169378542737661954
# Inspecting node 299228245
# Inspecting node 2369365718
# Inspecting node 1373493122
# Inspecting node 2834753506
# Inspecting node 999476893970763777
# Inspecting node 120320139
# Inspecting node 84734389
# Inspecting node 15407637
# Inspecting node 1899063048
# Inspecting node 1301967293849755653
# Inspecting node 324602007
# Inspecting node 292667439
# Inspecting node 522345885
# Inspecting node 12599562
# Inspecting node 4856851754
# Inspecting node 1248842158553141250
# Inspecting node 4026045455
# Inspecting node 3303438653
# Inspecting node 1129203001
# Inspecting node 2813664079
# Inspecting node 14518712
# Inspecting node 95209129
# Inspecting node 119797208
# Inspecting node 201984482
# Inspecting node 593944500
# Inspecting node 17105128
# Inspecting node 3409346380
# Inspecting node 33826892
# Inspecting node 273866823
# Inspecting node 37552089
# Inspecting node 377588094
# Inspecting node 266855812
# Inspecting node 341866567
# Inspecting node 60916234
# Inspecting node 262436837
# Inspecting node 1092244447184719873
# Inspecting node 2548489298
# Inspecting node 218952640
# Inspecting node 1382491059247255554
# Inspecting node 516915897
# Inspecting node 965028316460797953
# Inspecting node 195899568
# Inspecting node 2432750568
# Inspecting node 331067472
# Inspecting node 272133230
# Inspecting node 108413104
# Inspecting node 177347829
# Inspecting node 964446120402300928
# Inspecting node 1573418346
# Inspecting node 89496127
# Inspecting node 735508941258399744
# Inspecting node 542244178
# Inspecting node 1005899772916477952
# Inspecting node 366171300
# Inspecting node 29545977
# Inspecting node 59686058
# Inspecting node 965478102594863104
# Inspecting node 366225624
# Inspecting node 393713239
# Inspecting node 1185972487538040832
# Inspecting node 889661863100907520
# Inspecting node 2813399220
# Inspecting node 2436061363
# Inspecting node 17900758
# Inspecting node 23491400
# Inspecting node 382949896
# Inspecting node 1009115210546929664
# Inspecting node 3148281878
# Inspecting node 1064964294448750595
# Inspecting node 814289414
# Inspecting node 2896012540
# Inspecting node 1280589273335500801
# Inspecting node 1227766472921014272
# Inspecting node 869639001400942592
# Inspecting node 116679707
# Inspecting node 342176065
# Inspecting node 1890389540
# Inspecting node 2785990732
# Inspecting node 40591485
# Inspecting node 3191905064
# Inspecting node 25813888
# Inspecting node 237536271
# Inspecting node 16982577
# Inspecting node 1563418116
# Inspecting node 2580573206
# Inspecting node 275979196
# Inspecting node 193471925
# Inspecting node 53772503
# Inspecting node 16195103
# Inspecting node 2776775090
# Inspecting node 998590102573023232
# Inspecting node 179129165
# Inspecting node 27101995
# Inspecting node 872156101
# Inspecting node 128908662
# Inspecting node 363070453
# Inspecting node 211564038
# Inspecting node 189349553
# Inspecting node 25127782
# Inspecting node 1166717268975333376
# Inspecting node 40550119
# Inspecting node 417389780
# Inspecting node 61521038
# Inspecting node 85428184
# Inspecting node 58319221
# Inspecting node 52080359
# Inspecting node 2513973205
# Inspecting node 283226685
# Inspecting node 45848808
# Inspecting node 1646334073
# Inspecting node 1360838234
# Inspecting node 21221149
# Inspecting node 507802048
# Inspecting node 190231473
# Inspecting node 993705834470367232
# Inspecting node 360677740
# Inspecting node 1362286033
# Inspecting node 3079986094
# Inspecting node 268528986
# Inspecting node 321752222
# Inspecting node 17280115
# Inspecting node 274220538
# Inspecting node 2352629420
# Inspecting node 51184630
# Inspecting node 908811901
# Inspecting node 408526152
# Inspecting node 371447080
# Inspecting node 2314531026
# Inspecting node 1172199939243425792
# Inspecting node 390392773
# Inspecting node 2289973748
# Inspecting node 495066576
# Inspecting node 1545053600
# Inspecting node 1318671397560979456
# Inspecting node 2891740872
# Inspecting node 2848993491
# Inspecting node 103297393
# Inspecting node 1851634098
# Inspecting node 398483708
# Inspecting node 1313212802799206406
# Inspecting node 79260190
# Inspecting node 27652488
# Inspecting node 89609585
# Inspecting node 44618408
# Inspecting node 880491635896922112
# Inspecting node 2761710808
# Inspecting node 1240867313445830656
# Inspecting node 247412217
# Inspecting node 1347654502787076096
# Inspecting node 982630470008553474
# Inspecting node 82167100
# Inspecting node 110754237
# Inspecting node 768069259100622848
# Inspecting node 1304210384367349770
# Inspecting node 1300291239581892609
# Inspecting node 2253903906
# Inspecting node 78403337
# Inspecting node 862703683
# Inspecting node 1071951545212723200
# Inspecting node 840470152391016448
# Inspecting node 498423001
# Inspecting node 1197522605760303104
# Inspecting node 510093784
# Inspecting node 447415943
# Inspecting node 1201788959719936007
# Inspecting node 1633538270
# Inspecting node 122525211
# Inspecting node 192842634
# Inspecting node 551152504
# Inspecting node 378351271
# Inspecting node 57033548
# Inspecting node 255067647
# Inspecting node 35863342
# Inspecting node 2715275551
# Inspecting node 719557076599619584
# Inspecting node 980875592
# Inspecting node 1051100859831148544
# Inspecting node 2300474413
# Inspecting node 1238447220
# Inspecting node 994295935
# Inspecting node 838098877
# Inspecting node 829761553218072576
# Inspecting node 951280545421410305
# Inspecting node 1157684886
# Inspecting node 80970676
# Inspecting node 18923250
# Inspecting node 1136294664
# Inspecting node 951892305098788864
# Inspecting node 3010143902
# Inspecting node 297020666
# Inspecting node 1045793762063060992
# Inspecting node 98588419
# Inspecting node 76179144
# Inspecting node 46956207
# Inspecting node 819853925184638976
# Inspecting node 16552108
# Inspecting node 29754743
# Inspecting node 153515520
# Inspecting node 386330680
# Inspecting node 2736446758
# Inspecting node 35095520
# Inspecting node 1239564608941113347
# Inspecting node 58261480
# Inspecting node 169614697
# Inspecting node 1005522675761057792
# Inspecting node 816308397360508928
# Inspecting node 1407160205117435908
# Inspecting node 1175457080561537025
# Inspecting node 1011936943247101952
# Inspecting node 365078935
# Inspecting node 17540009
# Inspecting node 49660950
# Inspecting node 296549487
# Inspecting node 1228605451
# Inspecting node 1122706063466356737
# Inspecting node 234593598
# Inspecting node 1204301854433316866
# Inspecting node 1204430581410353154
# Inspecting node 893202244077854721
# Inspecting node 22971125
# Inspecting node 1193458951976869888
# Inspecting node 785853390
# Inspecting node 322106815
# Inspecting node 1957597519
# Inspecting node 1101092779378249729
# Inspecting node 3331826578
# Inspecting node 38720614
# Inspecting node 2912843536
# Inspecting node 183642459
# Inspecting node 2247495353
# Inspecting node 2748289416
# Inspecting node 2592210108
# Inspecting node 103701079
# Inspecting node 1352713370772770816
# Inspecting node 86410896
# Inspecting node 1038301598
# Inspecting node 1134248217472843787
# Inspecting node 999320625117196288
# Inspecting node 18390213
# Inspecting node 768295011007934469
# Inspecting node 1262878353431777280
# Inspecting node 729232479840800768
# Inspecting node 1415442622135603206
# Inspecting node 346123223
# Inspecting node 167912183
# Inspecting node 1076249609125675010
# Inspecting node 67793897
# Inspecting node 823096488
# Inspecting node 50154666
# Inspecting node 302593437
# Inspecting node 291862583
# Inspecting node 168371680
# Inspecting node 1251332171211644931
# Inspecting node 962073414
# Inspecting node 291523600
# Inspecting node 277085673
# Inspecting node 62664213
# Inspecting node 1337551744457469952
# Inspecting node 716460064039575552
# Inspecting node 3007815702
# Inspecting node 55819705
# Inspecting node 1404102585317986308
# Inspecting node 1280249212567818240
# Inspecting node 740981264740679681
# Inspecting node 247511435
# Inspecting node 1303772129847111681
# Inspecting node 1027307702047961088
# Inspecting node 1020156666204090368
# Inspecting node 38751529
# Inspecting node 718873385346797569
# Inspecting node 285806588
# Inspecting node 541129316
# Inspecting node 1655457050
# Inspecting node 57759275
# Inspecting node 824281652423753728
# Inspecting node 132015712
# Inspecting node 40647043
# Inspecting node 12992772
# Inspecting node 365132365
# Inspecting node 1129088815
# Inspecting node 1262268501823303680
# Inspecting node 288548798
# Inspecting node 87632735
# Inspecting node 40246161
# Inspecting node 1252686295
# Inspecting node 25333228
# Inspecting node 1093876945
# Inspecting node 205786669
# Inspecting node 1942350667
# Inspecting node 2863551224
# Inspecting node 720083863830069249
# Inspecting node 176207343
# Inspecting node 412708728
# Inspecting node 414218319
# Inspecting node 1271987860577517568
# Inspecting node 626984632
# Inspecting node 237594523
# Inspecting node 714340176
# Inspecting node 300638343
# Inspecting node 739845530612830208
# Inspecting node 715244769
# Inspecting node 817207955930001409
# Inspecting node 1363561650624733184
# Inspecting node 212468225
# Inspecting node 2673432539
# Inspecting node 23601374
# Inspecting node 51852542
# Inspecting node 321482430
# Inspecting node 1058965681671028736
# Inspecting node 35617919
# Inspecting node 371288369
# Inspecting node 4492249646
# Inspecting node 396106258
# Inspecting node 2287331581
# Inspecting node 150671052
# Inspecting node 3302256527
# Inspecting node 3269322830
# Inspecting node 1364751078659477504
# Inspecting node 168123931
# Inspecting node 1072189285
# Inspecting node 45976740
# Inspecting node 1435257575482740741
# Inspecting node 1099109729308008448
# Inspecting node 1366925295291424768
# Inspecting node 1356073687691141121
# Inspecting node 1580475270
# Inspecting node 1442893993935716361
# Inspecting node 392132054
# Inspecting node 207703739
# Inspecting node 1419489038747070467
# Inspecting node 928451444633563136
# Inspecting node 1119464753318043649
# Inspecting node 1440690378533838857
# Inspecting node 2931943245
# Inspecting node 1727398412
# Inspecting node 1444061901172854786
# Inspecting node 2938869339
# Inspecting node 1243723946660421637
# Inspecting node 2476755039
# Inspecting node 1331773252792770560
# Inspecting node 901618905076174848
# Inspecting node 339780511
# Inspecting node 980817985668550656
# Inspecting node 53694666
# Inspecting node 1445437990940004352
# Inspecting node 1243574020802367488
# Inspecting node 1055536236
# Inspecting node 68670486
# Inspecting node 451989089
# Inspecting node 1077731978
# Inspecting node 1271115442573185024
# Inspecting node 969744550955749383
# Inspecting node 26577630
# Inspecting node 1391981080945643523
# Inspecting node 46232947
# Inspecting node 266048357
# Inspecting node 293745266
# Inspecting node 415532452
# Inspecting node 3107597132
# Inspecting node 1183316407104266241
# Inspecting node 982472677775454209
# Inspecting node 3295839203
# Inspecting node 880913594531139584
# Inspecting node 1911858061
# Inspecting node 1097694473952342022
# Inspecting node 1388650232100134915
# Inspecting node 14100537
# Inspecting node 820656479812227073
# Inspecting node 1325249450793701376
# Inspecting node 1427996716138127360
# Inspecting node 1347691972358778885
# Inspecting node 1365678726
# Inspecting node 1295377965438644235
# Inspecting node 322090834
# Inspecting node 1342962255248424961
# Inspecting node 1195026680609292288
# Inspecting node 1116360718687690758
# Inspecting node 737359208945844224
# Inspecting node 3375064758
# Inspecting node 14538949
# Inspecting node 1084856644687679496
# Inspecting node 36133644
# Inspecting node 976345683681619968
# Inspecting node 366785595
# Inspecting node 2849064914
# Inspecting node 343059330
# Inspecting node 64123717
# Inspecting node 18420573
# Inspecting node 957106791753555968
# Inspecting node 751054068974575616
# Inspecting node 1186136760981454854
# Inspecting node 854065048683204615
# Inspecting node 317823907
# Inspecting node 952759886
# Inspecting node 474883984
# Inspecting node 1258133514421239813
# Inspecting node 2198792101
# Inspecting node 324555383
# Inspecting node 744660163873771520
# Inspecting node 726025903
# Inspecting node 1263514760584167424
# Inspecting node 714569357267853312
# Inspecting node 739149720
# Inspecting node 1136772811656126464
# Inspecting node 270307297
# Inspecting node 454774863
# Inspecting node 772948513
# Inspecting node 3333795492
# Inspecting node 2209473078
# Inspecting node 838196271571591168
# Inspecting node 18386792
# Inspecting node 1166799265806503936
# Inspecting node 262522708
# Inspecting node 1370402422062002179
# Inspecting node 1429982282891239433
# Inspecting node 1434265814325202944
# Inspecting node 1087134051914395648
# Inspecting node 791076864
# Inspecting node 121949981
# Inspecting node 256360738
# Inspecting node 1172475064870027264
# Inspecting node 1443468994107822081
# Inspecting node 941115769429024769
# Inspecting node 1313732971061362690
# Inspecting node 2305422800
# Inspecting node 242885214
# Inspecting node 1354230346586447877
# Inspecting node 469747759
# Inspecting node 432114850
# Inspecting node 1166000110586626048
# Inspecting node 884527637569323009
# Inspecting node 369653658
# Inspecting node 1434643524495020043
# Inspecting node 75984040
# Inspecting node 586195164
# Inspecting node 2902344555
# Inspecting node 564257648
# Inspecting node 1027229536902098944
# Inspecting node 2316626342
# Inspecting node 1925354744
# Inspecting node 958204773282533376
# Inspecting node 1445751022526160908
# Inspecting node 1183078912265355265
# Inspecting node 98767459
# Inspecting node 87297879
# Inspecting node 753394222267527168
# Inspecting node 373580557
# Inspecting node 1430260512688902150
# Inspecting node 2468436247
# Inspecting node 3308781515
# Inspecting node 2273880732
# Inspecting node 1302114263771668481
# Inspecting node 24181491
# Inspecting node 1309179346565898241
# Inspecting node 2231471516
# Inspecting node 1352351686778630145
# Inspecting node 1413321993470943237
# Inspecting node 603011131
# Inspecting node 1438876255202406406
# Inspecting node 1375883715776294914
# Inspecting node 1002002024
# Inspecting node 51384524
# Inspecting node 724114092672335874
# Inspecting node 552725069
# Inspecting node 1184298786329448448
# Inspecting node 334954251
# Inspecting node 101915304
# Inspecting node 1252767510983737344
# Inspecting node 1099811037975642112
# Inspecting node 1388988366247575559
# Inspecting node 1326022742286749696
# Inspecting node 1388801354244702209
# Inspecting node 961162177
# Inspecting node 1389555148318404610
# Inspecting node 1151641780267261952
# Inspecting node 27320189
# Inspecting node 1215379886887428096
# Inspecting node 1184882383
# Inspecting node 257699447
# Inspecting node 2397398196
# Inspecting node 807034969902252032
# Inspecting node 1353486048618274816
# Inspecting node 4866566489
# Inspecting node 3058888765
# Inspecting node 1173239638116446208
# Inspecting node 42894434
# Inspecting node 3078011282
# Inspecting node 32691118
# Inspecting node 544080126
# Inspecting node 1336660494
# Inspecting node 957190068594130946
# Inspecting node 1074149416699719681
# Inspecting node 825518936733085696
# Inspecting node 43199433
# Inspecting node 969376788525830146
# Inspecting node 35107179
# Inspecting node 366074756
# Inspecting node 359672860
# Inspecting node 82679357
# Inspecting node 883774859452579840
# Inspecting node 3418588623
# Inspecting node 710270422290403328
# Inspecting node 763168867371843584
# Inspecting node 1575198925
# Inspecting node 1301995158485958656
# Inspecting node 1260291453973983232
# Inspecting node 1601907697
# Inspecting node 29823611
# Inspecting node 1393039117110317058
# Inspecting node 236055343
# Inspecting node 320919057
# Inspecting node 2812908133
# Inspecting node 1325519307359490048
# Inspecting node 590735039
# Inspecting node 95577307
# Inspecting node 43948485
# Inspecting node 136332449
# Inspecting node 623936216
# Inspecting node 2873956499
# Inspecting node 4803873902
# Inspecting node 1147245556651233280
# Inspecting node 918919026344120321
# Inspecting node 37813045
# Inspecting node 24574252
# Inspecting node 1440809899500335110
# Inspecting node 1334205408110551042
# Inspecting node 1071298949837770753
# Inspecting node 915968072
# Inspecting node 885818088
# Inspecting node 227849419
# Inspecting node 2493753559
# Inspecting node 778842486
# Inspecting node 124839366
# Inspecting node 263750524
# Inspecting node 1357001901229899777
# Inspecting node 990301302264479749
# Inspecting node 1136065885456740352
# Inspecting node 1335377050878676992
# Inspecting node 138710067
# Inspecting node 1441961640459599874
# Inspecting node 2793008984
# Inspecting node 120187876
# Inspecting node 178544594
# Inspecting node 2838327755
# Inspecting node 1559780652
# Inspecting node 2291354802
# Inspecting node 1352707350784659456
# Inspecting node 1417352097150816256
# Inspecting node 1427768108614291465
# Inspecting node 1117485007944048640
# Inspecting node 1297264458
# Inspecting node 1194794785762004993
# Inspecting node 26089782
# Inspecting node 1446289055935864836
# Inspecting node 412499776
# Inspecting node 416476088
# Inspecting node 1028871362499305473
# Inspecting node 1438317451469541377
# Inspecting node 546527413
# Inspecting node 1323421765658431488
# Inspecting node 280677070
# Inspecting node 2332742508
# Inspecting node 1347272097786171394
# Inspecting node 2344419362
# Inspecting node 252150132
# Inspecting node 4787666543
# Inspecting node 1454456569
# Inspecting node 587733016
# Inspecting node 823265236916416512
# Inspecting node 1168589910825213952
# Inspecting node 753744536887824385
# Inspecting node 119925381
# Inspecting node 1269692602204532738
# Inspecting node 853722212741898240
# Inspecting node 43089397
# Inspecting node 2323751900
# Inspecting node 1213405462021853185
# Inspecting node 2937436849
# Inspecting node 272250877
# Inspecting node 1406573892
# Inspecting node 1942107584
# Inspecting node 2678072299
# Inspecting node 86384661
# Inspecting node 2983179809
# Inspecting node 3188558830
# Inspecting node 2874772780
# Inspecting node 222386937
# Inspecting node 261788602
# Inspecting node 292468351
# Inspecting node 22849568
# Inspecting node 1203545123356839936
# Inspecting node 19893907
# Inspecting node 1729880688
# Inspecting node 1361500715659755520
# Inspecting node 700287952
# Inspecting node 169268197
# Inspecting node 18622393
# Inspecting node 1304185921433227264
# Inspecting node 97121931
# Inspecting node 1699266222
# Inspecting node 729194378779078656
# Inspecting node 2752659114
# Inspecting node 373460084
# Inspecting node 908018227040710656
# Inspecting node 245149238
# Inspecting node 3242606862
# Inspecting node 29891001
# Inspecting node 720579941184757760
# Inspecting node 276713213
# Inspecting node 1424060815947206662
# Inspecting node 609432652
# Inspecting node 38625077
# Inspecting node 234550882
# Inspecting node 408072407
# Inspecting node 1427258589077508100
# Inspecting node 2242940071
# Inspecting node 44171755
# Inspecting node 41043869
# Inspecting node 436087744
# Inspecting node 578640179
# Inspecting node 132210296
# Inspecting node 923683393
# Inspecting node 1245003009555419137
# Inspecting node 1267504449087553539
# Inspecting node 65666257
# Inspecting node 407943040
# Inspecting node 240908125
# Inspecting node 1057988206963056640
# Inspecting node 130857133
# Inspecting node 1441410998355726344
# Inspecting node 24819740
# Inspecting node 1412813687811760135
# Inspecting node 2762829798
# Inspecting node 1317417438640697344
# Inspecting node 1185990712132812800
# Inspecting node 711980580813066240
# Inspecting node 3237884919
# Inspecting node 9455112
# Inspecting node 19198775
# Inspecting node 22630846
# Inspecting node 1434341584670273544
# Inspecting node 844292741077061632
# Inspecting node 1300624324206817280
# Inspecting node 1332164996592066561
# Inspecting node 337816824
# Inspecting node 153798495
# Inspecting node 1249204176548245504
# Inspecting node 3092462976
# Inspecting node 547671992
# Inspecting node 151547845
# Inspecting node 23554969
# Inspecting node 1314208704
# Inspecting node 808450734240972800
# Inspecting node 204846220
# Inspecting node 19478009
# Inspecting node 18940341
# Inspecting node 62292631
# Inspecting node 1239692519094575104
# Inspecting node 64261339
# Inspecting node 271989352
# Inspecting node 66334416
# Inspecting node 756584190112591872
# Inspecting node 24459228
# Inspecting node 771870952544096257
# Inspecting node 1242251887
# Inspecting node 15908286
# Inspecting node 1390840055200108546
# Inspecting node 2408260398
# Inspecting node 488067802
# Inspecting node 1511667030
# Inspecting node 579614622
# Inspecting node 728304522662043648
# Inspecting node 1092960066
# Inspecting node 64099329
# Inspecting node 1393055510480441345
# Inspecting node 2555583872
# Inspecting node 2452465303
# Inspecting node 282526718
# Inspecting node 4298769753
# Inspecting node 572827030
# Inspecting node 1414623993529880576
# Inspecting node 1255927911045095425
# Inspecting node 1373016955
# Inspecting node 2720800274
# Inspecting node 57661541
# Inspecting node 708739471
# Inspecting node 722623738672517120
# Inspecting node 157591483
# Inspecting node 1390378070482165763
# Inspecting node 2707780448
# Inspecting node 898554931271127042
# Inspecting node 525857359
# Inspecting node 2536457582
# Inspecting node 19634262
# Inspecting node 1357304889831878657
# Inspecting node 1243221104560345090
# Inspecting node 431141725
# Inspecting node 1244435052
# Inspecting node 159655782
# Inspecting node 382223500
# Inspecting node 535452718
# Inspecting node 1293199610178080775
# Inspecting node 12923812
# Inspecting node 16272844
# Inspecting node 335769776
# Inspecting node 16279532
# Inspecting node 3358671
# Inspecting node 16180205
# Inspecting node 2322580746
# Inspecting node 171115367
# Inspecting node 208750527
# Inspecting node 240786249
# Inspecting node 3257047456
# Inspecting node 500232993
# Inspecting node 1171073846335721472
# Inspecting node 1304472952482783232
# Inspecting node 1072270926
# Inspecting node 2789770741
# Inspecting node 2327530022
# Inspecting node 1002181382
# Inspecting node 47692251
# Inspecting node 743129088
# Inspecting node 271073165
# Inspecting node 1895316878
# Inspecting node 631988630
# Inspecting node 290162716
# Inspecting node 2229187188
# Inspecting node 274507495
# Inspecting node 417524720
# Inspecting node 415774799
# Inspecting node 579377522
# Inspecting node 32915303
# Inspecting node 245954929
# Inspecting node 170377354
# Inspecting node 1390883714
# Inspecting node 3363252329
# Inspecting node 1143342270399373313
# Inspecting node 272185225
# Inspecting node 1144289639924207616
# Inspecting node 43510607
# Inspecting node 524557553
# Inspecting node 256775505
# Inspecting node 493488747
# Inspecting node 868245382148521984
# Inspecting node 1170770038208565248
# Inspecting node 339752726
# Inspecting node 249221867
# Inspecting node 488052222
# Inspecting node 911471588
# Inspecting node 246466184
# Inspecting node 280552762
# Inspecting node 295951367
# Inspecting node 973087261
# Inspecting node 1321710295245447169
# Inspecting node 48369926
# Inspecting node 1438956476588957701
# Inspecting node 385008014
# Inspecting node 918152297544380417
# Inspecting node 33562561
# Inspecting node 987136895162384384
# Inspecting node 1327442450957303809
# Inspecting node 870473605473198080
# Inspecting node 35337644
# Inspecting node 1103832363363127297
# Inspecting node 1243323314652602368
# Inspecting node 1268045786312593408
# Inspecting node 17355421
# Inspecting node 24348660
# Inspecting node 14247924
# Inspecting node 106512310
# Inspecting node 1269254845615095810
# Inspecting node 1219578234
# Inspecting node 1380813355
# Inspecting node 883334379023597568
# Inspecting node 58878834
# Inspecting node 912346683291389953
# Inspecting node 3179475258
# Inspecting node 245939022
# Inspecting node 363654070
# Inspecting node 3071603495
# Inspecting node 573788425
# Inspecting node 878490462
# Inspecting node 1423385158263132168
# Inspecting node 1268728504964825088
# Inspecting node 46894332
# Inspecting node 136160953
# Inspecting node 107218304
# Inspecting node 73411833
# Inspecting node 1405971529217740812
# Inspecting node 1275123310788063233
# Inspecting node 1173035282461089793
# Inspecting node 1445090669643517961
# Inspecting node 1389241812276023296
# Inspecting node 501994958
# Inspecting node 2799175653
# Inspecting node 1429555219457773581
# Inspecting node 1668333199
# Inspecting node 1218019404992196609
# Inspecting node 1366204146957885445
# Inspecting node 1198972583288459265
# Inspecting node 1433247289330577408
# Inspecting node 502160853
# Inspecting node 41520537
# Inspecting node 1294478815628890112
# Inspecting node 395394840
# Inspecting node 1151704477
# Inspecting node 1044711566354960384
# Inspecting node 1271855851330916353
# Inspecting node 1497052201
# Inspecting node 975757898004549633
# Inspecting node 3245708989
# Inspecting node 1267640853000007680
# Inspecting node 29917096
# Inspecting node 245373521
# Inspecting node 1420482733135040522
# Inspecting node 1242510089145266182
# Inspecting node 28737527
# Inspecting node 1731401322
# Inspecting node 979870450577686528
# Inspecting node 1354922263418523648
# Inspecting node 24951781
# Inspecting node 15613754
# Inspecting node 100851235
# Inspecting node 59243738
# Inspecting node 17360968
# Inspecting node 360129945
# Inspecting node 1174006316412674048
# Inspecting node 21809306
# Inspecting node 1134558647835430912
# Inspecting node 855478711
# Inspecting node 25178951
# Inspecting node 52350953
# Inspecting node 20796969
# Inspecting node 55158039
# Inspecting node 1401659310015397889
# Inspecting node 215896862
# Inspecting node 4540976253
# Inspecting node 56016987
# Inspecting node 1357857933019598849
# Inspecting node 1125841354716696576
# Inspecting node 793343793642680320
# Inspecting node 48219360
# Inspecting node 399184212
# Inspecting node 827222807121637377
# Inspecting node 1138228267
# Inspecting node 1671821988
# Inspecting node 2321539819
# Inspecting node 17969963
# Inspecting node 1337935917298962434
# Inspecting node 1055170328442224641
# Inspecting node 325805788
# Inspecting node 1128406689802276865
# Inspecting node 1560811022
# Inspecting node 1264568784318345218
# Inspecting node 254240108
# Inspecting node 2237957942
# Inspecting node 387828045
# Inspecting node 3355188729
# Inspecting node 1483945802
# Inspecting node 1663608300
# Inspecting node 1335613030852386817
# Inspecting node 2678629590
# Inspecting node 884681534
# Inspecting node 420536762
# Inspecting node 4329525312
# Inspecting node 1547244656
# Inspecting node 109341612
# Inspecting node 108689047
# Inspecting node 1223265601147342848
# Inspecting node 297968019
# Inspecting node 183758895
# Inspecting node 45932749
# Inspecting node 418786259
# Inspecting node 70240459
# Inspecting node 1606592767
# Inspecting node 1047167241119326211
# Inspecting node 978673214283853825
# Inspecting node 17136419
# Inspecting node 1242152485
# Inspecting node 4445748801
# Inspecting node 1413908511461945350
# Inspecting node 1314819918328729600
# Inspecting node 1140532022
# Inspecting node 1200932043544117248
# Inspecting node 3109560272
# Inspecting node 162924629
# Inspecting node 182072629
# Inspecting node 980237238
# Inspecting node 1213189717425917953
# Inspecting node 2800741820
# Inspecting node 19135439
# Inspecting node 967241034873933824
# Inspecting node 3236492411
# Inspecting node 1235422076082589696
# Inspecting node 534591437
# Inspecting node 1454880680
# Inspecting node 1069754111078354948
# Inspecting node 2286750115
# Inspecting node 1375862610
# Inspecting node 26071396
# Inspecting node 375764669
# Inspecting node 1833674827
# Inspecting node 392380645
# Inspecting node 769165632738762752
# Inspecting node 989311745100566529
# Inspecting node 256552850
# Inspecting node 2218371769
# Inspecting node 29721598
# Inspecting node 1008103433822351360
# Inspecting node 1214027006242742273
# Inspecting node 142107502
# Inspecting node 1314568089300873216
# Inspecting node 801218452618956800
# Inspecting node 1330675961839443973
# Inspecting node 1441448795921952768
# Inspecting node 102491634
# Inspecting node 24978284
# Inspecting node 36988268
# Inspecting node 712792479729192960
# Inspecting node 890560416526594048
# Inspecting node 1413820603
# Inspecting node 37044121
# Inspecting node 832619717785329664
# Inspecting node 1171471512085389312
# Inspecting node 61542328
# Inspecting node 494320156
# Inspecting node 13716572
# Inspecting node 1017461230984990720
# Inspecting node 25703839
# Inspecting node 363666493
# Inspecting node 975491119734763522
# Inspecting node 61888526
# Inspecting node 2502596130
# Inspecting node 763867259777519618
# Inspecting node 1185294078256254977
# Inspecting node 1296424847149588483
# Inspecting node 2721515522
# Inspecting node 224600898
# Inspecting node 524785211
# Inspecting node 777617628009332736
# Inspecting node 189341190
# Inspecting node 2451955022
# Inspecting node 835061048533082113
# Inspecting node 248022226
# Inspecting node 2988258574
# Inspecting node 1001287095472873473
# Inspecting node 1182252711833718784
# Inspecting node 1861048644
# Inspecting node 2842385693
# Inspecting node 248065960
# Inspecting node 931882614
# Inspecting node 3290783049
# Inspecting node 359260523
# Inspecting node 16116228
# Inspecting node 243912778
# Inspecting node 2439108320
# Inspecting node 1176536298179284993
# Inspecting node 297771685
# Inspecting node 1128366660128260097
# Inspecting node 222987791
# Inspecting node 18597273
# Inspecting node 577727470
# Inspecting node 112767813
# Inspecting node 116837959
# Inspecting node 83712358
# Inspecting node 486703473
# Inspecting node 67758676
# Inspecting node 20346252
# Inspecting node 420560195
# Inspecting node 3153084524
# Inspecting node 1308040042724519939
# Inspecting node 1182947209
# Inspecting node 1258576501
# Inspecting node 213140093
# Inspecting node 225067116
# Inspecting node 18340314
# Inspecting node 1310724884008321028
# Inspecting node 160429871
# Inspecting node 214530013
# Inspecting node 110504574
# Inspecting node 24692082
# Inspecting node 16422863
# Inspecting node 1650588223
# Inspecting node 1548315212
# Inspecting node 1378038493105037320
# Inspecting node 4731285264
# Inspecting node 1260770767123312640
# Inspecting node 1260759194833006593
# Inspecting node 975784752648212480
# Inspecting node 2367303485
# Inspecting node 1346317368637603841
# Inspecting node 1426665402147360769
# Inspecting node 1024397417423106048
# Inspecting node 776153719675072512
# Inspecting node 787738985481240576
# Inspecting node 911264470210682880
# Inspecting node 1005823371144318977
# Inspecting node 1416921060788801539
# Inspecting node 17174462
# Inspecting node 1214396742
# Inspecting node 2379113581
# Inspecting node 1426711288462417921
# Inspecting node 21426717
# Inspecting node 975519759105060864
# Inspecting node 2394842400
# Inspecting node 1430196796781912066
# Inspecting node 1433249159474200577
# Inspecting node 20467453
# Inspecting node 1353457212799262720
# Inspecting node 877710910780985345
# Inspecting node 1413615091224924164
# Inspecting node 739208182837321729
# Inspecting node 16545084
# Inspecting node 1234968032734216193
# Inspecting node 979741136725184512
# Inspecting node 509604564
# Inspecting node 731972892
# Inspecting node 1357259774
# Inspecting node 308032537
# Inspecting node 782939425
# Inspecting node 824028437568438277
# Inspecting node 1255919262998441987
# Inspecting node 1291405539046457345
# Inspecting node 1306024583858917376
# Inspecting node 578272027
# Inspecting node 294660973
# Inspecting node 1212202179777331200
# Inspecting node 21632185
# Inspecting node 1227080599451701249
# Inspecting node 2906452022
# Inspecting node 1298675867061805056
# Inspecting node 15128653
# Inspecting node 820499790
# Inspecting node 1238950146559352834
# Inspecting node 1854934933
# Inspecting node 1444459015875014657
# Inspecting node 147340782
# Inspecting node 15677734
# Inspecting node 195207470
# Inspecting node 1282074147884015616
# Inspecting node 977009074217795584
# Inspecting node 3331283445
# Inspecting node 826085293677748224
# Inspecting node 1355980761443217415
# Inspecting node 92256613
# Inspecting node 1278822500143677442
# Inspecting node 187257177
# Inspecting node 902402049022808064
# Inspecting node 1694247541
# Inspecting node 403374868
# Inspecting node 42142250
# Inspecting node 4856189107
# Inspecting node 483313162
# Inspecting node 2427741792
# Inspecting node 2174574218
# Inspecting node 3831737053
# Inspecting node 892123934119927809
# Inspecting node 3660694460
# Inspecting node 3298660936
# Inspecting node 3289694144
# Inspecting node 459311957
# Inspecting node 33456207
# Inspecting node 144036263
# Inspecting node 1049412181559787521
# Inspecting node 826499437585371136
# Inspecting node 540672851
# Inspecting node 1444511517379026948
# Inspecting node 1023207519060197383
# Inspecting node 22532501
# Inspecting node 1067386991250206721
# Inspecting node 2800244863
# Inspecting node 92736596
# Inspecting node 1225489734178344962
# Inspecting node 66621998
# Inspecting node 1059573444214439937
# Inspecting node 1442259927779532808
# Inspecting node 751872198961487872
# Inspecting node 1190792680877559810
# Inspecting node 147981741
# Inspecting node 3158178364
# Inspecting node 1198789568214044672
# Inspecting node 1118222712818868229
# Inspecting node 1296542987850113024
# Inspecting node 1294643635397550080
# Inspecting node 920714531537481729
# Inspecting node 779333693936721920
# Inspecting node 49707487
# Inspecting node 1424936529621774338
# Inspecting node 1129198217164234753
# Inspecting node 1366519801997193216
# Inspecting node 32235586
# Inspecting node 44674554
# Inspecting node 224063162
# Inspecting node 369093
# Inspecting node 2883808867
# Inspecting node 292524345
# Inspecting node 22968164
# Inspecting node 1001274194443821064
# Inspecting node 15054416
# Inspecting node 21400756
# Inspecting node 4860164601
# Inspecting node 467804527
# Inspecting node 958181344286269440
# Inspecting node 778262568272027648
# Inspecting node 38929865
# Inspecting node 297074777
# Inspecting node 760353522718081026
# Inspecting node 928262146542026752
# Inspecting node 160673089
# Inspecting node 175939051
# Inspecting node 1187760523829563392
# Inspecting node 78429753
# Inspecting node 4722097454
# Inspecting node 1070001735454875648
# Inspecting node 35728556
# Inspecting node 1402352323851083779
# Inspecting node 1097176821622284289
# Inspecting node 150699925
# Inspecting node 1060278863874478080
# Inspecting node 813073081761570816
# Inspecting node 722880943380242432
# Inspecting node 14960142
# Inspecting node 1346936882
# Inspecting node 1073283389288005632
# Inspecting node 1297250167
# Inspecting node 1322191014455554048
# Inspecting node 1357200256618795008
# Inspecting node 16504074
# Inspecting node 158100294
# Inspecting node 817811639516991488
# Inspecting node 824357739501531136
# Inspecting node 268237247
# Inspecting node 21815663
# Inspecting node 318420941
# Inspecting node 341180420
# Inspecting node 2267952750
# Inspecting node 454336947
# Inspecting node 725309237862223872
# Inspecting node 353903334
# Inspecting node 2247798150
# Inspecting node 489749588
# Inspecting node 4819639768
# Inspecting node 1330218727
# Inspecting node 1481076481
# Inspecting node 2479224015
# Inspecting node 563152589
# Inspecting node 1317418116
# Inspecting node 1350924172554366979
# Inspecting node 23101207
# Inspecting node 1357917347181453312
# Inspecting node 721401357
# Inspecting node 2926114316
# Inspecting node 968303534822313984
# Inspecting node 77035084
# Inspecting node 85859978
# Inspecting node 2720749324
# Inspecting node 734095130
# Inspecting node 3257661611
# Inspecting node 1219432023044939776
# Inspecting node 998712356
# Inspecting node 603662056
# Inspecting node 4729460081
# Inspecting node 188565420
# Inspecting node 2534622463
# Inspecting node 165020784
# Inspecting node 84704052
# Inspecting node 4273980252
# Inspecting node 29256016
# Inspecting node 577968691
# Inspecting node 845271811097055234
# Inspecting node 470780364
# Inspecting node 22531935
# Inspecting node 59829657
# Inspecting node 275735174
# Inspecting node 559870034
# Inspecting node 7491592
# Inspecting node 23282993
# Inspecting node 2411078349
# Inspecting node 4148412316
# Inspecting node 73199415
# Inspecting node 366968661
# Inspecting node 341653196
# Inspecting node 605379442
# Inspecting node 28045785
# Inspecting node 40216513
# Inspecting node 925675836526776321
# Inspecting node 1080965055007592456
# Inspecting node 1032507164
# Inspecting node 820730609043505152
# Inspecting node 495401684
# Inspecting node 29904143
# Inspecting node 365563514
# Inspecting node 1142295084572073985
# Inspecting node 23522098
# Inspecting node 624251860
# Inspecting node 80212065
# Inspecting node 2829798301
# Inspecting node 1390067256080621568
# Inspecting node 38878429
# Inspecting node 2801061205
# Inspecting node 935335003084423168
# Inspecting node 622885791
# Inspecting node 1112914064076931072
# Inspecting node 384288098
# Inspecting node 515847342
# Inspecting node 3111765339
# Inspecting node 3419010088
# Inspecting node 571519594
# Inspecting node 935697022400602112
# Inspecting node 349692386
# Inspecting node 1223950760
# Inspecting node 3341414159
# Inspecting node 1382336580518621186
# Inspecting node 3142614406
# Inspecting node 731469980890476545
# Inspecting node 58340767
# Inspecting node 266653082
# Inspecting node 2853989866
# Inspecting node 3607702640
# Inspecting node 1421968442
# Inspecting node 297986745
# Inspecting node 54042169
# Inspecting node 577170668
# Inspecting node 880108852162707456
# Inspecting node 1380189591735517190
# Inspecting node 35051540
# Inspecting node 1074335960
# Inspecting node 1371923720609095686
# Inspecting node 1280972258
# Inspecting node 491697655
# Inspecting node 2651576688
# Inspecting node 1117035592565628928
# Inspecting node 163922710
# Inspecting node 1286102971974025217
# Inspecting node 2620272561
# Inspecting node 52516962
# Inspecting node 1065829609
# Inspecting node 1437800221375963143
# Inspecting node 1247541393121087495
# Inspecting node 892060639526395904
# Inspecting node 543143031
# Inspecting node 124878802
# Inspecting node 1341618252
# Inspecting node 727897637098135552
# Inspecting node 14221144
# Inspecting node 950848085802004480
# Inspecting node 16267310
# Inspecting node 2262304373
# Inspecting node 727519870590541824
# Inspecting node 92551736
# Inspecting node 3438124552
# Inspecting node 2749373577
# Inspecting node 535799622
# Inspecting node 1354038378640134145
# Inspecting node 1239698227739459584
# Inspecting node 196164822
# Inspecting node 3075929388
# Inspecting node 1212777267169873920
# Inspecting node 140253506
# Inspecting node 1571464364
# Inspecting node 37609730
# Inspecting node 1396338835596795904
# Inspecting node 1069734050301128705
# Inspecting node 1581712848
# Inspecting node 3268565808
# Inspecting node 786738726466707460
# Inspecting node 1115838887623122954
# Inspecting node 1498327201
# Inspecting node 1316013080250216453
# Inspecting node 957808962983755776
# Inspecting node 2727310657
# Inspecting node 2353185104
# Inspecting node 992390491105882112
# Inspecting node 1133696644422275072
# Inspecting node 3087811674
# Inspecting node 2151893489
# Inspecting node 904365258399244288
# Inspecting node 1393384383650975744
# Inspecting node 707364896153980928
# Inspecting node 371739649
# Inspecting node 1203817853494779904
# Inspecting node 1081036726758531072
# Inspecting node 2968424080
# Inspecting node 2151613567
# Inspecting node 198927392
# Inspecting node 951527727365988352
# Inspecting node 1093890667909124100
# Inspecting node 593891991
# Inspecting node 4850122813
# Inspecting node 872152901870911489
# Inspecting node 878242924567441408
# Inspecting node 1335043297
# Inspecting node 725731648017424385
# Inspecting node 1198351736
# Inspecting node 26557104
# Inspecting node 1042821954821087232
# Inspecting node 1428826266
# Inspecting node 2831610879
# Inspecting node 4681656433
# Inspecting node 775279674
# Inspecting node 596787864
# Inspecting node 273262205
# Inspecting node 24990450
# Inspecting node 342699819
# Inspecting node 378321467
# Inspecting node 217485938
# Inspecting node 967837552425119744
# Inspecting node 18579611
# Inspecting node 16811701
# Inspecting node 63476527
# Inspecting node 17442269
# Inspecting node 1366423551704784897
# Inspecting node 1070588953105969152
# Inspecting node 119911112
# Inspecting node 145878023
# Inspecting node 28540616
# Inspecting node 17050123
# Inspecting node 1432002021398306821
# Inspecting node 930479718
# Inspecting node 2341257349
# Inspecting node 587087289
# Inspecting node 708990479895896066
# Inspecting node 566196508
# Inspecting node 1019405015855878144
# Inspecting node 1275466513529671681
# Inspecting node 1347609010434953217
# Inspecting node 1419539298
# Inspecting node 57527830
# Inspecting node 24752425
# Inspecting node 29586080
# Inspecting node 1250609616192446466
# Inspecting node 2589728724
# Inspecting node 7922582
# Inspecting node 1124423281765797888
# Inspecting node 1077139237
# Inspecting node 199876983
# Inspecting node 18680879
# Inspecting node 380327126
# Inspecting node 3139690604
# Inspecting node 282111410
# Inspecting node 273727399
# Inspecting node 703722876
# Inspecting node 3357096478
# Inspecting node 838912397066846208
# Inspecting node 1437539837477748738
# Inspecting node 751919973497384962
# Inspecting node 1404491652580843525
# Inspecting node 1067154574278971392
# Inspecting node 576365948
# Inspecting node 31513326
# Inspecting node 1297575021578256388
# Inspecting node 1233196108211294209
# Inspecting node 19359977
# Inspecting node 745800926
# Inspecting node 2448257995
# Inspecting node 839668692866723840
# Inspecting node 15023001
# Inspecting node 30270072
# Inspecting node 17929195
# Inspecting node 385678932
# Inspecting node 1065257588151996422
# Inspecting node 1687712964
# Inspecting node 1345709200618389504
# Inspecting node 224737149
# Inspecting node 373940903
# Inspecting node 6013662
# Inspecting node 907302868645953537
# Inspecting node 1243336421164732416
# Inspecting node 240831038
# Inspecting node 290312086
# Inspecting node 4026420858
# Inspecting node 540103190
# Inspecting node 248866864
# Inspecting node 148618115
# Inspecting node 83307703
# Inspecting node 918318518
# Inspecting node 21166754
# Inspecting node 493604178
# Inspecting node 1222274097935073281
# Inspecting node 336662190
# Inspecting node 1254832256
# Inspecting node 65917423
# Inspecting node 15257975
# Inspecting node 18148460
# Inspecting node 168350399
# Inspecting node 18457918
# Inspecting node 165890739
# Inspecting node 1380663772906356737
# Inspecting node 554805867
# Inspecting node 1344041868779110400
# Inspecting node 373667686
# Inspecting node 1261311256151183362
# Inspecting node 1116067546778628097
# Inspecting node 1416035013502685184
# Inspecting node 24313572
# Inspecting node 1144704604442988544
# Inspecting node 222126993
# Inspecting node 2655180373
# Inspecting node 887262626
# Inspecting node 3131039404
# Inspecting node 249386982
# Inspecting node 4759974372
# Inspecting node 494732315
# Inspecting node 1405037853579436035
# Inspecting node 15049380
# Inspecting node 396149168
# Inspecting node 977021137
# Inspecting node 3320688247
# Inspecting node 880997516
# Inspecting node 264439847
# Inspecting node 1068193791511678977
# Inspecting node 636649732
# Inspecting node 14837621
# Inspecting node 596793900
# Inspecting node 4767685428
# Inspecting node 1407536941680279552
# Inspecting node 717895042602504192
# Inspecting node 52245251
# Inspecting node 2574056066
# Inspecting node 35476624
# Inspecting node 48035511
# Inspecting node 207677544
# Inspecting node 56029187
# Inspecting node 3306930701
# Inspecting node 1177657984220053506
# Inspecting node 165971686
# Inspecting node 758042170968375296
# Inspecting node 242492168
# Inspecting node 27460814
# Inspecting node 1231982311253708803
# Inspecting node 2533511951
# Inspecting node 3317590829
# Inspecting node 2416130503
# Inspecting node 724952267162542080
# Inspecting node 22491454
# Inspecting node 3029210380
# Inspecting node 2157300561
# Inspecting node 1053529093285785601
# Inspecting node 1130348139607576576
# Inspecting node 1232835905616011264
# Inspecting node 2922358250
# Inspecting node 1001986308343033856
# Inspecting node 1022679197976678400
# Inspecting node 2560632538
# Inspecting node 1317802041423646720
# Inspecting node 884265045479313408
# Inspecting node 1229474724142604288
# Inspecting node 486317915
# Inspecting node 235070820
# Inspecting node 755749623491244032
# Inspecting node 32189160
# Inspecting node 416468980
# Inspecting node 1051556700
# Inspecting node 1171534270168367105
# Inspecting node 23370368
# Inspecting node 1399510991885455362
# Inspecting node 1438462388647440386
# Inspecting node 214708464
# Inspecting node 547747984
# Inspecting node 366117993
# Inspecting node 262910171
# Inspecting node 1416997300199641091
# Inspecting node 24707528
# Inspecting node 521255914
# Inspecting node 1267810083389480963
# Inspecting node 165587758
# Inspecting node 1398595872187830274
# Inspecting node 1392128666998542337
# Inspecting node 2612807188
# Inspecting node 2652768953
# Inspecting node 292728050
# Inspecting node 96450418
# Inspecting node 2811765535
# Inspecting node 45010284
# Inspecting node 128290965
# Inspecting node 1088791968451313665
# Inspecting node 268573963
# Inspecting node 41089713
# Inspecting node 55841183
# Inspecting node 1419998048562909204
# Inspecting node 2969192164
# Inspecting node 1338252288
# Inspecting node 887732866423173125
# Inspecting node 39268708
# Inspecting node 995530035892121601
# Inspecting node 2694473137
# Inspecting node 421830937
# Inspecting node 1097531188338552832
# Inspecting node 64514213
# Inspecting node 67254536
# Inspecting node 1191423138954981382
# Inspecting node 244328935
# Inspecting node 15782904
# Inspecting node 147965270
# Inspecting node 2944338467
# ...
# Inspecting node 1411006381117919235
# Inspecting node 84353854
# Inspecting node 1446920962671185920
# Inspecting node 1365798226717151233
# Inspecting node 281811081
# Inspecting node 1406365981329346565
# Inspecting node 65767300
# Inspecting node 3011968549
# Inspecting node 1438896900070117381
# Inspecting node 547245887
# Inspecting node 1615902452
# Inspecting node 38885578
# Inspecting node 948223698649124870
# Inspecting node 1242785654368382979
# Inspecting node 3145151881
# Inspecting node 1148750306634883077
# Inspecting node 40109301
# Inspecting node 895679481720872960
# Inspecting node 2966914766
# Inspecting node 1347952445985497088
# Inspecting node 922806178446327809
# Inspecting node 131591657
# Inspecting node 1374005511495028737
# Inspecting node 408241959
# Inspecting node 809552357763661824
# Inspecting node 1556631295
# Inspecting node 282728904
# Inspecting node 785667382224293888
# Inspecting node 1013808600
# Inspecting node 16271356
# Inspecting node 4762708393
# Inspecting node 2167166754
# Inspecting node 517098546
# Inspecting node 886380609026785280
# Inspecting node 2869430815
# Inspecting node 937525764
# Inspecting node 981670040062779392
# Inspecting node 909852173479104512
# Inspecting node 220518078
# Inspecting node 226666386
# Inspecting node 288515399
# Inspecting node 220871206
# Inspecting node 17394737
# Inspecting node 85688497
# Inspecting node 85625597
# Inspecting node 32611097
# Inspecting node 1144689874424999937
# Inspecting node 2465329364
# Inspecting node 149701807
# Inspecting node 26186692
# Inspecting node 23371273
# Inspecting node 3015944460
# Inspecting node 760257132675600386
# Inspecting node 730797462991065088
# Inspecting node 771466526348107776
# Inspecting node 45950539
# Inspecting node 1160209698
# Inspecting node 1109141736972939264
# Inspecting node 169237647
# Inspecting node 1145662294849990656
# Inspecting node 78641250
# Inspecting node 821066393143672836
# Inspecting node 27740019
# Inspecting node 2201466604
# Inspecting node 1361822936
# Inspecting node 21108458
# Inspecting node 382935719
# Inspecting node 1252040788982169600
# Inspecting node 23937700
# Inspecting node 372577100
# Inspecting node 53807352
# Inspecting node 1177551303725240322
# Inspecting node 1252976493971595265
# Inspecting node 441289118
# Inspecting node 897094186213588992
# Inspecting node 3676427473
# Inspecting node 469671065
# Inspecting node 846920964113870848
# Inspecting node 268469213
# Inspecting node 24573102
# Inspecting node 16170023
# Inspecting node 2458783644
# Inspecting node 258405050
# Inspecting node 301144504
# Inspecting node 495918203
# Inspecting node 1239567083404292097
# Inspecting node 536853804
# Inspecting node 250839952
# Inspecting node 856686343144955904
# Inspecting node 981229378825801728
# Inspecting node 1335769353124343808
# Inspecting node 54650770
# Inspecting node 1691207420
# Inspecting node 479862010
# Inspecting node 702598323958620163
# Inspecting node 1197864396
# Inspecting node 272677124
# Inspecting node 54426656
# Inspecting node 1965901333
# Inspecting node 1336451673053679620
# Inspecting node 1442989306256113667
# Inspecting node 516604259
# Inspecting node 1420446766869225478
# Inspecting node 250804618
# Inspecting node 963133478
# Inspecting node 224723351
# Inspecting node 1329430334195208192
# Inspecting node 1107013222853304320
# Inspecting node 216438127
# Inspecting node 56568168
# Inspecting node 2289086672
# Inspecting node 342281222
# Inspecting node 250170548
# Inspecting node 896453296059146240
# Inspecting node 246116520
# Inspecting node 1017842910740410368
# Inspecting node 1281660648
# Inspecting node 818467340895522817
# Inspecting node 2414991108
# Inspecting node 2579229572
# Inspecting node 2568029796
# Inspecting node 1424797446845173778
# Inspecting node 24219018
# Inspecting node 1363912931151384588
# Inspecting node 103031465
# Inspecting node 2211020226
# Inspecting node 1310374181687537664
# Inspecting node 1239007657803026432
# Inspecting node 1384893312797003781
# Inspecting node 1927067096
# Inspecting node 17670732
# Inspecting node 939007961388662784
# Inspecting node 823680319274381312
# Inspecting node 1232369847134121986
# Inspecting node 1337783599446286338
# Inspecting node 17076793
# Inspecting node 1025381606
# Inspecting node 87863020
# Inspecting node 38042361
# Inspecting node 2699710783
# Inspecting node 316245912
# Inspecting node 1375846488031432705
# Inspecting node 8820062
# Inspecting node 1396272483309862913
# Inspecting node 830585528961495040
# Inspecting node 246667561
# Inspecting node 885644906915663872
# Inspecting node 375303344
# Inspecting node 1147137986431258624
# Inspecting node 1171095411307753472
# Inspecting node 18418465
# Inspecting node 590154066
# Inspecting node 59835490
# Inspecting node 1705708466
# Inspecting node 1041561337
# Inspecting node 1486136467
# Inspecting node 2807874943
# Inspecting node 17221430
# Inspecting node 1205581352
# Inspecting node 79121813
# Inspecting node 389705011
# Inspecting node 2190688044
# Inspecting node 715394299207090179
# Inspecting node 1382439377406722048
# Inspecting node 1199890847954882560
# Inspecting node 246380006
# Inspecting node 3179422780
# Inspecting node 36471917
# Inspecting node 23424817
# Inspecting node 9814812
# Inspecting node 840697793618550787
# Inspecting node 730780438269206528
# Inspecting node 294539923
# Inspecting node 1279157580799983617
# Inspecting node 403643684
# Inspecting node 53452624
# Inspecting node 2466115268
# Inspecting node 278882082
# Inspecting node 7562042
# Inspecting node 2395405134
# Inspecting node 18163138
# Inspecting node 865300797130764288
# Inspecting node 1287896006550589442
# Inspecting node 59342468
# Inspecting node 2886941025
# Inspecting node 962424351596281856
# Inspecting node 560765411
# Inspecting node 2924898800
# Inspecting node 1218987476112543744
# Inspecting node 2710528980
# Inspecting node 279748443
# Inspecting node 17702445
# Inspecting node 842121813278752768
# Inspecting node 327394273
# Inspecting node 1012406984719470592
# Inspecting node 10155832
# Inspecting node 439313680
# Inspecting node 1151231204923977729
# Inspecting node 989298765163937792
# Inspecting node 866416675
# Inspecting node 36877221
# Inspecting node 351155835
# Inspecting node 11423372
# Inspecting node 41378883
# Inspecting node 2334251844
# Inspecting node 263163489
# Inspecting node 1096251117745332226
# Inspecting node 1407372687316590594
# Inspecting node 1250830543119319042
# Inspecting node 2903614908
# Inspecting node 1351286814313738243
# Inspecting node 1403372126304866305
# Inspecting node 69712457
# Inspecting node 2730870751
# Inspecting node 16189107
# Inspecting node 414275183
# Inspecting node 393348427
# Inspecting node 248911548
# Inspecting node 34774986
# Inspecting node 1194310568200548352
# Inspecting node 1240872856508137472
# Inspecting node 242533078
# Inspecting node 78084063
# Inspecting node 42232039
# Inspecting node 41239526
# Inspecting node 3112228915
# Inspecting node 1852773120
# Inspecting node 1242517797621530625
# Inspecting node 960897097
# Inspecting node 185290543
# Inspecting node 305945328
# Inspecting node 155777848
# Inspecting node 248891184
# Inspecting node 1357931292
# Inspecting node 1582129344
# Inspecting node 63863473
# Inspecting node 744530425
# Inspecting node 1367957858
# Inspecting node 2469606308
# Inspecting node 326461319
# Inspecting node 529665584
# Inspecting node 154271777
# Inspecting node 1270383308
# Inspecting node 2312086998
# Inspecting node 1447429249
# Inspecting node 2861279433
# Inspecting node 466832463
# Inspecting node 67278150
# Inspecting node 1660911480
# Inspecting node 467664297
# Inspecting node 2573566824
# Inspecting node 132989977
# Inspecting node 954431291629473794
# Inspecting node 238865666
# Inspecting node 2569323896
# Inspecting node 788806262045732864
# Inspecting node 14165217
# Inspecting node 1447951549
# Inspecting node 1594767902
# Inspecting node 491779798
# Inspecting node 946092660795744256
# Inspecting node 74211986
# Inspecting node 524590563
# Inspecting node 1338157627453427713
# Inspecting node 823317383838253056
# Inspecting node 1044778781230039042
# Inspecting node 922963142300143616
# Inspecting node 74937543
# Inspecting node 1305697758
# Inspecting node 18463733
# Inspecting node 76264942
# Inspecting node 2905252436
# Inspecting node 44539994
# Inspecting node 396745864
# Inspecting node 1176801
# Inspecting node 1229442788623818752
# Inspecting node 2993775174
# Inspecting node 2462641501
# Inspecting node 560903736
# Inspecting node 1427351911410257934
# Inspecting node 245651739
# Inspecting node 4922698441
# Inspecting node 4024032261
# Inspecting node 15099646
# Inspecting node 75841164
# Inspecting node 794664236
# Inspecting node 1440828246132596736
# Inspecting node 3069762388
# Inspecting node 700994268
# Inspecting node 1104945319
# Inspecting node 38221378
# Inspecting node 3218932860
# Inspecting node 1201882182
# Inspecting node 1395092719
# Inspecting node 2871728962
# Inspecting node 815428708144218112
# Inspecting node 976143225927839744
# Inspecting node 727212809948401664
# Inspecting node 1373435309782822912
# Inspecting node 568769809
# Inspecting node 982017242354388992
# Inspecting node 36395646
# Inspecting node 40697478
# Inspecting node 1423672567869624322
# Inspecting node 164368721
# Inspecting node 46214091
# Inspecting node 2194496264
# Inspecting node 1057723606027792385
# Inspecting node 25209036
# Inspecting node 1347801793930035200
# Inspecting node 868994263
# Inspecting node 117589552
# Inspecting node 1080529497152278528
# Inspecting node 624962704
# Inspecting node 47022386
# Inspecting node 942370814
# Inspecting node 70499348
# Inspecting node 929856990934790144
# Inspecting node 314093378
# Inspecting node 3053107588
# Inspecting node 1459578954
# Inspecting node 4880637512
# Inspecting node 1932563430
# Inspecting node 1282257536
# Inspecting node 17300548
# Inspecting node 1236439017433989122
# Inspecting node 1444458812614709250
# Inspecting node 1386793782683652096
# Inspecting node 9575562
# Inspecting node 120139457
# Inspecting node 1240478580510871552
# Inspecting node 117562974
# Inspecting node 312422268
# Inspecting node 1333030975681536000
# Inspecting node 1040629333210148865
# Inspecting node 252399534
# Inspecting node 2459730643
# Inspecting node 1264712331457638400
# Inspecting node 1428151019981180932
# Inspecting node 280831905
# Inspecting node 1416101066580627464
# Inspecting node 1135929275272634369
# Inspecting node 360214917
# Inspecting node 1302065426961174530
# Inspecting node 39637553
# Inspecting node 114977658
# Inspecting node 1327696892608724992
# Inspecting node 1409204814534299649
# Inspecting node 371939653
# Inspecting node 190010892
# Inspecting node 1275457555490320385
# Inspecting node 1445833073770184706
# Inspecting node 1601728627
# Inspecting node 41748110
# Inspecting node 1438198932606160901
# Inspecting node 16491468
# Inspecting node 323895654
# Inspecting node 137045661
# Inspecting node 1352682350228942848
# Inspecting node 770683230223634433
# Inspecting node 3368587707
# Inspecting node 1120673221236408320
# Inspecting node 213879574
# Inspecting node 1414982991059709954
# Inspecting node 809651491
# Inspecting node 1491487802
# Inspecting node 4886317138
# Inspecting node 14912051
# Inspecting node 915727372443414528
# Inspecting node 966560892262502400
# Inspecting node 885737117745164288
# Inspecting node 981191210705530880
# Inspecting node 341002490
# Inspecting node 1948425750
# Inspecting node 1391765775594180612
# Inspecting node 1346126893733462016
# Inspecting node 1443254711381946371
# Inspecting node 95348250
# Inspecting node 1351325172184264704
# Inspecting node 487857297
# Inspecting node 94885717
# Inspecting node 925876396878020608
# Inspecting node 15300266
# Inspecting node 1212089073323503616
# Inspecting node 239096810
# Inspecting node 1353758379160834051
# Inspecting node 24728011
# Inspecting node 85640352
# Inspecting node 1012839192253075456
# Inspecting node 1259289117805776896
# Inspecting node 1309184065
# Inspecting node 1881851268
# Inspecting node 132512731
# Inspecting node 1181627354621399040
# Inspecting node 34478789
# Inspecting node 2842764204
# Inspecting node 1034903210547277824
# Inspecting node 1202669441000996864
# Inspecting node 961989099623137280
# Inspecting node 1263895193784184832
# Inspecting node 471366697
# Inspecting node 829731473443975170
# Inspecting node 590822892
# Inspecting node 382409124
# Inspecting node 851681
# Inspecting node 870842873628864513
# Inspecting node 271124533
# Inspecting node 446471174
# Inspecting node 228477243
# Inspecting node 1202388934208172032
# Inspecting node 1060751566657867776
# Inspecting node 257304118
# Inspecting node 4096225454
# Inspecting node 216266808
# Inspecting node 159065078
# Inspecting node 1058391394681868289
# Inspecting node 428602423
# Inspecting node 823397168975409152
# Inspecting node 1345473368494104580
# Inspecting node 46563847
# Inspecting node 2444436240
# Inspecting node 1126848839594467328
# Inspecting node 1257895028724203521
# Inspecting node 277513651
# Inspecting node 1110790944821932034
# Inspecting node 1161332556312326144
# Inspecting node 1346332104234295296
# Inspecting node 165942840
# Inspecting node 259587504
# Inspecting node 1925416346
# Inspecting node 15012924
# Inspecting node 18537391
# Inspecting node 42989776
# Inspecting node 93654204
# Inspecting node 34921899
# Inspecting node 2239987934
# Inspecting node 86320422
# Inspecting node 171411616
# Inspecting node 14650213
# Inspecting node 1087961
# Inspecting node 602903529
# Inspecting node 244204227
# Inspecting node 519071482
# Inspecting node 251635353
# Inspecting node 5654722
# Inspecting node 725037770033532929
# Inspecting node 40059893
# Inspecting node 237480031
# Inspecting node 1056707817216720896
# Inspecting node 1383581104473468929
# Inspecting node 373477857
# Inspecting node 20122522
# Inspecting node 4254675664
# Inspecting node 1259345602980298753
# Inspecting node 725344413162049536
# Inspecting node 1433115420563853312
# Inspecting node 166701763
# Inspecting node 582342806
# Inspecting node 14257934
# Inspecting node 1163072647661522946
# Inspecting node 1201151072733138945
# Inspecting node 1352358388638875652
# Inspecting node 549023337
# Inspecting node 936473743387394048
# Inspecting node 437944231
# Inspecting node 400071841
# Inspecting node 637320913
# Inspecting node 19114577
# Inspecting node 70065285
# Inspecting node 1268920433086210048
# Inspecting node 1176689353885724674
# Inspecting node 460592390
# Inspecting node 2262160692
# Inspecting node 2293461198
# Inspecting node 15219830
# Inspecting node 1201532829860892673
# Inspecting node 92417373
# Inspecting node 122127786
# Inspecting node 362454062
# Inspecting node 2984610092
# Inspecting node 415126004
# Inspecting node 844452866
# Inspecting node 14501713
# Inspecting node 1258440535402065920
# Inspecting node 2254247360
# Inspecting node 104585835
# Inspecting node 1410832490701467650
# Inspecting node 365780558
# Inspecting node 21632994
# Inspecting node 1338474046095233026
# Inspecting node 1113547517105528833
# Inspecting node 293588108
# Inspecting node 1155208255066558475
# Inspecting node 22523896
# Inspecting node 3675933919
# Inspecting node 2796774360
# Inspecting node 1095219121447301120
# Inspecting node 816758120819015680
# Inspecting node 825925386110382080
# Inspecting node 1529643188
# Inspecting node 246811073
# Inspecting node 3351916392
# Inspecting node 123910630
# Inspecting node 29304563
# Inspecting node 1396107226608283649
# Inspecting node 549598823
# Inspecting node 797133264716754944
# Inspecting node 768559569891012608
# Inspecting node 1880517650
# Inspecting node 1232471924145577985
# Inspecting node 1300309398166949889
# Inspecting node 1923754400
# Inspecting node 53754232
# Inspecting node 307324209
# Inspecting node 3165242127
# Inspecting node 730826158258946050
# Inspecting node 1577656471
# Inspecting node 1214368702277308421
# Inspecting node 299993498
# Inspecting node 1235344992765448193
# Inspecting node 625193066
# Inspecting node 467817388
# Inspecting node 3135148227
# Inspecting node 872810605
# Inspecting node 271504586
# Inspecting node 306967462
# Inspecting node 3299469609
# Inspecting node 1225848216467509248
# Inspecting node 259388196
# Inspecting node 525910396
# Inspecting node 358143304
# Inspecting node 1088545656002801664
# Inspecting node 1283460034182209537
# Inspecting node 1326306504027287554
# Inspecting node 100874975
# Inspecting node 811549418
# Inspecting node 145058470
# Inspecting node 15892547
# Inspecting node 2797935107
# Inspecting node 27388441
# Inspecting node 288495993
# Inspecting node 77596220
# Inspecting node 891058415195303939
# Inspecting node 1095768409449459712
# Inspecting node 881426857
# Inspecting node 17388526

# %% [markdown]
# Okay I have confirmed Degree is being respected for these 50 models

# %%
for node in G:
    print("Inspecting node {}".format(node))
    expectedDeg = G.in_degree(node) 
    for key, value in in_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break
# Out:
# Inspecting node 1385933370090209280
# Inspecting node 158095776
# Inspecting node 1416535505454338050
# Inspecting node 1604931252
# Inspecting node 544695802
# Inspecting node 716257068538327040
# Inspecting node 258170457
# Inspecting node 1086084557009575936
# Inspecting node 2817389862
# Inspecting node 822476228548403200
# Inspecting node 2353730881
# Inspecting node 921026239808208896
# Inspecting node 720934098223542272
# Inspecting node 2922779039
# Inspecting node 552891173
# Inspecting node 982496635
# Inspecting node 1433403537329819654
# Inspecting node 1175052073605353473
# Inspecting node 2784661153
# Inspecting node 102887506
# Inspecting node 18681111
# Inspecting node 952980338745147394
# Inspecting node 1438871779779530755
# Inspecting node 46975259
# Inspecting node 1157395568135557120
# Inspecting node 21951711
# Inspecting node 563064119
# Inspecting node 277332906
# Inspecting node 158458133
# Inspecting node 979827806023618560
# Inspecting node 18308257
# Inspecting node 846667915
# Inspecting node 258916078
# Inspecting node 1138564320390836224
# Inspecting node 17912334
# Inspecting node 2821464243
# Inspecting node 928790819145842688
# Inspecting node 753638148958216192
# Inspecting node 2256955027
# Inspecting node 1185936230393024512
# Inspecting node 14079041
# Inspecting node 3021899490
# Inspecting node 13880132
# Inspecting node 960624707820113920
# Inspecting node 52003137
# Inspecting node 1887595058
# Inspecting node 331864347
# Inspecting node 961514730
# Inspecting node 70750793
# Inspecting node 155629527
# Inspecting node 1161351506983038976
# Inspecting node 766360387
# Inspecting node 150270263
# Inspecting node 38471212
# Inspecting node 83153695
# Inspecting node 118937966
# Inspecting node 871189841186357248
# Inspecting node 293403080
# Inspecting node 629539554
# Inspecting node 1104422828
# Inspecting node 602083976
# Inspecting node 1311896805920043009
# Inspecting node 1318741345905922048
# Inspecting node 25314619
# Inspecting node 104300984
# Inspecting node 15702055
# Inspecting node 1153463878195589125
# Inspecting node 15633240
# Inspecting node 14991184
# Inspecting node 1242522201770856449
# Inspecting node 1440522413687521295
# Inspecting node 106524304
# Inspecting node 1292608204845834241
# Inspecting node 1446846657551683588
# Inspecting node 1389700907697270787
# Inspecting node 1445880242707570691
# Inspecting node 1545912997
# Inspecting node 831084798621782016
# Inspecting node 55976571
# Inspecting node 305401065
# Inspecting node 704798725747531776
# Inspecting node 47452040
# Inspecting node 475298690
# Inspecting node 16220555
# Inspecting node 4744498950
# Inspecting node 766759351973404672
# Inspecting node 47781573
# Inspecting node 994077337
# Inspecting node 14055736
# Inspecting node 1236010900693356549
# Inspecting node 1171683272
# Inspecting node 1338338931792756737
# Inspecting node 562243642
# Inspecting node 15772683
# Inspecting node 1251340447387172868
# Inspecting node 1350484767255519233
# Inspecting node 1335046616697372675
# Inspecting node 20750271
# Inspecting node 1162219997977960449
# Inspecting node 175259033
# Inspecting node 130909683
# Inspecting node 1364261390614106113
# Inspecting node 44416854
# Inspecting node 1511003670
# Inspecting node 536594609
# Inspecting node 24913022
# Inspecting node 17823761
# Inspecting node 273683993
# Inspecting node 215632349
# Inspecting node 1156602559378804741
# Inspecting node 1156033982586208256
# Inspecting node 47338701
# Inspecting node 139819609
# Inspecting node 413514250
# Inspecting node 2852899113
# Inspecting node 1381435843492085760
# Inspecting node 1189800120
# Inspecting node 138418077
# Inspecting node 382489139
# Inspecting node 374300583
# Inspecting node 3226840807
# Inspecting node 133863908
# Inspecting node 57127265
# Inspecting node 142731825
# Inspecting node 1417929933800751104
# Inspecting node 55823004
# Inspecting node 1447315781289750532
# Inspecting node 14262411
# Inspecting node 1707636642
# Inspecting node 845487573011173380
# Inspecting node 109144163
# Inspecting node 20199202
# Inspecting node 785448020628430849
# Inspecting node 77283552
# Inspecting node 38055290
# Inspecting node 34506336
# Inspecting node 242798024
# Inspecting node 138077463
# Inspecting node 121343164
# Inspecting node 814078628
# Inspecting node 196717787
# Inspecting node 18519855
# Inspecting node 268824309
# Inspecting node 2439928526
# Inspecting node 1169378542737661954
# Inspecting node 299228245
# Inspecting node 2369365718
# Inspecting node 1373493122
# Inspecting node 2834753506
# Inspecting node 999476893970763777
# Inspecting node 120320139
# Inspecting node 84734389
# Inspecting node 15407637
# Inspecting node 1899063048
# Inspecting node 1301967293849755653
# Inspecting node 324602007
# Inspecting node 292667439
# Inspecting node 522345885
# Inspecting node 12599562
# Inspecting node 4856851754
# Inspecting node 1248842158553141250
# Inspecting node 4026045455
# Inspecting node 3303438653
# Inspecting node 1129203001
# Inspecting node 2813664079
# Inspecting node 14518712
# Inspecting node 95209129
# Inspecting node 119797208
# Inspecting node 201984482
# Inspecting node 593944500
# Inspecting node 17105128
# Inspecting node 3409346380
# Inspecting node 33826892
# Inspecting node 273866823
# Inspecting node 37552089
# Inspecting node 377588094
# Inspecting node 266855812
# Inspecting node 341866567
# Inspecting node 60916234
# Inspecting node 262436837
# Inspecting node 1092244447184719873
# Inspecting node 2548489298
# Inspecting node 218952640
# Inspecting node 1382491059247255554
# Inspecting node 516915897
# Inspecting node 965028316460797953
# Inspecting node 195899568
# Inspecting node 2432750568
# Inspecting node 331067472
# Inspecting node 272133230
# Inspecting node 108413104
# Inspecting node 177347829
# Inspecting node 964446120402300928
# Inspecting node 1573418346
# Inspecting node 89496127
# Inspecting node 735508941258399744
# Inspecting node 542244178
# Inspecting node 1005899772916477952
# Inspecting node 366171300
# Inspecting node 29545977
# Inspecting node 59686058
# Inspecting node 965478102594863104
# Inspecting node 366225624
# Inspecting node 393713239
# Inspecting node 1185972487538040832
# Inspecting node 889661863100907520
# Inspecting node 2813399220
# Inspecting node 2436061363
# Inspecting node 17900758
# Inspecting node 23491400
# Inspecting node 382949896
# Inspecting node 1009115210546929664
# Inspecting node 3148281878
# Inspecting node 1064964294448750595
# Inspecting node 814289414
# Inspecting node 2896012540
# Inspecting node 1280589273335500801
# Inspecting node 1227766472921014272
# Inspecting node 869639001400942592
# Inspecting node 116679707
# Inspecting node 342176065
# Inspecting node 1890389540
# Inspecting node 2785990732
# Inspecting node 40591485
# Inspecting node 3191905064
# Inspecting node 25813888
# Inspecting node 237536271
# Inspecting node 16982577
# Inspecting node 1563418116
# Inspecting node 2580573206
# Inspecting node 275979196
# Inspecting node 193471925
# Inspecting node 53772503
# Inspecting node 16195103
# Inspecting node 2776775090
# Inspecting node 998590102573023232
# Inspecting node 179129165
# Inspecting node 27101995
# Inspecting node 872156101
# Inspecting node 128908662
# Inspecting node 363070453
# Inspecting node 211564038
# Inspecting node 189349553
# Inspecting node 25127782
# Inspecting node 1166717268975333376
# Inspecting node 40550119
# Inspecting node 417389780
# Inspecting node 61521038
# Inspecting node 85428184
# Inspecting node 58319221
# Inspecting node 52080359
# Inspecting node 2513973205
# Inspecting node 283226685
# Inspecting node 45848808
# Inspecting node 1646334073
# Inspecting node 1360838234
# Inspecting node 21221149
# Inspecting node 507802048
# Inspecting node 190231473
# Inspecting node 993705834470367232
# Inspecting node 360677740
# Inspecting node 1362286033
# Inspecting node 3079986094
# Inspecting node 268528986
# Inspecting node 321752222
# Inspecting node 17280115
# Inspecting node 274220538
# Inspecting node 2352629420
# Inspecting node 51184630
# Inspecting node 908811901
# Inspecting node 408526152
# Inspecting node 371447080
# Inspecting node 2314531026
# Inspecting node 1172199939243425792
# Inspecting node 390392773
# Inspecting node 2289973748
# Inspecting node 495066576
# Inspecting node 1545053600
# Inspecting node 1318671397560979456
# Inspecting node 2891740872
# Inspecting node 2848993491
# Inspecting node 103297393
# Inspecting node 1851634098
# Inspecting node 398483708
# Inspecting node 1313212802799206406
# Inspecting node 79260190
# Inspecting node 27652488
# Inspecting node 89609585
# Inspecting node 44618408
# Inspecting node 880491635896922112
# Inspecting node 2761710808
# Inspecting node 1240867313445830656
# Inspecting node 247412217
# Inspecting node 1347654502787076096
# Inspecting node 982630470008553474
# Inspecting node 82167100
# Inspecting node 110754237
# Inspecting node 768069259100622848
# Inspecting node 1304210384367349770
# Inspecting node 1300291239581892609
# Inspecting node 2253903906
# Inspecting node 78403337
# Inspecting node 862703683
# Inspecting node 1071951545212723200
# Inspecting node 840470152391016448
# Inspecting node 498423001
# Inspecting node 1197522605760303104
# Inspecting node 510093784
# Inspecting node 447415943
# Inspecting node 1201788959719936007
# Inspecting node 1633538270
# Inspecting node 122525211
# Inspecting node 192842634
# Inspecting node 551152504
# Inspecting node 378351271
# Inspecting node 57033548
# Inspecting node 255067647
# Inspecting node 35863342
# Inspecting node 2715275551
# Inspecting node 719557076599619584
# Inspecting node 980875592
# Inspecting node 1051100859831148544
# Inspecting node 2300474413
# Inspecting node 1238447220
# Inspecting node 994295935
# Inspecting node 838098877
# Inspecting node 829761553218072576
# Inspecting node 951280545421410305
# Inspecting node 1157684886
# Inspecting node 80970676
# Inspecting node 18923250
# Inspecting node 1136294664
# Inspecting node 951892305098788864
# Inspecting node 3010143902
# Inspecting node 297020666
# Inspecting node 1045793762063060992
# Inspecting node 98588419
# Inspecting node 76179144
# Inspecting node 46956207
# Inspecting node 819853925184638976
# Inspecting node 16552108
# Inspecting node 29754743
# Inspecting node 153515520
# Inspecting node 386330680
# Inspecting node 2736446758
# Inspecting node 35095520
# Inspecting node 1239564608941113347
# Inspecting node 58261480
# Inspecting node 169614697
# Inspecting node 1005522675761057792
# Inspecting node 816308397360508928
# Inspecting node 1407160205117435908
# Inspecting node 1175457080561537025
# Inspecting node 1011936943247101952
# Inspecting node 365078935
# Inspecting node 17540009
# Inspecting node 49660950
# Inspecting node 296549487
# Inspecting node 1228605451
# Inspecting node 1122706063466356737
# Inspecting node 234593598
# Inspecting node 1204301854433316866
# Inspecting node 1204430581410353154
# Inspecting node 893202244077854721
# Inspecting node 22971125
# Inspecting node 1193458951976869888
# Inspecting node 785853390
# Inspecting node 322106815
# Inspecting node 1957597519
# Inspecting node 1101092779378249729
# Inspecting node 3331826578
# Inspecting node 38720614
# Inspecting node 2912843536
# Inspecting node 183642459
# Inspecting node 2247495353
# Inspecting node 2748289416
# Inspecting node 2592210108
# Inspecting node 103701079
# Inspecting node 1352713370772770816
# Inspecting node 86410896
# Inspecting node 1038301598
# Inspecting node 1134248217472843787
# Inspecting node 999320625117196288
# Inspecting node 18390213
# Inspecting node 768295011007934469
# Inspecting node 1262878353431777280
# Inspecting node 729232479840800768
# Inspecting node 1415442622135603206
# Inspecting node 346123223
# Inspecting node 167912183
# Inspecting node 1076249609125675010
# Inspecting node 67793897
# Inspecting node 823096488
# Inspecting node 50154666
# Inspecting node 302593437
# Inspecting node 291862583
# Inspecting node 168371680
# Inspecting node 1251332171211644931
# Inspecting node 962073414
# Inspecting node 291523600
# Inspecting node 277085673
# Inspecting node 62664213
# Inspecting node 1337551744457469952
# Inspecting node 716460064039575552
# Inspecting node 3007815702
# Inspecting node 55819705
# Inspecting node 1404102585317986308
# Inspecting node 1280249212567818240
# Inspecting node 740981264740679681
# Inspecting node 247511435
# Inspecting node 1303772129847111681
# Inspecting node 1027307702047961088
# Inspecting node 1020156666204090368
# Inspecting node 38751529
# Inspecting node 718873385346797569
# Inspecting node 285806588
# Inspecting node 541129316
# Inspecting node 1655457050
# Inspecting node 57759275
# Inspecting node 824281652423753728
# Inspecting node 132015712
# Inspecting node 40647043
# Inspecting node 12992772
# Inspecting node 365132365
# Inspecting node 1129088815
# Inspecting node 1262268501823303680
# Inspecting node 288548798
# Inspecting node 87632735
# Inspecting node 40246161
# Inspecting node 1252686295
# Inspecting node 25333228
# Inspecting node 1093876945
# Inspecting node 205786669
# Inspecting node 1942350667
# Inspecting node 2863551224
# Inspecting node 720083863830069249
# Inspecting node 176207343
# Inspecting node 412708728
# Inspecting node 414218319
# Inspecting node 1271987860577517568
# Inspecting node 626984632
# Inspecting node 237594523
# Inspecting node 714340176
# Inspecting node 300638343
# Inspecting node 739845530612830208
# Inspecting node 715244769
# Inspecting node 817207955930001409
# Inspecting node 1363561650624733184
# Inspecting node 212468225
# Inspecting node 2673432539
# Inspecting node 23601374
# Inspecting node 51852542
# Inspecting node 321482430
# Inspecting node 1058965681671028736
# Inspecting node 35617919
# Inspecting node 371288369
# Inspecting node 4492249646
# Inspecting node 396106258
# Inspecting node 2287331581
# Inspecting node 150671052
# Inspecting node 3302256527
# Inspecting node 3269322830
# Inspecting node 1364751078659477504
# Inspecting node 168123931
# Inspecting node 1072189285
# Inspecting node 45976740
# Inspecting node 1435257575482740741
# Inspecting node 1099109729308008448
# Inspecting node 1366925295291424768
# Inspecting node 1356073687691141121
# Inspecting node 1580475270
# Inspecting node 1442893993935716361
# Inspecting node 392132054
# Inspecting node 207703739
# Inspecting node 1419489038747070467
# Inspecting node 928451444633563136
# Inspecting node 1119464753318043649
# Inspecting node 1440690378533838857
# Inspecting node 2931943245
# Inspecting node 1727398412
# Inspecting node 1444061901172854786
# Inspecting node 2938869339
# Inspecting node 1243723946660421637
# Inspecting node 2476755039
# Inspecting node 1331773252792770560
# Inspecting node 901618905076174848
# Inspecting node 339780511
# Inspecting node 980817985668550656
# Inspecting node 53694666
# Inspecting node 1445437990940004352
# Inspecting node 1243574020802367488
# Inspecting node 1055536236
# Inspecting node 68670486
# Inspecting node 451989089
# Inspecting node 1077731978
# Inspecting node 1271115442573185024
# Inspecting node 969744550955749383
# Inspecting node 26577630
# Inspecting node 1391981080945643523
# Inspecting node 46232947
# Inspecting node 266048357
# Inspecting node 293745266
# Inspecting node 415532452
# Inspecting node 3107597132
# Inspecting node 1183316407104266241
# Inspecting node 982472677775454209
# Inspecting node 3295839203
# Inspecting node 880913594531139584
# Inspecting node 1911858061
# Inspecting node 1097694473952342022
# Inspecting node 1388650232100134915
# Inspecting node 14100537
# Inspecting node 820656479812227073
# Inspecting node 1325249450793701376
# Inspecting node 1427996716138127360
# Inspecting node 1347691972358778885
# Inspecting node 1365678726
# Inspecting node 1295377965438644235
# Inspecting node 322090834
# Inspecting node 1342962255248424961
# Inspecting node 1195026680609292288
# Inspecting node 1116360718687690758
# Inspecting node 737359208945844224
# Inspecting node 3375064758
# Inspecting node 14538949
# Inspecting node 1084856644687679496
# Inspecting node 36133644
# Inspecting node 976345683681619968
# Inspecting node 366785595
# Inspecting node 2849064914
# Inspecting node 343059330
# Inspecting node 64123717
# Inspecting node 18420573
# Inspecting node 957106791753555968
# Inspecting node 751054068974575616
# Inspecting node 1186136760981454854
# Inspecting node 854065048683204615
# Inspecting node 317823907
# Inspecting node 952759886
# Inspecting node 474883984
# Inspecting node 1258133514421239813
# Inspecting node 2198792101
# Inspecting node 324555383
# Inspecting node 744660163873771520
# Inspecting node 726025903
# Inspecting node 1263514760584167424
# Inspecting node 714569357267853312
# Inspecting node 739149720
# Inspecting node 1136772811656126464
# Inspecting node 270307297
# Inspecting node 454774863
# Inspecting node 772948513
# Inspecting node 3333795492
# Inspecting node 2209473078
# Inspecting node 838196271571591168
# Inspecting node 18386792
# Inspecting node 1166799265806503936
# Inspecting node 262522708
# Inspecting node 1370402422062002179
# Inspecting node 1429982282891239433
# Inspecting node 1434265814325202944
# Inspecting node 1087134051914395648
# Inspecting node 791076864
# Inspecting node 121949981
# Inspecting node 256360738
# Inspecting node 1172475064870027264
# Inspecting node 1443468994107822081
# Inspecting node 941115769429024769
# Inspecting node 1313732971061362690
# Inspecting node 2305422800
# Inspecting node 242885214
# Inspecting node 1354230346586447877
# Inspecting node 469747759
# Inspecting node 432114850
# Inspecting node 1166000110586626048
# Inspecting node 884527637569323009
# Inspecting node 369653658
# Inspecting node 1434643524495020043
# Inspecting node 75984040
# Inspecting node 586195164
# Inspecting node 2902344555
# Inspecting node 564257648
# Inspecting node 1027229536902098944
# Inspecting node 2316626342
# Inspecting node 1925354744
# Inspecting node 958204773282533376
# Inspecting node 1445751022526160908
# Inspecting node 1183078912265355265
# Inspecting node 98767459
# Inspecting node 87297879
# Inspecting node 753394222267527168
# Inspecting node 373580557
# Inspecting node 1430260512688902150
# Inspecting node 2468436247
# Inspecting node 3308781515
# Inspecting node 2273880732
# Inspecting node 1302114263771668481
# Inspecting node 24181491
# Inspecting node 1309179346565898241
# Inspecting node 2231471516
# Inspecting node 1352351686778630145
# Inspecting node 1413321993470943237
# Inspecting node 603011131
# Inspecting node 1438876255202406406
# Inspecting node 1375883715776294914
# Inspecting node 1002002024
# Inspecting node 51384524
# Inspecting node 724114092672335874
# Inspecting node 552725069
# Inspecting node 1184298786329448448
# Inspecting node 334954251
# Inspecting node 101915304
# Inspecting node 1252767510983737344
# Inspecting node 1099811037975642112
# Inspecting node 1388988366247575559
# Inspecting node 1326022742286749696
# Inspecting node 1388801354244702209
# Inspecting node 961162177
# Inspecting node 1389555148318404610
# Inspecting node 1151641780267261952
# Inspecting node 27320189
# Inspecting node 1215379886887428096
# Inspecting node 1184882383
# Inspecting node 257699447
# Inspecting node 2397398196
# Inspecting node 807034969902252032
# Inspecting node 1353486048618274816
# Inspecting node 4866566489
# Inspecting node 3058888765
# Inspecting node 1173239638116446208
# Inspecting node 42894434
# Inspecting node 3078011282
# Inspecting node 32691118
# Inspecting node 544080126
# Inspecting node 1336660494
# Inspecting node 957190068594130946
# Inspecting node 1074149416699719681
# Inspecting node 825518936733085696
# Inspecting node 43199433
# Inspecting node 969376788525830146
# Inspecting node 35107179
# Inspecting node 366074756
# Inspecting node 359672860
# Inspecting node 82679357
# Inspecting node 883774859452579840
# Inspecting node 3418588623
# Inspecting node 710270422290403328
# Inspecting node 763168867371843584
# Inspecting node 1575198925
# Inspecting node 1301995158485958656
# Inspecting node 1260291453973983232
# Inspecting node 1601907697
# Inspecting node 29823611
# Inspecting node 1393039117110317058
# Inspecting node 236055343
# Inspecting node 320919057
# Inspecting node 2812908133
# Inspecting node 1325519307359490048
# Inspecting node 590735039
# Inspecting node 95577307
# Inspecting node 43948485
# Inspecting node 136332449
# Inspecting node 623936216
# Inspecting node 2873956499
# Inspecting node 4803873902
# Inspecting node 1147245556651233280
# Inspecting node 918919026344120321
# Inspecting node 37813045
# Inspecting node 24574252
# Inspecting node 1440809899500335110
# Inspecting node 1334205408110551042
# Inspecting node 1071298949837770753
# Inspecting node 915968072
# Inspecting node 885818088
# Inspecting node 227849419
# Inspecting node 2493753559
# Inspecting node 778842486
# Inspecting node 124839366
# Inspecting node 263750524
# Inspecting node 1357001901229899777
# Inspecting node 990301302264479749
# Inspecting node 1136065885456740352
# Inspecting node 1335377050878676992
# Inspecting node 138710067
# Inspecting node 1441961640459599874
# Inspecting node 2793008984
# Inspecting node 120187876
# Inspecting node 178544594
# Inspecting node 2838327755
# Inspecting node 1559780652
# Inspecting node 2291354802
# Inspecting node 1352707350784659456
# Inspecting node 1417352097150816256
# Inspecting node 1427768108614291465
# Inspecting node 1117485007944048640
# Inspecting node 1297264458
# Inspecting node 1194794785762004993
# Inspecting node 26089782
# Inspecting node 1446289055935864836
# Inspecting node 412499776
# Inspecting node 416476088
# Inspecting node 1028871362499305473
# Inspecting node 1438317451469541377
# Inspecting node 546527413
# Inspecting node 1323421765658431488
# Inspecting node 280677070
# Inspecting node 2332742508
# Inspecting node 1347272097786171394
# Inspecting node 2344419362
# Inspecting node 252150132
# Inspecting node 4787666543
# Inspecting node 1454456569
# Inspecting node 587733016
# Inspecting node 823265236916416512
# Inspecting node 1168589910825213952
# Inspecting node 753744536887824385
# Inspecting node 119925381
# Inspecting node 1269692602204532738
# Inspecting node 853722212741898240
# Inspecting node 43089397
# Inspecting node 2323751900
# Inspecting node 1213405462021853185
# Inspecting node 2937436849
# Inspecting node 272250877
# Inspecting node 1406573892
# Inspecting node 1942107584
# Inspecting node 2678072299
# Inspecting node 86384661
# Inspecting node 2983179809
# Inspecting node 3188558830
# Inspecting node 2874772780
# Inspecting node 222386937
# Inspecting node 261788602
# Inspecting node 292468351
# Inspecting node 22849568
# Inspecting node 1203545123356839936
# Inspecting node 19893907
# Inspecting node 1729880688
# Inspecting node 1361500715659755520
# Inspecting node 700287952
# Inspecting node 169268197
# Inspecting node 18622393
# Inspecting node 1304185921433227264
# Inspecting node 97121931
# Inspecting node 1699266222
# Inspecting node 729194378779078656
# Inspecting node 2752659114
# Inspecting node 373460084
# Inspecting node 908018227040710656
# Inspecting node 245149238
# Inspecting node 3242606862
# Inspecting node 29891001
# Inspecting node 720579941184757760
# Inspecting node 276713213
# Inspecting node 1424060815947206662
# Inspecting node 609432652
# Inspecting node 38625077
# Inspecting node 234550882
# Inspecting node 408072407
# Inspecting node 1427258589077508100
# Inspecting node 2242940071
# Inspecting node 44171755
# Inspecting node 41043869
# Inspecting node 436087744
# Inspecting node 578640179
# Inspecting node 132210296
# Inspecting node 923683393
# Inspecting node 1245003009555419137
# Inspecting node 1267504449087553539
# Inspecting node 65666257
# Inspecting node 407943040
# Inspecting node 240908125
# Inspecting node 1057988206963056640
# Inspecting node 130857133
# Inspecting node 1441410998355726344
# Inspecting node 24819740
# Inspecting node 1412813687811760135
# Inspecting node 2762829798
# Inspecting node 1317417438640697344
# Inspecting node 1185990712132812800
# Inspecting node 711980580813066240
# Inspecting node 3237884919
# Inspecting node 9455112
# Inspecting node 19198775
# Inspecting node 22630846
# Inspecting node 1434341584670273544
# Inspecting node 844292741077061632
# Inspecting node 1300624324206817280
# Inspecting node 1332164996592066561
# Inspecting node 337816824
# Inspecting node 153798495
# Inspecting node 1249204176548245504
# Inspecting node 3092462976
# Inspecting node 547671992
# Inspecting node 151547845
# Inspecting node 23554969
# Inspecting node 1314208704
# Inspecting node 808450734240972800
# Inspecting node 204846220
# Inspecting node 19478009
# Inspecting node 18940341
# Inspecting node 62292631
# Inspecting node 1239692519094575104
# Inspecting node 64261339
# Inspecting node 271989352
# Inspecting node 66334416
# Inspecting node 756584190112591872
# Inspecting node 24459228
# Inspecting node 771870952544096257
# Inspecting node 1242251887
# Inspecting node 15908286
# Inspecting node 1390840055200108546
# Inspecting node 2408260398
# Inspecting node 488067802
# Inspecting node 1511667030
# Inspecting node 579614622
# Inspecting node 728304522662043648
# Inspecting node 1092960066
# Inspecting node 64099329
# Inspecting node 1393055510480441345
# Inspecting node 2555583872
# Inspecting node 2452465303
# Inspecting node 282526718
# Inspecting node 4298769753
# Inspecting node 572827030
# Inspecting node 1414623993529880576
# Inspecting node 1255927911045095425
# Inspecting node 1373016955
# Inspecting node 2720800274
# Inspecting node 57661541
# Inspecting node 708739471
# Inspecting node 722623738672517120
# Inspecting node 157591483
# Inspecting node 1390378070482165763
# Inspecting node 2707780448
# Inspecting node 898554931271127042
# Inspecting node 525857359
# Inspecting node 2536457582
# Inspecting node 19634262
# Inspecting node 1357304889831878657
# Inspecting node 1243221104560345090
# Inspecting node 431141725
# Inspecting node 1244435052
# Inspecting node 159655782
# Inspecting node 382223500
# Inspecting node 535452718
# Inspecting node 1293199610178080775
# Inspecting node 12923812
# Inspecting node 16272844
# Inspecting node 335769776
# Inspecting node 16279532
# Inspecting node 3358671
# Inspecting node 16180205
# Inspecting node 2322580746
# Inspecting node 171115367
# Inspecting node 208750527
# Inspecting node 240786249
# Inspecting node 3257047456
# Inspecting node 500232993
# Inspecting node 1171073846335721472
# Inspecting node 1304472952482783232
# Inspecting node 1072270926
# Inspecting node 2789770741
# Inspecting node 2327530022
# Inspecting node 1002181382
# Inspecting node 47692251
# Inspecting node 743129088
# Inspecting node 271073165
# Inspecting node 1895316878
# Inspecting node 631988630
# Inspecting node 290162716
# Inspecting node 2229187188
# Inspecting node 274507495
# Inspecting node 417524720
# Inspecting node 415774799
# Inspecting node 579377522
# Inspecting node 32915303
# Inspecting node 245954929
# Inspecting node 170377354
# Inspecting node 1390883714
# Inspecting node 3363252329
# Inspecting node 1143342270399373313
# Inspecting node 272185225
# Inspecting node 1144289639924207616
# Inspecting node 43510607
# Inspecting node 524557553
# Inspecting node 256775505
# Inspecting node 493488747
# Inspecting node 868245382148521984
# Inspecting node 1170770038208565248
# Inspecting node 339752726
# Inspecting node 249221867
# Inspecting node 488052222
# Inspecting node 911471588
# Inspecting node 246466184
# Inspecting node 280552762
# Inspecting node 295951367
# Inspecting node 973087261
# Inspecting node 1321710295245447169
# Inspecting node 48369926
# Inspecting node 1438956476588957701
# Inspecting node 385008014
# Inspecting node 918152297544380417
# Inspecting node 33562561
# Inspecting node 987136895162384384
# Inspecting node 1327442450957303809
# Inspecting node 870473605473198080
# Inspecting node 35337644
# Inspecting node 1103832363363127297
# Inspecting node 1243323314652602368
# Inspecting node 1268045786312593408
# Inspecting node 17355421
# Inspecting node 24348660
# Inspecting node 14247924
# Inspecting node 106512310
# Inspecting node 1269254845615095810
# Inspecting node 1219578234
# Inspecting node 1380813355
# Inspecting node 883334379023597568
# Inspecting node 58878834
# Inspecting node 912346683291389953
# Inspecting node 3179475258
# Inspecting node 245939022
# Inspecting node 363654070
# Inspecting node 3071603495
# Inspecting node 573788425
# Inspecting node 878490462
# Inspecting node 1423385158263132168
# Inspecting node 1268728504964825088
# Inspecting node 46894332
# Inspecting node 136160953
# Inspecting node 107218304
# Inspecting node 73411833
# Inspecting node 1405971529217740812
# Inspecting node 1275123310788063233
# Inspecting node 1173035282461089793
# Inspecting node 1445090669643517961
# Inspecting node 1389241812276023296
# Inspecting node 501994958
# Inspecting node 2799175653
# Inspecting node 1429555219457773581
# Inspecting node 1668333199
# Inspecting node 1218019404992196609
# Inspecting node 1366204146957885445
# Inspecting node 1198972583288459265
# Inspecting node 1433247289330577408
# Inspecting node 502160853
# Inspecting node 41520537
# Inspecting node 1294478815628890112
# Inspecting node 395394840
# Inspecting node 1151704477
# Inspecting node 1044711566354960384
# Inspecting node 1271855851330916353
# Inspecting node 1497052201
# Inspecting node 975757898004549633
# Inspecting node 3245708989
# Inspecting node 1267640853000007680
# Inspecting node 29917096
# Inspecting node 245373521
# Inspecting node 1420482733135040522
# Inspecting node 1242510089145266182
# Inspecting node 28737527
# Inspecting node 1731401322
# Inspecting node 979870450577686528
# Inspecting node 1354922263418523648
# Inspecting node 24951781
# Inspecting node 15613754
# Inspecting node 100851235
# Inspecting node 59243738
# Inspecting node 17360968
# Inspecting node 360129945
# Inspecting node 1174006316412674048
# Inspecting node 21809306
# Inspecting node 1134558647835430912
# Inspecting node 855478711
# Inspecting node 25178951
# Inspecting node 52350953
# Inspecting node 20796969
# Inspecting node 55158039
# Inspecting node 1401659310015397889
# Inspecting node 215896862
# Inspecting node 4540976253
# Inspecting node 56016987
# Inspecting node 1357857933019598849
# Inspecting node 1125841354716696576
# Inspecting node 793343793642680320
# Inspecting node 48219360
# Inspecting node 399184212
# Inspecting node 827222807121637377
# Inspecting node 1138228267
# Inspecting node 1671821988
# Inspecting node 2321539819
# Inspecting node 17969963
# Inspecting node 1337935917298962434
# Inspecting node 1055170328442224641
# Inspecting node 325805788
# Inspecting node 1128406689802276865
# Inspecting node 1560811022
# Inspecting node 1264568784318345218
# Inspecting node 254240108
# Inspecting node 2237957942
# Inspecting node 387828045
# Inspecting node 3355188729
# Inspecting node 1483945802
# Inspecting node 1663608300
# Inspecting node 1335613030852386817
# Inspecting node 2678629590
# Inspecting node 884681534
# Inspecting node 420536762
# Inspecting node 4329525312
# Inspecting node 1547244656
# Inspecting node 109341612
# Inspecting node 108689047
# Inspecting node 1223265601147342848
# Inspecting node 297968019
# Inspecting node 183758895
# Inspecting node 45932749
# Inspecting node 418786259
# Inspecting node 70240459
# Inspecting node 1606592767
# Inspecting node 1047167241119326211
# Inspecting node 978673214283853825
# Inspecting node 17136419
# Inspecting node 1242152485
# Inspecting node 4445748801
# Inspecting node 1413908511461945350
# Inspecting node 1314819918328729600
# Inspecting node 1140532022
# Inspecting node 1200932043544117248
# Inspecting node 3109560272
# Inspecting node 162924629
# Inspecting node 182072629
# Inspecting node 980237238
# Inspecting node 1213189717425917953
# Inspecting node 2800741820
# Inspecting node 19135439
# Inspecting node 967241034873933824
# Inspecting node 3236492411
# Inspecting node 1235422076082589696
# Inspecting node 534591437
# Inspecting node 1454880680
# Inspecting node 1069754111078354948
# Inspecting node 2286750115
# Inspecting node 1375862610
# Inspecting node 26071396
# Inspecting node 375764669
# Inspecting node 1833674827
# Inspecting node 392380645
# Inspecting node 769165632738762752
# Inspecting node 989311745100566529
# Inspecting node 256552850
# Inspecting node 2218371769
# Inspecting node 29721598
# Inspecting node 1008103433822351360
# Inspecting node 1214027006242742273
# Inspecting node 142107502
# Inspecting node 1314568089300873216
# Inspecting node 801218452618956800
# Inspecting node 1330675961839443973
# Inspecting node 1441448795921952768
# Inspecting node 102491634
# Inspecting node 24978284
# Inspecting node 36988268
# Inspecting node 712792479729192960
# Inspecting node 890560416526594048
# Inspecting node 1413820603
# Inspecting node 37044121
# Inspecting node 832619717785329664
# Inspecting node 1171471512085389312
# Inspecting node 61542328
# Inspecting node 494320156
# Inspecting node 13716572
# Inspecting node 1017461230984990720
# Inspecting node 25703839
# Inspecting node 363666493
# Inspecting node 975491119734763522
# Inspecting node 61888526
# Inspecting node 2502596130
# Inspecting node 763867259777519618
# Inspecting node 1185294078256254977
# Inspecting node 1296424847149588483
# Inspecting node 2721515522
# Inspecting node 224600898
# Inspecting node 524785211
# Inspecting node 777617628009332736
# Inspecting node 189341190
# Inspecting node 2451955022
# Inspecting node 835061048533082113
# Inspecting node 248022226
# Inspecting node 2988258574
# Inspecting node 1001287095472873473
# Inspecting node 1182252711833718784
# Inspecting node 1861048644
# Inspecting node 2842385693
# Inspecting node 248065960
# Inspecting node 931882614
# Inspecting node 3290783049
# Inspecting node 359260523
# Inspecting node 16116228
# Inspecting node 243912778
# Inspecting node 2439108320
# Inspecting node 1176536298179284993
# Inspecting node 297771685
# Inspecting node 1128366660128260097
# Inspecting node 222987791
# Inspecting node 18597273
# Inspecting node 577727470
# Inspecting node 112767813
# Inspecting node 116837959
# Inspecting node 83712358
# Inspecting node 486703473
# Inspecting node 67758676
# Inspecting node 20346252
# Inspecting node 420560195
# Inspecting node 3153084524
# Inspecting node 1308040042724519939
# Inspecting node 1182947209
# Inspecting node 1258576501
# Inspecting node 213140093
# Inspecting node 225067116
# Inspecting node 18340314
# Inspecting node 1310724884008321028
# Inspecting node 160429871
# Inspecting node 214530013
# Inspecting node 110504574
# Inspecting node 24692082
# Inspecting node 16422863
# Inspecting node 1650588223
# Inspecting node 1548315212
# Inspecting node 1378038493105037320
# Inspecting node 4731285264
# Inspecting node 1260770767123312640
# Inspecting node 1260759194833006593
# Inspecting node 975784752648212480
# Inspecting node 2367303485
# Inspecting node 1346317368637603841
# Inspecting node 1426665402147360769
# Inspecting node 1024397417423106048
# Inspecting node 776153719675072512
# Inspecting node 787738985481240576
# Inspecting node 911264470210682880
# Inspecting node 1005823371144318977
# Inspecting node 1416921060788801539
# Inspecting node 17174462
# Inspecting node 1214396742
# Inspecting node 2379113581
# Inspecting node 1426711288462417921
# Inspecting node 21426717
# Inspecting node 975519759105060864
# Inspecting node 2394842400
# Inspecting node 1430196796781912066
# Inspecting node 1433249159474200577
# Inspecting node 20467453
# Inspecting node 1353457212799262720
# Inspecting node 877710910780985345
# Inspecting node 1413615091224924164
# Inspecting node 739208182837321729
# Inspecting node 16545084
# Inspecting node 1234968032734216193
# Inspecting node 979741136725184512
# Inspecting node 509604564
# Inspecting node 731972892
# Inspecting node 1357259774
# Inspecting node 308032537
# Inspecting node 782939425
# Inspecting node 824028437568438277
# Inspecting node 1255919262998441987
# Inspecting node 1291405539046457345
# Inspecting node 1306024583858917376
# Inspecting node 578272027
# Inspecting node 294660973
# Inspecting node 1212202179777331200
# Inspecting node 21632185
# Inspecting node 1227080599451701249
# Inspecting node 2906452022
# Inspecting node 1298675867061805056
# Inspecting node 15128653
# Inspecting node 820499790
# Inspecting node 1238950146559352834
# Inspecting node 1854934933
# Inspecting node 1444459015875014657
# Inspecting node 147340782
# Inspecting node 15677734
# Inspecting node 195207470
# Inspecting node 1282074147884015616
# Inspecting node 977009074217795584
# Inspecting node 3331283445
# Inspecting node 826085293677748224
# Inspecting node 1355980761443217415
# Inspecting node 92256613
# Inspecting node 1278822500143677442
# Inspecting node 187257177
# Inspecting node 902402049022808064
# Inspecting node 1694247541
# Inspecting node 403374868
# Inspecting node 42142250
# Inspecting node 4856189107
# Inspecting node 483313162
# Inspecting node 2427741792
# Inspecting node 2174574218
# Inspecting node 3831737053
# Inspecting node 892123934119927809
# Inspecting node 3660694460
# Inspecting node 3298660936
# Inspecting node 3289694144
# Inspecting node 459311957
# Inspecting node 33456207
# Inspecting node 144036263
# Inspecting node 1049412181559787521
# Inspecting node 826499437585371136
# Inspecting node 540672851
# Inspecting node 1444511517379026948
# Inspecting node 1023207519060197383
# Inspecting node 22532501
# Inspecting node 1067386991250206721
# Inspecting node 2800244863
# Inspecting node 92736596
# Inspecting node 1225489734178344962
# Inspecting node 66621998
# Inspecting node 1059573444214439937
# Inspecting node 1442259927779532808
# Inspecting node 751872198961487872
# Inspecting node 1190792680877559810
# Inspecting node 147981741
# Inspecting node 3158178364
# Inspecting node 1198789568214044672
# Inspecting node 1118222712818868229
# Inspecting node 1296542987850113024
# Inspecting node 1294643635397550080
# Inspecting node 920714531537481729
# Inspecting node 779333693936721920
# Inspecting node 49707487
# Inspecting node 1424936529621774338
# Inspecting node 1129198217164234753
# Inspecting node 1366519801997193216
# Inspecting node 32235586
# Inspecting node 44674554
# Inspecting node 224063162
# Inspecting node 369093
# Inspecting node 2883808867
# Inspecting node 292524345
# Inspecting node 22968164
# Inspecting node 1001274194443821064
# Inspecting node 15054416
# Inspecting node 21400756
# Inspecting node 4860164601
# Inspecting node 467804527
# Inspecting node 958181344286269440
# Inspecting node 778262568272027648
# Inspecting node 38929865
# Inspecting node 297074777
# Inspecting node 760353522718081026
# Inspecting node 928262146542026752
# Inspecting node 160673089
# Inspecting node 175939051
# Inspecting node 1187760523829563392
# Inspecting node 78429753
# Inspecting node 4722097454
# Inspecting node 1070001735454875648
# Inspecting node 35728556
# Inspecting node 1402352323851083779
# Inspecting node 1097176821622284289
# Inspecting node 150699925
# Inspecting node 1060278863874478080
# Inspecting node 813073081761570816
# Inspecting node 722880943380242432
# Inspecting node 14960142
# Inspecting node 1346936882
# Inspecting node 1073283389288005632
# Inspecting node 1297250167
# Inspecting node 1322191014455554048
# Inspecting node 1357200256618795008
# Inspecting node 16504074
# Inspecting node 158100294
# Inspecting node 817811639516991488
# Inspecting node 824357739501531136
# Inspecting node 268237247
# Inspecting node 21815663
# Inspecting node 318420941
# Inspecting node 341180420
# Inspecting node 2267952750
# Inspecting node 454336947
# Inspecting node 725309237862223872
# Inspecting node 353903334
# Inspecting node 2247798150
# Inspecting node 489749588
# Inspecting node 4819639768
# Inspecting node 1330218727
# Inspecting node 1481076481
# Inspecting node 2479224015
# Inspecting node 563152589
# Inspecting node 1317418116
# Inspecting node 1350924172554366979
# Inspecting node 23101207
# Inspecting node 1357917347181453312
# Inspecting node 721401357
# Inspecting node 2926114316
# Inspecting node 968303534822313984
# Inspecting node 77035084
# Inspecting node 85859978
# Inspecting node 2720749324
# Inspecting node 734095130
# Inspecting node 3257661611
# Inspecting node 1219432023044939776
# Inspecting node 998712356
# Inspecting node 603662056
# Inspecting node 4729460081
# Inspecting node 188565420
# Inspecting node 2534622463
# Inspecting node 165020784
# Inspecting node 84704052
# Inspecting node 4273980252
# Inspecting node 29256016
# Inspecting node 577968691
# Inspecting node 845271811097055234
# Inspecting node 470780364
# Inspecting node 22531935
# Inspecting node 59829657
# Inspecting node 275735174
# Inspecting node 559870034
# Inspecting node 7491592
# Inspecting node 23282993
# Inspecting node 2411078349
# Inspecting node 4148412316
# Inspecting node 73199415
# Inspecting node 366968661
# Inspecting node 341653196
# Inspecting node 605379442
# Inspecting node 28045785
# Inspecting node 40216513
# Inspecting node 925675836526776321
# Inspecting node 1080965055007592456
# Inspecting node 1032507164
# Inspecting node 820730609043505152
# Inspecting node 495401684
# Inspecting node 29904143
# Inspecting node 365563514
# Inspecting node 1142295084572073985
# Inspecting node 23522098
# Inspecting node 624251860
# Inspecting node 80212065
# Inspecting node 2829798301
# Inspecting node 1390067256080621568
# Inspecting node 38878429
# Inspecting node 2801061205
# Inspecting node 935335003084423168
# Inspecting node 622885791
# Inspecting node 1112914064076931072
# Inspecting node 384288098
# Inspecting node 515847342
# Inspecting node 3111765339
# Inspecting node 3419010088
# Inspecting node 571519594
# Inspecting node 935697022400602112
# Inspecting node 349692386
# Inspecting node 1223950760
# Inspecting node 3341414159
# Inspecting node 1382336580518621186
# Inspecting node 3142614406
# Inspecting node 731469980890476545
# Inspecting node 58340767
# Inspecting node 266653082
# Inspecting node 2853989866
# Inspecting node 3607702640
# Inspecting node 1421968442
# Inspecting node 297986745
# Inspecting node 54042169
# Inspecting node 577170668
# Inspecting node 880108852162707456
# Inspecting node 1380189591735517190
# Inspecting node 35051540
# Inspecting node 1074335960
# Inspecting node 1371923720609095686
# Inspecting node 1280972258
# Inspecting node 491697655
# Inspecting node 2651576688
# Inspecting node 1117035592565628928
# Inspecting node 163922710
# Inspecting node 1286102971974025217
# Inspecting node 2620272561
# Inspecting node 52516962
# Inspecting node 1065829609
# Inspecting node 1437800221375963143
# Inspecting node 1247541393121087495
# Inspecting node 892060639526395904
# Inspecting node 543143031
# Inspecting node 124878802
# Inspecting node 1341618252
# Inspecting node 727897637098135552
# Inspecting node 14221144
# Inspecting node 950848085802004480
# Inspecting node 16267310
# Inspecting node 2262304373
# Inspecting node 727519870590541824
# Inspecting node 92551736
# Inspecting node 3438124552
# Inspecting node 2749373577
# Inspecting node 535799622
# Inspecting node 1354038378640134145
# Inspecting node 1239698227739459584
# Inspecting node 196164822
# Inspecting node 3075929388
# Inspecting node 1212777267169873920
# Inspecting node 140253506
# Inspecting node 1571464364
# Inspecting node 37609730
# Inspecting node 1396338835596795904
# Inspecting node 1069734050301128705
# Inspecting node 1581712848
# Inspecting node 3268565808
# Inspecting node 786738726466707460
# Inspecting node 1115838887623122954
# Inspecting node 1498327201
# Inspecting node 1316013080250216453
# Inspecting node 957808962983755776
# Inspecting node 2727310657
# Inspecting node 2353185104
# Inspecting node 992390491105882112
# Inspecting node 1133696644422275072
# Inspecting node 3087811674
# Inspecting node 2151893489
# Inspecting node 904365258399244288
# Inspecting node 1393384383650975744
# Inspecting node 707364896153980928
# Inspecting node 371739649
# Inspecting node 1203817853494779904
# Inspecting node 1081036726758531072
# Inspecting node 2968424080
# Inspecting node 2151613567
# Inspecting node 198927392
# Inspecting node 951527727365988352
# Inspecting node 1093890667909124100
# Inspecting node 593891991
# Inspecting node 4850122813
# Inspecting node 872152901870911489
# Inspecting node 878242924567441408
# Inspecting node 1335043297
# Inspecting node 725731648017424385
# Inspecting node 1198351736
# Inspecting node 26557104
# Inspecting node 1042821954821087232
# Inspecting node 1428826266
# Inspecting node 2831610879
# Inspecting node 4681656433
# Inspecting node 775279674
# Inspecting node 596787864
# Inspecting node 273262205
# Inspecting node 24990450
# Inspecting node 342699819
# Inspecting node 378321467
# Inspecting node 217485938
# Inspecting node 967837552425119744
# Inspecting node 18579611
# Inspecting node 16811701
# Inspecting node 63476527
# Inspecting node 17442269
# Inspecting node 1366423551704784897
# Inspecting node 1070588953105969152
# Inspecting node 119911112
# Inspecting node 145878023
# Inspecting node 28540616
# Inspecting node 17050123
# Inspecting node 1432002021398306821
# Inspecting node 930479718
# Inspecting node 2341257349
# Inspecting node 587087289
# Inspecting node 708990479895896066
# Inspecting node 566196508
# Inspecting node 1019405015855878144
# Inspecting node 1275466513529671681
# Inspecting node 1347609010434953217
# Inspecting node 1419539298
# Inspecting node 57527830
# Inspecting node 24752425
# Inspecting node 29586080
# Inspecting node 1250609616192446466
# Inspecting node 2589728724
# Inspecting node 7922582
# Inspecting node 1124423281765797888
# Inspecting node 1077139237
# Inspecting node 199876983
# Inspecting node 18680879
# Inspecting node 380327126
# Inspecting node 3139690604
# Inspecting node 282111410
# Inspecting node 273727399
# Inspecting node 703722876
# Inspecting node 3357096478
# Inspecting node 838912397066846208
# Inspecting node 1437539837477748738
# Inspecting node 751919973497384962
# Inspecting node 1404491652580843525
# Inspecting node 1067154574278971392
# Inspecting node 576365948
# Inspecting node 31513326
# Inspecting node 1297575021578256388
# Inspecting node 1233196108211294209
# Inspecting node 19359977
# Inspecting node 745800926
# Inspecting node 2448257995
# Inspecting node 839668692866723840
# Inspecting node 15023001
# Inspecting node 30270072
# Inspecting node 17929195
# Inspecting node 385678932
# Inspecting node 1065257588151996422
# Inspecting node 1687712964
# Inspecting node 1345709200618389504
# Inspecting node 224737149
# Inspecting node 373940903
# Inspecting node 6013662
# Inspecting node 907302868645953537
# Inspecting node 1243336421164732416
# Inspecting node 240831038
# Inspecting node 290312086
# Inspecting node 4026420858
# Inspecting node 540103190
# Inspecting node 248866864
# Inspecting node 148618115
# Inspecting node 83307703
# Inspecting node 918318518
# Inspecting node 21166754
# Inspecting node 493604178
# Inspecting node 1222274097935073281
# Inspecting node 336662190
# Inspecting node 1254832256
# Inspecting node 65917423
# Inspecting node 15257975
# Inspecting node 18148460
# Inspecting node 168350399
# Inspecting node 18457918
# Inspecting node 165890739
# Inspecting node 1380663772906356737
# Inspecting node 554805867
# Inspecting node 1344041868779110400
# Inspecting node 373667686
# Inspecting node 1261311256151183362
# Inspecting node 1116067546778628097
# Inspecting node 1416035013502685184
# Inspecting node 24313572
# Inspecting node 1144704604442988544
# Inspecting node 222126993
# Inspecting node 2655180373
# Inspecting node 887262626
# Inspecting node 3131039404
# Inspecting node 249386982
# Inspecting node 4759974372
# Inspecting node 494732315
# Inspecting node 1405037853579436035
# Inspecting node 15049380
# Inspecting node 396149168
# Inspecting node 977021137
# Inspecting node 3320688247
# Inspecting node 880997516
# Inspecting node 264439847
# Inspecting node 1068193791511678977
# Inspecting node 636649732
# Inspecting node 14837621
# Inspecting node 596793900
# Inspecting node 4767685428
# Inspecting node 1407536941680279552
# Inspecting node 717895042602504192
# Inspecting node 52245251
# Inspecting node 2574056066
# Inspecting node 35476624
# Inspecting node 48035511
# Inspecting node 207677544
# Inspecting node 56029187
# Inspecting node 3306930701
# Inspecting node 1177657984220053506
# Inspecting node 165971686
# Inspecting node 758042170968375296
# Inspecting node 242492168
# Inspecting node 27460814
# Inspecting node 1231982311253708803
# Inspecting node 2533511951
# Inspecting node 3317590829
# Inspecting node 2416130503
# Inspecting node 724952267162542080
# Inspecting node 22491454
# Inspecting node 3029210380
# Inspecting node 2157300561
# Inspecting node 1053529093285785601
# Inspecting node 1130348139607576576
# Inspecting node 1232835905616011264
# Inspecting node 2922358250
# Inspecting node 1001986308343033856
# Inspecting node 1022679197976678400
# Inspecting node 2560632538
# Inspecting node 1317802041423646720
# Inspecting node 884265045479313408
# Inspecting node 1229474724142604288
# Inspecting node 486317915
# Inspecting node 235070820
# Inspecting node 755749623491244032
# Inspecting node 32189160
# Inspecting node 416468980
# Inspecting node 1051556700
# Inspecting node 1171534270168367105
# Inspecting node 23370368
# Inspecting node 1399510991885455362
# Inspecting node 1438462388647440386
# Inspecting node 214708464
# Inspecting node 547747984
# Inspecting node 366117993
# Inspecting node 262910171
# Inspecting node 1416997300199641091
# Inspecting node 24707528
# Inspecting node 521255914
# Inspecting node 1267810083389480963
# Inspecting node 165587758
# Inspecting node 1398595872187830274
# Inspecting node 1392128666998542337
# Inspecting node 2612807188
# Inspecting node 2652768953
# Inspecting node 292728050
# Inspecting node 96450418
# Inspecting node 2811765535
# Inspecting node 45010284
# Inspecting node 128290965
# Inspecting node 1088791968451313665
# Inspecting node 268573963
# Inspecting node 41089713
# Inspecting node 55841183
# Inspecting node 1419998048562909204
# Inspecting node 2969192164
# Inspecting node 1338252288
# Inspecting node 887732866423173125
# Inspecting node 39268708
# Inspecting node 995530035892121601
# Inspecting node 2694473137
# Inspecting node 421830937
# Inspecting node 1097531188338552832
# Inspecting node 64514213
# Inspecting node 67254536
# Inspecting node 1191423138954981382
# Inspecting node 244328935
# Inspecting node 15782904
# Inspecting node 147965270
# Inspecting node 2944338467
# ...
# Inspecting node 1411006381117919235
# Inspecting node 84353854
# Inspecting node 1446920962671185920
# Inspecting node 1365798226717151233
# Inspecting node 281811081
# Inspecting node 1406365981329346565
# Inspecting node 65767300
# Inspecting node 3011968549
# Inspecting node 1438896900070117381
# Inspecting node 547245887
# Inspecting node 1615902452
# Inspecting node 38885578
# Inspecting node 948223698649124870
# Inspecting node 1242785654368382979
# Inspecting node 3145151881
# Inspecting node 1148750306634883077
# Inspecting node 40109301
# Inspecting node 895679481720872960
# Inspecting node 2966914766
# Inspecting node 1347952445985497088
# Inspecting node 922806178446327809
# Inspecting node 131591657
# Inspecting node 1374005511495028737
# Inspecting node 408241959
# Inspecting node 809552357763661824
# Inspecting node 1556631295
# Inspecting node 282728904
# Inspecting node 785667382224293888
# Inspecting node 1013808600
# Inspecting node 16271356
# Inspecting node 4762708393
# Inspecting node 2167166754
# Inspecting node 517098546
# Inspecting node 886380609026785280
# Inspecting node 2869430815
# Inspecting node 937525764
# Inspecting node 981670040062779392
# Inspecting node 909852173479104512
# Inspecting node 220518078
# Inspecting node 226666386
# Inspecting node 288515399
# Inspecting node 220871206
# Inspecting node 17394737
# Inspecting node 85688497
# Inspecting node 85625597
# Inspecting node 32611097
# Inspecting node 1144689874424999937
# Inspecting node 2465329364
# Inspecting node 149701807
# Inspecting node 26186692
# Inspecting node 23371273
# Inspecting node 3015944460
# Inspecting node 760257132675600386
# Inspecting node 730797462991065088
# Inspecting node 771466526348107776
# Inspecting node 45950539
# Inspecting node 1160209698
# Inspecting node 1109141736972939264
# Inspecting node 169237647
# Inspecting node 1145662294849990656
# Inspecting node 78641250
# Inspecting node 821066393143672836
# Inspecting node 27740019
# Inspecting node 2201466604
# Inspecting node 1361822936
# Inspecting node 21108458
# Inspecting node 382935719
# Inspecting node 1252040788982169600
# Inspecting node 23937700
# Inspecting node 372577100
# Inspecting node 53807352
# Inspecting node 1177551303725240322
# Inspecting node 1252976493971595265
# Inspecting node 441289118
# Inspecting node 897094186213588992
# Inspecting node 3676427473
# Inspecting node 469671065
# Inspecting node 846920964113870848
# Inspecting node 268469213
# Inspecting node 24573102
# Inspecting node 16170023
# Inspecting node 2458783644
# Inspecting node 258405050
# Inspecting node 301144504
# Inspecting node 495918203
# Inspecting node 1239567083404292097
# Inspecting node 536853804
# Inspecting node 250839952
# Inspecting node 856686343144955904
# Inspecting node 981229378825801728
# Inspecting node 1335769353124343808
# Inspecting node 54650770
# Inspecting node 1691207420
# Inspecting node 479862010
# Inspecting node 702598323958620163
# Inspecting node 1197864396
# Inspecting node 272677124
# Inspecting node 54426656
# Inspecting node 1965901333
# Inspecting node 1336451673053679620
# Inspecting node 1442989306256113667
# Inspecting node 516604259
# Inspecting node 1420446766869225478
# Inspecting node 250804618
# Inspecting node 963133478
# Inspecting node 224723351
# Inspecting node 1329430334195208192
# Inspecting node 1107013222853304320
# Inspecting node 216438127
# Inspecting node 56568168
# Inspecting node 2289086672
# Inspecting node 342281222
# Inspecting node 250170548
# Inspecting node 896453296059146240
# Inspecting node 246116520
# Inspecting node 1017842910740410368
# Inspecting node 1281660648
# Inspecting node 818467340895522817
# Inspecting node 2414991108
# Inspecting node 2579229572
# Inspecting node 2568029796
# Inspecting node 1424797446845173778
# Inspecting node 24219018
# Inspecting node 1363912931151384588
# Inspecting node 103031465
# Inspecting node 2211020226
# Inspecting node 1310374181687537664
# Inspecting node 1239007657803026432
# Inspecting node 1384893312797003781
# Inspecting node 1927067096
# Inspecting node 17670732
# Inspecting node 939007961388662784
# Inspecting node 823680319274381312
# Inspecting node 1232369847134121986
# Inspecting node 1337783599446286338
# Inspecting node 17076793
# Inspecting node 1025381606
# Inspecting node 87863020
# Inspecting node 38042361
# Inspecting node 2699710783
# Inspecting node 316245912
# Inspecting node 1375846488031432705
# Inspecting node 8820062
# Inspecting node 1396272483309862913
# Inspecting node 830585528961495040
# Inspecting node 246667561
# Inspecting node 885644906915663872
# Inspecting node 375303344
# Inspecting node 1147137986431258624
# Inspecting node 1171095411307753472
# Inspecting node 18418465
# Inspecting node 590154066
# Inspecting node 59835490
# Inspecting node 1705708466
# Inspecting node 1041561337
# Inspecting node 1486136467
# Inspecting node 2807874943
# Inspecting node 17221430
# Inspecting node 1205581352
# Inspecting node 79121813
# Inspecting node 389705011
# Inspecting node 2190688044
# Inspecting node 715394299207090179
# Inspecting node 1382439377406722048
# Inspecting node 1199890847954882560
# Inspecting node 246380006
# Inspecting node 3179422780
# Inspecting node 36471917
# Inspecting node 23424817
# Inspecting node 9814812
# Inspecting node 840697793618550787
# Inspecting node 730780438269206528
# Inspecting node 294539923
# Inspecting node 1279157580799983617
# Inspecting node 403643684
# Inspecting node 53452624
# Inspecting node 2466115268
# Inspecting node 278882082
# Inspecting node 7562042
# Inspecting node 2395405134
# Inspecting node 18163138
# Inspecting node 865300797130764288
# Inspecting node 1287896006550589442
# Inspecting node 59342468
# Inspecting node 2886941025
# Inspecting node 962424351596281856
# Inspecting node 560765411
# Inspecting node 2924898800
# Inspecting node 1218987476112543744
# Inspecting node 2710528980
# Inspecting node 279748443
# Inspecting node 17702445
# Inspecting node 842121813278752768
# Inspecting node 327394273
# Inspecting node 1012406984719470592
# Inspecting node 10155832
# Inspecting node 439313680
# Inspecting node 1151231204923977729
# Inspecting node 989298765163937792
# Inspecting node 866416675
# Inspecting node 36877221
# Inspecting node 351155835
# Inspecting node 11423372
# Inspecting node 41378883
# Inspecting node 2334251844
# Inspecting node 263163489
# Inspecting node 1096251117745332226
# Inspecting node 1407372687316590594
# Inspecting node 1250830543119319042
# Inspecting node 2903614908
# Inspecting node 1351286814313738243
# Inspecting node 1403372126304866305
# Inspecting node 69712457
# Inspecting node 2730870751
# Inspecting node 16189107
# Inspecting node 414275183
# Inspecting node 393348427
# Inspecting node 248911548
# Inspecting node 34774986
# Inspecting node 1194310568200548352
# Inspecting node 1240872856508137472
# Inspecting node 242533078
# Inspecting node 78084063
# Inspecting node 42232039
# Inspecting node 41239526
# Inspecting node 3112228915
# Inspecting node 1852773120
# Inspecting node 1242517797621530625
# Inspecting node 960897097
# Inspecting node 185290543
# Inspecting node 305945328
# Inspecting node 155777848
# Inspecting node 248891184
# Inspecting node 1357931292
# Inspecting node 1582129344
# Inspecting node 63863473
# Inspecting node 744530425
# Inspecting node 1367957858
# Inspecting node 2469606308
# Inspecting node 326461319
# Inspecting node 529665584
# Inspecting node 154271777
# Inspecting node 1270383308
# Inspecting node 2312086998
# Inspecting node 1447429249
# Inspecting node 2861279433
# Inspecting node 466832463
# Inspecting node 67278150
# Inspecting node 1660911480
# Inspecting node 467664297
# Inspecting node 2573566824
# Inspecting node 132989977
# Inspecting node 954431291629473794
# Inspecting node 238865666
# Inspecting node 2569323896
# Inspecting node 788806262045732864
# Inspecting node 14165217
# Inspecting node 1447951549
# Inspecting node 1594767902
# Inspecting node 491779798
# Inspecting node 946092660795744256
# Inspecting node 74211986
# Inspecting node 524590563
# Inspecting node 1338157627453427713
# Inspecting node 823317383838253056
# Inspecting node 1044778781230039042
# Inspecting node 922963142300143616
# Inspecting node 74937543
# Inspecting node 1305697758
# Inspecting node 18463733
# Inspecting node 76264942
# Inspecting node 2905252436
# Inspecting node 44539994
# Inspecting node 396745864
# Inspecting node 1176801
# Inspecting node 1229442788623818752
# Inspecting node 2993775174
# Inspecting node 2462641501
# Inspecting node 560903736
# Inspecting node 1427351911410257934
# Inspecting node 245651739
# Inspecting node 4922698441
# Inspecting node 4024032261
# Inspecting node 15099646
# Inspecting node 75841164
# Inspecting node 794664236
# Inspecting node 1440828246132596736
# Inspecting node 3069762388
# Inspecting node 700994268
# Inspecting node 1104945319
# Inspecting node 38221378
# Inspecting node 3218932860
# Inspecting node 1201882182
# Inspecting node 1395092719
# Inspecting node 2871728962
# Inspecting node 815428708144218112
# Inspecting node 976143225927839744
# Inspecting node 727212809948401664
# Inspecting node 1373435309782822912
# Inspecting node 568769809
# Inspecting node 982017242354388992
# Inspecting node 36395646
# Inspecting node 40697478
# Inspecting node 1423672567869624322
# Inspecting node 164368721
# Inspecting node 46214091
# Inspecting node 2194496264
# Inspecting node 1057723606027792385
# Inspecting node 25209036
# Inspecting node 1347801793930035200
# Inspecting node 868994263
# Inspecting node 117589552
# Inspecting node 1080529497152278528
# Inspecting node 624962704
# Inspecting node 47022386
# Inspecting node 942370814
# Inspecting node 70499348
# Inspecting node 929856990934790144
# Inspecting node 314093378
# Inspecting node 3053107588
# Inspecting node 1459578954
# Inspecting node 4880637512
# Inspecting node 1932563430
# Inspecting node 1282257536
# Inspecting node 17300548
# Inspecting node 1236439017433989122
# Inspecting node 1444458812614709250
# Inspecting node 1386793782683652096
# Inspecting node 9575562
# Inspecting node 120139457
# Inspecting node 1240478580510871552
# Inspecting node 117562974
# Inspecting node 312422268
# Inspecting node 1333030975681536000
# Inspecting node 1040629333210148865
# Inspecting node 252399534
# Inspecting node 2459730643
# Inspecting node 1264712331457638400
# Inspecting node 1428151019981180932
# Inspecting node 280831905
# Inspecting node 1416101066580627464
# Inspecting node 1135929275272634369
# Inspecting node 360214917
# Inspecting node 1302065426961174530
# Inspecting node 39637553
# Inspecting node 114977658
# Inspecting node 1327696892608724992
# Inspecting node 1409204814534299649
# Inspecting node 371939653
# Inspecting node 190010892
# Inspecting node 1275457555490320385
# Inspecting node 1445833073770184706
# Inspecting node 1601728627
# Inspecting node 41748110
# Inspecting node 1438198932606160901
# Inspecting node 16491468
# Inspecting node 323895654
# Inspecting node 137045661
# Inspecting node 1352682350228942848
# Inspecting node 770683230223634433
# Inspecting node 3368587707
# Inspecting node 1120673221236408320
# Inspecting node 213879574
# Inspecting node 1414982991059709954
# Inspecting node 809651491
# Inspecting node 1491487802
# Inspecting node 4886317138
# Inspecting node 14912051
# Inspecting node 915727372443414528
# Inspecting node 966560892262502400
# Inspecting node 885737117745164288
# Inspecting node 981191210705530880
# Inspecting node 341002490
# Inspecting node 1948425750
# Inspecting node 1391765775594180612
# Inspecting node 1346126893733462016
# Inspecting node 1443254711381946371
# Inspecting node 95348250
# Inspecting node 1351325172184264704
# Inspecting node 487857297
# Inspecting node 94885717
# Inspecting node 925876396878020608
# Inspecting node 15300266
# Inspecting node 1212089073323503616
# Inspecting node 239096810
# Inspecting node 1353758379160834051
# Inspecting node 24728011
# Inspecting node 85640352
# Inspecting node 1012839192253075456
# Inspecting node 1259289117805776896
# Inspecting node 1309184065
# Inspecting node 1881851268
# Inspecting node 132512731
# Inspecting node 1181627354621399040
# Inspecting node 34478789
# Inspecting node 2842764204
# Inspecting node 1034903210547277824
# Inspecting node 1202669441000996864
# Inspecting node 961989099623137280
# Inspecting node 1263895193784184832
# Inspecting node 471366697
# Inspecting node 829731473443975170
# Inspecting node 590822892
# Inspecting node 382409124
# Inspecting node 851681
# Inspecting node 870842873628864513
# Inspecting node 271124533
# Inspecting node 446471174
# Inspecting node 228477243
# Inspecting node 1202388934208172032
# Inspecting node 1060751566657867776
# Inspecting node 257304118
# Inspecting node 4096225454
# Inspecting node 216266808
# Inspecting node 159065078
# Inspecting node 1058391394681868289
# Inspecting node 428602423
# Inspecting node 823397168975409152
# Inspecting node 1345473368494104580
# Inspecting node 46563847
# Inspecting node 2444436240
# Inspecting node 1126848839594467328
# Inspecting node 1257895028724203521
# Inspecting node 277513651
# Inspecting node 1110790944821932034
# Inspecting node 1161332556312326144
# Inspecting node 1346332104234295296
# Inspecting node 165942840
# Inspecting node 259587504
# Inspecting node 1925416346
# Inspecting node 15012924
# Inspecting node 18537391
# Inspecting node 42989776
# Inspecting node 93654204
# Inspecting node 34921899
# Inspecting node 2239987934
# Inspecting node 86320422
# Inspecting node 171411616
# Inspecting node 14650213
# Inspecting node 1087961
# Inspecting node 602903529
# Inspecting node 244204227
# Inspecting node 519071482
# Inspecting node 251635353
# Inspecting node 5654722
# Inspecting node 725037770033532929
# Inspecting node 40059893
# Inspecting node 237480031
# Inspecting node 1056707817216720896
# Inspecting node 1383581104473468929
# Inspecting node 373477857
# Inspecting node 20122522
# Inspecting node 4254675664
# Inspecting node 1259345602980298753
# Inspecting node 725344413162049536
# Inspecting node 1433115420563853312
# Inspecting node 166701763
# Inspecting node 582342806
# Inspecting node 14257934
# Inspecting node 1163072647661522946
# Inspecting node 1201151072733138945
# Inspecting node 1352358388638875652
# Inspecting node 549023337
# Inspecting node 936473743387394048
# Inspecting node 437944231
# Inspecting node 400071841
# Inspecting node 637320913
# Inspecting node 19114577
# Inspecting node 70065285
# Inspecting node 1268920433086210048
# Inspecting node 1176689353885724674
# Inspecting node 460592390
# Inspecting node 2262160692
# Inspecting node 2293461198
# Inspecting node 15219830
# Inspecting node 1201532829860892673
# Inspecting node 92417373
# Inspecting node 122127786
# Inspecting node 362454062
# Inspecting node 2984610092
# Inspecting node 415126004
# Inspecting node 844452866
# Inspecting node 14501713
# Inspecting node 1258440535402065920
# Inspecting node 2254247360
# Inspecting node 104585835
# Inspecting node 1410832490701467650
# Inspecting node 365780558
# Inspecting node 21632994
# Inspecting node 1338474046095233026
# Inspecting node 1113547517105528833
# Inspecting node 293588108
# Inspecting node 1155208255066558475
# Inspecting node 22523896
# Inspecting node 3675933919
# Inspecting node 2796774360
# Inspecting node 1095219121447301120
# Inspecting node 816758120819015680
# Inspecting node 825925386110382080
# Inspecting node 1529643188
# Inspecting node 246811073
# Inspecting node 3351916392
# Inspecting node 123910630
# Inspecting node 29304563
# Inspecting node 1396107226608283649
# Inspecting node 549598823
# Inspecting node 797133264716754944
# Inspecting node 768559569891012608
# Inspecting node 1880517650
# Inspecting node 1232471924145577985
# Inspecting node 1300309398166949889
# Inspecting node 1923754400
# Inspecting node 53754232
# Inspecting node 307324209
# Inspecting node 3165242127
# Inspecting node 730826158258946050
# Inspecting node 1577656471
# Inspecting node 1214368702277308421
# Inspecting node 299993498
# Inspecting node 1235344992765448193
# Inspecting node 625193066
# Inspecting node 467817388
# Inspecting node 3135148227
# Inspecting node 872810605
# Inspecting node 271504586
# Inspecting node 306967462
# Inspecting node 3299469609
# Inspecting node 1225848216467509248
# Inspecting node 259388196
# Inspecting node 525910396
# Inspecting node 358143304
# Inspecting node 1088545656002801664
# Inspecting node 1283460034182209537
# Inspecting node 1326306504027287554
# Inspecting node 100874975
# Inspecting node 811549418
# Inspecting node 145058470
# Inspecting node 15892547
# Inspecting node 2797935107
# Inspecting node 27388441
# Inspecting node 288495993
# Inspecting node 77596220
# Inspecting node 891058415195303939
# Inspecting node 1095768409449459712
# Inspecting node 881426857
# Inspecting node 17388526

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.out_degree(node) 
    for key, value in out_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
degrees = {}
in_degrees = {}
out_degrees = {}

dirname = "Directed_Unweighted_Models/Group2_1"
directory = os.fsencode(dirname)

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    H = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    degree_dist = {}
    in_degree_dist = {}
    out_degree_dist = {}
    
    for node in H:
        degree_dist[node] = H.degree(node)
        in_degree_dist[node] = H.in_degree(node)
        out_degree_dist[node] = H.out_degree(node)
    degrees[filename] = degree_dist
    in_degrees[filename] = in_degree_dist
    out_degrees[filename] = out_degree_dist
# Out:
# Directed_Unweighted_Random_Null_Model_577
# Directed_Unweighted_Random_Null_Model_578
# Directed_Unweighted_Random_Null_Model_579
# Directed_Unweighted_Random_Null_Model_580
# Directed_Unweighted_Random_Null_Model_581
# Directed_Unweighted_Random_Null_Model_582
# Directed_Unweighted_Random_Null_Model_583
# Directed_Unweighted_Random_Null_Model_584
# Directed_Unweighted_Random_Null_Model_585
# Directed_Unweighted_Random_Null_Model_586
# Directed_Unweighted_Random_Null_Model_587
# Directed_Unweighted_Random_Null_Model_588
# Directed_Unweighted_Random_Null_Model_589
# Directed_Unweighted_Random_Null_Model_590
# Directed_Unweighted_Random_Null_Model_591
# Directed_Unweighted_Random_Null_Model_592
# Directed_Unweighted_Random_Null_Model_593
# Directed_Unweighted_Random_Null_Model_594
# Directed_Unweighted_Random_Null_Model_595
# Directed_Unweighted_Random_Null_Model_596
# Directed_Unweighted_Random_Null_Model_597
# Directed_Unweighted_Random_Null_Model_598
# Directed_Unweighted_Random_Null_Model_599

# %% [markdown]
# Go through each degree node in G and for each of the models check if some degree is different. If it is stop and report it

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.degree(node) 
    for key, value in degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break
# Out:
# Inspecting node 1385933370090209280
# Inspecting node 158095776
# Inspecting node 1416535505454338050
# Inspecting node 1604931252
# Inspecting node 544695802
# Inspecting node 716257068538327040
# Inspecting node 258170457
# Inspecting node 1086084557009575936
# Inspecting node 2817389862
# Inspecting node 822476228548403200
# Inspecting node 2353730881
# Inspecting node 921026239808208896
# Inspecting node 720934098223542272
# Inspecting node 2922779039
# Inspecting node 552891173
# Inspecting node 982496635
# Inspecting node 1433403537329819654
# Inspecting node 1175052073605353473
# Inspecting node 2784661153
# Inspecting node 102887506
# Inspecting node 18681111
# Inspecting node 952980338745147394
# Inspecting node 1438871779779530755
# Inspecting node 46975259
# Inspecting node 1157395568135557120
# Inspecting node 21951711
# Inspecting node 563064119
# Inspecting node 277332906
# Inspecting node 158458133
# Inspecting node 979827806023618560
# Inspecting node 18308257
# Inspecting node 846667915
# Inspecting node 258916078
# Inspecting node 1138564320390836224
# Inspecting node 17912334
# Inspecting node 2821464243
# Inspecting node 928790819145842688
# Inspecting node 753638148958216192
# Inspecting node 2256955027
# Inspecting node 1185936230393024512
# Inspecting node 14079041
# Inspecting node 3021899490
# Inspecting node 13880132
# Inspecting node 960624707820113920
# Inspecting node 52003137
# Inspecting node 1887595058
# Inspecting node 331864347
# Inspecting node 961514730
# Inspecting node 70750793
# Inspecting node 155629527
# Inspecting node 1161351506983038976
# Inspecting node 766360387
# Inspecting node 150270263
# Inspecting node 38471212
# Inspecting node 83153695
# Inspecting node 118937966
# Inspecting node 871189841186357248
# Inspecting node 293403080
# Inspecting node 629539554
# Inspecting node 1104422828
# Inspecting node 602083976
# Inspecting node 1311896805920043009
# Inspecting node 1318741345905922048
# Inspecting node 25314619
# Inspecting node 104300984
# Inspecting node 15702055
# Inspecting node 1153463878195589125
# Inspecting node 15633240
# Inspecting node 14991184
# Inspecting node 1242522201770856449
# Inspecting node 1440522413687521295
# Inspecting node 106524304
# Inspecting node 1292608204845834241
# Inspecting node 1446846657551683588
# Inspecting node 1389700907697270787
# Inspecting node 1445880242707570691
# Inspecting node 1545912997
# Inspecting node 831084798621782016
# Inspecting node 55976571
# Inspecting node 305401065
# Inspecting node 704798725747531776
# Inspecting node 47452040
# Inspecting node 475298690
# Inspecting node 16220555
# Inspecting node 4744498950
# Inspecting node 766759351973404672
# Inspecting node 47781573
# Inspecting node 994077337
# Inspecting node 14055736
# Inspecting node 1236010900693356549
# Inspecting node 1171683272
# Inspecting node 1338338931792756737
# Inspecting node 562243642
# Inspecting node 15772683
# Inspecting node 1251340447387172868
# Inspecting node 1350484767255519233
# Inspecting node 1335046616697372675
# Inspecting node 20750271
# Inspecting node 1162219997977960449
# Inspecting node 175259033
# Inspecting node 130909683
# Inspecting node 1364261390614106113
# Inspecting node 44416854
# Inspecting node 1511003670
# Inspecting node 536594609
# Inspecting node 24913022
# Inspecting node 17823761
# Inspecting node 273683993
# Inspecting node 215632349
# Inspecting node 1156602559378804741
# Inspecting node 1156033982586208256
# Inspecting node 47338701
# Inspecting node 139819609
# Inspecting node 413514250
# Inspecting node 2852899113
# Inspecting node 1381435843492085760
# Inspecting node 1189800120
# Inspecting node 138418077
# Inspecting node 382489139
# Inspecting node 374300583
# Inspecting node 3226840807
# Inspecting node 133863908
# Inspecting node 57127265
# Inspecting node 142731825
# Inspecting node 1417929933800751104
# Inspecting node 55823004
# Inspecting node 1447315781289750532
# Inspecting node 14262411
# Inspecting node 1707636642
# Inspecting node 845487573011173380
# Inspecting node 109144163
# Inspecting node 20199202
# Inspecting node 785448020628430849
# Inspecting node 77283552
# Inspecting node 38055290
# Inspecting node 34506336
# Inspecting node 242798024
# Inspecting node 138077463
# Inspecting node 121343164
# Inspecting node 814078628
# Inspecting node 196717787
# Inspecting node 18519855
# Inspecting node 268824309
# Inspecting node 2439928526
# Inspecting node 1169378542737661954
# Inspecting node 299228245
# Inspecting node 2369365718
# Inspecting node 1373493122
# Inspecting node 2834753506
# Inspecting node 999476893970763777
# Inspecting node 120320139
# Inspecting node 84734389
# Inspecting node 15407637
# Inspecting node 1899063048
# Inspecting node 1301967293849755653
# Inspecting node 324602007
# Inspecting node 292667439
# Inspecting node 522345885
# Inspecting node 12599562
# Inspecting node 4856851754
# Inspecting node 1248842158553141250
# Inspecting node 4026045455
# Inspecting node 3303438653
# Inspecting node 1129203001
# Inspecting node 2813664079
# Inspecting node 14518712
# Inspecting node 95209129
# Inspecting node 119797208
# Inspecting node 201984482
# Inspecting node 593944500
# Inspecting node 17105128
# Inspecting node 3409346380
# Inspecting node 33826892
# Inspecting node 273866823
# Inspecting node 37552089
# Inspecting node 377588094
# Inspecting node 266855812
# Inspecting node 341866567
# Inspecting node 60916234
# Inspecting node 262436837
# Inspecting node 1092244447184719873
# Inspecting node 2548489298
# Inspecting node 218952640
# Inspecting node 1382491059247255554
# Inspecting node 516915897
# Inspecting node 965028316460797953
# Inspecting node 195899568
# Inspecting node 2432750568
# Inspecting node 331067472
# Inspecting node 272133230
# Inspecting node 108413104
# Inspecting node 177347829
# Inspecting node 964446120402300928
# Inspecting node 1573418346
# Inspecting node 89496127
# Inspecting node 735508941258399744
# Inspecting node 542244178
# Inspecting node 1005899772916477952
# Inspecting node 366171300
# Inspecting node 29545977
# Inspecting node 59686058
# Inspecting node 965478102594863104
# Inspecting node 366225624
# Inspecting node 393713239
# Inspecting node 1185972487538040832
# Inspecting node 889661863100907520
# Inspecting node 2813399220
# Inspecting node 2436061363
# Inspecting node 17900758
# Inspecting node 23491400
# Inspecting node 382949896
# Inspecting node 1009115210546929664
# Inspecting node 3148281878
# Inspecting node 1064964294448750595
# Inspecting node 814289414
# Inspecting node 2896012540
# Inspecting node 1280589273335500801
# Inspecting node 1227766472921014272
# Inspecting node 869639001400942592
# Inspecting node 116679707
# Inspecting node 342176065
# Inspecting node 1890389540
# Inspecting node 2785990732
# Inspecting node 40591485
# Inspecting node 3191905064
# Inspecting node 25813888
# Inspecting node 237536271
# Inspecting node 16982577
# Inspecting node 1563418116
# Inspecting node 2580573206
# Inspecting node 275979196
# Inspecting node 193471925
# Inspecting node 53772503
# Inspecting node 16195103
# Inspecting node 2776775090
# Inspecting node 998590102573023232
# Inspecting node 179129165
# Inspecting node 27101995
# Inspecting node 872156101
# Inspecting node 128908662
# Inspecting node 363070453
# Inspecting node 211564038
# Inspecting node 189349553
# Inspecting node 25127782
# Inspecting node 1166717268975333376
# Inspecting node 40550119
# Inspecting node 417389780
# Inspecting node 61521038
# Inspecting node 85428184
# Inspecting node 58319221
# Inspecting node 52080359
# Inspecting node 2513973205
# Inspecting node 283226685
# Inspecting node 45848808
# Inspecting node 1646334073
# Inspecting node 1360838234
# Inspecting node 21221149
# Inspecting node 507802048
# Inspecting node 190231473
# Inspecting node 993705834470367232
# Inspecting node 360677740
# Inspecting node 1362286033
# Inspecting node 3079986094
# Inspecting node 268528986
# Inspecting node 321752222
# Inspecting node 17280115
# Inspecting node 274220538
# Inspecting node 2352629420
# Inspecting node 51184630
# Inspecting node 908811901
# Inspecting node 408526152
# Inspecting node 371447080
# Inspecting node 2314531026
# Inspecting node 1172199939243425792
# Inspecting node 390392773
# Inspecting node 2289973748
# Inspecting node 495066576
# Inspecting node 1545053600
# Inspecting node 1318671397560979456
# Inspecting node 2891740872
# Inspecting node 2848993491
# Inspecting node 103297393
# Inspecting node 1851634098
# Inspecting node 398483708
# Inspecting node 1313212802799206406
# Inspecting node 79260190
# Inspecting node 27652488
# Inspecting node 89609585
# Inspecting node 44618408
# Inspecting node 880491635896922112
# Inspecting node 2761710808
# Inspecting node 1240867313445830656
# Inspecting node 247412217
# Inspecting node 1347654502787076096
# Inspecting node 982630470008553474
# Inspecting node 82167100
# Inspecting node 110754237
# Inspecting node 768069259100622848
# Inspecting node 1304210384367349770
# Inspecting node 1300291239581892609
# Inspecting node 2253903906
# Inspecting node 78403337
# Inspecting node 862703683
# Inspecting node 1071951545212723200
# Inspecting node 840470152391016448
# Inspecting node 498423001
# Inspecting node 1197522605760303104
# Inspecting node 510093784
# Inspecting node 447415943
# Inspecting node 1201788959719936007
# Inspecting node 1633538270
# Inspecting node 122525211
# Inspecting node 192842634
# Inspecting node 551152504
# Inspecting node 378351271
# Inspecting node 57033548
# Inspecting node 255067647
# Inspecting node 35863342
# Inspecting node 2715275551
# Inspecting node 719557076599619584
# Inspecting node 980875592
# Inspecting node 1051100859831148544
# Inspecting node 2300474413
# Inspecting node 1238447220
# Inspecting node 994295935
# Inspecting node 838098877
# Inspecting node 829761553218072576
# Inspecting node 951280545421410305
# Inspecting node 1157684886
# Inspecting node 80970676
# Inspecting node 18923250
# Inspecting node 1136294664
# Inspecting node 951892305098788864
# Inspecting node 3010143902
# Inspecting node 297020666
# Inspecting node 1045793762063060992
# Inspecting node 98588419
# Inspecting node 76179144
# Inspecting node 46956207
# Inspecting node 819853925184638976
# Inspecting node 16552108
# Inspecting node 29754743
# Inspecting node 153515520
# Inspecting node 386330680
# Inspecting node 2736446758
# Inspecting node 35095520
# Inspecting node 1239564608941113347
# Inspecting node 58261480
# Inspecting node 169614697
# Inspecting node 1005522675761057792
# Inspecting node 816308397360508928
# Inspecting node 1407160205117435908
# Inspecting node 1175457080561537025
# Inspecting node 1011936943247101952
# Inspecting node 365078935
# Inspecting node 17540009
# Inspecting node 49660950
# Inspecting node 296549487
# Inspecting node 1228605451
# Inspecting node 1122706063466356737
# Inspecting node 234593598
# Inspecting node 1204301854433316866
# Inspecting node 1204430581410353154
# Inspecting node 893202244077854721
# Inspecting node 22971125
# Inspecting node 1193458951976869888
# Inspecting node 785853390
# Inspecting node 322106815
# Inspecting node 1957597519
# Inspecting node 1101092779378249729
# Inspecting node 3331826578
# Inspecting node 38720614
# Inspecting node 2912843536
# Inspecting node 183642459
# Inspecting node 2247495353
# Inspecting node 2748289416
# Inspecting node 2592210108
# Inspecting node 103701079
# Inspecting node 1352713370772770816
# Inspecting node 86410896
# Inspecting node 1038301598
# Inspecting node 1134248217472843787
# Inspecting node 999320625117196288
# Inspecting node 18390213
# Inspecting node 768295011007934469
# Inspecting node 1262878353431777280
# Inspecting node 729232479840800768
# Inspecting node 1415442622135603206
# Inspecting node 346123223
# Inspecting node 167912183
# Inspecting node 1076249609125675010
# Inspecting node 67793897
# Inspecting node 823096488
# Inspecting node 50154666
# Inspecting node 302593437
# Inspecting node 291862583
# Inspecting node 168371680
# Inspecting node 1251332171211644931
# Inspecting node 962073414
# Inspecting node 291523600
# Inspecting node 277085673
# Inspecting node 62664213
# Inspecting node 1337551744457469952
# Inspecting node 716460064039575552
# Inspecting node 3007815702
# Inspecting node 55819705
# Inspecting node 1404102585317986308
# Inspecting node 1280249212567818240
# Inspecting node 740981264740679681
# Inspecting node 247511435
# Inspecting node 1303772129847111681
# Inspecting node 1027307702047961088
# Inspecting node 1020156666204090368
# Inspecting node 38751529
# Inspecting node 718873385346797569
# Inspecting node 285806588
# Inspecting node 541129316
# Inspecting node 1655457050
# Inspecting node 57759275
# Inspecting node 824281652423753728
# Inspecting node 132015712
# Inspecting node 40647043
# Inspecting node 12992772
# Inspecting node 365132365
# Inspecting node 1129088815
# Inspecting node 1262268501823303680
# Inspecting node 288548798
# Inspecting node 87632735
# Inspecting node 40246161
# Inspecting node 1252686295
# Inspecting node 25333228
# Inspecting node 1093876945
# Inspecting node 205786669
# Inspecting node 1942350667
# Inspecting node 2863551224
# Inspecting node 720083863830069249
# Inspecting node 176207343
# Inspecting node 412708728
# Inspecting node 414218319
# Inspecting node 1271987860577517568
# Inspecting node 626984632
# Inspecting node 237594523
# Inspecting node 714340176
# Inspecting node 300638343
# Inspecting node 739845530612830208
# Inspecting node 715244769
# Inspecting node 817207955930001409
# Inspecting node 1363561650624733184
# Inspecting node 212468225
# Inspecting node 2673432539
# Inspecting node 23601374
# Inspecting node 51852542
# Inspecting node 321482430
# Inspecting node 1058965681671028736
# Inspecting node 35617919
# Inspecting node 371288369
# Inspecting node 4492249646
# Inspecting node 396106258
# Inspecting node 2287331581
# Inspecting node 150671052
# Inspecting node 3302256527
# Inspecting node 3269322830
# Inspecting node 1364751078659477504
# Inspecting node 168123931
# Inspecting node 1072189285
# Inspecting node 45976740
# Inspecting node 1435257575482740741
# Inspecting node 1099109729308008448
# Inspecting node 1366925295291424768
# Inspecting node 1356073687691141121
# Inspecting node 1580475270
# Inspecting node 1442893993935716361
# Inspecting node 392132054
# Inspecting node 207703739
# Inspecting node 1419489038747070467
# Inspecting node 928451444633563136
# Inspecting node 1119464753318043649
# Inspecting node 1440690378533838857
# Inspecting node 2931943245
# Inspecting node 1727398412
# Inspecting node 1444061901172854786
# Inspecting node 2938869339
# Inspecting node 1243723946660421637
# Inspecting node 2476755039
# Inspecting node 1331773252792770560
# Inspecting node 901618905076174848
# Inspecting node 339780511
# Inspecting node 980817985668550656
# Inspecting node 53694666
# Inspecting node 1445437990940004352
# Inspecting node 1243574020802367488
# Inspecting node 1055536236
# Inspecting node 68670486
# Inspecting node 451989089
# Inspecting node 1077731978
# Inspecting node 1271115442573185024
# Inspecting node 969744550955749383
# Inspecting node 26577630
# Inspecting node 1391981080945643523
# Inspecting node 46232947
# Inspecting node 266048357
# Inspecting node 293745266
# Inspecting node 415532452
# Inspecting node 3107597132
# Inspecting node 1183316407104266241
# Inspecting node 982472677775454209
# Inspecting node 3295839203
# Inspecting node 880913594531139584
# Inspecting node 1911858061
# Inspecting node 1097694473952342022
# Inspecting node 1388650232100134915
# Inspecting node 14100537
# Inspecting node 820656479812227073
# Inspecting node 1325249450793701376
# Inspecting node 1427996716138127360
# Inspecting node 1347691972358778885
# Inspecting node 1365678726
# Inspecting node 1295377965438644235
# Inspecting node 322090834
# Inspecting node 1342962255248424961
# Inspecting node 1195026680609292288
# Inspecting node 1116360718687690758
# Inspecting node 737359208945844224
# Inspecting node 3375064758
# Inspecting node 14538949
# Inspecting node 1084856644687679496
# Inspecting node 36133644
# Inspecting node 976345683681619968
# Inspecting node 366785595
# Inspecting node 2849064914
# Inspecting node 343059330
# Inspecting node 64123717
# Inspecting node 18420573
# Inspecting node 957106791753555968
# Inspecting node 751054068974575616
# Inspecting node 1186136760981454854
# Inspecting node 854065048683204615
# Inspecting node 317823907
# Inspecting node 952759886
# Inspecting node 474883984
# Inspecting node 1258133514421239813
# Inspecting node 2198792101
# Inspecting node 324555383
# Inspecting node 744660163873771520
# Inspecting node 726025903
# Inspecting node 1263514760584167424
# Inspecting node 714569357267853312
# Inspecting node 739149720
# Inspecting node 1136772811656126464
# Inspecting node 270307297
# Inspecting node 454774863
# Inspecting node 772948513
# Inspecting node 3333795492
# Inspecting node 2209473078
# Inspecting node 838196271571591168
# Inspecting node 18386792
# Inspecting node 1166799265806503936
# Inspecting node 262522708
# Inspecting node 1370402422062002179
# Inspecting node 1429982282891239433
# Inspecting node 1434265814325202944
# Inspecting node 1087134051914395648
# Inspecting node 791076864
# Inspecting node 121949981
# Inspecting node 256360738
# Inspecting node 1172475064870027264
# Inspecting node 1443468994107822081
# Inspecting node 941115769429024769
# Inspecting node 1313732971061362690
# Inspecting node 2305422800
# Inspecting node 242885214
# Inspecting node 1354230346586447877
# Inspecting node 469747759
# Inspecting node 432114850
# Inspecting node 1166000110586626048
# Inspecting node 884527637569323009
# Inspecting node 369653658
# Inspecting node 1434643524495020043
# Inspecting node 75984040
# Inspecting node 586195164
# Inspecting node 2902344555
# Inspecting node 564257648
# Inspecting node 1027229536902098944
# Inspecting node 2316626342
# Inspecting node 1925354744
# Inspecting node 958204773282533376
# Inspecting node 1445751022526160908
# Inspecting node 1183078912265355265
# Inspecting node 98767459
# Inspecting node 87297879
# Inspecting node 753394222267527168
# Inspecting node 373580557
# Inspecting node 1430260512688902150
# Inspecting node 2468436247
# Inspecting node 3308781515
# Inspecting node 2273880732
# Inspecting node 1302114263771668481
# Inspecting node 24181491
# Inspecting node 1309179346565898241
# Inspecting node 2231471516
# Inspecting node 1352351686778630145
# Inspecting node 1413321993470943237
# Inspecting node 603011131
# Inspecting node 1438876255202406406
# Inspecting node 1375883715776294914
# Inspecting node 1002002024
# Inspecting node 51384524
# Inspecting node 724114092672335874
# Inspecting node 552725069
# Inspecting node 1184298786329448448
# Inspecting node 334954251
# Inspecting node 101915304
# Inspecting node 1252767510983737344
# Inspecting node 1099811037975642112
# Inspecting node 1388988366247575559
# Inspecting node 1326022742286749696
# Inspecting node 1388801354244702209
# Inspecting node 961162177
# Inspecting node 1389555148318404610
# Inspecting node 1151641780267261952
# Inspecting node 27320189
# Inspecting node 1215379886887428096
# Inspecting node 1184882383
# Inspecting node 257699447
# Inspecting node 2397398196
# Inspecting node 807034969902252032
# Inspecting node 1353486048618274816
# Inspecting node 4866566489
# Inspecting node 3058888765
# Inspecting node 1173239638116446208
# Inspecting node 42894434
# Inspecting node 3078011282
# Inspecting node 32691118
# Inspecting node 544080126
# Inspecting node 1336660494
# Inspecting node 957190068594130946
# Inspecting node 1074149416699719681
# Inspecting node 825518936733085696
# Inspecting node 43199433
# Inspecting node 969376788525830146
# Inspecting node 35107179
# Inspecting node 366074756
# Inspecting node 359672860
# Inspecting node 82679357
# Inspecting node 883774859452579840
# Inspecting node 3418588623
# Inspecting node 710270422290403328
# Inspecting node 763168867371843584
# Inspecting node 1575198925
# Inspecting node 1301995158485958656
# Inspecting node 1260291453973983232
# Inspecting node 1601907697
# Inspecting node 29823611
# Inspecting node 1393039117110317058
# Inspecting node 236055343
# Inspecting node 320919057
# Inspecting node 2812908133
# Inspecting node 1325519307359490048
# Inspecting node 590735039
# Inspecting node 95577307
# Inspecting node 43948485
# Inspecting node 136332449
# Inspecting node 623936216
# Inspecting node 2873956499
# Inspecting node 4803873902
# Inspecting node 1147245556651233280
# Inspecting node 918919026344120321
# Inspecting node 37813045
# Inspecting node 24574252
# Inspecting node 1440809899500335110
# Inspecting node 1334205408110551042
# Inspecting node 1071298949837770753
# Inspecting node 915968072
# Inspecting node 885818088
# Inspecting node 227849419
# Inspecting node 2493753559
# Inspecting node 778842486
# Inspecting node 124839366
# Inspecting node 263750524
# Inspecting node 1357001901229899777
# Inspecting node 990301302264479749
# Inspecting node 1136065885456740352
# Inspecting node 1335377050878676992
# Inspecting node 138710067
# Inspecting node 1441961640459599874
# Inspecting node 2793008984
# Inspecting node 120187876
# Inspecting node 178544594
# Inspecting node 2838327755
# Inspecting node 1559780652
# Inspecting node 2291354802
# Inspecting node 1352707350784659456
# Inspecting node 1417352097150816256
# Inspecting node 1427768108614291465
# Inspecting node 1117485007944048640
# Inspecting node 1297264458
# Inspecting node 1194794785762004993
# Inspecting node 26089782
# Inspecting node 1446289055935864836
# Inspecting node 412499776
# Inspecting node 416476088
# Inspecting node 1028871362499305473
# Inspecting node 1438317451469541377
# Inspecting node 546527413
# Inspecting node 1323421765658431488
# Inspecting node 280677070
# Inspecting node 2332742508
# Inspecting node 1347272097786171394
# Inspecting node 2344419362
# Inspecting node 252150132
# Inspecting node 4787666543
# Inspecting node 1454456569
# Inspecting node 587733016
# Inspecting node 823265236916416512
# Inspecting node 1168589910825213952
# Inspecting node 753744536887824385
# Inspecting node 119925381
# Inspecting node 1269692602204532738
# Inspecting node 853722212741898240
# Inspecting node 43089397
# Inspecting node 2323751900
# Inspecting node 1213405462021853185
# Inspecting node 2937436849
# Inspecting node 272250877
# Inspecting node 1406573892
# Inspecting node 1942107584
# Inspecting node 2678072299
# Inspecting node 86384661
# Inspecting node 2983179809
# Inspecting node 3188558830
# Inspecting node 2874772780
# Inspecting node 222386937
# Inspecting node 261788602
# Inspecting node 292468351
# Inspecting node 22849568
# Inspecting node 1203545123356839936
# Inspecting node 19893907
# Inspecting node 1729880688
# Inspecting node 1361500715659755520
# Inspecting node 700287952
# Inspecting node 169268197
# Inspecting node 18622393
# Inspecting node 1304185921433227264
# Inspecting node 97121931
# Inspecting node 1699266222
# Inspecting node 729194378779078656
# Inspecting node 2752659114
# Inspecting node 373460084
# Inspecting node 908018227040710656
# Inspecting node 245149238
# Inspecting node 3242606862
# Inspecting node 29891001
# Inspecting node 720579941184757760
# Inspecting node 276713213
# Inspecting node 1424060815947206662
# Inspecting node 609432652
# Inspecting node 38625077
# Inspecting node 234550882
# Inspecting node 408072407
# Inspecting node 1427258589077508100
# Inspecting node 2242940071
# Inspecting node 44171755
# Inspecting node 41043869
# Inspecting node 436087744
# Inspecting node 578640179
# Inspecting node 132210296
# Inspecting node 923683393
# Inspecting node 1245003009555419137
# Inspecting node 1267504449087553539
# Inspecting node 65666257
# Inspecting node 407943040
# Inspecting node 240908125
# Inspecting node 1057988206963056640
# Inspecting node 130857133
# Inspecting node 1441410998355726344
# Inspecting node 24819740
# Inspecting node 1412813687811760135
# Inspecting node 2762829798
# Inspecting node 1317417438640697344
# Inspecting node 1185990712132812800
# Inspecting node 711980580813066240
# Inspecting node 3237884919
# Inspecting node 9455112
# Inspecting node 19198775
# Inspecting node 22630846
# Inspecting node 1434341584670273544
# Inspecting node 844292741077061632
# Inspecting node 1300624324206817280
# Inspecting node 1332164996592066561
# Inspecting node 337816824
# Inspecting node 153798495
# Inspecting node 1249204176548245504
# Inspecting node 3092462976
# Inspecting node 547671992
# Inspecting node 151547845
# Inspecting node 23554969
# Inspecting node 1314208704
# Inspecting node 808450734240972800
# Inspecting node 204846220
# Inspecting node 19478009
# Inspecting node 18940341
# Inspecting node 62292631
# Inspecting node 1239692519094575104
# Inspecting node 64261339
# Inspecting node 271989352
# Inspecting node 66334416
# Inspecting node 756584190112591872
# Inspecting node 24459228
# Inspecting node 771870952544096257
# Inspecting node 1242251887
# Inspecting node 15908286
# Inspecting node 1390840055200108546
# Inspecting node 2408260398
# Inspecting node 488067802
# Inspecting node 1511667030
# Inspecting node 579614622
# Inspecting node 728304522662043648
# Inspecting node 1092960066
# Inspecting node 64099329
# Inspecting node 1393055510480441345
# Inspecting node 2555583872
# Inspecting node 2452465303
# Inspecting node 282526718
# Inspecting node 4298769753
# Inspecting node 572827030
# Inspecting node 1414623993529880576
# Inspecting node 1255927911045095425
# Inspecting node 1373016955
# Inspecting node 2720800274
# Inspecting node 57661541
# Inspecting node 708739471
# Inspecting node 722623738672517120
# Inspecting node 157591483
# Inspecting node 1390378070482165763
# Inspecting node 2707780448
# Inspecting node 898554931271127042
# Inspecting node 525857359
# Inspecting node 2536457582
# Inspecting node 19634262
# Inspecting node 1357304889831878657
# Inspecting node 1243221104560345090
# Inspecting node 431141725
# Inspecting node 1244435052
# Inspecting node 159655782
# Inspecting node 382223500
# Inspecting node 535452718
# Inspecting node 1293199610178080775
# Inspecting node 12923812
# Inspecting node 16272844
# Inspecting node 335769776
# Inspecting node 16279532
# Inspecting node 3358671
# Inspecting node 16180205
# Inspecting node 2322580746
# Inspecting node 171115367
# Inspecting node 208750527
# Inspecting node 240786249
# Inspecting node 3257047456
# Inspecting node 500232993
# Inspecting node 1171073846335721472
# Inspecting node 1304472952482783232
# Inspecting node 1072270926
# Inspecting node 2789770741
# Inspecting node 2327530022
# Inspecting node 1002181382
# Inspecting node 47692251
# Inspecting node 743129088
# Inspecting node 271073165
# Inspecting node 1895316878
# Inspecting node 631988630
# Inspecting node 290162716
# Inspecting node 2229187188
# Inspecting node 274507495
# Inspecting node 417524720
# Inspecting node 415774799
# Inspecting node 579377522
# Inspecting node 32915303
# Inspecting node 245954929
# Inspecting node 170377354
# Inspecting node 1390883714
# Inspecting node 3363252329
# Inspecting node 1143342270399373313
# Inspecting node 272185225
# Inspecting node 1144289639924207616
# Inspecting node 43510607
# Inspecting node 524557553
# Inspecting node 256775505
# Inspecting node 493488747
# Inspecting node 868245382148521984
# Inspecting node 1170770038208565248
# Inspecting node 339752726
# Inspecting node 249221867
# Inspecting node 488052222
# Inspecting node 911471588
# Inspecting node 246466184
# Inspecting node 280552762
# Inspecting node 295951367
# Inspecting node 973087261
# Inspecting node 1321710295245447169
# Inspecting node 48369926
# Inspecting node 1438956476588957701
# Inspecting node 385008014
# Inspecting node 918152297544380417
# Inspecting node 33562561
# Inspecting node 987136895162384384
# Inspecting node 1327442450957303809
# Inspecting node 870473605473198080
# Inspecting node 35337644
# Inspecting node 1103832363363127297
# Inspecting node 1243323314652602368
# Inspecting node 1268045786312593408
# Inspecting node 17355421
# Inspecting node 24348660
# Inspecting node 14247924
# Inspecting node 106512310
# Inspecting node 1269254845615095810
# Inspecting node 1219578234
# Inspecting node 1380813355
# Inspecting node 883334379023597568
# Inspecting node 58878834
# Inspecting node 912346683291389953
# Inspecting node 3179475258
# Inspecting node 245939022
# Inspecting node 363654070
# Inspecting node 3071603495
# Inspecting node 573788425
# Inspecting node 878490462
# Inspecting node 1423385158263132168
# Inspecting node 1268728504964825088
# Inspecting node 46894332
# Inspecting node 136160953
# Inspecting node 107218304
# Inspecting node 73411833
# Inspecting node 1405971529217740812
# Inspecting node 1275123310788063233
# Inspecting node 1173035282461089793
# Inspecting node 1445090669643517961
# Inspecting node 1389241812276023296
# Inspecting node 501994958
# Inspecting node 2799175653
# Inspecting node 1429555219457773581
# Inspecting node 1668333199
# Inspecting node 1218019404992196609
# Inspecting node 1366204146957885445
# Inspecting node 1198972583288459265
# Inspecting node 1433247289330577408
# Inspecting node 502160853
# Inspecting node 41520537
# Inspecting node 1294478815628890112
# Inspecting node 395394840
# Inspecting node 1151704477
# Inspecting node 1044711566354960384
# Inspecting node 1271855851330916353
# Inspecting node 1497052201
# Inspecting node 975757898004549633
# Inspecting node 3245708989
# Inspecting node 1267640853000007680
# Inspecting node 29917096
# Inspecting node 245373521
# Inspecting node 1420482733135040522
# Inspecting node 1242510089145266182
# Inspecting node 28737527
# Inspecting node 1731401322
# Inspecting node 979870450577686528
# Inspecting node 1354922263418523648
# Inspecting node 24951781
# Inspecting node 15613754
# Inspecting node 100851235
# Inspecting node 59243738
# Inspecting node 17360968
# Inspecting node 360129945
# Inspecting node 1174006316412674048
# Inspecting node 21809306
# Inspecting node 1134558647835430912
# Inspecting node 855478711
# Inspecting node 25178951
# Inspecting node 52350953
# Inspecting node 20796969
# Inspecting node 55158039
# Inspecting node 1401659310015397889
# Inspecting node 215896862
# Inspecting node 4540976253
# Inspecting node 56016987
# Inspecting node 1357857933019598849
# Inspecting node 1125841354716696576
# Inspecting node 793343793642680320
# Inspecting node 48219360
# Inspecting node 399184212
# Inspecting node 827222807121637377
# Inspecting node 1138228267
# Inspecting node 1671821988
# Inspecting node 2321539819
# Inspecting node 17969963
# Inspecting node 1337935917298962434
# Inspecting node 1055170328442224641
# Inspecting node 325805788
# Inspecting node 1128406689802276865
# Inspecting node 1560811022
# Inspecting node 1264568784318345218
# Inspecting node 254240108
# Inspecting node 2237957942
# Inspecting node 387828045
# Inspecting node 3355188729
# Inspecting node 1483945802
# Inspecting node 1663608300
# Inspecting node 1335613030852386817
# Inspecting node 2678629590
# Inspecting node 884681534
# Inspecting node 420536762
# Inspecting node 4329525312
# Inspecting node 1547244656
# Inspecting node 109341612
# Inspecting node 108689047
# Inspecting node 1223265601147342848
# Inspecting node 297968019
# Inspecting node 183758895
# Inspecting node 45932749
# Inspecting node 418786259
# Inspecting node 70240459
# Inspecting node 1606592767
# Inspecting node 1047167241119326211
# Inspecting node 978673214283853825
# Inspecting node 17136419
# Inspecting node 1242152485
# Inspecting node 4445748801
# Inspecting node 1413908511461945350
# Inspecting node 1314819918328729600
# Inspecting node 1140532022
# Inspecting node 1200932043544117248
# Inspecting node 3109560272
# Inspecting node 162924629
# Inspecting node 182072629
# Inspecting node 980237238
# Inspecting node 1213189717425917953
# Inspecting node 2800741820
# Inspecting node 19135439
# Inspecting node 967241034873933824
# Inspecting node 3236492411
# Inspecting node 1235422076082589696
# Inspecting node 534591437
# Inspecting node 1454880680
# Inspecting node 1069754111078354948
# Inspecting node 2286750115
# Inspecting node 1375862610
# Inspecting node 26071396
# Inspecting node 375764669
# Inspecting node 1833674827
# Inspecting node 392380645
# Inspecting node 769165632738762752
# Inspecting node 989311745100566529
# Inspecting node 256552850
# Inspecting node 2218371769
# Inspecting node 29721598
# Inspecting node 1008103433822351360
# Inspecting node 1214027006242742273
# Inspecting node 142107502
# Inspecting node 1314568089300873216
# Inspecting node 801218452618956800
# Inspecting node 1330675961839443973
# Inspecting node 1441448795921952768
# Inspecting node 102491634
# Inspecting node 24978284
# Inspecting node 36988268
# Inspecting node 712792479729192960
# Inspecting node 890560416526594048
# Inspecting node 1413820603
# Inspecting node 37044121
# Inspecting node 832619717785329664
# Inspecting node 1171471512085389312
# Inspecting node 61542328
# Inspecting node 494320156
# Inspecting node 13716572
# Inspecting node 1017461230984990720
# Inspecting node 25703839
# Inspecting node 363666493
# Inspecting node 975491119734763522
# Inspecting node 61888526
# Inspecting node 2502596130
# Inspecting node 763867259777519618
# Inspecting node 1185294078256254977
# Inspecting node 1296424847149588483
# Inspecting node 2721515522
# Inspecting node 224600898
# Inspecting node 524785211
# Inspecting node 777617628009332736
# Inspecting node 189341190
# Inspecting node 2451955022
# Inspecting node 835061048533082113
# Inspecting node 248022226
# Inspecting node 2988258574
# Inspecting node 1001287095472873473
# Inspecting node 1182252711833718784
# Inspecting node 1861048644
# Inspecting node 2842385693
# Inspecting node 248065960
# Inspecting node 931882614
# Inspecting node 3290783049
# Inspecting node 359260523
# Inspecting node 16116228
# Inspecting node 243912778
# Inspecting node 2439108320
# Inspecting node 1176536298179284993
# Inspecting node 297771685
# Inspecting node 1128366660128260097
# Inspecting node 222987791
# Inspecting node 18597273
# Inspecting node 577727470
# Inspecting node 112767813
# Inspecting node 116837959
# Inspecting node 83712358
# Inspecting node 486703473
# Inspecting node 67758676
# Inspecting node 20346252
# Inspecting node 420560195
# Inspecting node 3153084524
# Inspecting node 1308040042724519939
# Inspecting node 1182947209
# Inspecting node 1258576501
# Inspecting node 213140093
# Inspecting node 225067116
# Inspecting node 18340314
# Inspecting node 1310724884008321028
# Inspecting node 160429871
# Inspecting node 214530013
# Inspecting node 110504574
# Inspecting node 24692082
# Inspecting node 16422863
# Inspecting node 1650588223
# Inspecting node 1548315212
# Inspecting node 1378038493105037320
# Inspecting node 4731285264
# Inspecting node 1260770767123312640
# Inspecting node 1260759194833006593
# Inspecting node 975784752648212480
# Inspecting node 2367303485
# Inspecting node 1346317368637603841
# Inspecting node 1426665402147360769
# Inspecting node 1024397417423106048
# Inspecting node 776153719675072512
# Inspecting node 787738985481240576
# Inspecting node 911264470210682880
# Inspecting node 1005823371144318977
# Inspecting node 1416921060788801539
# Inspecting node 17174462
# Inspecting node 1214396742
# Inspecting node 2379113581
# Inspecting node 1426711288462417921
# Inspecting node 21426717
# Inspecting node 975519759105060864
# Inspecting node 2394842400
# Inspecting node 1430196796781912066
# Inspecting node 1433249159474200577
# Inspecting node 20467453
# Inspecting node 1353457212799262720
# Inspecting node 877710910780985345
# Inspecting node 1413615091224924164
# Inspecting node 739208182837321729
# Inspecting node 16545084
# Inspecting node 1234968032734216193
# Inspecting node 979741136725184512
# Inspecting node 509604564
# Inspecting node 731972892
# Inspecting node 1357259774
# Inspecting node 308032537
# Inspecting node 782939425
# Inspecting node 824028437568438277
# Inspecting node 1255919262998441987
# Inspecting node 1291405539046457345
# Inspecting node 1306024583858917376
# Inspecting node 578272027
# Inspecting node 294660973
# Inspecting node 1212202179777331200
# Inspecting node 21632185
# Inspecting node 1227080599451701249
# Inspecting node 2906452022
# Inspecting node 1298675867061805056
# Inspecting node 15128653
# Inspecting node 820499790
# Inspecting node 1238950146559352834
# Inspecting node 1854934933
# Inspecting node 1444459015875014657
# Inspecting node 147340782
# Inspecting node 15677734
# Inspecting node 195207470
# Inspecting node 1282074147884015616
# Inspecting node 977009074217795584
# Inspecting node 3331283445
# Inspecting node 826085293677748224
# Inspecting node 1355980761443217415
# Inspecting node 92256613
# Inspecting node 1278822500143677442
# Inspecting node 187257177
# Inspecting node 902402049022808064
# Inspecting node 1694247541
# Inspecting node 403374868
# Inspecting node 42142250
# Inspecting node 4856189107
# Inspecting node 483313162
# Inspecting node 2427741792
# Inspecting node 2174574218
# Inspecting node 3831737053
# Inspecting node 892123934119927809
# Inspecting node 3660694460
# Inspecting node 3298660936
# Inspecting node 3289694144
# Inspecting node 459311957
# Inspecting node 33456207
# Inspecting node 144036263
# Inspecting node 1049412181559787521
# Inspecting node 826499437585371136
# Inspecting node 540672851
# Inspecting node 1444511517379026948
# Inspecting node 1023207519060197383
# Inspecting node 22532501
# Inspecting node 1067386991250206721
# Inspecting node 2800244863
# Inspecting node 92736596
# Inspecting node 1225489734178344962
# Inspecting node 66621998
# Inspecting node 1059573444214439937
# Inspecting node 1442259927779532808
# Inspecting node 751872198961487872
# Inspecting node 1190792680877559810
# Inspecting node 147981741
# Inspecting node 3158178364
# Inspecting node 1198789568214044672
# Inspecting node 1118222712818868229
# Inspecting node 1296542987850113024
# Inspecting node 1294643635397550080
# Inspecting node 920714531537481729
# Inspecting node 779333693936721920
# Inspecting node 49707487
# Inspecting node 1424936529621774338
# Inspecting node 1129198217164234753
# Inspecting node 1366519801997193216
# Inspecting node 32235586
# Inspecting node 44674554
# Inspecting node 224063162
# Inspecting node 369093
# Inspecting node 2883808867
# Inspecting node 292524345
# Inspecting node 22968164
# Inspecting node 1001274194443821064
# Inspecting node 15054416
# Inspecting node 21400756
# Inspecting node 4860164601
# Inspecting node 467804527
# Inspecting node 958181344286269440
# Inspecting node 778262568272027648
# Inspecting node 38929865
# Inspecting node 297074777
# Inspecting node 760353522718081026
# Inspecting node 928262146542026752
# Inspecting node 160673089
# Inspecting node 175939051
# Inspecting node 1187760523829563392
# Inspecting node 78429753
# Inspecting node 4722097454
# Inspecting node 1070001735454875648
# Inspecting node 35728556
# Inspecting node 1402352323851083779
# Inspecting node 1097176821622284289
# Inspecting node 150699925
# Inspecting node 1060278863874478080
# Inspecting node 813073081761570816
# Inspecting node 722880943380242432
# Inspecting node 14960142
# Inspecting node 1346936882
# Inspecting node 1073283389288005632
# Inspecting node 1297250167
# Inspecting node 1322191014455554048
# Inspecting node 1357200256618795008
# Inspecting node 16504074
# Inspecting node 158100294
# Inspecting node 817811639516991488
# Inspecting node 824357739501531136
# Inspecting node 268237247
# Inspecting node 21815663
# Inspecting node 318420941
# Inspecting node 341180420
# Inspecting node 2267952750
# Inspecting node 454336947
# Inspecting node 725309237862223872
# Inspecting node 353903334
# Inspecting node 2247798150
# Inspecting node 489749588
# Inspecting node 4819639768
# Inspecting node 1330218727
# Inspecting node 1481076481
# Inspecting node 2479224015
# Inspecting node 563152589
# Inspecting node 1317418116
# Inspecting node 1350924172554366979
# Inspecting node 23101207
# Inspecting node 1357917347181453312
# Inspecting node 721401357
# Inspecting node 2926114316
# Inspecting node 968303534822313984
# Inspecting node 77035084
# Inspecting node 85859978
# Inspecting node 2720749324
# Inspecting node 734095130
# Inspecting node 3257661611
# Inspecting node 1219432023044939776
# Inspecting node 998712356
# Inspecting node 603662056
# Inspecting node 4729460081
# Inspecting node 188565420
# Inspecting node 2534622463
# Inspecting node 165020784
# Inspecting node 84704052
# Inspecting node 4273980252
# Inspecting node 29256016
# Inspecting node 577968691
# Inspecting node 845271811097055234
# Inspecting node 470780364
# Inspecting node 22531935
# Inspecting node 59829657
# Inspecting node 275735174
# Inspecting node 559870034
# Inspecting node 7491592
# Inspecting node 23282993
# Inspecting node 2411078349
# Inspecting node 4148412316
# Inspecting node 73199415
# Inspecting node 366968661
# Inspecting node 341653196
# Inspecting node 605379442
# Inspecting node 28045785
# Inspecting node 40216513
# Inspecting node 925675836526776321
# Inspecting node 1080965055007592456
# Inspecting node 1032507164
# Inspecting node 820730609043505152
# Inspecting node 495401684
# Inspecting node 29904143
# Inspecting node 365563514
# Inspecting node 1142295084572073985
# Inspecting node 23522098
# Inspecting node 624251860
# Inspecting node 80212065
# Inspecting node 2829798301
# Inspecting node 1390067256080621568
# Inspecting node 38878429
# Inspecting node 2801061205
# Inspecting node 935335003084423168
# Inspecting node 622885791
# Inspecting node 1112914064076931072
# Inspecting node 384288098
# Inspecting node 515847342
# Inspecting node 3111765339
# Inspecting node 3419010088
# Inspecting node 571519594
# Inspecting node 935697022400602112
# Inspecting node 349692386
# Inspecting node 1223950760
# Inspecting node 3341414159
# Inspecting node 1382336580518621186
# Inspecting node 3142614406
# Inspecting node 731469980890476545
# Inspecting node 58340767
# Inspecting node 266653082
# Inspecting node 2853989866
# Inspecting node 3607702640
# Inspecting node 1421968442
# Inspecting node 297986745
# Inspecting node 54042169
# Inspecting node 577170668
# Inspecting node 880108852162707456
# Inspecting node 1380189591735517190
# Inspecting node 35051540
# Inspecting node 1074335960
# Inspecting node 1371923720609095686
# Inspecting node 1280972258
# Inspecting node 491697655
# Inspecting node 2651576688
# Inspecting node 1117035592565628928
# Inspecting node 163922710
# Inspecting node 1286102971974025217
# Inspecting node 2620272561
# Inspecting node 52516962
# Inspecting node 1065829609
# Inspecting node 1437800221375963143
# Inspecting node 1247541393121087495
# Inspecting node 892060639526395904
# Inspecting node 543143031
# Inspecting node 124878802
# Inspecting node 1341618252
# Inspecting node 727897637098135552
# Inspecting node 14221144
# Inspecting node 950848085802004480
# Inspecting node 16267310
# Inspecting node 2262304373
# Inspecting node 727519870590541824
# Inspecting node 92551736
# Inspecting node 3438124552
# Inspecting node 2749373577
# Inspecting node 535799622
# Inspecting node 1354038378640134145
# Inspecting node 1239698227739459584
# Inspecting node 196164822
# Inspecting node 3075929388
# Inspecting node 1212777267169873920
# Inspecting node 140253506
# Inspecting node 1571464364
# Inspecting node 37609730
# Inspecting node 1396338835596795904
# Inspecting node 1069734050301128705
# Inspecting node 1581712848
# Inspecting node 3268565808
# Inspecting node 786738726466707460
# Inspecting node 1115838887623122954
# Inspecting node 1498327201
# Inspecting node 1316013080250216453
# Inspecting node 957808962983755776
# Inspecting node 2727310657
# Inspecting node 2353185104
# Inspecting node 992390491105882112
# Inspecting node 1133696644422275072
# Inspecting node 3087811674
# Inspecting node 2151893489
# Inspecting node 904365258399244288
# Inspecting node 1393384383650975744
# Inspecting node 707364896153980928
# Inspecting node 371739649
# Inspecting node 1203817853494779904
# Inspecting node 1081036726758531072
# Inspecting node 2968424080
# Inspecting node 2151613567
# Inspecting node 198927392
# Inspecting node 951527727365988352
# Inspecting node 1093890667909124100
# Inspecting node 593891991
# Inspecting node 4850122813
# Inspecting node 872152901870911489
# Inspecting node 878242924567441408
# Inspecting node 1335043297
# Inspecting node 725731648017424385
# Inspecting node 1198351736
# Inspecting node 26557104
# Inspecting node 1042821954821087232
# Inspecting node 1428826266
# Inspecting node 2831610879
# Inspecting node 4681656433
# Inspecting node 775279674
# Inspecting node 596787864
# Inspecting node 273262205
# Inspecting node 24990450
# Inspecting node 342699819
# Inspecting node 378321467
# Inspecting node 217485938
# Inspecting node 967837552425119744
# Inspecting node 18579611
# Inspecting node 16811701
# Inspecting node 63476527
# Inspecting node 17442269
# Inspecting node 1366423551704784897
# Inspecting node 1070588953105969152
# Inspecting node 119911112
# Inspecting node 145878023
# Inspecting node 28540616
# Inspecting node 17050123
# Inspecting node 1432002021398306821
# Inspecting node 930479718
# Inspecting node 2341257349
# Inspecting node 587087289
# Inspecting node 708990479895896066
# Inspecting node 566196508
# Inspecting node 1019405015855878144
# Inspecting node 1275466513529671681
# Inspecting node 1347609010434953217
# Inspecting node 1419539298
# Inspecting node 57527830
# Inspecting node 24752425
# Inspecting node 29586080
# Inspecting node 1250609616192446466
# Inspecting node 2589728724
# Inspecting node 7922582
# Inspecting node 1124423281765797888
# Inspecting node 1077139237
# Inspecting node 199876983
# Inspecting node 18680879
# Inspecting node 380327126
# Inspecting node 3139690604
# Inspecting node 282111410
# Inspecting node 273727399
# Inspecting node 703722876
# Inspecting node 3357096478
# Inspecting node 838912397066846208
# Inspecting node 1437539837477748738
# Inspecting node 751919973497384962
# Inspecting node 1404491652580843525
# Inspecting node 1067154574278971392
# Inspecting node 576365948
# Inspecting node 31513326
# Inspecting node 1297575021578256388
# Inspecting node 1233196108211294209
# Inspecting node 19359977
# Inspecting node 745800926
# Inspecting node 2448257995
# Inspecting node 839668692866723840
# Inspecting node 15023001
# Inspecting node 30270072
# Inspecting node 17929195
# Inspecting node 385678932
# Inspecting node 1065257588151996422
# Inspecting node 1687712964
# Inspecting node 1345709200618389504
# Inspecting node 224737149
# Inspecting node 373940903
# Inspecting node 6013662
# Inspecting node 907302868645953537
# Inspecting node 1243336421164732416
# Inspecting node 240831038
# Inspecting node 290312086
# Inspecting node 4026420858
# Inspecting node 540103190
# Inspecting node 248866864
# Inspecting node 148618115
# Inspecting node 83307703
# Inspecting node 918318518
# Inspecting node 21166754
# Inspecting node 493604178
# Inspecting node 1222274097935073281
# Inspecting node 336662190
# Inspecting node 1254832256
# Inspecting node 65917423
# Inspecting node 15257975
# Inspecting node 18148460
# Inspecting node 168350399
# Inspecting node 18457918
# Inspecting node 165890739
# Inspecting node 1380663772906356737
# Inspecting node 554805867
# Inspecting node 1344041868779110400
# Inspecting node 373667686
# Inspecting node 1261311256151183362
# Inspecting node 1116067546778628097
# Inspecting node 1416035013502685184
# Inspecting node 24313572
# Inspecting node 1144704604442988544
# Inspecting node 222126993
# Inspecting node 2655180373
# Inspecting node 887262626
# Inspecting node 3131039404
# Inspecting node 249386982
# Inspecting node 4759974372
# Inspecting node 494732315
# Inspecting node 1405037853579436035
# Inspecting node 15049380
# Inspecting node 396149168
# Inspecting node 977021137
# Inspecting node 3320688247
# Inspecting node 880997516
# Inspecting node 264439847
# Inspecting node 1068193791511678977
# Inspecting node 636649732
# Inspecting node 14837621
# Inspecting node 596793900
# Inspecting node 4767685428
# Inspecting node 1407536941680279552
# Inspecting node 717895042602504192
# Inspecting node 52245251
# Inspecting node 2574056066
# Inspecting node 35476624
# Inspecting node 48035511
# Inspecting node 207677544
# Inspecting node 56029187
# Inspecting node 3306930701
# Inspecting node 1177657984220053506
# Inspecting node 165971686
# Inspecting node 758042170968375296
# Inspecting node 242492168
# Inspecting node 27460814
# Inspecting node 1231982311253708803
# Inspecting node 2533511951
# Inspecting node 3317590829
# Inspecting node 2416130503
# Inspecting node 724952267162542080
# Inspecting node 22491454
# Inspecting node 3029210380
# Inspecting node 2157300561
# Inspecting node 1053529093285785601
# Inspecting node 1130348139607576576
# Inspecting node 1232835905616011264
# Inspecting node 2922358250
# Inspecting node 1001986308343033856
# Inspecting node 1022679197976678400
# Inspecting node 2560632538
# Inspecting node 1317802041423646720
# Inspecting node 884265045479313408
# Inspecting node 1229474724142604288
# Inspecting node 486317915
# Inspecting node 235070820
# Inspecting node 755749623491244032
# Inspecting node 32189160
# Inspecting node 416468980
# Inspecting node 1051556700
# Inspecting node 1171534270168367105
# Inspecting node 23370368
# Inspecting node 1399510991885455362
# Inspecting node 1438462388647440386
# Inspecting node 214708464
# Inspecting node 547747984
# Inspecting node 366117993
# Inspecting node 262910171
# Inspecting node 1416997300199641091
# Inspecting node 24707528
# Inspecting node 521255914
# Inspecting node 1267810083389480963
# Inspecting node 165587758
# Inspecting node 1398595872187830274
# Inspecting node 1392128666998542337
# Inspecting node 2612807188
# Inspecting node 2652768953
# Inspecting node 292728050
# Inspecting node 96450418
# Inspecting node 2811765535
# Inspecting node 45010284
# Inspecting node 128290965
# Inspecting node 1088791968451313665
# Inspecting node 268573963
# Inspecting node 41089713
# Inspecting node 55841183
# Inspecting node 1419998048562909204
# Inspecting node 2969192164
# Inspecting node 1338252288
# Inspecting node 887732866423173125
# Inspecting node 39268708
# Inspecting node 995530035892121601
# Inspecting node 2694473137
# Inspecting node 421830937
# Inspecting node 1097531188338552832
# Inspecting node 64514213
# Inspecting node 67254536
# Inspecting node 1191423138954981382
# Inspecting node 244328935
# Inspecting node 15782904
# Inspecting node 147965270
# Inspecting node 2944338467
# ...
# Inspecting node 1411006381117919235
# Inspecting node 84353854
# Inspecting node 1446920962671185920
# Inspecting node 1365798226717151233
# Inspecting node 281811081
# Inspecting node 1406365981329346565
# Inspecting node 65767300
# Inspecting node 3011968549
# Inspecting node 1438896900070117381
# Inspecting node 547245887
# Inspecting node 1615902452
# Inspecting node 38885578
# Inspecting node 948223698649124870
# Inspecting node 1242785654368382979
# Inspecting node 3145151881
# Inspecting node 1148750306634883077
# Inspecting node 40109301
# Inspecting node 895679481720872960
# Inspecting node 2966914766
# Inspecting node 1347952445985497088
# Inspecting node 922806178446327809
# Inspecting node 131591657
# Inspecting node 1374005511495028737
# Inspecting node 408241959
# Inspecting node 809552357763661824
# Inspecting node 1556631295
# Inspecting node 282728904
# Inspecting node 785667382224293888
# Inspecting node 1013808600
# Inspecting node 16271356
# Inspecting node 4762708393
# Inspecting node 2167166754
# Inspecting node 517098546
# Inspecting node 886380609026785280
# Inspecting node 2869430815
# Inspecting node 937525764
# Inspecting node 981670040062779392
# Inspecting node 909852173479104512
# Inspecting node 220518078
# Inspecting node 226666386
# Inspecting node 288515399
# Inspecting node 220871206
# Inspecting node 17394737
# Inspecting node 85688497
# Inspecting node 85625597
# Inspecting node 32611097
# Inspecting node 1144689874424999937
# Inspecting node 2465329364
# Inspecting node 149701807
# Inspecting node 26186692
# Inspecting node 23371273
# Inspecting node 3015944460
# Inspecting node 760257132675600386
# Inspecting node 730797462991065088
# Inspecting node 771466526348107776
# Inspecting node 45950539
# Inspecting node 1160209698
# Inspecting node 1109141736972939264
# Inspecting node 169237647
# Inspecting node 1145662294849990656
# Inspecting node 78641250
# Inspecting node 821066393143672836
# Inspecting node 27740019
# Inspecting node 2201466604
# Inspecting node 1361822936
# Inspecting node 21108458
# Inspecting node 382935719
# Inspecting node 1252040788982169600
# Inspecting node 23937700
# Inspecting node 372577100
# Inspecting node 53807352
# Inspecting node 1177551303725240322
# Inspecting node 1252976493971595265
# Inspecting node 441289118
# Inspecting node 897094186213588992
# Inspecting node 3676427473
# Inspecting node 469671065
# Inspecting node 846920964113870848
# Inspecting node 268469213
# Inspecting node 24573102
# Inspecting node 16170023
# Inspecting node 2458783644
# Inspecting node 258405050
# Inspecting node 301144504
# Inspecting node 495918203
# Inspecting node 1239567083404292097
# Inspecting node 536853804
# Inspecting node 250839952
# Inspecting node 856686343144955904
# Inspecting node 981229378825801728
# Inspecting node 1335769353124343808
# Inspecting node 54650770
# Inspecting node 1691207420
# Inspecting node 479862010
# Inspecting node 702598323958620163
# Inspecting node 1197864396
# Inspecting node 272677124
# Inspecting node 54426656
# Inspecting node 1965901333
# Inspecting node 1336451673053679620
# Inspecting node 1442989306256113667
# Inspecting node 516604259
# Inspecting node 1420446766869225478
# Inspecting node 250804618
# Inspecting node 963133478
# Inspecting node 224723351
# Inspecting node 1329430334195208192
# Inspecting node 1107013222853304320
# Inspecting node 216438127
# Inspecting node 56568168
# Inspecting node 2289086672
# Inspecting node 342281222
# Inspecting node 250170548
# Inspecting node 896453296059146240
# Inspecting node 246116520
# Inspecting node 1017842910740410368
# Inspecting node 1281660648
# Inspecting node 818467340895522817
# Inspecting node 2414991108
# Inspecting node 2579229572
# Inspecting node 2568029796
# Inspecting node 1424797446845173778
# Inspecting node 24219018
# Inspecting node 1363912931151384588
# Inspecting node 103031465
# Inspecting node 2211020226
# Inspecting node 1310374181687537664
# Inspecting node 1239007657803026432
# Inspecting node 1384893312797003781
# Inspecting node 1927067096
# Inspecting node 17670732
# Inspecting node 939007961388662784
# Inspecting node 823680319274381312
# Inspecting node 1232369847134121986
# Inspecting node 1337783599446286338
# Inspecting node 17076793
# Inspecting node 1025381606
# Inspecting node 87863020
# Inspecting node 38042361
# Inspecting node 2699710783
# Inspecting node 316245912
# Inspecting node 1375846488031432705
# Inspecting node 8820062
# Inspecting node 1396272483309862913
# Inspecting node 830585528961495040
# Inspecting node 246667561
# Inspecting node 885644906915663872
# Inspecting node 375303344
# Inspecting node 1147137986431258624
# Inspecting node 1171095411307753472
# Inspecting node 18418465
# Inspecting node 590154066
# Inspecting node 59835490
# Inspecting node 1705708466
# Inspecting node 1041561337
# Inspecting node 1486136467
# Inspecting node 2807874943
# Inspecting node 17221430
# Inspecting node 1205581352
# Inspecting node 79121813
# Inspecting node 389705011
# Inspecting node 2190688044
# Inspecting node 715394299207090179
# Inspecting node 1382439377406722048
# Inspecting node 1199890847954882560
# Inspecting node 246380006
# Inspecting node 3179422780
# Inspecting node 36471917
# Inspecting node 23424817
# Inspecting node 9814812
# Inspecting node 840697793618550787
# Inspecting node 730780438269206528
# Inspecting node 294539923
# Inspecting node 1279157580799983617
# Inspecting node 403643684
# Inspecting node 53452624
# Inspecting node 2466115268
# Inspecting node 278882082
# Inspecting node 7562042
# Inspecting node 2395405134
# Inspecting node 18163138
# Inspecting node 865300797130764288
# Inspecting node 1287896006550589442
# Inspecting node 59342468
# Inspecting node 2886941025
# Inspecting node 962424351596281856
# Inspecting node 560765411
# Inspecting node 2924898800
# Inspecting node 1218987476112543744
# Inspecting node 2710528980
# Inspecting node 279748443
# Inspecting node 17702445
# Inspecting node 842121813278752768
# Inspecting node 327394273
# Inspecting node 1012406984719470592
# Inspecting node 10155832
# Inspecting node 439313680
# Inspecting node 1151231204923977729
# Inspecting node 989298765163937792
# Inspecting node 866416675
# Inspecting node 36877221
# Inspecting node 351155835
# Inspecting node 11423372
# Inspecting node 41378883
# Inspecting node 2334251844
# Inspecting node 263163489
# Inspecting node 1096251117745332226
# Inspecting node 1407372687316590594
# Inspecting node 1250830543119319042
# Inspecting node 2903614908
# Inspecting node 1351286814313738243
# Inspecting node 1403372126304866305
# Inspecting node 69712457
# Inspecting node 2730870751
# Inspecting node 16189107
# Inspecting node 414275183
# Inspecting node 393348427
# Inspecting node 248911548
# Inspecting node 34774986
# Inspecting node 1194310568200548352
# Inspecting node 1240872856508137472
# Inspecting node 242533078
# Inspecting node 78084063
# Inspecting node 42232039
# Inspecting node 41239526
# Inspecting node 3112228915
# Inspecting node 1852773120
# Inspecting node 1242517797621530625
# Inspecting node 960897097
# Inspecting node 185290543
# Inspecting node 305945328
# Inspecting node 155777848
# Inspecting node 248891184
# Inspecting node 1357931292
# Inspecting node 1582129344
# Inspecting node 63863473
# Inspecting node 744530425
# Inspecting node 1367957858
# Inspecting node 2469606308
# Inspecting node 326461319
# Inspecting node 529665584
# Inspecting node 154271777
# Inspecting node 1270383308
# Inspecting node 2312086998
# Inspecting node 1447429249
# Inspecting node 2861279433
# Inspecting node 466832463
# Inspecting node 67278150
# Inspecting node 1660911480
# Inspecting node 467664297
# Inspecting node 2573566824
# Inspecting node 132989977
# Inspecting node 954431291629473794
# Inspecting node 238865666
# Inspecting node 2569323896
# Inspecting node 788806262045732864
# Inspecting node 14165217
# Inspecting node 1447951549
# Inspecting node 1594767902
# Inspecting node 491779798
# Inspecting node 946092660795744256
# Inspecting node 74211986
# Inspecting node 524590563
# Inspecting node 1338157627453427713
# Inspecting node 823317383838253056
# Inspecting node 1044778781230039042
# Inspecting node 922963142300143616
# Inspecting node 74937543
# Inspecting node 1305697758
# Inspecting node 18463733
# Inspecting node 76264942
# Inspecting node 2905252436
# Inspecting node 44539994
# Inspecting node 396745864
# Inspecting node 1176801
# Inspecting node 1229442788623818752
# Inspecting node 2993775174
# Inspecting node 2462641501
# Inspecting node 560903736
# Inspecting node 1427351911410257934
# Inspecting node 245651739
# Inspecting node 4922698441
# Inspecting node 4024032261
# Inspecting node 15099646
# Inspecting node 75841164
# Inspecting node 794664236
# Inspecting node 1440828246132596736
# Inspecting node 3069762388
# Inspecting node 700994268
# Inspecting node 1104945319
# Inspecting node 38221378
# Inspecting node 3218932860
# Inspecting node 1201882182
# Inspecting node 1395092719
# Inspecting node 2871728962
# Inspecting node 815428708144218112
# Inspecting node 976143225927839744
# Inspecting node 727212809948401664
# Inspecting node 1373435309782822912
# Inspecting node 568769809
# Inspecting node 982017242354388992
# Inspecting node 36395646
# Inspecting node 40697478
# Inspecting node 1423672567869624322
# Inspecting node 164368721
# Inspecting node 46214091
# Inspecting node 2194496264
# Inspecting node 1057723606027792385
# Inspecting node 25209036
# Inspecting node 1347801793930035200
# Inspecting node 868994263
# Inspecting node 117589552
# Inspecting node 1080529497152278528
# Inspecting node 624962704
# Inspecting node 47022386
# Inspecting node 942370814
# Inspecting node 70499348
# Inspecting node 929856990934790144
# Inspecting node 314093378
# Inspecting node 3053107588
# Inspecting node 1459578954
# Inspecting node 4880637512
# Inspecting node 1932563430
# Inspecting node 1282257536
# Inspecting node 17300548
# Inspecting node 1236439017433989122
# Inspecting node 1444458812614709250
# Inspecting node 1386793782683652096
# Inspecting node 9575562
# Inspecting node 120139457
# Inspecting node 1240478580510871552
# Inspecting node 117562974
# Inspecting node 312422268
# Inspecting node 1333030975681536000
# Inspecting node 1040629333210148865
# Inspecting node 252399534
# Inspecting node 2459730643
# Inspecting node 1264712331457638400
# Inspecting node 1428151019981180932
# Inspecting node 280831905
# Inspecting node 1416101066580627464
# Inspecting node 1135929275272634369
# Inspecting node 360214917
# Inspecting node 1302065426961174530
# Inspecting node 39637553
# Inspecting node 114977658
# Inspecting node 1327696892608724992
# Inspecting node 1409204814534299649
# Inspecting node 371939653
# Inspecting node 190010892
# Inspecting node 1275457555490320385
# Inspecting node 1445833073770184706
# Inspecting node 1601728627
# Inspecting node 41748110
# Inspecting node 1438198932606160901
# Inspecting node 16491468
# Inspecting node 323895654
# Inspecting node 137045661
# Inspecting node 1352682350228942848
# Inspecting node 770683230223634433
# Inspecting node 3368587707
# Inspecting node 1120673221236408320
# Inspecting node 213879574
# Inspecting node 1414982991059709954
# Inspecting node 809651491
# Inspecting node 1491487802
# Inspecting node 4886317138
# Inspecting node 14912051
# Inspecting node 915727372443414528
# Inspecting node 966560892262502400
# Inspecting node 885737117745164288
# Inspecting node 981191210705530880
# Inspecting node 341002490
# Inspecting node 1948425750
# Inspecting node 1391765775594180612
# Inspecting node 1346126893733462016
# Inspecting node 1443254711381946371
# Inspecting node 95348250
# Inspecting node 1351325172184264704
# Inspecting node 487857297
# Inspecting node 94885717
# Inspecting node 925876396878020608
# Inspecting node 15300266
# Inspecting node 1212089073323503616
# Inspecting node 239096810
# Inspecting node 1353758379160834051
# Inspecting node 24728011
# Inspecting node 85640352
# Inspecting node 1012839192253075456
# Inspecting node 1259289117805776896
# Inspecting node 1309184065
# Inspecting node 1881851268
# Inspecting node 132512731
# Inspecting node 1181627354621399040
# Inspecting node 34478789
# Inspecting node 2842764204
# Inspecting node 1034903210547277824
# Inspecting node 1202669441000996864
# Inspecting node 961989099623137280
# Inspecting node 1263895193784184832
# Inspecting node 471366697
# Inspecting node 829731473443975170
# Inspecting node 590822892
# Inspecting node 382409124
# Inspecting node 851681
# Inspecting node 870842873628864513
# Inspecting node 271124533
# Inspecting node 446471174
# Inspecting node 228477243
# Inspecting node 1202388934208172032
# Inspecting node 1060751566657867776
# Inspecting node 257304118
# Inspecting node 4096225454
# Inspecting node 216266808
# Inspecting node 159065078
# Inspecting node 1058391394681868289
# Inspecting node 428602423
# Inspecting node 823397168975409152
# Inspecting node 1345473368494104580
# Inspecting node 46563847
# Inspecting node 2444436240
# Inspecting node 1126848839594467328
# Inspecting node 1257895028724203521
# Inspecting node 277513651
# Inspecting node 1110790944821932034
# Inspecting node 1161332556312326144
# Inspecting node 1346332104234295296
# Inspecting node 165942840
# Inspecting node 259587504
# Inspecting node 1925416346
# Inspecting node 15012924
# Inspecting node 18537391
# Inspecting node 42989776
# Inspecting node 93654204
# Inspecting node 34921899
# Inspecting node 2239987934
# Inspecting node 86320422
# Inspecting node 171411616
# Inspecting node 14650213
# Inspecting node 1087961
# Inspecting node 602903529
# Inspecting node 244204227
# Inspecting node 519071482
# Inspecting node 251635353
# Inspecting node 5654722
# Inspecting node 725037770033532929
# Inspecting node 40059893
# Inspecting node 237480031
# Inspecting node 1056707817216720896
# Inspecting node 1383581104473468929
# Inspecting node 373477857
# Inspecting node 20122522
# Inspecting node 4254675664
# Inspecting node 1259345602980298753
# Inspecting node 725344413162049536
# Inspecting node 1433115420563853312
# Inspecting node 166701763
# Inspecting node 582342806
# Inspecting node 14257934
# Inspecting node 1163072647661522946
# Inspecting node 1201151072733138945
# Inspecting node 1352358388638875652
# Inspecting node 549023337
# Inspecting node 936473743387394048
# Inspecting node 437944231
# Inspecting node 400071841
# Inspecting node 637320913
# Inspecting node 19114577
# Inspecting node 70065285
# Inspecting node 1268920433086210048
# Inspecting node 1176689353885724674
# Inspecting node 460592390
# Inspecting node 2262160692
# Inspecting node 2293461198
# Inspecting node 15219830
# Inspecting node 1201532829860892673
# Inspecting node 92417373
# Inspecting node 122127786
# Inspecting node 362454062
# Inspecting node 2984610092
# Inspecting node 415126004
# Inspecting node 844452866
# Inspecting node 14501713
# Inspecting node 1258440535402065920
# Inspecting node 2254247360
# Inspecting node 104585835
# Inspecting node 1410832490701467650
# Inspecting node 365780558
# Inspecting node 21632994
# Inspecting node 1338474046095233026
# Inspecting node 1113547517105528833
# Inspecting node 293588108
# Inspecting node 1155208255066558475
# Inspecting node 22523896
# Inspecting node 3675933919
# Inspecting node 2796774360
# Inspecting node 1095219121447301120
# Inspecting node 816758120819015680
# Inspecting node 825925386110382080
# Inspecting node 1529643188
# Inspecting node 246811073
# Inspecting node 3351916392
# Inspecting node 123910630
# Inspecting node 29304563
# Inspecting node 1396107226608283649
# Inspecting node 549598823
# Inspecting node 797133264716754944
# Inspecting node 768559569891012608
# Inspecting node 1880517650
# Inspecting node 1232471924145577985
# Inspecting node 1300309398166949889
# Inspecting node 1923754400
# Inspecting node 53754232
# Inspecting node 307324209
# Inspecting node 3165242127
# Inspecting node 730826158258946050
# Inspecting node 1577656471
# Inspecting node 1214368702277308421
# Inspecting node 299993498
# Inspecting node 1235344992765448193
# Inspecting node 625193066
# Inspecting node 467817388
# Inspecting node 3135148227
# Inspecting node 872810605
# Inspecting node 271504586
# Inspecting node 306967462
# Inspecting node 3299469609
# Inspecting node 1225848216467509248
# Inspecting node 259388196
# Inspecting node 525910396
# Inspecting node 358143304
# Inspecting node 1088545656002801664
# Inspecting node 1283460034182209537
# Inspecting node 1326306504027287554
# Inspecting node 100874975
# Inspecting node 811549418
# Inspecting node 145058470
# Inspecting node 15892547
# Inspecting node 2797935107
# Inspecting node 27388441
# Inspecting node 288495993
# Inspecting node 77596220
# Inspecting node 891058415195303939
# Inspecting node 1095768409449459712
# Inspecting node 881426857
# Inspecting node 17388526

# %% [markdown]
# Okay I have confirmed Degree is being respected for these 50 models

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.in_degree(node) 
    for key, value in in_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break
# Out:
# Inspecting node 1385933370090209280
# Inspecting node 158095776
# Inspecting node 1416535505454338050
# Inspecting node 1604931252
# Inspecting node 544695802
# Inspecting node 716257068538327040
# Inspecting node 258170457
# Inspecting node 1086084557009575936
# Inspecting node 2817389862
# Inspecting node 822476228548403200
# Inspecting node 2353730881
# Inspecting node 921026239808208896
# Inspecting node 720934098223542272
# Inspecting node 2922779039
# Inspecting node 552891173
# Inspecting node 982496635
# Inspecting node 1433403537329819654
# Inspecting node 1175052073605353473
# Inspecting node 2784661153
# Inspecting node 102887506
# Inspecting node 18681111
# Inspecting node 952980338745147394
# Inspecting node 1438871779779530755
# Inspecting node 46975259
# Inspecting node 1157395568135557120
# Inspecting node 21951711
# Inspecting node 563064119
# Inspecting node 277332906
# Inspecting node 158458133
# Inspecting node 979827806023618560
# Inspecting node 18308257
# Inspecting node 846667915
# Inspecting node 258916078
# Inspecting node 1138564320390836224
# Inspecting node 17912334
# Inspecting node 2821464243
# Inspecting node 928790819145842688
# Inspecting node 753638148958216192
# Inspecting node 2256955027
# Inspecting node 1185936230393024512
# Inspecting node 14079041
# Inspecting node 3021899490
# Inspecting node 13880132
# Inspecting node 960624707820113920
# Inspecting node 52003137
# Inspecting node 1887595058
# Inspecting node 331864347
# Inspecting node 961514730
# Inspecting node 70750793
# Inspecting node 155629527
# Inspecting node 1161351506983038976
# Inspecting node 766360387
# Inspecting node 150270263
# Inspecting node 38471212
# Inspecting node 83153695
# Inspecting node 118937966
# Inspecting node 871189841186357248
# Inspecting node 293403080
# Inspecting node 629539554
# Inspecting node 1104422828
# Inspecting node 602083976
# Inspecting node 1311896805920043009
# Inspecting node 1318741345905922048
# Inspecting node 25314619
# Inspecting node 104300984
# Inspecting node 15702055
# Inspecting node 1153463878195589125
# Inspecting node 15633240
# Inspecting node 14991184
# Inspecting node 1242522201770856449
# Inspecting node 1440522413687521295
# Inspecting node 106524304
# Inspecting node 1292608204845834241
# Inspecting node 1446846657551683588
# Inspecting node 1389700907697270787
# Inspecting node 1445880242707570691
# Inspecting node 1545912997
# Inspecting node 831084798621782016
# Inspecting node 55976571
# Inspecting node 305401065
# Inspecting node 704798725747531776
# Inspecting node 47452040
# Inspecting node 475298690
# Inspecting node 16220555
# Inspecting node 4744498950
# Inspecting node 766759351973404672
# Inspecting node 47781573
# Inspecting node 994077337
# Inspecting node 14055736
# Inspecting node 1236010900693356549
# Inspecting node 1171683272
# Inspecting node 1338338931792756737
# Inspecting node 562243642
# Inspecting node 15772683
# Inspecting node 1251340447387172868
# Inspecting node 1350484767255519233
# Inspecting node 1335046616697372675
# Inspecting node 20750271
# Inspecting node 1162219997977960449
# Inspecting node 175259033
# Inspecting node 130909683
# Inspecting node 1364261390614106113
# Inspecting node 44416854
# Inspecting node 1511003670
# Inspecting node 536594609
# Inspecting node 24913022
# Inspecting node 17823761
# Inspecting node 273683993
# Inspecting node 215632349
# Inspecting node 1156602559378804741
# Inspecting node 1156033982586208256
# Inspecting node 47338701
# Inspecting node 139819609
# Inspecting node 413514250
# Inspecting node 2852899113
# Inspecting node 1381435843492085760
# Inspecting node 1189800120
# Inspecting node 138418077
# Inspecting node 382489139
# Inspecting node 374300583
# Inspecting node 3226840807
# Inspecting node 133863908
# Inspecting node 57127265
# Inspecting node 142731825
# Inspecting node 1417929933800751104
# Inspecting node 55823004
# Inspecting node 1447315781289750532
# Inspecting node 14262411
# Inspecting node 1707636642
# Inspecting node 845487573011173380
# Inspecting node 109144163
# Inspecting node 20199202
# Inspecting node 785448020628430849
# Inspecting node 77283552
# Inspecting node 38055290
# Inspecting node 34506336
# Inspecting node 242798024
# Inspecting node 138077463
# Inspecting node 121343164
# Inspecting node 814078628
# Inspecting node 196717787
# Inspecting node 18519855
# Inspecting node 268824309
# Inspecting node 2439928526
# Inspecting node 1169378542737661954
# Inspecting node 299228245
# Inspecting node 2369365718
# Inspecting node 1373493122
# Inspecting node 2834753506
# Inspecting node 999476893970763777
# Inspecting node 120320139
# Inspecting node 84734389
# Inspecting node 15407637
# Inspecting node 1899063048
# Inspecting node 1301967293849755653
# Inspecting node 324602007
# Inspecting node 292667439
# Inspecting node 522345885
# Inspecting node 12599562
# Inspecting node 4856851754
# Inspecting node 1248842158553141250
# Inspecting node 4026045455
# Inspecting node 3303438653
# Inspecting node 1129203001
# Inspecting node 2813664079
# Inspecting node 14518712
# Inspecting node 95209129
# Inspecting node 119797208
# Inspecting node 201984482
# Inspecting node 593944500
# Inspecting node 17105128
# Inspecting node 3409346380
# Inspecting node 33826892
# Inspecting node 273866823
# Inspecting node 37552089
# Inspecting node 377588094
# Inspecting node 266855812
# Inspecting node 341866567
# Inspecting node 60916234
# Inspecting node 262436837
# Inspecting node 1092244447184719873
# Inspecting node 2548489298
# Inspecting node 218952640
# Inspecting node 1382491059247255554
# Inspecting node 516915897
# Inspecting node 965028316460797953
# Inspecting node 195899568
# Inspecting node 2432750568
# Inspecting node 331067472
# Inspecting node 272133230
# Inspecting node 108413104
# Inspecting node 177347829
# Inspecting node 964446120402300928
# Inspecting node 1573418346
# Inspecting node 89496127
# Inspecting node 735508941258399744
# Inspecting node 542244178
# Inspecting node 1005899772916477952
# Inspecting node 366171300
# Inspecting node 29545977
# Inspecting node 59686058
# Inspecting node 965478102594863104
# Inspecting node 366225624
# Inspecting node 393713239
# Inspecting node 1185972487538040832
# Inspecting node 889661863100907520
# Inspecting node 2813399220
# Inspecting node 2436061363
# Inspecting node 17900758
# Inspecting node 23491400
# Inspecting node 382949896
# Inspecting node 1009115210546929664
# Inspecting node 3148281878
# Inspecting node 1064964294448750595
# Inspecting node 814289414
# Inspecting node 2896012540
# Inspecting node 1280589273335500801
# Inspecting node 1227766472921014272
# Inspecting node 869639001400942592
# Inspecting node 116679707
# Inspecting node 342176065
# Inspecting node 1890389540
# Inspecting node 2785990732
# Inspecting node 40591485
# Inspecting node 3191905064
# Inspecting node 25813888
# Inspecting node 237536271
# Inspecting node 16982577
# Inspecting node 1563418116
# Inspecting node 2580573206
# Inspecting node 275979196
# Inspecting node 193471925
# Inspecting node 53772503
# Inspecting node 16195103
# Inspecting node 2776775090
# Inspecting node 998590102573023232
# Inspecting node 179129165
# Inspecting node 27101995
# Inspecting node 872156101
# Inspecting node 128908662
# Inspecting node 363070453
# Inspecting node 211564038
# Inspecting node 189349553
# Inspecting node 25127782
# Inspecting node 1166717268975333376
# Inspecting node 40550119
# Inspecting node 417389780
# Inspecting node 61521038
# Inspecting node 85428184
# Inspecting node 58319221
# Inspecting node 52080359
# Inspecting node 2513973205
# Inspecting node 283226685
# Inspecting node 45848808
# Inspecting node 1646334073
# Inspecting node 1360838234
# Inspecting node 21221149
# Inspecting node 507802048
# Inspecting node 190231473
# Inspecting node 993705834470367232
# Inspecting node 360677740
# Inspecting node 1362286033
# Inspecting node 3079986094
# Inspecting node 268528986
# Inspecting node 321752222
# Inspecting node 17280115
# Inspecting node 274220538
# Inspecting node 2352629420
# Inspecting node 51184630
# Inspecting node 908811901
# Inspecting node 408526152
# Inspecting node 371447080
# Inspecting node 2314531026
# Inspecting node 1172199939243425792
# Inspecting node 390392773
# Inspecting node 2289973748
# Inspecting node 495066576
# Inspecting node 1545053600
# Inspecting node 1318671397560979456
# Inspecting node 2891740872
# Inspecting node 2848993491
# Inspecting node 103297393
# Inspecting node 1851634098
# Inspecting node 398483708
# Inspecting node 1313212802799206406
# Inspecting node 79260190
# Inspecting node 27652488
# Inspecting node 89609585
# Inspecting node 44618408
# Inspecting node 880491635896922112
# Inspecting node 2761710808
# Inspecting node 1240867313445830656
# Inspecting node 247412217
# Inspecting node 1347654502787076096
# Inspecting node 982630470008553474
# Inspecting node 82167100
# Inspecting node 110754237
# Inspecting node 768069259100622848
# Inspecting node 1304210384367349770
# Inspecting node 1300291239581892609
# Inspecting node 2253903906
# Inspecting node 78403337
# Inspecting node 862703683
# Inspecting node 1071951545212723200
# Inspecting node 840470152391016448
# Inspecting node 498423001
# Inspecting node 1197522605760303104
# Inspecting node 510093784
# Inspecting node 447415943
# Inspecting node 1201788959719936007
# Inspecting node 1633538270
# Inspecting node 122525211
# Inspecting node 192842634
# Inspecting node 551152504
# Inspecting node 378351271
# Inspecting node 57033548
# Inspecting node 255067647
# Inspecting node 35863342
# Inspecting node 2715275551
# Inspecting node 719557076599619584
# Inspecting node 980875592
# Inspecting node 1051100859831148544
# Inspecting node 2300474413
# Inspecting node 1238447220
# Inspecting node 994295935
# Inspecting node 838098877
# Inspecting node 829761553218072576
# Inspecting node 951280545421410305
# Inspecting node 1157684886
# Inspecting node 80970676
# Inspecting node 18923250
# Inspecting node 1136294664
# Inspecting node 951892305098788864
# Inspecting node 3010143902
# Inspecting node 297020666
# Inspecting node 1045793762063060992
# Inspecting node 98588419
# Inspecting node 76179144
# Inspecting node 46956207
# Inspecting node 819853925184638976
# Inspecting node 16552108
# Inspecting node 29754743
# Inspecting node 153515520
# Inspecting node 386330680
# Inspecting node 2736446758
# Inspecting node 35095520
# Inspecting node 1239564608941113347
# Inspecting node 58261480
# Inspecting node 169614697
# Inspecting node 1005522675761057792
# Inspecting node 816308397360508928
# Inspecting node 1407160205117435908
# Inspecting node 1175457080561537025
# Inspecting node 1011936943247101952
# Inspecting node 365078935
# Inspecting node 17540009
# Inspecting node 49660950
# Inspecting node 296549487
# Inspecting node 1228605451
# Inspecting node 1122706063466356737
# Inspecting node 234593598
# Inspecting node 1204301854433316866
# Inspecting node 1204430581410353154
# Inspecting node 893202244077854721
# Inspecting node 22971125
# Inspecting node 1193458951976869888
# Inspecting node 785853390
# Inspecting node 322106815
# Inspecting node 1957597519
# Inspecting node 1101092779378249729
# Inspecting node 3331826578
# Inspecting node 38720614
# Inspecting node 2912843536
# Inspecting node 183642459
# Inspecting node 2247495353
# Inspecting node 2748289416
# Inspecting node 2592210108
# Inspecting node 103701079
# Inspecting node 1352713370772770816
# Inspecting node 86410896
# Inspecting node 1038301598
# Inspecting node 1134248217472843787
# Inspecting node 999320625117196288
# Inspecting node 18390213
# Inspecting node 768295011007934469
# Inspecting node 1262878353431777280
# Inspecting node 729232479840800768
# Inspecting node 1415442622135603206
# Inspecting node 346123223
# Inspecting node 167912183
# Inspecting node 1076249609125675010
# Inspecting node 67793897
# Inspecting node 823096488
# Inspecting node 50154666
# Inspecting node 302593437
# Inspecting node 291862583
# Inspecting node 168371680
# Inspecting node 1251332171211644931
# Inspecting node 962073414
# Inspecting node 291523600
# Inspecting node 277085673
# Inspecting node 62664213
# Inspecting node 1337551744457469952
# Inspecting node 716460064039575552
# Inspecting node 3007815702
# Inspecting node 55819705
# Inspecting node 1404102585317986308
# Inspecting node 1280249212567818240
# Inspecting node 740981264740679681
# Inspecting node 247511435
# Inspecting node 1303772129847111681
# Inspecting node 1027307702047961088
# Inspecting node 1020156666204090368
# Inspecting node 38751529
# Inspecting node 718873385346797569
# Inspecting node 285806588
# Inspecting node 541129316
# Inspecting node 1655457050
# Inspecting node 57759275
# Inspecting node 824281652423753728
# Inspecting node 132015712
# Inspecting node 40647043
# Inspecting node 12992772
# Inspecting node 365132365
# Inspecting node 1129088815
# Inspecting node 1262268501823303680
# Inspecting node 288548798
# Inspecting node 87632735
# Inspecting node 40246161
# Inspecting node 1252686295
# Inspecting node 25333228
# Inspecting node 1093876945
# Inspecting node 205786669
# Inspecting node 1942350667
# Inspecting node 2863551224
# Inspecting node 720083863830069249
# Inspecting node 176207343
# Inspecting node 412708728
# Inspecting node 414218319
# Inspecting node 1271987860577517568
# Inspecting node 626984632
# Inspecting node 237594523
# Inspecting node 714340176
# Inspecting node 300638343
# Inspecting node 739845530612830208
# Inspecting node 715244769
# Inspecting node 817207955930001409
# Inspecting node 1363561650624733184
# Inspecting node 212468225
# Inspecting node 2673432539
# Inspecting node 23601374
# Inspecting node 51852542
# Inspecting node 321482430
# Inspecting node 1058965681671028736
# Inspecting node 35617919
# Inspecting node 371288369
# Inspecting node 4492249646
# Inspecting node 396106258
# Inspecting node 2287331581
# Inspecting node 150671052
# Inspecting node 3302256527
# Inspecting node 3269322830
# Inspecting node 1364751078659477504
# Inspecting node 168123931
# Inspecting node 1072189285
# Inspecting node 45976740
# Inspecting node 1435257575482740741
# Inspecting node 1099109729308008448
# Inspecting node 1366925295291424768
# Inspecting node 1356073687691141121
# Inspecting node 1580475270
# Inspecting node 1442893993935716361
# Inspecting node 392132054
# Inspecting node 207703739
# Inspecting node 1419489038747070467
# Inspecting node 928451444633563136
# Inspecting node 1119464753318043649
# Inspecting node 1440690378533838857
# Inspecting node 2931943245
# Inspecting node 1727398412
# Inspecting node 1444061901172854786
# Inspecting node 2938869339
# Inspecting node 1243723946660421637
# Inspecting node 2476755039
# Inspecting node 1331773252792770560
# Inspecting node 901618905076174848
# Inspecting node 339780511
# Inspecting node 980817985668550656
# Inspecting node 53694666
# Inspecting node 1445437990940004352
# Inspecting node 1243574020802367488
# Inspecting node 1055536236
# Inspecting node 68670486
# Inspecting node 451989089
# Inspecting node 1077731978
# Inspecting node 1271115442573185024
# Inspecting node 969744550955749383
# Inspecting node 26577630
# Inspecting node 1391981080945643523
# Inspecting node 46232947
# Inspecting node 266048357
# Inspecting node 293745266
# Inspecting node 415532452
# Inspecting node 3107597132
# Inspecting node 1183316407104266241
# Inspecting node 982472677775454209
# Inspecting node 3295839203
# Inspecting node 880913594531139584
# Inspecting node 1911858061
# Inspecting node 1097694473952342022
# Inspecting node 1388650232100134915
# Inspecting node 14100537
# Inspecting node 820656479812227073
# Inspecting node 1325249450793701376
# Inspecting node 1427996716138127360
# Inspecting node 1347691972358778885
# Inspecting node 1365678726
# Inspecting node 1295377965438644235
# Inspecting node 322090834
# Inspecting node 1342962255248424961
# Inspecting node 1195026680609292288
# Inspecting node 1116360718687690758
# Inspecting node 737359208945844224
# Inspecting node 3375064758
# Inspecting node 14538949
# Inspecting node 1084856644687679496
# Inspecting node 36133644
# Inspecting node 976345683681619968
# Inspecting node 366785595
# Inspecting node 2849064914
# Inspecting node 343059330
# Inspecting node 64123717
# Inspecting node 18420573
# Inspecting node 957106791753555968
# Inspecting node 751054068974575616
# Inspecting node 1186136760981454854
# Inspecting node 854065048683204615
# Inspecting node 317823907
# Inspecting node 952759886
# Inspecting node 474883984
# Inspecting node 1258133514421239813
# Inspecting node 2198792101
# Inspecting node 324555383
# Inspecting node 744660163873771520
# Inspecting node 726025903
# Inspecting node 1263514760584167424
# Inspecting node 714569357267853312
# Inspecting node 739149720
# Inspecting node 1136772811656126464
# Inspecting node 270307297
# Inspecting node 454774863
# Inspecting node 772948513
# Inspecting node 3333795492
# Inspecting node 2209473078
# Inspecting node 838196271571591168
# Inspecting node 18386792
# Inspecting node 1166799265806503936
# Inspecting node 262522708
# Inspecting node 1370402422062002179
# Inspecting node 1429982282891239433
# Inspecting node 1434265814325202944
# Inspecting node 1087134051914395648
# Inspecting node 791076864
# Inspecting node 121949981
# Inspecting node 256360738
# Inspecting node 1172475064870027264
# Inspecting node 1443468994107822081
# Inspecting node 941115769429024769
# Inspecting node 1313732971061362690
# Inspecting node 2305422800
# Inspecting node 242885214
# Inspecting node 1354230346586447877
# Inspecting node 469747759
# Inspecting node 432114850
# Inspecting node 1166000110586626048
# Inspecting node 884527637569323009
# Inspecting node 369653658
# Inspecting node 1434643524495020043
# Inspecting node 75984040
# Inspecting node 586195164
# Inspecting node 2902344555
# Inspecting node 564257648
# Inspecting node 1027229536902098944
# Inspecting node 2316626342
# Inspecting node 1925354744
# Inspecting node 958204773282533376
# Inspecting node 1445751022526160908
# Inspecting node 1183078912265355265
# Inspecting node 98767459
# Inspecting node 87297879
# Inspecting node 753394222267527168
# Inspecting node 373580557
# Inspecting node 1430260512688902150
# Inspecting node 2468436247
# Inspecting node 3308781515
# Inspecting node 2273880732
# Inspecting node 1302114263771668481
# Inspecting node 24181491
# Inspecting node 1309179346565898241
# Inspecting node 2231471516
# Inspecting node 1352351686778630145
# Inspecting node 1413321993470943237
# Inspecting node 603011131
# Inspecting node 1438876255202406406
# Inspecting node 1375883715776294914
# Inspecting node 1002002024
# Inspecting node 51384524
# Inspecting node 724114092672335874
# Inspecting node 552725069
# Inspecting node 1184298786329448448
# Inspecting node 334954251
# Inspecting node 101915304
# Inspecting node 1252767510983737344
# Inspecting node 1099811037975642112
# Inspecting node 1388988366247575559
# Inspecting node 1326022742286749696
# Inspecting node 1388801354244702209
# Inspecting node 961162177
# Inspecting node 1389555148318404610
# Inspecting node 1151641780267261952
# Inspecting node 27320189
# Inspecting node 1215379886887428096
# Inspecting node 1184882383
# Inspecting node 257699447
# Inspecting node 2397398196
# Inspecting node 807034969902252032
# Inspecting node 1353486048618274816
# Inspecting node 4866566489
# Inspecting node 3058888765
# Inspecting node 1173239638116446208
# Inspecting node 42894434
# Inspecting node 3078011282
# Inspecting node 32691118
# Inspecting node 544080126
# Inspecting node 1336660494
# Inspecting node 957190068594130946
# Inspecting node 1074149416699719681
# Inspecting node 825518936733085696
# Inspecting node 43199433
# Inspecting node 969376788525830146
# Inspecting node 35107179
# Inspecting node 366074756
# Inspecting node 359672860
# Inspecting node 82679357
# Inspecting node 883774859452579840
# Inspecting node 3418588623
# Inspecting node 710270422290403328
# Inspecting node 763168867371843584
# Inspecting node 1575198925
# Inspecting node 1301995158485958656
# Inspecting node 1260291453973983232
# Inspecting node 1601907697
# Inspecting node 29823611
# Inspecting node 1393039117110317058
# Inspecting node 236055343
# Inspecting node 320919057
# Inspecting node 2812908133
# Inspecting node 1325519307359490048
# Inspecting node 590735039
# Inspecting node 95577307
# Inspecting node 43948485
# Inspecting node 136332449
# Inspecting node 623936216
# Inspecting node 2873956499
# Inspecting node 4803873902
# Inspecting node 1147245556651233280
# Inspecting node 918919026344120321
# Inspecting node 37813045
# Inspecting node 24574252
# Inspecting node 1440809899500335110
# Inspecting node 1334205408110551042
# Inspecting node 1071298949837770753
# Inspecting node 915968072
# Inspecting node 885818088
# Inspecting node 227849419
# Inspecting node 2493753559
# Inspecting node 778842486
# Inspecting node 124839366
# Inspecting node 263750524
# Inspecting node 1357001901229899777
# Inspecting node 990301302264479749
# Inspecting node 1136065885456740352
# Inspecting node 1335377050878676992
# Inspecting node 138710067
# Inspecting node 1441961640459599874
# Inspecting node 2793008984
# Inspecting node 120187876
# Inspecting node 178544594
# Inspecting node 2838327755
# Inspecting node 1559780652
# Inspecting node 2291354802
# Inspecting node 1352707350784659456
# Inspecting node 1417352097150816256
# Inspecting node 1427768108614291465
# Inspecting node 1117485007944048640
# Inspecting node 1297264458
# Inspecting node 1194794785762004993
# Inspecting node 26089782
# Inspecting node 1446289055935864836
# Inspecting node 412499776
# Inspecting node 416476088
# Inspecting node 1028871362499305473
# Inspecting node 1438317451469541377
# Inspecting node 546527413
# Inspecting node 1323421765658431488
# Inspecting node 280677070
# Inspecting node 2332742508
# Inspecting node 1347272097786171394
# Inspecting node 2344419362
# Inspecting node 252150132
# Inspecting node 4787666543
# Inspecting node 1454456569
# Inspecting node 587733016
# Inspecting node 823265236916416512
# Inspecting node 1168589910825213952
# Inspecting node 753744536887824385
# Inspecting node 119925381
# Inspecting node 1269692602204532738
# Inspecting node 853722212741898240
# Inspecting node 43089397
# Inspecting node 2323751900
# Inspecting node 1213405462021853185
# Inspecting node 2937436849
# Inspecting node 272250877
# Inspecting node 1406573892
# Inspecting node 1942107584
# Inspecting node 2678072299
# Inspecting node 86384661
# Inspecting node 2983179809
# Inspecting node 3188558830
# Inspecting node 2874772780
# Inspecting node 222386937
# Inspecting node 261788602
# Inspecting node 292468351
# Inspecting node 22849568
# Inspecting node 1203545123356839936
# Inspecting node 19893907
# Inspecting node 1729880688
# Inspecting node 1361500715659755520
# Inspecting node 700287952
# Inspecting node 169268197
# Inspecting node 18622393
# Inspecting node 1304185921433227264
# Inspecting node 97121931
# Inspecting node 1699266222
# Inspecting node 729194378779078656
# Inspecting node 2752659114
# Inspecting node 373460084
# Inspecting node 908018227040710656
# Inspecting node 245149238
# Inspecting node 3242606862
# Inspecting node 29891001
# Inspecting node 720579941184757760
# Inspecting node 276713213
# Inspecting node 1424060815947206662
# Inspecting node 609432652
# Inspecting node 38625077
# Inspecting node 234550882
# Inspecting node 408072407
# Inspecting node 1427258589077508100
# Inspecting node 2242940071
# Inspecting node 44171755
# Inspecting node 41043869
# Inspecting node 436087744
# Inspecting node 578640179
# Inspecting node 132210296
# Inspecting node 923683393
# Inspecting node 1245003009555419137
# Inspecting node 1267504449087553539
# Inspecting node 65666257
# Inspecting node 407943040
# Inspecting node 240908125
# Inspecting node 1057988206963056640
# Inspecting node 130857133
# Inspecting node 1441410998355726344
# Inspecting node 24819740
# Inspecting node 1412813687811760135
# Inspecting node 2762829798
# Inspecting node 1317417438640697344
# Inspecting node 1185990712132812800
# Inspecting node 711980580813066240
# Inspecting node 3237884919
# Inspecting node 9455112
# Inspecting node 19198775
# Inspecting node 22630846
# Inspecting node 1434341584670273544
# Inspecting node 844292741077061632
# Inspecting node 1300624324206817280
# Inspecting node 1332164996592066561
# Inspecting node 337816824
# Inspecting node 153798495
# Inspecting node 1249204176548245504
# Inspecting node 3092462976
# Inspecting node 547671992
# Inspecting node 151547845
# Inspecting node 23554969
# Inspecting node 1314208704
# Inspecting node 808450734240972800
# Inspecting node 204846220
# Inspecting node 19478009
# Inspecting node 18940341
# Inspecting node 62292631
# Inspecting node 1239692519094575104
# Inspecting node 64261339
# Inspecting node 271989352
# Inspecting node 66334416
# Inspecting node 756584190112591872
# Inspecting node 24459228
# Inspecting node 771870952544096257
# Inspecting node 1242251887
# Inspecting node 15908286
# Inspecting node 1390840055200108546
# Inspecting node 2408260398
# Inspecting node 488067802
# Inspecting node 1511667030
# Inspecting node 579614622
# Inspecting node 728304522662043648
# Inspecting node 1092960066
# Inspecting node 64099329
# Inspecting node 1393055510480441345
# Inspecting node 2555583872
# Inspecting node 2452465303
# Inspecting node 282526718
# Inspecting node 4298769753
# Inspecting node 572827030
# Inspecting node 1414623993529880576
# Inspecting node 1255927911045095425
# Inspecting node 1373016955
# Inspecting node 2720800274
# Inspecting node 57661541
# Inspecting node 708739471
# Inspecting node 722623738672517120
# Inspecting node 157591483
# Inspecting node 1390378070482165763
# Inspecting node 2707780448
# Inspecting node 898554931271127042
# Inspecting node 525857359
# Inspecting node 2536457582
# Inspecting node 19634262
# Inspecting node 1357304889831878657
# Inspecting node 1243221104560345090
# Inspecting node 431141725
# Inspecting node 1244435052
# Inspecting node 159655782
# Inspecting node 382223500
# Inspecting node 535452718
# Inspecting node 1293199610178080775
# Inspecting node 12923812
# Inspecting node 16272844
# Inspecting node 335769776
# Inspecting node 16279532
# Inspecting node 3358671
# Inspecting node 16180205
# Inspecting node 2322580746
# Inspecting node 171115367
# Inspecting node 208750527
# Inspecting node 240786249
# Inspecting node 3257047456
# Inspecting node 500232993
# Inspecting node 1171073846335721472
# Inspecting node 1304472952482783232
# Inspecting node 1072270926
# Inspecting node 2789770741
# Inspecting node 2327530022
# Inspecting node 1002181382
# Inspecting node 47692251
# Inspecting node 743129088
# Inspecting node 271073165
# Inspecting node 1895316878
# Inspecting node 631988630
# Inspecting node 290162716
# Inspecting node 2229187188
# Inspecting node 274507495
# Inspecting node 417524720
# Inspecting node 415774799
# Inspecting node 579377522
# Inspecting node 32915303
# Inspecting node 245954929
# Inspecting node 170377354
# Inspecting node 1390883714
# Inspecting node 3363252329
# Inspecting node 1143342270399373313
# Inspecting node 272185225
# Inspecting node 1144289639924207616
# Inspecting node 43510607
# Inspecting node 524557553
# Inspecting node 256775505
# Inspecting node 493488747
# Inspecting node 868245382148521984
# Inspecting node 1170770038208565248
# Inspecting node 339752726
# Inspecting node 249221867
# Inspecting node 488052222
# Inspecting node 911471588
# Inspecting node 246466184
# Inspecting node 280552762
# Inspecting node 295951367
# Inspecting node 973087261
# Inspecting node 1321710295245447169
# Inspecting node 48369926
# Inspecting node 1438956476588957701
# Inspecting node 385008014
# Inspecting node 918152297544380417
# Inspecting node 33562561
# Inspecting node 987136895162384384
# Inspecting node 1327442450957303809
# Inspecting node 870473605473198080
# Inspecting node 35337644
# Inspecting node 1103832363363127297
# Inspecting node 1243323314652602368
# Inspecting node 1268045786312593408
# Inspecting node 17355421
# Inspecting node 24348660
# Inspecting node 14247924
# Inspecting node 106512310
# Inspecting node 1269254845615095810
# Inspecting node 1219578234
# Inspecting node 1380813355
# Inspecting node 883334379023597568
# Inspecting node 58878834
# Inspecting node 912346683291389953
# Inspecting node 3179475258
# Inspecting node 245939022
# Inspecting node 363654070
# Inspecting node 3071603495
# Inspecting node 573788425
# Inspecting node 878490462
# Inspecting node 1423385158263132168
# Inspecting node 1268728504964825088
# Inspecting node 46894332
# Inspecting node 136160953
# Inspecting node 107218304
# Inspecting node 73411833
# Inspecting node 1405971529217740812
# Inspecting node 1275123310788063233
# Inspecting node 1173035282461089793
# Inspecting node 1445090669643517961
# Inspecting node 1389241812276023296
# Inspecting node 501994958
# Inspecting node 2799175653
# Inspecting node 1429555219457773581
# Inspecting node 1668333199
# Inspecting node 1218019404992196609
# Inspecting node 1366204146957885445
# Inspecting node 1198972583288459265
# Inspecting node 1433247289330577408
# Inspecting node 502160853
# Inspecting node 41520537
# Inspecting node 1294478815628890112
# Inspecting node 395394840
# Inspecting node 1151704477
# Inspecting node 1044711566354960384
# Inspecting node 1271855851330916353
# Inspecting node 1497052201
# Inspecting node 975757898004549633
# Inspecting node 3245708989
# Inspecting node 1267640853000007680
# Inspecting node 29917096
# Inspecting node 245373521
# Inspecting node 1420482733135040522
# Inspecting node 1242510089145266182
# Inspecting node 28737527
# Inspecting node 1731401322
# Inspecting node 979870450577686528
# Inspecting node 1354922263418523648
# Inspecting node 24951781
# Inspecting node 15613754
# Inspecting node 100851235
# Inspecting node 59243738
# Inspecting node 17360968
# Inspecting node 360129945
# Inspecting node 1174006316412674048
# Inspecting node 21809306
# Inspecting node 1134558647835430912
# Inspecting node 855478711
# Inspecting node 25178951
# Inspecting node 52350953
# Inspecting node 20796969
# Inspecting node 55158039
# Inspecting node 1401659310015397889
# Inspecting node 215896862
# Inspecting node 4540976253
# Inspecting node 56016987
# Inspecting node 1357857933019598849
# Inspecting node 1125841354716696576
# Inspecting node 793343793642680320
# Inspecting node 48219360
# Inspecting node 399184212
# Inspecting node 827222807121637377
# Inspecting node 1138228267
# Inspecting node 1671821988
# Inspecting node 2321539819
# Inspecting node 17969963
# Inspecting node 1337935917298962434
# Inspecting node 1055170328442224641
# Inspecting node 325805788
# Inspecting node 1128406689802276865
# Inspecting node 1560811022
# Inspecting node 1264568784318345218
# Inspecting node 254240108
# Inspecting node 2237957942
# Inspecting node 387828045
# Inspecting node 3355188729
# Inspecting node 1483945802
# Inspecting node 1663608300
# Inspecting node 1335613030852386817
# Inspecting node 2678629590
# Inspecting node 884681534
# Inspecting node 420536762
# Inspecting node 4329525312
# Inspecting node 1547244656
# Inspecting node 109341612
# Inspecting node 108689047
# Inspecting node 1223265601147342848
# Inspecting node 297968019
# Inspecting node 183758895
# Inspecting node 45932749
# Inspecting node 418786259
# Inspecting node 70240459
# Inspecting node 1606592767
# Inspecting node 1047167241119326211
# Inspecting node 978673214283853825
# Inspecting node 17136419
# Inspecting node 1242152485
# Inspecting node 4445748801
# Inspecting node 1413908511461945350
# Inspecting node 1314819918328729600
# Inspecting node 1140532022
# Inspecting node 1200932043544117248
# Inspecting node 3109560272
# Inspecting node 162924629
# Inspecting node 182072629
# Inspecting node 980237238
# Inspecting node 1213189717425917953
# Inspecting node 2800741820
# Inspecting node 19135439
# Inspecting node 967241034873933824
# Inspecting node 3236492411
# Inspecting node 1235422076082589696
# Inspecting node 534591437
# Inspecting node 1454880680
# Inspecting node 1069754111078354948
# Inspecting node 2286750115
# Inspecting node 1375862610
# Inspecting node 26071396
# Inspecting node 375764669
# Inspecting node 1833674827
# Inspecting node 392380645
# Inspecting node 769165632738762752
# Inspecting node 989311745100566529
# Inspecting node 256552850
# Inspecting node 2218371769
# Inspecting node 29721598
# Inspecting node 1008103433822351360
# Inspecting node 1214027006242742273
# Inspecting node 142107502
# Inspecting node 1314568089300873216
# Inspecting node 801218452618956800
# Inspecting node 1330675961839443973
# Inspecting node 1441448795921952768
# Inspecting node 102491634
# Inspecting node 24978284
# Inspecting node 36988268
# Inspecting node 712792479729192960
# Inspecting node 890560416526594048
# Inspecting node 1413820603
# Inspecting node 37044121
# Inspecting node 832619717785329664
# Inspecting node 1171471512085389312
# Inspecting node 61542328
# Inspecting node 494320156
# Inspecting node 13716572
# Inspecting node 1017461230984990720
# Inspecting node 25703839
# Inspecting node 363666493
# Inspecting node 975491119734763522
# Inspecting node 61888526
# Inspecting node 2502596130
# Inspecting node 763867259777519618
# Inspecting node 1185294078256254977
# Inspecting node 1296424847149588483
# Inspecting node 2721515522
# Inspecting node 224600898
# Inspecting node 524785211
# Inspecting node 777617628009332736
# Inspecting node 189341190
# Inspecting node 2451955022
# Inspecting node 835061048533082113
# Inspecting node 248022226
# Inspecting node 2988258574
# Inspecting node 1001287095472873473
# Inspecting node 1182252711833718784
# Inspecting node 1861048644
# Inspecting node 2842385693
# Inspecting node 248065960
# Inspecting node 931882614
# Inspecting node 3290783049
# Inspecting node 359260523
# Inspecting node 16116228
# Inspecting node 243912778
# Inspecting node 2439108320
# Inspecting node 1176536298179284993
# Inspecting node 297771685
# Inspecting node 1128366660128260097
# Inspecting node 222987791
# Inspecting node 18597273
# Inspecting node 577727470
# Inspecting node 112767813
# Inspecting node 116837959
# Inspecting node 83712358
# Inspecting node 486703473
# Inspecting node 67758676
# Inspecting node 20346252
# Inspecting node 420560195
# Inspecting node 3153084524
# Inspecting node 1308040042724519939
# Inspecting node 1182947209
# Inspecting node 1258576501
# Inspecting node 213140093
# Inspecting node 225067116
# Inspecting node 18340314
# Inspecting node 1310724884008321028
# Inspecting node 160429871
# Inspecting node 214530013
# Inspecting node 110504574
# Inspecting node 24692082
# Inspecting node 16422863
# Inspecting node 1650588223
# Inspecting node 1548315212
# Inspecting node 1378038493105037320
# Inspecting node 4731285264
# Inspecting node 1260770767123312640
# Inspecting node 1260759194833006593
# Inspecting node 975784752648212480
# Inspecting node 2367303485
# Inspecting node 1346317368637603841
# Inspecting node 1426665402147360769
# Inspecting node 1024397417423106048
# Inspecting node 776153719675072512
# Inspecting node 787738985481240576
# Inspecting node 911264470210682880
# Inspecting node 1005823371144318977
# Inspecting node 1416921060788801539
# Inspecting node 17174462
# Inspecting node 1214396742
# Inspecting node 2379113581
# Inspecting node 1426711288462417921
# Inspecting node 21426717
# Inspecting node 975519759105060864
# Inspecting node 2394842400
# Inspecting node 1430196796781912066
# Inspecting node 1433249159474200577
# Inspecting node 20467453
# Inspecting node 1353457212799262720
# Inspecting node 877710910780985345
# Inspecting node 1413615091224924164
# Inspecting node 739208182837321729
# Inspecting node 16545084
# Inspecting node 1234968032734216193
# Inspecting node 979741136725184512
# Inspecting node 509604564
# Inspecting node 731972892
# Inspecting node 1357259774
# Inspecting node 308032537
# Inspecting node 782939425
# Inspecting node 824028437568438277
# Inspecting node 1255919262998441987
# Inspecting node 1291405539046457345
# Inspecting node 1306024583858917376
# Inspecting node 578272027
# Inspecting node 294660973
# Inspecting node 1212202179777331200
# Inspecting node 21632185
# Inspecting node 1227080599451701249
# Inspecting node 2906452022
# Inspecting node 1298675867061805056
# Inspecting node 15128653
# Inspecting node 820499790
# Inspecting node 1238950146559352834
# Inspecting node 1854934933
# Inspecting node 1444459015875014657
# Inspecting node 147340782
# Inspecting node 15677734
# Inspecting node 195207470
# Inspecting node 1282074147884015616
# Inspecting node 977009074217795584
# Inspecting node 3331283445
# Inspecting node 826085293677748224
# Inspecting node 1355980761443217415
# Inspecting node 92256613
# Inspecting node 1278822500143677442
# Inspecting node 187257177
# Inspecting node 902402049022808064
# Inspecting node 1694247541
# Inspecting node 403374868
# Inspecting node 42142250
# Inspecting node 4856189107
# Inspecting node 483313162
# Inspecting node 2427741792
# Inspecting node 2174574218
# Inspecting node 3831737053
# Inspecting node 892123934119927809
# Inspecting node 3660694460
# Inspecting node 3298660936
# Inspecting node 3289694144
# Inspecting node 459311957
# Inspecting node 33456207
# Inspecting node 144036263
# Inspecting node 1049412181559787521
# Inspecting node 826499437585371136
# Inspecting node 540672851
# Inspecting node 1444511517379026948
# Inspecting node 1023207519060197383
# Inspecting node 22532501
# Inspecting node 1067386991250206721
# Inspecting node 2800244863
# Inspecting node 92736596
# Inspecting node 1225489734178344962
# Inspecting node 66621998
# Inspecting node 1059573444214439937
# Inspecting node 1442259927779532808
# Inspecting node 751872198961487872
# Inspecting node 1190792680877559810
# Inspecting node 147981741
# Inspecting node 3158178364
# Inspecting node 1198789568214044672
# Inspecting node 1118222712818868229
# Inspecting node 1296542987850113024
# Inspecting node 1294643635397550080
# Inspecting node 920714531537481729
# Inspecting node 779333693936721920
# Inspecting node 49707487
# Inspecting node 1424936529621774338
# Inspecting node 1129198217164234753
# Inspecting node 1366519801997193216
# Inspecting node 32235586
# Inspecting node 44674554
# Inspecting node 224063162
# Inspecting node 369093
# Inspecting node 2883808867
# Inspecting node 292524345
# Inspecting node 22968164
# Inspecting node 1001274194443821064
# Inspecting node 15054416
# Inspecting node 21400756
# Inspecting node 4860164601
# Inspecting node 467804527
# Inspecting node 958181344286269440
# Inspecting node 778262568272027648
# Inspecting node 38929865
# Inspecting node 297074777
# Inspecting node 760353522718081026
# Inspecting node 928262146542026752
# Inspecting node 160673089
# Inspecting node 175939051
# Inspecting node 1187760523829563392
# Inspecting node 78429753
# Inspecting node 4722097454
# Inspecting node 1070001735454875648
# Inspecting node 35728556
# Inspecting node 1402352323851083779
# Inspecting node 1097176821622284289
# Inspecting node 150699925
# Inspecting node 1060278863874478080
# Inspecting node 813073081761570816
# Inspecting node 722880943380242432
# Inspecting node 14960142
# Inspecting node 1346936882
# Inspecting node 1073283389288005632
# Inspecting node 1297250167
# Inspecting node 1322191014455554048
# Inspecting node 1357200256618795008
# Inspecting node 16504074
# Inspecting node 158100294
# Inspecting node 817811639516991488
# Inspecting node 824357739501531136
# Inspecting node 268237247
# Inspecting node 21815663
# Inspecting node 318420941
# Inspecting node 341180420
# Inspecting node 2267952750
# Inspecting node 454336947
# Inspecting node 725309237862223872
# Inspecting node 353903334
# Inspecting node 2247798150
# Inspecting node 489749588
# Inspecting node 4819639768
# Inspecting node 1330218727
# Inspecting node 1481076481
# Inspecting node 2479224015
# Inspecting node 563152589
# Inspecting node 1317418116
# Inspecting node 1350924172554366979
# Inspecting node 23101207
# Inspecting node 1357917347181453312
# Inspecting node 721401357
# Inspecting node 2926114316
# Inspecting node 968303534822313984
# Inspecting node 77035084
# Inspecting node 85859978
# Inspecting node 2720749324
# Inspecting node 734095130
# Inspecting node 3257661611
# Inspecting node 1219432023044939776
# Inspecting node 998712356
# Inspecting node 603662056
# Inspecting node 4729460081
# Inspecting node 188565420
# Inspecting node 2534622463
# Inspecting node 165020784
# Inspecting node 84704052
# Inspecting node 4273980252
# Inspecting node 29256016
# Inspecting node 577968691
# Inspecting node 845271811097055234
# Inspecting node 470780364
# Inspecting node 22531935
# Inspecting node 59829657
# Inspecting node 275735174
# Inspecting node 559870034
# Inspecting node 7491592
# Inspecting node 23282993
# Inspecting node 2411078349
# Inspecting node 4148412316
# Inspecting node 73199415
# Inspecting node 366968661
# Inspecting node 341653196
# Inspecting node 605379442
# Inspecting node 28045785
# Inspecting node 40216513
# Inspecting node 925675836526776321
# Inspecting node 1080965055007592456
# Inspecting node 1032507164
# Inspecting node 820730609043505152
# Inspecting node 495401684
# Inspecting node 29904143
# Inspecting node 365563514
# Inspecting node 1142295084572073985
# Inspecting node 23522098
# Inspecting node 624251860
# Inspecting node 80212065
# Inspecting node 2829798301
# Inspecting node 1390067256080621568
# Inspecting node 38878429
# Inspecting node 2801061205
# Inspecting node 935335003084423168
# Inspecting node 622885791
# Inspecting node 1112914064076931072
# Inspecting node 384288098
# Inspecting node 515847342
# Inspecting node 3111765339
# Inspecting node 3419010088
# Inspecting node 571519594
# Inspecting node 935697022400602112
# Inspecting node 349692386
# Inspecting node 1223950760
# Inspecting node 3341414159
# Inspecting node 1382336580518621186
# Inspecting node 3142614406
# Inspecting node 731469980890476545
# Inspecting node 58340767
# Inspecting node 266653082
# Inspecting node 2853989866
# Inspecting node 3607702640
# Inspecting node 1421968442
# Inspecting node 297986745
# Inspecting node 54042169
# Inspecting node 577170668
# Inspecting node 880108852162707456
# Inspecting node 1380189591735517190
# Inspecting node 35051540
# Inspecting node 1074335960
# Inspecting node 1371923720609095686
# Inspecting node 1280972258
# Inspecting node 491697655
# Inspecting node 2651576688
# Inspecting node 1117035592565628928
# Inspecting node 163922710
# Inspecting node 1286102971974025217
# Inspecting node 2620272561
# Inspecting node 52516962
# Inspecting node 1065829609
# Inspecting node 1437800221375963143
# Inspecting node 1247541393121087495
# Inspecting node 892060639526395904
# Inspecting node 543143031
# Inspecting node 124878802
# Inspecting node 1341618252
# Inspecting node 727897637098135552
# Inspecting node 14221144
# Inspecting node 950848085802004480
# Inspecting node 16267310
# Inspecting node 2262304373
# Inspecting node 727519870590541824
# Inspecting node 92551736
# Inspecting node 3438124552
# Inspecting node 2749373577
# Inspecting node 535799622
# Inspecting node 1354038378640134145
# Inspecting node 1239698227739459584
# Inspecting node 196164822
# Inspecting node 3075929388
# Inspecting node 1212777267169873920
# Inspecting node 140253506
# Inspecting node 1571464364
# Inspecting node 37609730
# Inspecting node 1396338835596795904
# Inspecting node 1069734050301128705
# Inspecting node 1581712848
# Inspecting node 3268565808
# Inspecting node 786738726466707460
# Inspecting node 1115838887623122954
# Inspecting node 1498327201
# Inspecting node 1316013080250216453
# Inspecting node 957808962983755776
# Inspecting node 2727310657
# Inspecting node 2353185104
# Inspecting node 992390491105882112
# Inspecting node 1133696644422275072
# Inspecting node 3087811674
# Inspecting node 2151893489
# Inspecting node 904365258399244288
# Inspecting node 1393384383650975744
# Inspecting node 707364896153980928
# Inspecting node 371739649
# Inspecting node 1203817853494779904
# Inspecting node 1081036726758531072
# Inspecting node 2968424080
# Inspecting node 2151613567
# Inspecting node 198927392
# Inspecting node 951527727365988352
# Inspecting node 1093890667909124100
# Inspecting node 593891991
# Inspecting node 4850122813
# Inspecting node 872152901870911489
# Inspecting node 878242924567441408
# Inspecting node 1335043297
# Inspecting node 725731648017424385
# Inspecting node 1198351736
# Inspecting node 26557104
# Inspecting node 1042821954821087232
# Inspecting node 1428826266
# Inspecting node 2831610879
# Inspecting node 4681656433
# Inspecting node 775279674
# Inspecting node 596787864
# Inspecting node 273262205
# Inspecting node 24990450
# Inspecting node 342699819
# Inspecting node 378321467
# Inspecting node 217485938
# Inspecting node 967837552425119744
# Inspecting node 18579611
# Inspecting node 16811701
# Inspecting node 63476527
# Inspecting node 17442269
# Inspecting node 1366423551704784897
# Inspecting node 1070588953105969152
# Inspecting node 119911112
# Inspecting node 145878023
# Inspecting node 28540616
# Inspecting node 17050123
# Inspecting node 1432002021398306821
# Inspecting node 930479718
# Inspecting node 2341257349
# Inspecting node 587087289
# Inspecting node 708990479895896066
# Inspecting node 566196508
# Inspecting node 1019405015855878144
# Inspecting node 1275466513529671681
# Inspecting node 1347609010434953217
# Inspecting node 1419539298
# Inspecting node 57527830
# Inspecting node 24752425
# Inspecting node 29586080
# Inspecting node 1250609616192446466
# Inspecting node 2589728724
# Inspecting node 7922582
# Inspecting node 1124423281765797888
# Inspecting node 1077139237
# Inspecting node 199876983
# Inspecting node 18680879
# Inspecting node 380327126
# Inspecting node 3139690604
# Inspecting node 282111410
# Inspecting node 273727399
# Inspecting node 703722876
# Inspecting node 3357096478
# Inspecting node 838912397066846208
# Inspecting node 1437539837477748738
# Inspecting node 751919973497384962
# Inspecting node 1404491652580843525
# Inspecting node 1067154574278971392
# Inspecting node 576365948
# Inspecting node 31513326
# Inspecting node 1297575021578256388
# Inspecting node 1233196108211294209
# Inspecting node 19359977
# Inspecting node 745800926
# Inspecting node 2448257995
# Inspecting node 839668692866723840
# Inspecting node 15023001
# Inspecting node 30270072
# Inspecting node 17929195
# Inspecting node 385678932
# Inspecting node 1065257588151996422
# Inspecting node 1687712964
# Inspecting node 1345709200618389504
# Inspecting node 224737149
# Inspecting node 373940903
# Inspecting node 6013662
# Inspecting node 907302868645953537
# Inspecting node 1243336421164732416
# Inspecting node 240831038
# Inspecting node 290312086
# Inspecting node 4026420858
# Inspecting node 540103190
# Inspecting node 248866864
# Inspecting node 148618115
# Inspecting node 83307703
# Inspecting node 918318518
# Inspecting node 21166754
# Inspecting node 493604178
# Inspecting node 1222274097935073281
# Inspecting node 336662190
# Inspecting node 1254832256
# Inspecting node 65917423
# Inspecting node 15257975
# Inspecting node 18148460
# Inspecting node 168350399
# Inspecting node 18457918
# Inspecting node 165890739
# Inspecting node 1380663772906356737
# Inspecting node 554805867
# Inspecting node 1344041868779110400
# Inspecting node 373667686
# Inspecting node 1261311256151183362
# Inspecting node 1116067546778628097
# Inspecting node 1416035013502685184
# Inspecting node 24313572
# Inspecting node 1144704604442988544
# Inspecting node 222126993
# Inspecting node 2655180373
# Inspecting node 887262626
# Inspecting node 3131039404
# Inspecting node 249386982
# Inspecting node 4759974372
# Inspecting node 494732315
# Inspecting node 1405037853579436035
# Inspecting node 15049380
# Inspecting node 396149168
# Inspecting node 977021137
# Inspecting node 3320688247
# Inspecting node 880997516
# Inspecting node 264439847
# Inspecting node 1068193791511678977
# Inspecting node 636649732
# Inspecting node 14837621
# Inspecting node 596793900
# Inspecting node 4767685428
# Inspecting node 1407536941680279552
# Inspecting node 717895042602504192
# Inspecting node 52245251
# Inspecting node 2574056066
# Inspecting node 35476624
# Inspecting node 48035511
# Inspecting node 207677544
# Inspecting node 56029187
# Inspecting node 3306930701
# Inspecting node 1177657984220053506
# Inspecting node 165971686
# Inspecting node 758042170968375296
# Inspecting node 242492168
# Inspecting node 27460814
# Inspecting node 1231982311253708803
# Inspecting node 2533511951
# Inspecting node 3317590829
# Inspecting node 2416130503
# Inspecting node 724952267162542080
# Inspecting node 22491454
# Inspecting node 3029210380
# Inspecting node 2157300561
# Inspecting node 1053529093285785601
# Inspecting node 1130348139607576576
# Inspecting node 1232835905616011264
# Inspecting node 2922358250
# Inspecting node 1001986308343033856
# Inspecting node 1022679197976678400
# Inspecting node 2560632538
# Inspecting node 1317802041423646720
# Inspecting node 884265045479313408
# Inspecting node 1229474724142604288
# Inspecting node 486317915
# Inspecting node 235070820
# Inspecting node 755749623491244032
# Inspecting node 32189160
# Inspecting node 416468980
# Inspecting node 1051556700
# Inspecting node 1171534270168367105
# Inspecting node 23370368
# Inspecting node 1399510991885455362
# Inspecting node 1438462388647440386
# Inspecting node 214708464
# Inspecting node 547747984
# Inspecting node 366117993
# Inspecting node 262910171
# Inspecting node 1416997300199641091
# Inspecting node 24707528
# Inspecting node 521255914
# Inspecting node 1267810083389480963
# Inspecting node 165587758
# Inspecting node 1398595872187830274
# Inspecting node 1392128666998542337
# Inspecting node 2612807188
# Inspecting node 2652768953
# Inspecting node 292728050
# Inspecting node 96450418
# Inspecting node 2811765535
# Inspecting node 45010284
# Inspecting node 128290965
# Inspecting node 1088791968451313665
# Inspecting node 268573963
# Inspecting node 41089713
# Inspecting node 55841183
# Inspecting node 1419998048562909204
# Inspecting node 2969192164
# Inspecting node 1338252288
# Inspecting node 887732866423173125
# Inspecting node 39268708
# Inspecting node 995530035892121601
# Inspecting node 2694473137
# Inspecting node 421830937
# Inspecting node 1097531188338552832
# Inspecting node 64514213
# Inspecting node 67254536
# Inspecting node 1191423138954981382
# Inspecting node 244328935
# Inspecting node 15782904
# Inspecting node 147965270
# Inspecting node 2944338467
# ...
# Inspecting node 1411006381117919235
# Inspecting node 84353854
# Inspecting node 1446920962671185920
# Inspecting node 1365798226717151233
# Inspecting node 281811081
# Inspecting node 1406365981329346565
# Inspecting node 65767300
# Inspecting node 3011968549
# Inspecting node 1438896900070117381
# Inspecting node 547245887
# Inspecting node 1615902452
# Inspecting node 38885578
# Inspecting node 948223698649124870
# Inspecting node 1242785654368382979
# Inspecting node 3145151881
# Inspecting node 1148750306634883077
# Inspecting node 40109301
# Inspecting node 895679481720872960
# Inspecting node 2966914766
# Inspecting node 1347952445985497088
# Inspecting node 922806178446327809
# Inspecting node 131591657
# Inspecting node 1374005511495028737
# Inspecting node 408241959
# Inspecting node 809552357763661824
# Inspecting node 1556631295
# Inspecting node 282728904
# Inspecting node 785667382224293888
# Inspecting node 1013808600
# Inspecting node 16271356
# Inspecting node 4762708393
# Inspecting node 2167166754
# Inspecting node 517098546
# Inspecting node 886380609026785280
# Inspecting node 2869430815
# Inspecting node 937525764
# Inspecting node 981670040062779392
# Inspecting node 909852173479104512
# Inspecting node 220518078
# Inspecting node 226666386
# Inspecting node 288515399
# Inspecting node 220871206
# Inspecting node 17394737
# Inspecting node 85688497
# Inspecting node 85625597
# Inspecting node 32611097
# Inspecting node 1144689874424999937
# Inspecting node 2465329364
# Inspecting node 149701807
# Inspecting node 26186692
# Inspecting node 23371273
# Inspecting node 3015944460
# Inspecting node 760257132675600386
# Inspecting node 730797462991065088
# Inspecting node 771466526348107776
# Inspecting node 45950539
# Inspecting node 1160209698
# Inspecting node 1109141736972939264
# Inspecting node 169237647
# Inspecting node 1145662294849990656
# Inspecting node 78641250
# Inspecting node 821066393143672836
# Inspecting node 27740019
# Inspecting node 2201466604
# Inspecting node 1361822936
# Inspecting node 21108458
# Inspecting node 382935719
# Inspecting node 1252040788982169600
# Inspecting node 23937700
# Inspecting node 372577100
# Inspecting node 53807352
# Inspecting node 1177551303725240322
# Inspecting node 1252976493971595265
# Inspecting node 441289118
# Inspecting node 897094186213588992
# Inspecting node 3676427473
# Inspecting node 469671065
# Inspecting node 846920964113870848
# Inspecting node 268469213
# Inspecting node 24573102
# Inspecting node 16170023
# Inspecting node 2458783644
# Inspecting node 258405050
# Inspecting node 301144504
# Inspecting node 495918203
# Inspecting node 1239567083404292097
# Inspecting node 536853804
# Inspecting node 250839952
# Inspecting node 856686343144955904
# Inspecting node 981229378825801728
# Inspecting node 1335769353124343808
# Inspecting node 54650770
# Inspecting node 1691207420
# Inspecting node 479862010
# Inspecting node 702598323958620163
# Inspecting node 1197864396
# Inspecting node 272677124
# Inspecting node 54426656
# Inspecting node 1965901333
# Inspecting node 1336451673053679620
# Inspecting node 1442989306256113667
# Inspecting node 516604259
# Inspecting node 1420446766869225478
# Inspecting node 250804618
# Inspecting node 963133478
# Inspecting node 224723351
# Inspecting node 1329430334195208192
# Inspecting node 1107013222853304320
# Inspecting node 216438127
# Inspecting node 56568168
# Inspecting node 2289086672
# Inspecting node 342281222
# Inspecting node 250170548
# Inspecting node 896453296059146240
# Inspecting node 246116520
# Inspecting node 1017842910740410368
# Inspecting node 1281660648
# Inspecting node 818467340895522817
# Inspecting node 2414991108
# Inspecting node 2579229572
# Inspecting node 2568029796
# Inspecting node 1424797446845173778
# Inspecting node 24219018
# Inspecting node 1363912931151384588
# Inspecting node 103031465
# Inspecting node 2211020226
# Inspecting node 1310374181687537664
# Inspecting node 1239007657803026432
# Inspecting node 1384893312797003781
# Inspecting node 1927067096
# Inspecting node 17670732
# Inspecting node 939007961388662784
# Inspecting node 823680319274381312
# Inspecting node 1232369847134121986
# Inspecting node 1337783599446286338
# Inspecting node 17076793
# Inspecting node 1025381606
# Inspecting node 87863020
# Inspecting node 38042361
# Inspecting node 2699710783
# Inspecting node 316245912
# Inspecting node 1375846488031432705
# Inspecting node 8820062
# Inspecting node 1396272483309862913
# Inspecting node 830585528961495040
# Inspecting node 246667561
# Inspecting node 885644906915663872
# Inspecting node 375303344
# Inspecting node 1147137986431258624
# Inspecting node 1171095411307753472
# Inspecting node 18418465
# Inspecting node 590154066
# Inspecting node 59835490
# Inspecting node 1705708466
# Inspecting node 1041561337
# Inspecting node 1486136467
# Inspecting node 2807874943
# Inspecting node 17221430
# Inspecting node 1205581352
# Inspecting node 79121813
# Inspecting node 389705011
# Inspecting node 2190688044
# Inspecting node 715394299207090179
# Inspecting node 1382439377406722048
# Inspecting node 1199890847954882560
# Inspecting node 246380006
# Inspecting node 3179422780
# Inspecting node 36471917
# Inspecting node 23424817
# Inspecting node 9814812
# Inspecting node 840697793618550787
# Inspecting node 730780438269206528
# Inspecting node 294539923
# Inspecting node 1279157580799983617
# Inspecting node 403643684
# Inspecting node 53452624
# Inspecting node 2466115268
# Inspecting node 278882082
# Inspecting node 7562042
# Inspecting node 2395405134
# Inspecting node 18163138
# Inspecting node 865300797130764288
# Inspecting node 1287896006550589442
# Inspecting node 59342468
# Inspecting node 2886941025
# Inspecting node 962424351596281856
# Inspecting node 560765411
# Inspecting node 2924898800
# Inspecting node 1218987476112543744
# Inspecting node 2710528980
# Inspecting node 279748443
# Inspecting node 17702445
# Inspecting node 842121813278752768
# Inspecting node 327394273
# Inspecting node 1012406984719470592
# Inspecting node 10155832
# Inspecting node 439313680
# Inspecting node 1151231204923977729
# Inspecting node 989298765163937792
# Inspecting node 866416675
# Inspecting node 36877221
# Inspecting node 351155835
# Inspecting node 11423372
# Inspecting node 41378883
# Inspecting node 2334251844
# Inspecting node 263163489
# Inspecting node 1096251117745332226
# Inspecting node 1407372687316590594
# Inspecting node 1250830543119319042
# Inspecting node 2903614908
# Inspecting node 1351286814313738243
# Inspecting node 1403372126304866305
# Inspecting node 69712457
# Inspecting node 2730870751
# Inspecting node 16189107
# Inspecting node 414275183
# Inspecting node 393348427
# Inspecting node 248911548
# Inspecting node 34774986
# Inspecting node 1194310568200548352
# Inspecting node 1240872856508137472
# Inspecting node 242533078
# Inspecting node 78084063
# Inspecting node 42232039
# Inspecting node 41239526
# Inspecting node 3112228915
# Inspecting node 1852773120
# Inspecting node 1242517797621530625
# Inspecting node 960897097
# Inspecting node 185290543
# Inspecting node 305945328
# Inspecting node 155777848
# Inspecting node 248891184
# Inspecting node 1357931292
# Inspecting node 1582129344
# Inspecting node 63863473
# Inspecting node 744530425
# Inspecting node 1367957858
# Inspecting node 2469606308
# Inspecting node 326461319
# Inspecting node 529665584
# Inspecting node 154271777
# Inspecting node 1270383308
# Inspecting node 2312086998
# Inspecting node 1447429249
# Inspecting node 2861279433
# Inspecting node 466832463
# Inspecting node 67278150
# Inspecting node 1660911480
# Inspecting node 467664297
# Inspecting node 2573566824
# Inspecting node 132989977
# Inspecting node 954431291629473794
# Inspecting node 238865666
# Inspecting node 2569323896
# Inspecting node 788806262045732864
# Inspecting node 14165217
# Inspecting node 1447951549
# Inspecting node 1594767902
# Inspecting node 491779798
# Inspecting node 946092660795744256
# Inspecting node 74211986
# Inspecting node 524590563
# Inspecting node 1338157627453427713
# Inspecting node 823317383838253056
# Inspecting node 1044778781230039042
# Inspecting node 922963142300143616
# Inspecting node 74937543
# Inspecting node 1305697758
# Inspecting node 18463733
# Inspecting node 76264942
# Inspecting node 2905252436
# Inspecting node 44539994
# Inspecting node 396745864
# Inspecting node 1176801
# Inspecting node 1229442788623818752
# Inspecting node 2993775174
# Inspecting node 2462641501
# Inspecting node 560903736
# Inspecting node 1427351911410257934
# Inspecting node 245651739
# Inspecting node 4922698441
# Inspecting node 4024032261
# Inspecting node 15099646
# Inspecting node 75841164
# Inspecting node 794664236
# Inspecting node 1440828246132596736
# Inspecting node 3069762388
# Inspecting node 700994268
# Inspecting node 1104945319
# Inspecting node 38221378
# Inspecting node 3218932860
# Inspecting node 1201882182
# Inspecting node 1395092719
# Inspecting node 2871728962
# Inspecting node 815428708144218112
# Inspecting node 976143225927839744
# Inspecting node 727212809948401664
# Inspecting node 1373435309782822912
# Inspecting node 568769809
# Inspecting node 982017242354388992
# Inspecting node 36395646
# Inspecting node 40697478
# Inspecting node 1423672567869624322
# Inspecting node 164368721
# Inspecting node 46214091
# Inspecting node 2194496264
# Inspecting node 1057723606027792385
# Inspecting node 25209036
# Inspecting node 1347801793930035200
# Inspecting node 868994263
# Inspecting node 117589552
# Inspecting node 1080529497152278528
# Inspecting node 624962704
# Inspecting node 47022386
# Inspecting node 942370814
# Inspecting node 70499348
# Inspecting node 929856990934790144
# Inspecting node 314093378
# Inspecting node 3053107588
# Inspecting node 1459578954
# Inspecting node 4880637512
# Inspecting node 1932563430
# Inspecting node 1282257536
# Inspecting node 17300548
# Inspecting node 1236439017433989122
# Inspecting node 1444458812614709250
# Inspecting node 1386793782683652096
# Inspecting node 9575562
# Inspecting node 120139457
# Inspecting node 1240478580510871552
# Inspecting node 117562974
# Inspecting node 312422268
# Inspecting node 1333030975681536000
# Inspecting node 1040629333210148865
# Inspecting node 252399534
# Inspecting node 2459730643
# Inspecting node 1264712331457638400
# Inspecting node 1428151019981180932
# Inspecting node 280831905
# Inspecting node 1416101066580627464
# Inspecting node 1135929275272634369
# Inspecting node 360214917
# Inspecting node 1302065426961174530
# Inspecting node 39637553
# Inspecting node 114977658
# Inspecting node 1327696892608724992
# Inspecting node 1409204814534299649
# Inspecting node 371939653
# Inspecting node 190010892
# Inspecting node 1275457555490320385
# Inspecting node 1445833073770184706
# Inspecting node 1601728627
# Inspecting node 41748110
# Inspecting node 1438198932606160901
# Inspecting node 16491468
# Inspecting node 323895654
# Inspecting node 137045661
# Inspecting node 1352682350228942848
# Inspecting node 770683230223634433
# Inspecting node 3368587707
# Inspecting node 1120673221236408320
# Inspecting node 213879574
# Inspecting node 1414982991059709954
# Inspecting node 809651491
# Inspecting node 1491487802
# Inspecting node 4886317138
# Inspecting node 14912051
# Inspecting node 915727372443414528
# Inspecting node 966560892262502400
# Inspecting node 885737117745164288
# Inspecting node 981191210705530880
# Inspecting node 341002490
# Inspecting node 1948425750
# Inspecting node 1391765775594180612
# Inspecting node 1346126893733462016
# Inspecting node 1443254711381946371
# Inspecting node 95348250
# Inspecting node 1351325172184264704
# Inspecting node 487857297
# Inspecting node 94885717
# Inspecting node 925876396878020608
# Inspecting node 15300266
# Inspecting node 1212089073323503616
# Inspecting node 239096810
# Inspecting node 1353758379160834051
# Inspecting node 24728011
# Inspecting node 85640352
# Inspecting node 1012839192253075456
# Inspecting node 1259289117805776896
# Inspecting node 1309184065
# Inspecting node 1881851268
# Inspecting node 132512731
# Inspecting node 1181627354621399040
# Inspecting node 34478789
# Inspecting node 2842764204
# Inspecting node 1034903210547277824
# Inspecting node 1202669441000996864
# Inspecting node 961989099623137280
# Inspecting node 1263895193784184832
# Inspecting node 471366697
# Inspecting node 829731473443975170
# Inspecting node 590822892
# Inspecting node 382409124
# Inspecting node 851681
# Inspecting node 870842873628864513
# Inspecting node 271124533
# Inspecting node 446471174
# Inspecting node 228477243
# Inspecting node 1202388934208172032
# Inspecting node 1060751566657867776
# Inspecting node 257304118
# Inspecting node 4096225454
# Inspecting node 216266808
# Inspecting node 159065078
# Inspecting node 1058391394681868289
# Inspecting node 428602423
# Inspecting node 823397168975409152
# Inspecting node 1345473368494104580
# Inspecting node 46563847
# Inspecting node 2444436240
# Inspecting node 1126848839594467328
# Inspecting node 1257895028724203521
# Inspecting node 277513651
# Inspecting node 1110790944821932034
# Inspecting node 1161332556312326144
# Inspecting node 1346332104234295296
# Inspecting node 165942840
# Inspecting node 259587504
# Inspecting node 1925416346
# Inspecting node 15012924
# Inspecting node 18537391
# Inspecting node 42989776
# Inspecting node 93654204
# Inspecting node 34921899
# Inspecting node 2239987934
# Inspecting node 86320422
# Inspecting node 171411616
# Inspecting node 14650213
# Inspecting node 1087961
# Inspecting node 602903529
# Inspecting node 244204227
# Inspecting node 519071482
# Inspecting node 251635353
# Inspecting node 5654722
# Inspecting node 725037770033532929
# Inspecting node 40059893
# Inspecting node 237480031
# Inspecting node 1056707817216720896
# Inspecting node 1383581104473468929
# Inspecting node 373477857
# Inspecting node 20122522
# Inspecting node 4254675664
# Inspecting node 1259345602980298753
# Inspecting node 725344413162049536
# Inspecting node 1433115420563853312
# Inspecting node 166701763
# Inspecting node 582342806
# Inspecting node 14257934
# Inspecting node 1163072647661522946
# Inspecting node 1201151072733138945
# Inspecting node 1352358388638875652
# Inspecting node 549023337
# Inspecting node 936473743387394048
# Inspecting node 437944231
# Inspecting node 400071841
# Inspecting node 637320913
# Inspecting node 19114577
# Inspecting node 70065285
# Inspecting node 1268920433086210048
# Inspecting node 1176689353885724674
# Inspecting node 460592390
# Inspecting node 2262160692
# Inspecting node 2293461198
# Inspecting node 15219830
# Inspecting node 1201532829860892673
# Inspecting node 92417373
# Inspecting node 122127786
# Inspecting node 362454062
# Inspecting node 2984610092
# Inspecting node 415126004
# Inspecting node 844452866
# Inspecting node 14501713
# Inspecting node 1258440535402065920
# Inspecting node 2254247360
# Inspecting node 104585835
# Inspecting node 1410832490701467650
# Inspecting node 365780558
# Inspecting node 21632994
# Inspecting node 1338474046095233026
# Inspecting node 1113547517105528833
# Inspecting node 293588108
# Inspecting node 1155208255066558475
# Inspecting node 22523896
# Inspecting node 3675933919
# Inspecting node 2796774360
# Inspecting node 1095219121447301120
# Inspecting node 816758120819015680
# Inspecting node 825925386110382080
# Inspecting node 1529643188
# Inspecting node 246811073
# Inspecting node 3351916392
# Inspecting node 123910630
# Inspecting node 29304563
# Inspecting node 1396107226608283649
# Inspecting node 549598823
# Inspecting node 797133264716754944
# Inspecting node 768559569891012608
# Inspecting node 1880517650
# Inspecting node 1232471924145577985
# Inspecting node 1300309398166949889
# Inspecting node 1923754400
# Inspecting node 53754232
# Inspecting node 307324209
# Inspecting node 3165242127
# Inspecting node 730826158258946050
# Inspecting node 1577656471
# Inspecting node 1214368702277308421
# Inspecting node 299993498
# Inspecting node 1235344992765448193
# Inspecting node 625193066
# Inspecting node 467817388
# Inspecting node 3135148227
# Inspecting node 872810605
# Inspecting node 271504586
# Inspecting node 306967462
# Inspecting node 3299469609
# Inspecting node 1225848216467509248
# Inspecting node 259388196
# Inspecting node 525910396
# Inspecting node 358143304
# Inspecting node 1088545656002801664
# Inspecting node 1283460034182209537
# Inspecting node 1326306504027287554
# Inspecting node 100874975
# Inspecting node 811549418
# Inspecting node 145058470
# Inspecting node 15892547
# Inspecting node 2797935107
# Inspecting node 27388441
# Inspecting node 288495993
# Inspecting node 77596220
# Inspecting node 891058415195303939
# Inspecting node 1095768409449459712
# Inspecting node 881426857
# Inspecting node 17388526

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.out_degree(node) 
    for key, value in out_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
degrees = {}
in_degrees = {}
out_degrees = {}

dirname = "Directed_Unweighted_Models/Group3"
directory = os.fsencode(dirname)

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    H = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    degree_dist = {}
    in_degree_dist = {}
    out_degree_dist = {}
    
    for node in H:
        degree_dist[node] = H.degree(node)
        in_degree_dist[node] = H.in_degree(node)
        out_degree_dist[node] = H.out_degree(node)
    degrees[filename] = degree_dist
    in_degrees[filename] = in_degree_dist
    out_degrees[filename] = out_degree_dist
# Out:
# Directed_Unweighted_Random_Null_Model_1112
# Directed_Unweighted_Random_Null_Model_1113
# Directed_Unweighted_Random_Null_Model_1114
# Directed_Unweighted_Random_Null_Model_1115
# Directed_Unweighted_Random_Null_Model_1116
# Directed_Unweighted_Random_Null_Model_1117
# Directed_Unweighted_Random_Null_Model_1118
# Directed_Unweighted_Random_Null_Model_1119
# Directed_Unweighted_Random_Null_Model_1120
# Directed_Unweighted_Random_Null_Model_1121
# Directed_Unweighted_Random_Null_Model_1122
# Directed_Unweighted_Random_Null_Model_1123
# Directed_Unweighted_Random_Null_Model_1124
# Directed_Unweighted_Random_Null_Model_1125
# Directed_Unweighted_Random_Null_Model_1126
# Directed_Unweighted_Random_Null_Model_1127
# Directed_Unweighted_Random_Null_Model_1128
# Directed_Unweighted_Random_Null_Model_1129
# Directed_Unweighted_Random_Null_Model_2000
# Directed_Unweighted_Random_Null_Model_2001
# Directed_Unweighted_Random_Null_Model_2002
# Directed_Unweighted_Random_Null_Model_2003
# Directed_Unweighted_Random_Null_Model_2004
# Directed_Unweighted_Random_Null_Model_2005
# Directed_Unweighted_Random_Null_Model_2006
# Directed_Unweighted_Random_Null_Model_2007
# Directed_Unweighted_Random_Null_Model_2008
# Directed_Unweighted_Random_Null_Model_2009
# Directed_Unweighted_Random_Null_Model_2010
# Directed_Unweighted_Random_Null_Model_2011
# Directed_Unweighted_Random_Null_Model_2012
# Directed_Unweighted_Random_Null_Model_2013
# Directed_Unweighted_Random_Null_Model_2014
# Directed_Unweighted_Random_Null_Model_2015
# Directed_Unweighted_Random_Null_Model_2016
# Directed_Unweighted_Random_Null_Model_2017
# Directed_Unweighted_Random_Null_Model_2018
# Directed_Unweighted_Random_Null_Model_2019
# Directed_Unweighted_Random_Null_Model_2020
# Directed_Unweighted_Random_Null_Model_2021
# Directed_Unweighted_Random_Null_Model_2022
# Directed_Unweighted_Random_Null_Model_2023
# Directed_Unweighted_Random_Null_Model_2024
# Directed_Unweighted_Random_Null_Model_2025
# Directed_Unweighted_Random_Null_Model_2026
# Directed_Unweighted_Random_Null_Model_2027
# Directed_Unweighted_Random_Null_Model_2028
# Directed_Unweighted_Random_Null_Model_2029
# Directed_Unweighted_Random_Null_Model_2030
# Directed_Unweighted_Random_Null_Model_2031
# Directed_Unweighted_Random_Null_Model_2032
# Directed_Unweighted_Random_Null_Model_2033
# Directed_Unweighted_Random_Null_Model_2034
# Directed_Unweighted_Random_Null_Model_2035
# Directed_Unweighted_Random_Null_Model_2036
# Directed_Unweighted_Random_Null_Model_2037
# Directed_Unweighted_Random_Null_Model_2038
# Directed_Unweighted_Random_Null_Model_2039
# Directed_Unweighted_Random_Null_Model_2040
# Directed_Unweighted_Random_Null_Model_2041
# Directed_Unweighted_Random_Null_Model_2042
# Directed_Unweighted_Random_Null_Model_2043
# Directed_Unweighted_Random_Null_Model_2044
# Directed_Unweighted_Random_Null_Model_2045
# Directed_Unweighted_Random_Null_Model_2046
# Directed_Unweighted_Random_Null_Model_2047
# Directed_Unweighted_Random_Null_Model_2048
# Directed_Unweighted_Random_Null_Model_2049
# Directed_Unweighted_Random_Null_Model_2050
# Directed_Unweighted_Random_Null_Model_2051
# Directed_Unweighted_Random_Null_Model_2052
# Directed_Unweighted_Random_Null_Model_2053
# Directed_Unweighted_Random_Null_Model_2054
# Directed_Unweighted_Random_Null_Model_2055
# Directed_Unweighted_Random_Null_Model_2056
# Directed_Unweighted_Random_Null_Model_2057
# Directed_Unweighted_Random_Null_Model_2058
# Directed_Unweighted_Random_Null_Model_2059
# Directed_Unweighted_Random_Null_Model_2060
# Directed_Unweighted_Random_Null_Model_2061
# Directed_Unweighted_Random_Null_Model_2062
# Directed_Unweighted_Random_Null_Model_2063
# Directed_Unweighted_Random_Null_Model_2064
# Directed_Unweighted_Random_Null_Model_2065
# Directed_Unweighted_Random_Null_Model_2066
# Directed_Unweighted_Random_Null_Model_2067
# Directed_Unweighted_Random_Null_Model_2068
# Directed_Unweighted_Random_Null_Model_2069
# Directed_Unweighted_Random_Null_Model_2070
# Directed_Unweighted_Random_Null_Model_2071
# Directed_Unweighted_Random_Null_Model_2072
# Directed_Unweighted_Random_Null_Model_2073
# Directed_Unweighted_Random_Null_Model_2074
# Directed_Unweighted_Random_Null_Model_2075
# Directed_Unweighted_Random_Null_Model_2076
# Directed_Unweighted_Random_Null_Model_2077
# Directed_Unweighted_Random_Null_Model_2078
# Directed_Unweighted_Random_Null_Model_2079
# Directed_Unweighted_Random_Null_Model_2080
# Directed_Unweighted_Random_Null_Model_2081
# Directed_Unweighted_Random_Null_Model_2082
# Directed_Unweighted_Random_Null_Model_2083
# Directed_Unweighted_Random_Null_Model_2084
# Directed_Unweighted_Random_Null_Model_2085
# Directed_Unweighted_Random_Null_Model_2086

# %% [markdown]
# Go through each degree node in G and for each of the models check if some degree is different. If it is stop and report it

# %%
G = nx.read_edgelist('largest_component_networkx_format.csv', comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=',', 
                     nodetype=int, 
                     encoding='utf-8')

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.degree(node) 
    for key, value in degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %% [markdown]
# Okay I have confirmed Degree is being respected for these 50 models

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.in_degree(node) 
    for key, value in in_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.out_degree(node) 
    for key, value in out_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
degrees = {}
in_degrees = {}
out_degrees = {}

dirname = "Directed_Unweighted_Models/Group4"
directory = os.fsencode(dirname)

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    H = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    degree_dist = {}
    in_degree_dist = {}
    out_degree_dist = {}
    
    for node in H:
        degree_dist[node] = H.degree(node)
        in_degree_dist[node] = H.in_degree(node)
        out_degree_dist[node] = H.out_degree(node)
    degrees[filename] = degree_dist
    in_degrees[filename] = in_degree_dist
    out_degrees[filename] = out_degree_dist
# Out:
# Directed_Unweighted_Random_Null_Model_1000
# Directed_Unweighted_Random_Null_Model_1001
# Directed_Unweighted_Random_Null_Model_1002
# Directed_Unweighted_Random_Null_Model_1003
# Directed_Unweighted_Random_Null_Model_1004
# Directed_Unweighted_Random_Null_Model_1005
# Directed_Unweighted_Random_Null_Model_1006
# Directed_Unweighted_Random_Null_Model_1007
# Directed_Unweighted_Random_Null_Model_1008
# Directed_Unweighted_Random_Null_Model_1009
# Directed_Unweighted_Random_Null_Model_1010
# Directed_Unweighted_Random_Null_Model_1011
# Directed_Unweighted_Random_Null_Model_1012
# Directed_Unweighted_Random_Null_Model_1013
# Directed_Unweighted_Random_Null_Model_1014
# Directed_Unweighted_Random_Null_Model_1015
# Directed_Unweighted_Random_Null_Model_1016
# Directed_Unweighted_Random_Null_Model_1017
# Directed_Unweighted_Random_Null_Model_1018
# Directed_Unweighted_Random_Null_Model_1019
# Directed_Unweighted_Random_Null_Model_1020
# Directed_Unweighted_Random_Null_Model_1021
# Directed_Unweighted_Random_Null_Model_1022
# Directed_Unweighted_Random_Null_Model_1023
# Directed_Unweighted_Random_Null_Model_1024
# Directed_Unweighted_Random_Null_Model_1025
# Directed_Unweighted_Random_Null_Model_1026
# Directed_Unweighted_Random_Null_Model_1027
# Directed_Unweighted_Random_Null_Model_1028
# Directed_Unweighted_Random_Null_Model_1029
# Directed_Unweighted_Random_Null_Model_1030
# Directed_Unweighted_Random_Null_Model_1031
# Directed_Unweighted_Random_Null_Model_1032
# Directed_Unweighted_Random_Null_Model_1033
# Directed_Unweighted_Random_Null_Model_1034
# Directed_Unweighted_Random_Null_Model_1035
# Directed_Unweighted_Random_Null_Model_1036
# Directed_Unweighted_Random_Null_Model_1037
# Directed_Unweighted_Random_Null_Model_1038
# Directed_Unweighted_Random_Null_Model_1039
# Directed_Unweighted_Random_Null_Model_1040
# Directed_Unweighted_Random_Null_Model_1041
# Directed_Unweighted_Random_Null_Model_1042
# Directed_Unweighted_Random_Null_Model_1043
# Directed_Unweighted_Random_Null_Model_1044
# Directed_Unweighted_Random_Null_Model_1045
# Directed_Unweighted_Random_Null_Model_1046
# Directed_Unweighted_Random_Null_Model_1047
# Directed_Unweighted_Random_Null_Model_1048
# Directed_Unweighted_Random_Null_Model_1049
# Directed_Unweighted_Random_Null_Model_1050
# Directed_Unweighted_Random_Null_Model_1051
# Directed_Unweighted_Random_Null_Model_1052
# Directed_Unweighted_Random_Null_Model_1053
# Directed_Unweighted_Random_Null_Model_1054
# Directed_Unweighted_Random_Null_Model_1055
# Directed_Unweighted_Random_Null_Model_1056
# Directed_Unweighted_Random_Null_Model_1057
# Directed_Unweighted_Random_Null_Model_1058
# Directed_Unweighted_Random_Null_Model_1059
# Directed_Unweighted_Random_Null_Model_1060
# Directed_Unweighted_Random_Null_Model_1061
# Directed_Unweighted_Random_Null_Model_1062
# Directed_Unweighted_Random_Null_Model_1063
# Directed_Unweighted_Random_Null_Model_1064
# Directed_Unweighted_Random_Null_Model_1065
# Directed_Unweighted_Random_Null_Model_1066
# Directed_Unweighted_Random_Null_Model_1067
# Directed_Unweighted_Random_Null_Model_1068
# Directed_Unweighted_Random_Null_Model_1069
# Directed_Unweighted_Random_Null_Model_1070
# Directed_Unweighted_Random_Null_Model_1071
# Directed_Unweighted_Random_Null_Model_1072
# Directed_Unweighted_Random_Null_Model_1073
# Directed_Unweighted_Random_Null_Model_1074
# Directed_Unweighted_Random_Null_Model_1075
# Directed_Unweighted_Random_Null_Model_1076
# Directed_Unweighted_Random_Null_Model_1077
# Directed_Unweighted_Random_Null_Model_1078
# Directed_Unweighted_Random_Null_Model_1079
# Directed_Unweighted_Random_Null_Model_1080
# Directed_Unweighted_Random_Null_Model_1081
# Directed_Unweighted_Random_Null_Model_1082
# Directed_Unweighted_Random_Null_Model_1083
# Directed_Unweighted_Random_Null_Model_1084
# Directed_Unweighted_Random_Null_Model_1085
# Directed_Unweighted_Random_Null_Model_1086
# Directed_Unweighted_Random_Null_Model_1087
# Directed_Unweighted_Random_Null_Model_1088
# Directed_Unweighted_Random_Null_Model_1089
# Directed_Unweighted_Random_Null_Model_1090
# Directed_Unweighted_Random_Null_Model_1091
# Directed_Unweighted_Random_Null_Model_1092
# Directed_Unweighted_Random_Null_Model_1093
# Directed_Unweighted_Random_Null_Model_1094
# Directed_Unweighted_Random_Null_Model_1095
# Directed_Unweighted_Random_Null_Model_1096
# Directed_Unweighted_Random_Null_Model_1097
# Directed_Unweighted_Random_Null_Model_1098
# Directed_Unweighted_Random_Null_Model_1099
# Directed_Unweighted_Random_Null_Model_1100
# Directed_Unweighted_Random_Null_Model_1101
# Directed_Unweighted_Random_Null_Model_1102
# Directed_Unweighted_Random_Null_Model_1103
# Directed_Unweighted_Random_Null_Model_1104
# Directed_Unweighted_Random_Null_Model_1105
# Directed_Unweighted_Random_Null_Model_1106
# Directed_Unweighted_Random_Null_Model_1107
# Directed_Unweighted_Random_Null_Model_1108
# Directed_Unweighted_Random_Null_Model_1109
# Directed_Unweighted_Random_Null_Model_1110
# Directed_Unweighted_Random_Null_Model_1111
# Directed_Unweighted_Random_Null_Model_600
# Directed_Unweighted_Random_Null_Model_601
# Directed_Unweighted_Random_Null_Model_602
# Directed_Unweighted_Random_Null_Model_603
# Directed_Unweighted_Random_Null_Model_604
# Directed_Unweighted_Random_Null_Model_605
# Directed_Unweighted_Random_Null_Model_606
# Directed_Unweighted_Random_Null_Model_607
# Directed_Unweighted_Random_Null_Model_608
# Directed_Unweighted_Random_Null_Model_609
# Directed_Unweighted_Random_Null_Model_610
# Directed_Unweighted_Random_Null_Model_611
# Directed_Unweighted_Random_Null_Model_612
# Directed_Unweighted_Random_Null_Model_613
# Directed_Unweighted_Random_Null_Model_614
# Directed_Unweighted_Random_Null_Model_615
# Directed_Unweighted_Random_Null_Model_616
# Directed_Unweighted_Random_Null_Model_617
# Directed_Unweighted_Random_Null_Model_618
# Directed_Unweighted_Random_Null_Model_619
# Directed_Unweighted_Random_Null_Model_620
# Directed_Unweighted_Random_Null_Model_621
# Directed_Unweighted_Random_Null_Model_622
# Directed_Unweighted_Random_Null_Model_623
# Directed_Unweighted_Random_Null_Model_624
# Directed_Unweighted_Random_Null_Model_625
# Directed_Unweighted_Random_Null_Model_626
# Directed_Unweighted_Random_Null_Model_627
# Directed_Unweighted_Random_Null_Model_628
# Directed_Unweighted_Random_Null_Model_629
# Directed_Unweighted_Random_Null_Model_630
# Directed_Unweighted_Random_Null_Model_631
# Directed_Unweighted_Random_Null_Model_632
# Directed_Unweighted_Random_Null_Model_633
# Directed_Unweighted_Random_Null_Model_634

# %% [markdown]
# Go through each degree node in G and for each of the models check if some degree is different. If it is stop and report it

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.degree(node) 
    for key, value in degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %% [markdown]
# Okay I have confirmed Degree is being respected for these 50 models

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.in_degree(node) 
    for key, value in in_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.out_degree(node) 
    for key, value in out_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
degrees = {}
in_degrees = {}
out_degrees = {}

dirname = "Directed_Unweighted_Models/Group5"
directory = os.fsencode(dirname)

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    print(filename)
    H = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    degree_dist = {}
    in_degree_dist = {}
    out_degree_dist = {}
    
    for node in H:
        degree_dist[node] = H.degree(node)
        in_degree_dist[node] = H.in_degree(node)
        out_degree_dist[node] = H.out_degree(node)
    degrees[filename] = degree_dist
    in_degrees[filename] = in_degree_dist
    out_degrees[filename] = out_degree_dist
# Out:
# Directed_Unweighted_Random_Null_Model_2087
# Directed_Unweighted_Random_Null_Model_2088
# Directed_Unweighted_Random_Null_Model_2089
# Directed_Unweighted_Random_Null_Model_2090
# Directed_Unweighted_Random_Null_Model_2091
# Directed_Unweighted_Random_Null_Model_2092
# Directed_Unweighted_Random_Null_Model_2093
# Directed_Unweighted_Random_Null_Model_2094
# Directed_Unweighted_Random_Null_Model_2095
# Directed_Unweighted_Random_Null_Model_2096
# Directed_Unweighted_Random_Null_Model_2097
# Directed_Unweighted_Random_Null_Model_2098
# Directed_Unweighted_Random_Null_Model_2099
# Directed_Unweighted_Random_Null_Model_2100
# Directed_Unweighted_Random_Null_Model_2101
# Directed_Unweighted_Random_Null_Model_2102
# Directed_Unweighted_Random_Null_Model_2103
# Directed_Unweighted_Random_Null_Model_2104
# Directed_Unweighted_Random_Null_Model_2105
# Directed_Unweighted_Random_Null_Model_2106
# Directed_Unweighted_Random_Null_Model_2107
# Directed_Unweighted_Random_Null_Model_2108
# Directed_Unweighted_Random_Null_Model_2109
# Directed_Unweighted_Random_Null_Model_2110
# Directed_Unweighted_Random_Null_Model_2111
# Directed_Unweighted_Random_Null_Model_2112
# Directed_Unweighted_Random_Null_Model_2113
# Directed_Unweighted_Random_Null_Model_2114
# Directed_Unweighted_Random_Null_Model_2115
# Directed_Unweighted_Random_Null_Model_2116
# Directed_Unweighted_Random_Null_Model_2117
# Directed_Unweighted_Random_Null_Model_2118
# Directed_Unweighted_Random_Null_Model_2119
# Directed_Unweighted_Random_Null_Model_2120
# Directed_Unweighted_Random_Null_Model_2121
# Directed_Unweighted_Random_Null_Model_2122
# Directed_Unweighted_Random_Null_Model_2123
# Directed_Unweighted_Random_Null_Model_2124
# Directed_Unweighted_Random_Null_Model_2125
# Directed_Unweighted_Random_Null_Model_2126
# Directed_Unweighted_Random_Null_Model_2127
# Directed_Unweighted_Random_Null_Model_2128
# Directed_Unweighted_Random_Null_Model_2129
# Directed_Unweighted_Random_Null_Model_2130
# Directed_Unweighted_Random_Null_Model_2131
# Directed_Unweighted_Random_Null_Model_2132
# Directed_Unweighted_Random_Null_Model_2133
# Directed_Unweighted_Random_Null_Model_2134
# Directed_Unweighted_Random_Null_Model_2135
# Directed_Unweighted_Random_Null_Model_2136
# Directed_Unweighted_Random_Null_Model_2137
# Directed_Unweighted_Random_Null_Model_2138
# Directed_Unweighted_Random_Null_Model_2139
# Directed_Unweighted_Random_Null_Model_2140
# Directed_Unweighted_Random_Null_Model_2141
# Directed_Unweighted_Random_Null_Model_2142
# Directed_Unweighted_Random_Null_Model_2143
# Directed_Unweighted_Random_Null_Model_2144
# Directed_Unweighted_Random_Null_Model_2145
# Directed_Unweighted_Random_Null_Model_2146
# Directed_Unweighted_Random_Null_Model_2147
# Directed_Unweighted_Random_Null_Model_2148
# Directed_Unweighted_Random_Null_Model_2149
# Directed_Unweighted_Random_Null_Model_2150
# Directed_Unweighted_Random_Null_Model_2151
# Directed_Unweighted_Random_Null_Model_2152
# Directed_Unweighted_Random_Null_Model_2153
# Directed_Unweighted_Random_Null_Model_2154
# Directed_Unweighted_Random_Null_Model_2155
# Directed_Unweighted_Random_Null_Model_2156
# Directed_Unweighted_Random_Null_Model_2157
# Directed_Unweighted_Random_Null_Model_2158
# Directed_Unweighted_Random_Null_Model_2159
# Directed_Unweighted_Random_Null_Model_2160
# Directed_Unweighted_Random_Null_Model_2161
# Directed_Unweighted_Random_Null_Model_2162
# Directed_Unweighted_Random_Null_Model_2163
# Directed_Unweighted_Random_Null_Model_2164
# Directed_Unweighted_Random_Null_Model_2165
# Directed_Unweighted_Random_Null_Model_2166
# Directed_Unweighted_Random_Null_Model_2167
# Directed_Unweighted_Random_Null_Model_2168
# Directed_Unweighted_Random_Null_Model_2169
# Directed_Unweighted_Random_Null_Model_2170
# Directed_Unweighted_Random_Null_Model_2171
# Directed_Unweighted_Random_Null_Model_2172
# Directed_Unweighted_Random_Null_Model_2173
# Directed_Unweighted_Random_Null_Model_2174
# Directed_Unweighted_Random_Null_Model_2175
# Directed_Unweighted_Random_Null_Model_2176
# Directed_Unweighted_Random_Null_Model_2177
# Directed_Unweighted_Random_Null_Model_2178
# Directed_Unweighted_Random_Null_Model_2179
# Directed_Unweighted_Random_Null_Model_2180
# Directed_Unweighted_Random_Null_Model_2181
# Directed_Unweighted_Random_Null_Model_2182
# Directed_Unweighted_Random_Null_Model_2183
# Directed_Unweighted_Random_Null_Model_2184
# Directed_Unweighted_Random_Null_Model_2185
# Directed_Unweighted_Random_Null_Model_2186
# Directed_Unweighted_Random_Null_Model_2187
# Directed_Unweighted_Random_Null_Model_2188
# Directed_Unweighted_Random_Null_Model_2189
# Directed_Unweighted_Random_Null_Model_2190
# Directed_Unweighted_Random_Null_Model_2191
# Directed_Unweighted_Random_Null_Model_2192
# Directed_Unweighted_Random_Null_Model_2193
# Directed_Unweighted_Random_Null_Model_2194
# Directed_Unweighted_Random_Null_Model_2195
# Directed_Unweighted_Random_Null_Model_2196
# Directed_Unweighted_Random_Null_Model_2197
# Directed_Unweighted_Random_Null_Model_2198
# Directed_Unweighted_Random_Null_Model_2199
# Directed_Unweighted_Random_Null_Model_2200
# Directed_Unweighted_Random_Null_Model_2201
# Directed_Unweighted_Random_Null_Model_2202
# Directed_Unweighted_Random_Null_Model_2203
# Directed_Unweighted_Random_Null_Model_2204
# Directed_Unweighted_Random_Null_Model_2205
# Directed_Unweighted_Random_Null_Model_2206
# Directed_Unweighted_Random_Null_Model_2207
# Directed_Unweighted_Random_Null_Model_2208
# Directed_Unweighted_Random_Null_Model_2209
# Directed_Unweighted_Random_Null_Model_2210
# Directed_Unweighted_Random_Null_Model_2211
# Directed_Unweighted_Random_Null_Model_2212
# Directed_Unweighted_Random_Null_Model_2213
# Directed_Unweighted_Random_Null_Model_2214
# Directed_Unweighted_Random_Null_Model_2215
# Directed_Unweighted_Random_Null_Model_2216
# Directed_Unweighted_Random_Null_Model_2217
# Directed_Unweighted_Random_Null_Model_2218
# Directed_Unweighted_Random_Null_Model_2219
# Directed_Unweighted_Random_Null_Model_2220
# Directed_Unweighted_Random_Null_Model_2221
# Directed_Unweighted_Random_Null_Model_2222
# Directed_Unweighted_Random_Null_Model_2223
# Directed_Unweighted_Random_Null_Model_2224
# Directed_Unweighted_Random_Null_Model_2225
# Directed_Unweighted_Random_Null_Model_2226
# Directed_Unweighted_Random_Null_Model_2227
# Directed_Unweighted_Random_Null_Model_2228
# Directed_Unweighted_Random_Null_Model_2229
# Directed_Unweighted_Random_Null_Model_2230
# Directed_Unweighted_Random_Null_Model_2231
# Directed_Unweighted_Random_Null_Model_2232
# Directed_Unweighted_Random_Null_Model_2233
# Directed_Unweighted_Random_Null_Model_2234
# Directed_Unweighted_Random_Null_Model_2235
# Directed_Unweighted_Random_Null_Model_2236
# Directed_Unweighted_Random_Null_Model_2237
# Directed_Unweighted_Random_Null_Model_2238
# Directed_Unweighted_Random_Null_Model_2239
# Directed_Unweighted_Random_Null_Model_2240
# Directed_Unweighted_Random_Null_Model_2241
# Directed_Unweighted_Random_Null_Model_2242
# Directed_Unweighted_Random_Null_Model_2243
# Directed_Unweighted_Random_Null_Model_2244
# Directed_Unweighted_Random_Null_Model_2245
# Directed_Unweighted_Random_Null_Model_2246
# Directed_Unweighted_Random_Null_Model_2247
# Directed_Unweighted_Random_Null_Model_2248
# Directed_Unweighted_Random_Null_Model_2249

# %% [markdown]
# Go through each degree node in G and for each of the models check if some degree is different. If it is stop and report it

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.degree(node) 
    for key, value in degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %% [markdown]
# Okay I have confirmed Degree is being respected for these 50 models

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.in_degree(node) 
    for key, value in in_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %%
for node in G:
#     print("Inspecting node {}".format(node))
    expectedDeg = G.out_degree(node) 
    for key, value in out_degrees.items():
        if (value[node] !=expectedDeg ):
            print("Error, In-Degree not the same for node {}. Expected: {} Received: {}.".format(node, expectedDeg, value[node]))
            break

# %% [markdown]
# I have confirmed that all Models have the same in and out degree distribution as G
