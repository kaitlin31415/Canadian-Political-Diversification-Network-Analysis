# %%
import networkx as nx
import pandas as pd

# %%
clustering_coefs_filename = "Group1_clustering_coefs.csv"
apl_filename = "Group1_apl.csv"
deg_cen_pd = "Group1_deg_cen_df.csv"
in_deg_cen_pd = "Group1_out_deg_cen_df.csv"
out_deg_cen_pd = "Group1_in_deg_cen_df.csv"
eigenvector_cen_pd = "Group1_eigenvector_cen_df.csv"
betweenness_cen_pd = "Group1_betweenness_cen_df.csv"

clustering_pd = "Group1_clustering_df.csv"
path_length_pd = "Group1_path_length_df.csv"

# %%
def persist_centrality_to_csv(centrality_dict, filename,columnname):
    #open the current csv
    persisted = pd.read_csv(filename)
    curr = pd.DataFrame.from_dict(centrality_dict, orient="index", columns = [columnname])
    persisted = persisted.set_index("Unnamed: 0")
    persisted = persisted.merge(curr, left_index=True, right_index=True)
    persisted.to_csv(filename)

# %%
def persist_first_to_csv(centrality_dict, filename,columnname):
    curr = pd.DataFrame.from_dict(centrality_dict, orient="index", columns = [columnname])
    curr.to_csv(filename)

# %%
average_shortest_paths = []
average_clustering = []

# %%
filename = "Directed_Unweighted_Models/TestGroup/Directed_Unweighted_Random_Null_Model_0"
G = nx.read_edgelist("Directed_Unweighted_Models/TestGroup/Directed_Unweighted_Random_Null_Model_0", comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
average_shortest_paths.append(nx.average_shortest_path_length(G))
average_clustering.append(nx.average_clustering(G))
print(type(nx.clustering(G)))

persist_first_to_csv(nx.clustering(G),clustering_pd,"filename")
persist_first_to_csv(nx.degree_centrality(G),deg_cen_pd,filename)
persist_first_to_csv(nx.in_degree_centrality(G),in_deg_cen_pd,filename)
persist_first_to_csv(nx.out_degree_centrality(G),out_deg_cen_pd,filename)
persist_first_to_csv(nx.eigenvector_centrality(G),eigenvector_cen_pd,filename)
persist_first_to_csv(nx.betweenness_centrality(G,k=None, normalized=True),betweenness_cen_pd,filename)
# Out:
# <class 'dict'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\kaitlin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1670                 blocks = [
# -> 1671                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1672                 ]
#
# c:\users\kaitlin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2743
# -> 2744     return klass(values, ndim=ndim, placement=placement)
#    2745
#
# c:\users\kaitlin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     130             raise ValueError(
# ...

# %%
filename = "Directed_Unweighted_Models/TestGroup/Directed_Unweighted_Random_Null_Model_1"
G = nx.read_edgelist("Directed_Unweighted_Models/TestGroup/Directed_Unweighted_Random_Null_Model_1", comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
average_shortest_paths.append(nx.average_shortest_path_length(G))
average_clustering.append(nx.average_clustering(G))
print(type(nx.clustering(G)))
# Out:
# <class 'dict'>

# %%
 persisted = pd.read_csv(clustering_pd)

# %%
persisted
# Out:
#                Unnamed: 0  filename
# 0     1385933370090209280  0.000000
# 1                20139753  0.000000
# 2     1416535505454338050  0.000000
# 3                23491400  0.000067
# 4              1319298517  0.004762
# ...                   ...       ...
# 8927             77596220  0.000000
# 8928   891058415195303939  0.000000
# 8929  1095768409449459712  0.000000
# 8930            881426857  0.000000
# 8931             17388526  0.000000
#
# [8932 rows x 2 columns]

# %%
persisted.set_index("Unnamed: 0")
# Out:
#                      filename
# Unnamed: 0
# 1385933370090209280  0.000000
# 20139753             0.000000
# 1416535505454338050  0.000000
# 23491400             0.000067
# 1319298517           0.004762
# ...                       ...
# 77596220             0.000000
# 891058415195303939   0.000000
# 1095768409449459712  0.000000
# 881426857            0.000000
# 17388526             0.000000
#
# [8932 rows x 1 columns]

# %%
curr = pd.DataFrame.from_dict(nx.degree_centrality(G), orient="index", columns = ["Directed_Unweighted_Random_Null_Model_1"])

# %%
curr
# Out:
#                      Directed_Unweighted_Random_Null_Model_1
# 1385933370090209280                                 0.000112
# 20139753                                            0.006606
# 1416535505454338050                                 0.000224
# 23491400                                            0.013772
# 1319298517                                          0.001680
# ...                                                      ...
# 77596220                                            0.000112
# 891058415195303939                                  0.000112
# 1095768409449459712                                 0.000112
# 881426857                                           0.000112
# 17388526                                            0.000112
#
# [8932 rows x 1 columns]

# %%
import os
dirname = 'Directed_Unweighted_Models/TestGroup'
directory = os.fsencode(dirname)

average_shortest_paths = []
average_clustering = []

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    G = nx.read_edgelist(dirname + '/' + filename, comments='#',
                     create_using=nx.DiGraph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')
    average_shortest_paths.append(nx.average_shortest_path_length(G))
    average_clustering.append(nx.average_clustering(G))
    

    persist_centrality_to_csv(nx.clustering(G),clustering_pd,filename)
    persist_centrality_to_csv(nx.degree_centrality(G),deg_cen_pd,filename)
    persist_centrality_to_csv(nx.in_degree_centrality(G),in_deg_cen_pd,filename)
    persist_centrality_to_csv(nx.out_degree_centrality(G),out_deg_cen_pd,filename)
    persist_centrality_to_csv(nx.eigenvector_centrality(G),eigenvector_cen_pd,filename)
    persist_centrality_to_csv(nx.betweenness_centrality(G,k=None, normalized=True),betweenness_cen_pd,filename)
    
    
print(average_clustering)
print(average_shortest_paths)
# Out:
# [0.001668921062299448, 0.0020126005874050675, 0.0019058125798674989, 0.0014705744516620971]
# [0.0010475520564362606, 0.0018425082421468508, 0.002158171598014995, 0.0027854492543545398]

# %%
test = pd.read_csv(clustering_pd)

# %%
# Out:
#          Unnamed: 0     filename  Directed_Unweighted_Random_Null_Model_0  \
# count  8.932000e+03  8932.000000                              8932.000000
# mean   3.838540e+17     0.001669                                 0.001669
# std    5.493847e+17     0.023133                                 0.023133
# min    2.460000e+02     0.000000                                 0.000000
# 25%    2.456144e+08     0.000000                                 0.000000
# 50%    1.611561e+09     0.000000                                 0.000000
# 75%    9.594433e+17     0.000000                                 0.000000
# max    1.449406e+18     0.500000                                 0.500000
#
#        Directed_Unweighted_Random_Null_Model_1  \
# count                              8932.000000
# mean                                  0.002013
# std                                   0.026453
# min                                   0.000000
# 25%                                   0.000000
# ...
