# %%
import random
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

import math

# %matplotlib inline

# %%
G = nx.DiGraph() 
G.add_edge(1, 2)
G.add_edge(2, 3)
G.add_edge(4, 3)
G.add_edge(3, 5)
G.add_edge(4, 5)
G.add_edge(5, 6)

G[1][2]["weight"] = 10
G[2][3]["weight"] = 9
G[4][3]["weight"] = 8
G[3][5]["weight"] = 7
G[4][5]["weight"] = 6
G[5][6]["weight"] = 5

# %%
G[2][3]["weight"]
# Out:
# 9

# %%
def directed_connected_double_edge_swap_weighted(G, nswap=1, _window_threshold=3, seed=None):
    """Attempts the specified number of double-edge swaps in the graph `G`.

    A double-edge swap selects two random edges
    and creates the new edges u->x and v->y::

     u-->v           u-->y
            becomes  
     x-->y           x-->v
     edge weight from u-->v becomes the edge weight for u-->y
     
     edge weight from x-->y becomes the edge weight for x-->v
     

    If either `(u, x)` or `(v, y)` already exist, then no swap is performed
    so the actual number of swapped edges is always *at most* `nswap`.

    Parameters
    ----------
    G : graph
       An undirected graph

    nswap : integer (optional, default=1)
       Number of double-edge swaps to perform

    _window_threshold : integer

       The window size below which connectedness of the graph will be checked
       after each swap.

       The "window" in this function is a dynamically updated integer that
       represents the number of swap attempts to make before checking if the
       graph remains connected. It is an optimization used to decrease the
       running time of the algorithm in exchange for increased complexity of
       implementation.

       If the window size is below this threshold, then the algorithm checks
       after each swap if the graph remains connected by checking if there is a
       path joining the two nodes whose edge was just removed. If the window
       size is above this threshold, then the algorithm performs do all the
       swaps in the window and only then check if the graph is still connected.

    seed : integer, random_state, or None (default)
        Indicator of random number generation state.
        See :ref:`Randomness<randomness>`.

    Returns
    -------
    int
       The number of successful swaps

    Raises
    ------

    NetworkXError

       If the input graph is not connected, or if the graph has fewer than four
       nodes.

    Notes
    -----

    The initial graph `G` must be connected, and the resulting graph is
    connected. The graph `G` is modified in place.

    References
    ----------
    .. [1] C. Gkantsidis and M. Mihail and E. Zegura,
           The Markov chain simulation method for generating connected
           power law random graphs, 2003.
           http://citeseer.ist.psu.edu/gkantsidis03markov.html
    """
    if not nx.is_weakly_connected(G):
        raise nx.NetworkXError("Graph not connected")

    n = 0
    swapcount = 0
    deg = G.degree()
    # Label key for nodes
    keys, degrees = zip(*G.degree())  # keys, degree
    cdf = nx.utils.cumulative_distribution(list(d for n, d in G.degree()))
    discrete_sequence = nx.utils.discrete_sequence
    window = 1
    while n < nswap:
        print("---------------------")
        wcount = 0
        swapped = []
        # If the window is small, we just check each time whether the graph is
        # connected by checking if the nodes that were just separated are still
        # connected.
        if window < _window_threshold:
            # This Boolean keeps track of whether there was a failure or not.
            fail = False
            while wcount < window and n < nswap:
                # Pick two random edges without creating the edge list. Choose
                # source nodes from the discrete degree distribution.
                (ui, xi) = discrete_sequence(2, cdistribution=cdf, seed=seed)
                # If the source nodes are the same, skip this pair.
                if ui == xi:
                    continue
                # Convert an index to a node label.
                u = keys[ui]  # convert index to label
                print("u: ")
                print(u)
                x = keys[xi]
                print("x: ")
                print(x)
                # Choose targets uniformly from neighbors.
                if(len(list(G[u])) >0 and len(list(G[x])) >0 ):
                    print("Outgoing edges u:")
                    print(list(G[u]))
                    v = random.choice(list(G[u]))
                    y = random.choice(list(G[x]))
                    print("Outgoing edges x:")
                    print(list(G[x]))
                    print("v:")
                    print(v)
            
                    print("y:")
                    print(y)
                else:
                    continue
                # If the target nodes are the same, skip this pair.
                if v == y:
#                     print("sametarget")
                    continue
                print(G.edges(data=True))
                #edge weight from u-->v becomes the edge weight for u-->y
                uv_weight = G[u][v]["weight"] 
                print("uv_weight:")
                print(uv_weight)
                #edge weight from x-->y becomes the edge weight for x-->v
                xy_weight = G[x][y]["weight"]     
                print("xy_weight:")
                print(xy_weight)
                if (v not in G[x]) and (y not in G[u]):  # don't create parallel edges
                    if (u == y or x ==v): # dont create a self loop
                        print("No self loops swap not made")
                        print("______________________")
                        continue
                    G.add_edge(u, y)
                    G[u][y]["weight"] = uv_weight
                    
                    print("edge_added: ")
                    print(u)
                    print("->")
                    print(y)
                    print("u->y edge weight:")
                    print(G[u][y]["weight"] )
                    G.add_edge(x, v)
                    G[x][v]["weight"] = xy_weight
                    print("edge_added: ")
                    print(x)
                    print("->")
                    print(v)
                    print("x->v edge weight:")
                    print(G[x][v]["weight"] )


                    print("_____removed Edges___")
                    G.remove_edge(u, v)
                    print(u)
                    print("->")
                    print(v)
                    G.remove_edge(x, y)
                    print(x)
                    print("->")
                    print(y)
                    print("______________________")
                    swapped.append((u, v, x, y))
                    swapcount += 1
                else:
                    print("Swap not made")
                    print("______________________")
                n += 1
                # If G remains connected... WHY ARE BOTH NOT CHECKED?
                if nx.has_path(G, u, v):
                    wcount += 1
                # Otherwise, undo the changes.
                else:
                    G.add_edge(u, v)
                    G[u][v]["weight"] = uv_weight
                    G.add_edge(x, y)
                    G[x][y]["weight"] = xy_weight
#                     print("We made the Graph disconnected")
                    G.remove_edge(u, y)
                    G.remove_edge(x, v)
                    swapcount -= 1
                    fail = True
            # If one of the swaps failed, reduce the window size.
            if fail:
                window = int(math.ceil(window / 2))
            else:
                window += 1
        # If the window is large, then there is a good chance that a bunch of
        # swaps will work. It's quicker to do all those swaps first and then
        # check if the graph remains connected.
        else:
            while wcount < window and n < nswap:
                # Pick two random edges without creating the edge list. Choose
                # source nodes from the discrete degree distribution.
                (ui, xi) = nx.utils.discrete_sequence(2, cdistribution=cdf)
                # If the source nodes are the same, skip this pair.
                if ui == xi:
                    continue
                u = keys[ui]  # convert index to label
                print("u: ")
                print(u)
                x = keys[xi]
                print("x: ")
                print(x)
                # Choose targets uniformly from neighbors.
                if(len(list(G[u])) >0 and len(list(G[x])) >0 ):
                    print("Outgoing edges u:")
                    print(list(G[u]))
                    v = random.choice(list(G[u]))
                    y = random.choice(list(G[x]))
                    print("Outgoing edges x:")
                    print(list(G[x]))
                    print("v:")
                    print(v)
            
                    print("y:")
                    print(y)
                else:
                    continue
                # If the target nodes are the same, skip this pair.
                if v == y:
                    continue
                #edge weight from u-->v becomes the edge weight for u-->y
                print(G.edges(data=True))
                uv_weight = G[u][v]["weight"] 
                print("uv_weight:")
                print(uv_weight)
                #edge weight from x-->y becomes the edge weight for x-->v
                xy_weight = G[x][y]["weight"]     
                print("xy_weight:")
                print(xy_weight)
                
                if (v not in G[x]) and (y not in G[u]):  # don't create parallel edges
                    if (u == y or x ==v): # dont create a self loop
                        print("No self loops swap not made")
                        print("______________________")
                        continue
                    G.add_edge(u, y)
                    G[u][y]["weight"] = uv_weight
                    
                    print("edge_added: ")
                    print(u)
                    print("->")
                    print(y)
                    print("u->y edge weight:")
                    print(G[u][y]["weight"] )
                    G.add_edge(x, v)
                    G[x][v]["weight"] = xy_weight
                    print("edge_added: ")
                    print(x)
                    print("->")
                    print(v)
                    print("x->v edge weight:")
                    print(G[x][v]["weight"] )

                    print("_____removed Edges___")
                    G.remove_edge(u, v)
                    print(u)
                    print("->")
                    print(v)
                    G.remove_edge(x, y)
                    print(x)
                    print("->")
                    print(y)
                    print("______________________")
                    swapped.append((u, v, x, y, uv_weight, xy_weight))
                    swapcount += 1
                else:
                    print("Swap not made")
                    print("______________________")
                n += 1
                wcount += 1
            # If the graph remains connected, increase the window size.
            if nx.is_weakly_connected(G):
                window += 1
            # Otherwise, undo the changes from the previous window and decrease
            # the window size.
            else:
                while swapped:
                    (u, v, x, y, uv_weight, xy_weight) = swapped.pop()
                    G.add_edge(u, v)
                    G.add_edge(x, y)
                    G[u][v]["weight"] = uv_weight
                    G[x][y]["weight"] = xy_weight
                    G.remove_edge(u, y)
                    G.remove_edge(x, v)
                    swapcount -= 1
                window = int(math.ceil(window / 2))
    return swapcount

# %%
H_1 = G.copy()

# %%
H_1.edges(data=True)
# Out:
# OutEdgeDataView([(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})])

# %%
directed_connected_double_edge_swap_weighted(H_1, nswap=100*len( G.edges() ))
# Out:
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 7
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 8
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 4
# ->
# 5
# 3
# ->
# 2
# ______________________
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 6}), (4, 2, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 6}), (4, 2, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 6}), (4, 2, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 6}), (4, 2, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 10
# edge_added:
# 2
# ->
# 3
# u->y edge weight:
# 9
# edge_added:
# 1
# ->
# 5
# x->v edge weight:
# 10
# _____removed Edges___
# 2
# ->
# 5
# 1
# ->
# 3
# ______________________
# u:
# 5
# x:
# 6
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6, 2]
# v:
# 5
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 6}), (4, 2, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# edge_added:
# 3
# ->
# 6
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 5
# x->v edge weight:
# 6
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 6
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 3
# u->y edge weight:
# 6
# edge_added:
# 5
# ->
# 6
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 6
# 5
# ->
# 3
# ______________________
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 3]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 8
# Swap not made
# ______________________
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 3]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 8
# Swap not made
# ______________________
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 6
# x:
# 2
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 10
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 6
# edge_added:
# 5
# ->
# 3
# u->y edge weight:
# 5
# edge_added:
# 4
# ->
# 6
# x->v edge weight:
# 6
# _____removed Edges___
# 5
# ->
# 6
# 4
# ->
# 3
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2, 3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 10
# edge_added:
# 4
# ->
# 5
# u->y edge weight:
# 6
# edge_added:
# 1
# ->
# 3
# x->v edge weight:
# 10
# _____removed Edges___
# 4
# ->
# 3
# 1
# ->
# 5
# ______________________
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# edge_added:
# 5
# ->
# 2
# u->y edge weight:
# 5
# edge_added:
# 4
# ->
# 6
# x->v edge weight:
# 8
# _____removed Edges___
# 5
# ->
# 6
# 4
# ->
# 2
# ______________________
# u:
# 2
# x:
# 6
# u:
# 5
# x:
# 6
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 2]
# v:
# 5
# y:
# 5
# u:
# 2
# x:
# 6
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 8
# Swap not made
# ______________________
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 5
# edge_added:
# 2
# ->
# 6
# u->y edge weight:
# 9
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 2
# ->
# 3
# 5
# ->
# 6
# ______________________
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 7
# Swap not made
# ______________________
# ---------------------
# u:
# 6
# x:
# 4
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 2]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 6
# edge_added:
# 2
# ->
# 5
# u->y edge weight:
# 9
# edge_added:
# 4
# ->
# 3
# x->v edge weight:
# 6
# _____removed Edges___
# 2
# ->
# 3
# 4
# ->
# 5
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 6
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 5
# edge_added:
# 2
# ->
# 6
# u->y edge weight:
# 9
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 2
# ->
# 3
# 5
# ->
# 6
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 6
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 5
# edge_added:
# 1
# ->
# 6
# u->y edge weight:
# 10
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 1
# ->
# 3
# 5
# ->
# 6
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 6
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# edge_added:
# 5
# ->
# 3
# u->y edge weight:
# 5
# edge_added:
# 2
# ->
# 6
# x->v edge weight:
# 9
# _____removed Edges___
# 5
# ->
# 6
# 2
# ->
# 3
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 5]
# v:
# 3
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 8
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 6
# u:
# 5
# x:
# 6
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 6
# u->y edge weight:
# 8
# edge_added:
# 5
# ->
# 2
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 2
# 5
# ->
# 6
# ______________________
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 10
# edge_added:
# 5
# ->
# 3
# u->y edge weight:
# 5
# edge_added:
# 1
# ->
# 2
# x->v edge weight:
# 10
# _____removed Edges___
# 5
# ->
# 2
# 1
# ->
# 3
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 7
# Swap not made
# ______________________
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 8
# edge_added:
# 5
# ->
# 6
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 6
# 5
# ->
# 2
# ______________________
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 8
# Swap not made
# ______________________
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 9
# edge_added:
# 4
# ->
# 3
# u->y edge weight:
# 6
# edge_added:
# 2
# ->
# 5
# x->v edge weight:
# 9
# _____removed Edges___
# 4
# ->
# 5
# 2
# ->
# 3
# ______________________
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 3]
# v:
# 6
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 8}), (4, 3, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# edge_added:
# 5
# ->
# 2
# u->y edge weight:
# 5
# edge_added:
# 4
# ->
# 6
# x->v edge weight:
# 8
# _____removed Edges___
# 5
# ->
# 6
# 4
# ->
# 2
# ______________________
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 9
# edge_added:
# 1
# ->
# 5
# u->y edge weight:
# 10
# edge_added:
# 2
# ->
# 3
# x->v edge weight:
# 9
# _____removed Edges___
# 1
# ->
# 3
# 2
# ->
# 5
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 6}), (4, 6, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 7
# edge_added:
# 4
# ->
# 5
# u->y edge weight:
# 8
# edge_added:
# 3
# ->
# 6
# x->v edge weight:
# 7
# _____removed Edges___
# 4
# ->
# 6
# 3
# ->
# 5
# ______________________
# ---------------------
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 9
# edge_added:
# 1
# ->
# 3
# u->y edge weight:
# 10
# edge_added:
# 2
# ->
# 5
# x->v edge weight:
# 9
# _____removed Edges___
# 1
# ->
# 5
# 2
# ->
# 3
# ______________________
# u:
# 4
# x:
# 6
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# edge_added:
# 5
# ->
# 6
# u->y edge weight:
# 5
# edge_added:
# 3
# ->
# 2
# x->v edge weight:
# 7
# _____removed Edges___
# 5
# ->
# 2
# 3
# ->
# 6
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 10
# edge_added:
# 5
# ->
# 3
# u->y edge weight:
# 5
# edge_added:
# 1
# ->
# 6
# x->v edge weight:
# 10
# _____removed Edges___
# 5
# ->
# 6
# 1
# ->
# 3
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# Swap not made
# ______________________
# ---------------------
# u:
# 6
# x:
# 4
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 5]
# v:
# 5
# y:
# 5
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# edge_added:
# 1
# ->
# 6
# u->y edge weight:
# 10
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 6
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 6}), (4, 5, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 6
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 3
# 5
# ->
# 2
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 6
# Swap not made
# ______________________
# ---------------------
# u:
# 6
# x:
# 2
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 2]
# v:
# 3
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 6
# x:
# 5
# u:
# 3
# x:
# 6
# u:
# 2
# x:
# 6
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 3
# u->y edge weight:
# 6
# edge_added:
# 5
# ->
# 2
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 2
# 5
# ->
# 3
# ______________________
# ---------------------
# u:
# 3
# x:
# 6
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# edge_added:
# 5
# ->
# 6
# u->y edge weight:
# 5
# edge_added:
# 3
# ->
# 2
# x->v edge weight:
# 7
# _____removed Edges___
# 5
# ->
# 2
# 3
# ->
# 6
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5, 3]
# v:
# 2
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 9
# Swap not made
# ______________________
# u:
# 6
# x:
# 3
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 6
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 3
# 5
# ->
# 2
# ______________________
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# edge_added:
# 3
# ->
# 5
# u->y edge weight:
# 7
# edge_added:
# 1
# ->
# 6
# x->v edge weight:
# 10
# _____removed Edges___
# 3
# ->
# 6
# 1
# ->
# 5
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 7
# edge_added:
# 4
# ->
# 6
# u->y edge weight:
# 6
# edge_added:
# 3
# ->
# 2
# x->v edge weight:
# 7
# _____removed Edges___
# 4
# ->
# 2
# 3
# ->
# 6
# ______________________
# ---------------------
# u:
# 1
# x:
# 6
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 6]
# v:
# 3
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 6]
# v:
# 3
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 8
# edge_added:
# 2
# ->
# 5
# u->y edge weight:
# 9
# edge_added:
# 4
# ->
# 3
# x->v edge weight:
# 8
# _____removed Edges___
# 2
# ->
# 3
# 4
# ->
# 5
# ______________________
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 6, {'weight': 6}), (4, 3, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6, 3]
# v:
# 2
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 6, {'weight': 6}), (4, 3, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# edge_added:
# 3
# ->
# 6
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 2
# x->v edge weight:
# 6
# _____removed Edges___
# 3
# ->
# 2
# 4
# ->
# 6
# ______________________
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# edge_added:
# 3
# ->
# 5
# u->y edge weight:
# 7
# edge_added:
# 1
# ->
# 2
# x->v edge weight:
# 10
# _____removed Edges___
# 3
# ->
# 2
# 1
# ->
# 5
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 6]
# v:
# 3
# y:
# 3
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 6]
# v:
# 5
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 6
# edge_added:
# 2
# ->
# 6
# u->y edge weight:
# 9
# edge_added:
# 4
# ->
# 5
# x->v edge weight:
# 6
# _____removed Edges___
# 2
# ->
# 5
# 4
# ->
# 6
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# edge_added:
# 1
# ->
# 2
# u->y edge weight:
# 10
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 2, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 2, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 2, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 6]
# v:
# 5
# y:
# 3
# [(1, 2, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 8
# No self loops swap not made
# ______________________
# u:
# 6
# x:
# 5
# u:
# 6
# x:
# 2
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 6]
# v:
# 5
# y:
# 3
# [(1, 2, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 8
# edge_added:
# 2
# ->
# 3
# u->y edge weight:
# 9
# edge_added:
# 4
# ->
# 5
# x->v edge weight:
# 8
# _____removed Edges___
# 2
# ->
# 5
# 4
# ->
# 3
# ______________________
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6, 5]
# v:
# 5
# y:
# 6
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# Swap not made
# ______________________
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# edge_added:
# 1
# ->
# 5
# u->y edge weight:
# 10
# edge_added:
# 3
# ->
# 2
# x->v edge weight:
# 7
# _____removed Edges___
# 1
# ->
# 2
# 3
# ->
# 5
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 6
# x:
# 5
# u:
# 6
# x:
# 2
# u:
# 6
# x:
# 3
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [6, 5]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 6, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 7
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 6
# edge_added:
# 3
# ->
# 6
# x->v edge weight:
# 7
# _____removed Edges___
# 4
# ->
# 6
# 3
# ->
# 2
# ______________________
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# edge_added:
# 3
# ->
# 5
# u->y edge weight:
# 7
# edge_added:
# 1
# ->
# 6
# x->v edge weight:
# 10
# _____removed Edges___
# 3
# ->
# 6
# 1
# ->
# 5
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 6, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 6, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 7
# Swap not made
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 2]
# v:
# 5
# y:
# 2
# [(1, 6, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# Swap not made
# ______________________
# ---------------------
# u:
# 6
# x:
# 5
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5, 2]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 8
# edge_added:
# 3
# ->
# 5
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 6
# x->v edge weight:
# 8
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 2, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# edge_added:
# 1
# ->
# 6
# u->y edge weight:
# 10
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 6
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 2, {'weight': 6}), (4, 5, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# edge_added:
# 3
# ->
# 2
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 6
# x->v edge weight:
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 2
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 9
# edge_added:
# 1
# ->
# 3
# u->y edge weight:
# 10
# edge_added:
# 2
# ->
# 5
# x->v edge weight:
# 9
# _____removed Edges___
# 1
# ->
# 5
# 2
# ->
# 3
# ______________________
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 6
# x:
# 5
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 6
# x:
# 3
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 6
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 3
# u->y edge weight:
# 6
# edge_added:
# 5
# ->
# 2
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 2
# 5
# ->
# 3
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# edge_added:
# 3
# ->
# 5
# u->y edge weight:
# 7
# edge_added:
# 1
# ->
# 6
# x->v edge weight:
# 10
# _____removed Edges___
# 3
# ->
# 6
# 1
# ->
# 5
# ______________________
# u:
# 5
# x:
# 6
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# edge_added:
# 1
# ->
# 6
# u->y edge weight:
# 10
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 6
# ______________________
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 3
# x:
# 6
# u:
# 6
# x:
# 1
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 3]
# v:
# 3
# y:
# 3
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 3, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 6
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 3
# 5
# ->
# 2
# ______________________
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 7
# edge_added:
# 4
# ->
# 6
# u->y edge weight:
# 6
# edge_added:
# 3
# ->
# 2
# x->v edge weight:
# 7
# _____removed Edges___
# 4
# ->
# 2
# 3
# ->
# 6
# ______________________
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 6
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5, 6]
# v:
# 2
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# edge_added:
# 3
# ->
# 6
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 2
# x->v edge weight:
# 6
# _____removed Edges___
# 3
# ->
# 2
# 4
# ->
# 6
# ______________________
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 7
# edge_added:
# 1
# ->
# 2
# u->y edge weight:
# 10
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# u:
# 6
# x:
# 5
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 5
# edge_added:
# 1
# ->
# 3
# u->y edge weight:
# 10
# edge_added:
# 5
# ->
# 2
# x->v edge weight:
# 5
# _____removed Edges___
# 1
# ->
# 2
# 5
# ->
# 3
# ______________________
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 7
# Swap not made
# ______________________
# ---------------------
# u:
# 6
# x:
# 5
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 6]
# v:
# 3
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 6
# edge_added:
# 2
# ->
# 6
# u->y edge weight:
# 9
# edge_added:
# 4
# ->
# 3
# x->v edge weight:
# 6
# _____removed Edges___
# 2
# ->
# 3
# 4
# ->
# 6
# ______________________
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 8}), (4, 6, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ...
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [6, 5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [6, 5]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 6, {'weight': 8}), (4, 5, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 3
# u->y edge weight:
# 8
# edge_added:
# 5
# ->
# 6
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 6
# 5
# ->
# 3
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 7
# Swap not made
# ______________________
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 10
# edge_added:
# 5
# ->
# 2
# u->y edge weight:
# 5
# edge_added:
# 1
# ->
# 6
# x->v edge weight:
# 10
# _____removed Edges___
# 5
# ->
# 6
# 1
# ->
# 2
# ______________________
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 6, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 10
# edge_added:
# 5
# ->
# 6
# u->y edge weight:
# 5
# edge_added:
# 1
# ->
# 2
# x->v edge weight:
# 10
# _____removed Edges___
# 5
# ->
# 2
# 1
# ->
# 6
# ______________________
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5, 3]
# v:
# 2
# y:
# 5
# [(1, 2, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 6
# edge_added:
# 1
# ->
# 5
# u->y edge weight:
# 10
# edge_added:
# 4
# ->
# 2
# x->v edge weight:
# 6
# _____removed Edges___
# 1
# ->
# 2
# 4
# ->
# 5
# ______________________
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 5
# edge_added:
# 2
# ->
# 6
# u->y edge weight:
# 9
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 2
# ->
# 3
# 5
# ->
# 6
# ______________________
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 2
# [(1, 5, {'weight': 10}), (2, 6, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 6
# edge_added:
# 1
# ->
# 2
# u->y edge weight:
# 10
# edge_added:
# 4
# ->
# 5
# x->v edge weight:
# 6
# _____removed Edges___
# 1
# ->
# 5
# 4
# ->
# 2
# ______________________
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# [(1, 2, {'weight': 10}), (2, 6, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 10
# edge_added:
# 5
# ->
# 2
# u->y edge weight:
# 5
# edge_added:
# 1
# ->
# 3
# x->v edge weight:
# 10
# _____removed Edges___
# 5
# ->
# 3
# 1
# ->
# 2
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 6, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 6
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 6, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# edge_added:
# 3
# ->
# 6
# u->y edge weight:
# 7
# edge_added:
# 2
# ->
# 5
# x->v edge weight:
# 9
# _____removed Edges___
# 3
# ->
# 5
# 2
# ->
# 6
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# edge_added:
# 5
# ->
# 3
# u->y edge weight:
# 5
# edge_added:
# 4
# ->
# 2
# x->v edge weight:
# 8
# _____removed Edges___
# 5
# ->
# 2
# 4
# ->
# 3
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5, 2]
# v:
# 6
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 6}), (4, 2, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 8
# edge_added:
# 3
# ->
# 2
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 6
# x->v edge weight:
# 8
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 2
# ______________________
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 10
# edge_added:
# 2
# ->
# 3
# u->y edge weight:
# 9
# edge_added:
# 1
# ->
# 5
# x->v edge weight:
# 10
# _____removed Edges___
# 2
# ->
# 5
# 1
# ->
# 3
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 6}), (4, 6, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 3
# u->y edge weight:
# 8
# edge_added:
# 5
# ->
# 6
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 6
# 5
# ->
# 3
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 1
# x:
# 6
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# edge_added:
# 3
# ->
# 6
# u->y edge weight:
# 7
# edge_added:
# 5
# ->
# 2
# x->v edge weight:
# 5
# _____removed Edges___
# 3
# ->
# 2
# 5
# ->
# 6
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5, 3]
# v:
# 2
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 6
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 10
# edge_added:
# 2
# ->
# 5
# u->y edge weight:
# 9
# edge_added:
# 1
# ->
# 3
# x->v edge weight:
# 10
# _____removed Edges___
# 2
# ->
# 3
# 1
# ->
# 5
# ______________________
# u:
# 6
# x:
# 5
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 3]
# v:
# 3
# y:
# 3
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5, 3]
# v:
# 6
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 8
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 6
# x:
# 2
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 6, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 2, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# edge_added:
# 5
# ->
# 6
# u->y edge weight:
# 5
# edge_added:
# 3
# ->
# 2
# x->v edge weight:
# 7
# _____removed Edges___
# 5
# ->
# 2
# 3
# ->
# 6
# ______________________
# u:
# 3
# x:
# 6
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 3]
# v:
# 5
# y:
# 5
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 5, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 7
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 6
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 4
# ->
# 5
# 3
# ->
# 2
# ______________________
# u:
# 5
# x:
# 6
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 6
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 2]
# v:
# 6
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 8
# edge_added:
# 5
# ->
# 3
# u->y edge weight:
# 5
# edge_added:
# 4
# ->
# 6
# x->v edge weight:
# 8
# _____removed Edges___
# 5
# ->
# 6
# 4
# ->
# 3
# ______________________
# u:
# 3
# x:
# 6
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 6}), (4, 6, {'weight': 8}), (5, 3, {'weight': 5})]
# uv_weight:
# 8
# xy_weight:
# 5
# edge_added:
# 4
# ->
# 3
# u->y edge weight:
# 8
# edge_added:
# 5
# ->
# 6
# x->v edge weight:
# 5
# _____removed Edges___
# 4
# ->
# 6
# 5
# ->
# 3
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2, 3]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 2, {'weight': 6}), (4, 3, {'weight': 8}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# edge_added:
# 3
# ->
# 2
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 5
# x->v edge weight:
# 6
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 2
# ______________________
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 10
# edge_added:
# 2
# ->
# 3
# u->y edge weight:
# 9
# edge_added:
# 1
# ->
# 5
# x->v edge weight:
# 10
# _____removed Edges___
# 2
# ->
# 5
# 1
# ->
# 3
# ______________________
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 6
# x:
# 3
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 10
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 5]
# v:
# 3
# y:
# 3
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 9
# Swap not made
# ______________________
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 5, {'weight': 10}), (2, 3, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 9
# edge_added:
# 1
# ->
# 3
# u->y edge weight:
# 10
# edge_added:
# 2
# ->
# 5
# x->v edge weight:
# 9
# _____removed Edges___
# 1
# ->
# 5
# 2
# ->
# 3
# ______________________
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 4
# x:
# 6
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 2
# x:
# 6
# u:
# 6
# x:
# 3
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 6
# xy_weight:
# 7
# edge_added:
# 4
# ->
# 2
# u->y edge weight:
# 6
# edge_added:
# 3
# ->
# 5
# x->v edge weight:
# 7
# _____removed Edges___
# 4
# ->
# 5
# 3
# ->
# 2
# ______________________
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 7
# No self loops swap not made
# ______________________
# u:
# 6
# x:
# 4
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# u:
# 6
# x:
# 5
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# [(1, 3, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 6, {'weight': 5})]
# uv_weight:
# 10
# xy_weight:
# 5
# edge_added:
# 1
# ->
# 6
# u->y edge weight:
# 10
# edge_added:
# 5
# ->
# 3
# x->v edge weight:
# 5
# _____removed Edges___
# 1
# ->
# 3
# 5
# ->
# 6
# ______________________
# u:
# 6
# x:
# 2
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 2
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# edge_added:
# 3
# ->
# 2
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 5
# x->v edge weight:
# 6
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 2
# ______________________
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 5]
# v:
# 3
# y:
# 3
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 5
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 2, {'weight': 7}), (4, 3, {'weight': 8}), (4, 5, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 6
# edge_added:
# 3
# ->
# 5
# u->y edge weight:
# 7
# edge_added:
# 4
# ->
# 2
# x->v edge weight:
# 6
# _____removed Edges___
# 3
# ->
# 2
# 4
# ->
# 5
# ______________________
# u:
# 3
# x:
# 6
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 9
# xy_weight:
# 5
# No self loops swap not made
# ______________________
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 5
# xy_weight:
# 9
# No self loops swap not made
# ______________________
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# [(1, 6, {'weight': 10}), (2, 5, {'weight': 9}), (3, 5, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})]
# uv_weight:
# 7
# xy_weight:
# 10
# edge_added:
# 3
# ->
# 6
# u->y edge weight:
# 7
# edge_added:
# 1
# ->
# 5
# x->v edge weight:
# 10
# _____removed Edges___
# 3
# ->
# 5
# 1
# ->
# 6
# ______________________
# 434

# %%
H_1.edges(data=True)
# Out:
# OutEdgeDataView([(1, 5, {'weight': 10}), (2, 5, {'weight': 9}), (3, 6, {'weight': 7}), (4, 3, {'weight': 8}), (4, 2, {'weight': 6}), (5, 3, {'weight': 5})])
