# %%
import networkx as nx

# %%
G = nx.DiGraph() 
G.add_edge(1, 2)
G.add_edge(2, 3)
G.add_edge(4, 3)
G.add_edge(3, 5)
G.add_edge(4, 5)
G.add_edge(5, 6)

# %%
keys[4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13272/559891156.py in <module>
# ----> 1 keys[4]
#
# NameError: name 'keys' is not defined

# %%
G[3]
# Out:
# AtlasView({5: {}})

# %%
import random
def double_edge_swap_directed(G, nswap=1, max_tries=100, seed=None):
    """Swap two edges in the graph while keeping the node in degree and out degree fixed.

    A double-edge swap selects two random edges
    and creates the new edges u->x and v->y::

     u-->v           u-->y
            becomes  
     x-->y           x-->v

    If either the edge u->y or x->v already exist no swap is performed
    and another attempt is made to find a suitable edge pair.

    Parameters
    ----------
    G : graph
       An undirected graph

    nswap : integer (optional, default=1)
       Number of double-edge swaps to perform

    max_tries : integer (optional)
       Maximum number of attempts to swap edges

    seed : integer, random_state, or None (default)
        Indicator of random number generation state.
        See :ref:`Randomness<randomness>`.

    Returns
    -------
    G : graph
       The graph after double edge swaps.

    Notes
    -----
    Does not enforce any connectivity constraints.

    The graph G is modified in place.
    """

    if nswap > max_tries:
        raise nx.NetworkXError("Number of swaps > number of tries allowed.")
    if len(G) < 4:
        raise nx.NetworkXError("Graph has less than four nodes.")
    # Instead of choosing uniformly at random from a generated edge list,
    # this algorithm chooses nonuniformly from the set of nodes with
    # probability weighted by degree.
    n = 0
    swapcount = 0
    keys, degrees = zip(*G.degree())  # keys, degree
    cdf = nx.utils.cumulative_distribution(degrees)  # cdf of degree
    discrete_sequence = nx.utils.discrete_sequence
    while swapcount < nswap:
        
        print("---------------------")
        #        if random.random() < 0.5: continue # trick to avoid periodicities?
        # pick two random edges without creating edge list
        # choose source node indices from discrete distribution
        (ui, xi) = discrete_sequence(2, cdistribution=cdf, seed=seed)
       # print(type(ui))
        if ui == xi:
            print("samesource")
            continue  # same source, skip
            
        u = keys[ui]  # convert index to label
        print("u: ")
        print(u)
        x = keys[xi]
        print("x: ")
        print(x)
        # choose target uniformly from neighbors
        if(len(list(G[u])) >0 and len(list(G[x])) >0 ):
            print("Outgoing edges u:")
            print(list(G[u]))
            v = random.choice(list(G[u]))
            y = random.choice(list(G[x]))
            print("Outgoing edges x:")
            print(list(G[x]))
            
            print("v:")
            print(v)
            
            print("y:")
            print(y)
        else:
            print("No outward edge")
            continue
        if v == y:
            print("sametarget")
            continue  # same target, skip
        if (v not in G[x]) and (y not in G[u]):  # don't create parallel edges
            if (u == y or x ==v): # dont create a self loop
                continue
            G.add_edge(u, y)
            print("edge_added: ")
            print(u)
            print("->")
            print(y)
            G.add_edge(x, v)
            print("edge_added: ")
            print(x)
            print("->")
            print(v)
            
            print("_____removed Edges___")
            G.remove_edge(u, v)
            print(u)
            print("->")
            print(v)
            G.remove_edge(x, y)
            print(x)
            print("->")
            print(y)
            print("______________________")
            print(G.edges())
            print("Number of edges: " + str(len(G.edges())))
            swapcount += 1
        if n >= max_tries:
            e = (
                f"Maximum number of swap attempts ({n}) exceeded "
                f"before desired swaps achieved ({nswap})."
            )
            raise nx.NetworkXAlgorithmError(e)
        n += 1
    return G

# %%
H_1 = G.copy()

# %%
H_1.edges()
# Out:
# OutEdgeView([(1, 2), (2, 3), (3, 5), (4, 3), (4, 5), (5, 6)])

# %%
double_edge_swap_directed(H_1, nswap=100*len( G.edges() ), max_tries=1e75)
# Out:
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 4
# ->
# 6
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 4
# ->
# 3
# 5
# ->
# 6
# ______________________
# [(1, 2), (2, 3), (3, 5), (4, 5), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# edge_added:
# 1
# ->
# 3
# edge_added:
# 5
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 3), (3, 5), (4, 5), (4, 6), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# edge_added:
# 4
# ->
# 2
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 4
# ->
# 6
# 5
# ->
# 2
# ______________________
# [(1, 3), (2, 3), (3, 5), (4, 5), (4, 2), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 2
# ->
# 3
# 5
# ->
# 6
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 5), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 5
# ->
# 6
# edge_added:
# 2
# ->
# 3
# _____removed Edges___
# 5
# ->
# 3
# 2
# ->
# 6
# ______________________
# [(1, 3), (2, 3), (3, 5), (4, 5), (4, 2), (5, 6)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 1
# ->
# 6
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 1
# ->
# 3
# 5
# ->
# 6
# ______________________
# [(1, 6), (2, 3), (3, 5), (4, 5), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 2]
# v:
# 3
# y:
# 5
# edge_added:
# 2
# ->
# 5
# edge_added:
# 4
# ->
# 3
# _____removed Edges___
# 2
# ->
# 3
# 4
# ->
# 5
# ______________________
# [(1, 6), (2, 5), (3, 5), (4, 2), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 1
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 2), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2, 3]
# v:
# 5
# y:
# 3
# edge_added:
# 2
# ->
# 3
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 2
# ->
# 5
# 4
# ->
# 3
# ______________________
# [(1, 5), (2, 3), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 1
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 6
# ______________________
# [(1, 6), (2, 3), (3, 5), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 1
# ->
# 6
# ______________________
# [(1, 5), (2, 3), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 5]
# v:
# 3
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# edge_added:
# 2
# ->
# 5
# edge_added:
# 1
# ->
# 3
# _____removed Edges___
# 2
# ->
# 3
# 1
# ->
# 5
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# edge_added:
# 2
# ->
# 3
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 2
# ->
# 5
# 1
# ->
# 3
# ______________________
# [(1, 5), (2, 3), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 5), (4, 2), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2, 6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 6
# ______________________
# [(1, 5), (2, 3), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 5), (4, 2), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [2, 6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 4
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 4
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# edge_added:
# 4
# ->
# 3
# edge_added:
# 2
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 2
# ->
# 3
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 2), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2, 3]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 4
# ->
# 2
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 5]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 4
# ->
# 2
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 1
# ->
# 2
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 1
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 6
# ______________________
# [(1, 6), (2, 5), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 1
# ->
# 6
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 2
# ->
# 5
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 2
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 2
# ->
# 5
# 3
# ->
# 6
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 6
# No outward edge
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 2
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 6
# No outward edge
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# edge_added:
# 4
# ->
# 5
# edge_added:
# 1
# ->
# 3
# _____removed Edges___
# 4
# ->
# 3
# 1
# ->
# 5
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 2
# edge_added:
# 3
# ->
# 2
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 2
# ______________________
# [(1, 3), (2, 5), (3, 2), (4, 5), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 6]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 6]
# v:
# 5
# y:
# 6
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 6]
# v:
# 3
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 4
# ->
# 3
# _____removed Edges___
# 1
# ->
# 3
# 4
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 6), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [6, 3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6, 3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [6, 3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# edge_added:
# 4
# ->
# 5
# edge_added:
# 2
# ->
# 3
# _____removed Edges___
# 4
# ->
# 3
# 2
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 2), (4, 6), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 2), (2, 3), (3, 5), (4, 6), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 3
# ->
# 2
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 1
# ->
# 2
# ______________________
# [(1, 5), (2, 3), (3, 2), (4, 6), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [6, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# edge_added:
# 4
# ->
# 3
# edge_added:
# 2
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 2
# ->
# 3
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 6), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [6, 3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6, 3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 6
# x:
# 4
# No outward edge
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6, 3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [6, 3]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6, 3]
# v:
# 2
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 4
# ->
# 2
# _____removed Edges___
# 3
# ->
# 2
# 4
# ->
# 6
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 1
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 6
# ______________________
# [(1, 6), (2, 5), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# edge_added:
# 4
# ->
# 5
# edge_added:
# 2
# ->
# 3
# _____removed Edges___
# 4
# ->
# 3
# 2
# ->
# 5
# ______________________
# [(1, 6), (2, 3), (3, 5), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 1
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 5), (4, 2), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 6]
# v:
# 3
# y:
# 6
# edge_added:
# 5
# ->
# 6
# edge_added:
# 4
# ->
# 3
# _____removed Edges___
# 5
# ->
# 3
# 4
# ->
# 6
# ______________________
# [(1, 5), (2, 3), (3, 5), (4, 2), (4, 3), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# edge_added:
# 4
# ->
# 5
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 4
# ->
# 2
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 2), (4, 3), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 1
# ->
# 2
# _____removed Edges___
# 3
# ->
# 2
# 1
# ->
# 5
# ______________________
# [(1, 2), (2, 3), (3, 5), (4, 3), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 2
# ->
# 3
# 5
# ->
# 6
# ______________________
# [(1, 2), (2, 6), (3, 5), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 2
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# edge_added:
# 5
# ->
# 2
# edge_added:
# 1
# ->
# 3
# _____removed Edges___
# 5
# ->
# 3
# 1
# ->
# 2
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 3), (4, 5), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# [(1, 3), (2, 5), (3, 5), (4, 3), (4, 6), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 6
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 3), (4, 5), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 6
# No outward edge
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 5
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 2
# ->
# 5
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 3), (4, 5), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 4
# ->
# 2
# _____removed Edges___
# 5
# ->
# 2
# 4
# ->
# 3
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 5), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 5
# ->
# 6
# edge_added:
# 2
# ->
# 3
# _____removed Edges___
# 5
# ->
# 3
# 2
# ->
# 6
# ______________________
# [(1, 3), (2, 3), (3, 5), (4, 5), (4, 2), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 1
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 1
# ->
# 3
# ______________________
# [(1, 6), (2, 3), (3, 5), (4, 5), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 2]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 1
# ->
# 3
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 1
# ->
# 6
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 3), (3, 5), (4, 5), (4, 2), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# ---------------------
# u:
# 3
# x:
# 6
# No outward edge
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 2
# ->
# 3
# 5
# ->
# 6
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 5), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 2]
# v:
# 3
# y:
# 2
# edge_added:
# 5
# ->
# 2
# edge_added:
# 4
# ->
# 3
# _____removed Edges___
# 5
# ->
# 3
# 4
# ->
# 2
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 5), (4, 3), (5, 2)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5, 3]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 1
# ->
# 2
# _____removed Edges___
# 5
# ->
# 2
# 1
# ->
# 3
# ______________________
# [(1, 2), (2, 6), (3, 5), (4, 5), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 3]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 2
# ->
# 3
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 5
# ->
# 3
# ______________________
# [(1, 2), (2, 3), (3, 5), (4, 5), (4, 3), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5, 3]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 4
# ->
# 3
# ______________________
# [(1, 2), (2, 3), (3, 5), (4, 5), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 3), (3, 2), (4, 5), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 2), (2, 3), (3, 5), (4, 5), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5, 6]
# v:
# 5
# y:
# 6
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# edge_added:
# 4
# ->
# 3
# edge_added:
# 2
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 2
# ->
# 3
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 6), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 6
# No outward edge
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6, 3]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 6
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 5]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# edge_added:
# 1
# ->
# 6
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 3
# ->
# 6
# ______________________
# [(1, 6), (2, 5), (3, 2), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 5
# ->
# 6
# edge_added:
# 1
# ->
# 3
# _____removed Edges___
# 5
# ->
# 3
# 1
# ->
# 6
# ______________________
# [(1, 3), (2, 5), (3, 2), (4, 3), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 5]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 4
# ->
# 3
# ______________________
# [(1, 3), (2, 5), (3, 2), (4, 5), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 6]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5, 6]
# v:
# 2
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 2
# _____removed Edges___
# 3
# ->
# 2
# 4
# ->
# 5
# ______________________
# [(1, 3), (2, 5), (3, 5), (4, 6), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [6, 2]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 4
# ->
# 3
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 4
# ->
# 6
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 5), (3, 5), (4, 2), (4, 3), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2, 3]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 4
# ->
# 3
# ______________________
# [(1, 3), (2, 5), (3, 5), (4, 2), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2, 6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 6
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 5]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# edge_added:
# 4
# ->
# 3
# edge_added:
# 5
# ->
# 2
# _____removed Edges___
# 4
# ->
# 2
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 5), (4, 3), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5, 3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 2
# ->
# 5
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 5), (4, 3), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 1
# ->
# 2
# _____removed Edges___
# 5
# ->
# 2
# 1
# ->
# 3
# ______________________
# [(1, 2), (2, 6), (3, 5), (4, 5), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 3]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 2
# No outward edge
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 4
# ->
# 6
# edge_added:
# 2
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 2
# ->
# 6
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# edge_added:
# 1
# ->
# 3
# edge_added:
# 5
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 5), (3, 5), (4, 3), (4, 6), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 1
# ->
# 2
# _____removed Edges___
# 5
# ->
# 2
# 1
# ->
# 3
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 2
# No outward edge
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 6
# No outward edge
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 4
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 6
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# edge_added:
# 1
# ->
# 3
# edge_added:
# 5
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 3), (4, 5), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# edge_added:
# 4
# ->
# 2
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 4
# ->
# 3
# 5
# ->
# 2
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 5), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [5, 2]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# edge_added:
# 4
# ->
# 3
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 1
# ->
# 3
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 2), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 3]
# v:
# 3
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 2
# ->
# 5
# 3
# ->
# 6
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 2), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [2, 3]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2, 3]
# v:
# 5
# y:
# 2
# edge_added:
# 3
# ->
# 2
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 2
# ______________________
# [(1, 5), (2, 6), (3, 2), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 2
# ->
# 3
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 5
# ->
# 3
# ______________________
# [(1, 5), (2, 3), (3, 2), (4, 3), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 5
# ->
# 2
# _____removed Edges___
# 3
# ->
# 2
# 5
# ->
# 6
# ______________________
# [(1, 5), (2, 3), (3, 6), (4, 3), (4, 5), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 6
# No outward edge
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 3
# x:
# 6
# No outward edge
# ---------------------
# u:
# 6
# x:
# 2
# No outward edge
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# edge_added:
# 5
# ->
# 6
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 5
# ->
# 2
# 3
# ->
# 6
# ______________________
# [(1, 5), (2, 3), (3, 2), (4, 3), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 2
# ->
# 3
# ______________________
# [(1, 5), (2, 6), (3, 2), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 2), (2, 6), (3, 5), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 6
# x:
# 2
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 2
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 2
# ->
# 6
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 3
# x:
# 6
# No outward edge
# ---------------------
# u:
# 6
# x:
# 4
# No outward edge
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 4
# ->
# 2
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 1
# ->
# 2
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 6
# x:
# 2
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 2]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 4
# ->
# 2
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# samesource
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 6]
# v:
# 2
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 4
# ->
# 2
# _____removed Edges___
# 3
# ->
# 2
# 4
# ->
# 6
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 2
# ->
# 5
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 2
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 2]
# v:
# 6
# y:
# 2
# edge_added:
# 3
# ->
# 2
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 2
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# edge_added:
# 4
# ->
# 2
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 4
# ->
# 6
# 3
# ->
# 2
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 2
# ->
# 5
# 3
# ->
# 6
# ______________________
# ...
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 2
# ->
# 3
# 5
# ->
# 6
# ______________________
# [(1, 5), (2, 6), (3, 2), (4, 5), (4, 3), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [5, 3]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 4
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 4
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 2
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 2
# ->
# 6
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 2
# ->
# 5
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 2
# ->
# 3
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 5
# ->
# 3
# ______________________
# [(1, 5), (2, 3), (3, 5), (4, 3), (4, 2), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 4
# x:
# 2
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 2
# edge_added:
# 3
# ->
# 2
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 2
# ______________________
# [(1, 5), (2, 3), (3, 2), (4, 3), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 2
# ->
# 3
# ______________________
# [(1, 5), (2, 6), (3, 2), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 2), (2, 6), (3, 5), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# ---------------------
# u:
# 2
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# ---------------------
# u:
# 6
# x:
# 2
# No outward edge
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 2
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# edge_added:
# 1
# ->
# 6
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 3
# ->
# 6
# ______________________
# [(1, 6), (2, 5), (3, 2), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 6
# No outward edge
# ---------------------
# u:
# 1
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 1
# ->
# 3
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 1
# ->
# 6
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 5), (3, 2), (4, 3), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 5]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# edge_added:
# 4
# ->
# 6
# edge_added:
# 5
# ->
# 3
# _____removed Edges___
# 4
# ->
# 3
# 5
# ->
# 6
# ______________________
# [(1, 3), (2, 5), (3, 2), (4, 5), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5, 6]
# v:
# 3
# y:
# 6
# edge_added:
# 5
# ->
# 6
# edge_added:
# 4
# ->
# 3
# _____removed Edges___
# 5
# ->
# 3
# 4
# ->
# 6
# ______________________
# [(1, 3), (2, 5), (3, 2), (4, 5), (4, 3), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# edge_added:
# 5
# ->
# 2
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 3
# ->
# 2
# ______________________
# [(1, 3), (2, 5), (3, 6), (4, 5), (4, 3), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5, 3]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# [(1, 3), (2, 5), (3, 5), (4, 3), (4, 6), (5, 2)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 6]
# v:
# 2
# y:
# 6
# edge_added:
# 5
# ->
# 6
# edge_added:
# 4
# ->
# 2
# _____removed Edges___
# 5
# ->
# 2
# 4
# ->
# 6
# ______________________
# [(1, 3), (2, 5), (3, 5), (4, 3), (4, 2), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 5
# x:
# 1
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 1
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 1
# ->
# 3
# ______________________
# [(1, 6), (2, 5), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [5]
# v:
# 5
# y:
# 5
# sametarget
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 2]
# v:
# 5
# y:
# 2
# edge_added:
# 3
# ->
# 2
# edge_added:
# 4
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 4
# ->
# 2
# ______________________
# [(1, 6), (2, 5), (3, 2), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 6
# x:
# 3
# No outward edge
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3]
# v:
# 2
# y:
# 3
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 5]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# edge_added:
# 3
# ->
# 6
# edge_added:
# 1
# ->
# 2
# _____removed Edges___
# 3
# ->
# 2
# 1
# ->
# 6
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3, 5]
# v:
# 6
# y:
# 5
# edge_added:
# 3
# ->
# 5
# edge_added:
# 4
# ->
# 6
# _____removed Edges___
# 3
# ->
# 6
# 4
# ->
# 5
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 6]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 3
# x:
# 4
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3, 6]
# v:
# 5
# y:
# 3
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 2
# No outward edge
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [5]
# v:
# 2
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [2]
# v:
# 6
# y:
# 2
# edge_added:
# 4
# ->
# 2
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 4
# ->
# 6
# 3
# ->
# 2
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 2]
# v:
# 3
# y:
# 2
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 2
# ->
# 5
# 3
# ->
# 6
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 2
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 1
# ->
# 6
# edge_added:
# 2
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 2
# ->
# 6
# ______________________
# [(1, 6), (2, 5), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 1
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 6
# No outward edge
# ---------------------
# samesource
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [6]
# v:
# 3
# y:
# 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# u:
# 4
# x:
# 5
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [3]
# v:
# 3
# y:
# 3
# sametarget
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [6]
# v:
# 2
# y:
# 6
# edge_added:
# 4
# ->
# 6
# edge_added:
# 3
# ->
# 2
# _____removed Edges___
# 4
# ->
# 2
# 3
# ->
# 6
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 6
# x:
# 1
# No outward edge
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 3
# x:
# 1
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 3
# ->
# 2
# edge_added:
# 1
# ->
# 5
# _____removed Edges___
# 3
# ->
# 5
# 1
# ->
# 2
# ______________________
# [(1, 5), (2, 5), (3, 2), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 3
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2]
# v:
# 3
# y:
# 2
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [3]
# v:
# 5
# y:
# 3
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [3, 6]
# v:
# 3
# y:
# 6
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [2]
# v:
# 5
# y:
# 2
# edge_added:
# 1
# ->
# 2
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 1
# ->
# 5
# 3
# ->
# 2
# ______________________
# [(1, 2), (2, 5), (3, 5), (4, 3), (4, 6), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# ---------------------
# u:
# 4
# x:
# 3
# Outgoing edges u:
# [3, 6]
# Outgoing edges x:
# [5]
# v:
# 6
# y:
# 5
# edge_added:
# 4
# ->
# 5
# edge_added:
# 3
# ->
# 6
# _____removed Edges___
# 4
# ->
# 6
# 3
# ->
# 5
# ______________________
# [(1, 2), (2, 5), (3, 6), (4, 3), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 3
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# ---------------------
# samesource
# ---------------------
# u:
# 1
# x:
# 4
# Outgoing edges u:
# [2]
# Outgoing edges x:
# [3, 5]
# v:
# 2
# y:
# 5
# edge_added:
# 1
# ->
# 5
# edge_added:
# 4
# ->
# 2
# _____removed Edges___
# 1
# ->
# 2
# 4
# ->
# 5
# ______________________
# [(1, 5), (2, 5), (3, 6), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 3
# Outgoing edges u:
# [5]
# Outgoing edges x:
# [6]
# v:
# 5
# y:
# 6
# edge_added:
# 2
# ->
# 6
# edge_added:
# 3
# ->
# 5
# _____removed Edges___
# 2
# ->
# 5
# 3
# ->
# 6
# ______________________
# [(1, 5), (2, 6), (3, 5), (4, 3), (4, 2), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 6
# x:
# 4
# No outward edge
# ---------------------
# u:
# 4
# x:
# 1
# Outgoing edges u:
# [3, 2]
# Outgoing edges x:
# [5]
# v:
# 3
# y:
# 5
# edge_added:
# 4
# ->
# 5
# edge_added:
# 1
# ->
# 3
# _____removed Edges___
# 4
# ->
# 3
# 1
# ->
# 5
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6
# ---------------------
# u:
# 5
# x:
# 4
# Outgoing edges u:
# [3]
# Outgoing edges x:
# [2, 5]
# v:
# 3
# y:
# 5
# ---------------------
# samesource
# ---------------------
# samesource
# ---------------------
# u:
# 6
# x:
# 5
# No outward edge
# ---------------------
# u:
# 2
# x:
# 5
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 2
# ->
# 3
# edge_added:
# 5
# ->
# 6
# _____removed Edges___
# 2
# ->
# 6
# 5
# ->
# 3
# ______________________
# [(1, 3), (2, 3), (3, 5), (4, 2), (4, 5), (5, 6)]
# Number of edges: 6
# ---------------------
# u:
# 2
# x:
# 6
# No outward edge
# ---------------------
# u:
# 5
# x:
# 2
# Outgoing edges u:
# [6]
# Outgoing edges x:
# [3]
# v:
# 6
# y:
# 3
# edge_added:
# 5
# ->
# 3
# edge_added:
# 2
# ->
# 6
# _____removed Edges___
# 5
# ->
# 6
# 2
# ->
# 3
# ______________________
# [(1, 3), (2, 6), (3, 5), (4, 2), (4, 5), (5, 3)]
# Number of edges: 6

# %%
H_1.edges()
# Out:
# OutEdgeView([(1, 3), (2, 6), (3, 5), (4, 2), (4, 5), (5, 3)])

# %%
G.degree()
# Out:
# DiDegreeView({1: 1, 2: 2, 3: 3, 4: 2, 5: 3, 6: 1})

# %%
H_1.degree()
# Out:
# DiDegreeView({1: 1, 2: 2, 3: 3, 4: 2, 5: 3, 6: 1})

# %%
G.in_degree()
# Out:
# InDegreeView({1: 0, 2: 1, 3: 2, 4: 0, 5: 2, 6: 1})

# %%
G.out_degree()
# Out:
# OutDegreeView({1: 1, 2: 1, 3: 1, 4: 2, 5: 1, 6: 0})

# %%
H_1.in_degree()
# Out:
# InDegreeView({1: 0, 2: 1, 3: 2, 4: 0, 5: 2, 6: 1})

# %%
H_1.out_degree()
# Out:
# OutDegreeView({1: 1, 2: 1, 3: 1, 4: 2, 5: 1, 6: 0})

# %%
https://python.hotexamples.com/examples/networkx/-/double_edge_swap/python-double_edge_swap-function-examples.html#:~:text=H%20%3D%20G.copy()%0A%20%20%20%20nx.double_edge_swap(H%2C%20nswap%3DQ*len(%20G.edges()%20)%2C%20max_tries%3D1e75)

# %%
G_undirected = nx.Graph() 
G_undirected.add_edge(1, 2)
G_undirected.add_edge(2, 3)
G_undirected.add_edge(4, 3)
G_undirected.add_edge(3, 5)
G_undirected.add_edge(4, 5)
G_undirected.add_edge(5, 6)

H = G_undirected.copy()
    
nx.double_edge_swap(H, nswap=100*len( G_undirected.edges() ), max_tries=1e75)
