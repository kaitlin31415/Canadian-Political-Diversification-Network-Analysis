# %%
import pandas as pd

# %%
nodes_df = pd.read_csv("Network_export_nodes_betweenness_undirected_with_communities_and_degs.csv")

# %%
nodes_df.head()
# Out:
#                     Id  Label  timeset      twittername first name  \
# 0             83508245    NaN      NaN          dckurek     Damien
# 1           4568748862    NaN      NaN   ziad_aboultaif       Ziad
# 2             44070432    NaN      NaN   LailaGoodridge      Laila
# 3  1425866189780160514    NaN      NaN       POhara2021    Patrick
# 4  1420552213253038080    NaN      NaN  NathalieSincla3   Nathalie
#
#            last name political affiliation  betweenness_centrality  \
# 0              Kurek          Conservative           127428.131518
# 1          Aboultaif          Conservative            40337.761048
# 2          Goodridge          Conservative            62169.550313
# 3             O'Hara        Bloc Québécois            33266.819168
# 4  Sinclair-Desgagné        Bloc Québécois           107366.831360
#
#    communityid  out_degree_centrality
# 0          3.0               0.000000
# 1          3.0               0.000000
# 2          3.0               0.000000
# 3          4.0               0.000447
# 4          4.0               0.000000

# %%
edges_df = pd.read_csv("../../Network_export_edges.csv")

# %%
edges_df = edges_df[["Source","Target","Weight"]]

# %%
edges_df.head()
# Out:
#                 Source     Target  Weight
# 0  1385933370090209280  158095776       1
# 1  1416535505454338050  158095776       8
# 2            544695802  158095776       1
# 3   716257068538327040  158095776       1
# 4            258170457  158095776       1

# %% [markdown]
# Join the sources with the id to get the source id betweenness centrality

# %%
source_info = pd.merge(
    nodes_df,
    edges_df,
    how="inner",
    on=None,
    left_on="Id",
    right_on="Source",
    left_index=False,
    right_index=False,
    sort=True,
    suffixes=("_x", "_y"),
    copy=True,
    indicator=False,
    validate=None,
)

# %%
source_info.head()
# Out:
#        Id  Label  timeset twittername first name last name  \
# 0     246    NaN      NaN         NaN        NaN       NaN
# 1   42203    NaN      NaN         NaN        NaN       NaN
# 2  369093    NaN      NaN         NaN        NaN       NaN
# 3  851681    NaN      NaN         NaN        NaN       NaN
# 4  863841    NaN      NaN         NaN        NaN       NaN
#
#   political affiliation  betweenness_centrality  communityid  \
# 0                   NaN                     0.0          2.0
# 1                   NaN                     0.0          2.0
# 2                   NaN                     0.0          5.0
# 3                   NaN                     0.0          2.0
# 4                   NaN                     0.0          1.0
#
#    out_degree_centrality  Source     Target  Weight
# 0               0.000112     246   47452040       1
# 1               0.000112   42203   14079041       1
# 2               0.000112  369093  211564038       1
# 3               0.000112  851681   17823761       1
# 4               0.000112  863841   25127782       1

# %%
full_info = source_info = pd.merge(
    nodes_df,
    source_info,
    how="inner",
    on=None,
    left_on="Id",
    right_on="Target",
    left_index=False,
    right_index=False,
    sort=True,
    suffixes=("_Target", "_Source"),
    copy=True,
    indicator=False,
    validate=None,
)

# %%
full_info.head()
# Out:
#    Id_Target  Label_Target  timeset_Target twittername_Target  \
# 0    3358671           NaN             NaN          KenHardie
# 1    3358671           NaN             NaN          KenHardie
# 2    3358671           NaN             NaN          KenHardie
# 3    3358671           NaN             NaN          KenHardie
# 4    3358671           NaN             NaN          KenHardie
#
#   first name_Target last name_Target political affiliation_Target  \
# 0               Ken           Hardie                      Liberal
# 1               Ken           Hardie                      Liberal
# 2               Ken           Hardie                      Liberal
# 3               Ken           Hardie                      Liberal
# 4               Ken           Hardie                      Liberal
#
#    betweenness_centrality_Target  communityid_Target  \
# 0                   37051.950849                 1.0
# 1                   37051.950849                 1.0
# 2                   37051.950849                 1.0
# 3                   37051.950849                 1.0
# 4                   37051.950849                 1.0
#
#    out_degree_centrality_Target  ...  twittername_Source  first name_Source  \
# 0                           0.0  ...                 NaN                NaN
# 1                           0.0  ...                 NaN                NaN
# 2                           0.0  ...                 NaN                NaN
# 3                           0.0  ...                 NaN                NaN
# 4                           0.0  ...                 NaN                NaN
#
#    last name_Source political affiliation_Source  \
# 0               NaN                          NaN
# 1               NaN                          NaN
# 2               NaN                          NaN
# 3               NaN                          NaN
# 4               NaN                          NaN
#
#   betweenness_centrality_Source communityid_Source  \
# 0                  3.097217e+06                1.0
# 1                  0.000000e+00                1.0
# 2                  0.000000e+00                1.0
# 3                  3.070061e+03                1.0
# 4                  5.736894e+02                1.0
#
#   out_degree_centrality_Source     Source   Target  Weight
# 0                     0.011728   16272844  3358671       7
# 1                     0.000112   37609340  3358671       1
# 2                     0.000112   79251430  3358671       1
# 3                     0.000447  272626019  3358671       1
# 4                     0.000335  291362474  3358671       1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Edges Between Communities

# %% [markdown]
# Select communities where communityid_Target, and communityid_Source

# %%
edges_between_communities = full_info[full_info['communityid_Target'] != full_info['communityid_Source']]

# %%
edges_between_communities[['Id_Target','Id_Source', 'communityid_Target', 'communityid_Source', 'betweenness_centrality_Source', 'betweenness_centrality_Target']]
# Out:
#                  Id_Target            Id_Source  communityid_Target  \
# 62                14079041             51184630                 2.0
# 88                14079041            122130825                 2.0
# 152               14079041            514482028                 2.0
# 163               14079041            609432652                 2.0
# 208               14079041           2434162616                 2.0
# ...                    ...                  ...                 ...
# 13658  1337408652416864259           3586975572                 3.0
# 13660  1342125115383939073             16213179                 4.0
# 13779  1381435843492085760             15677734                 1.0
# 13903  1382491059247255554           2548489298                 3.0
# 13937  1382491059247255554  1446352422272528385                 3.0
#
#        communityid_Source  betweenness_centrality_Source  \
# 62                   13.0                   3.285554e+03
# 88                    1.0                   7.547094e+04
# 152                   1.0                   9.425050e+04
# 163                   1.0                   7.710107e+05
# 208                   1.0                   1.198769e+06
# ...                   ...                            ...
# 13658                 2.0                   4.754587e+03
# 13660                 1.0                   2.325127e+05
# 13779                 2.0                   3.890402e+05
# 13903                 2.0                   1.205265e+05
# 13937                 1.0                   3.781095e+06
#
#        betweenness_centrality_Target
# 62                      3.091533e+06
# 88                      3.091533e+06
# 152                     3.091533e+06
# 163                     3.091533e+06
# 208                     3.091533e+06
# ...                              ...
# 13658                   1.081790e+03
# 13660                   4.702230e+05
# 13779                   4.676709e+05
# 13903                   4.223475e+05
# 13937                   4.223475e+05
#
# [495 rows x 6 columns]
